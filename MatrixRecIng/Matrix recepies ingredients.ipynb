# %%
import numpy as np
import pandas as pd

# %%
ingredients = pd.read_csv('Source1Ingredients.csv')
ingredients2 = pd.read_csv('Source2Ingredients.csv')

# %%
from tqdm import tqdm
from stop_words import get_stop_words
stop_words = get_stop_words('en')


def isIngredient(word):
    if len(word) < 2:
        return False
    
    if isNumberInside(word):
        return False
    
    if isPreposition(word):
        return False
    
    if isNoisy(word):
        return False
    
    if isArticle(word):
        return False
    
    if isAction(word):
        return False

    if hasStrange(word):
        return False
    
    
    return True
    
    
def hasStrange(string):
    symbols = ['<', '/', '>', '&', ':', ';', '"']
    for s in symbols:
        if s in string:
            return True
    
    return False
def isAction(string):
    if string[-2:] == 'ed' or string[-2:] == 'ly' or string[-3:] == 'ing':
        return True
    return False
    
def isNumberInside (string):
    for caracter in string:
        if caracter.isnumeric():
            return True
    return False

def isPreposition (string):
    prepositions = ["aboard",'choose', 'almost',"about","above","across","after","against","along","amid","among","anti","around","as","at","before","behind","below","beneath","beside","besides","between","beyond","but","by","concerning","considering","despite","down","during","except","excepting","excluding","following","for","from","in","inside","into","like","minus","near","of","off","on","onto","opposite","outside","over","past","per","plus","regarding","round","save","since","than","through","to","toward","towards","under","underneath","unlike","until","up","upon","versus","via","with","within","without"]
    if string in prepositions:
        return True
    return False

def isNoisy (string):
    noisy = ['whole','baby', 'small','pound','finely','white','freshly','chopped', 'ounce', 'cup', 'ground', 'fresh', 'teaspoon', 'large', 'sliced', 'black', '<strong>for', "cup","tablespoon", "teaspoon", "tablespoon", "ml","if","tbsp","tbsb","tb","tbp","and","tsp","level","extra","cut","or","you","leave","plain","selection","medium","clear","few","price","yellow","new","half", "while", "when","very", "use", "two","three"]
    if string in noisy or string in stop_words:
        return True
    return False

def isArticle (string):
    articles = ["the","a","one","some","few"]
    if string in articles:
        return True
    return False
    
corpus = []
for ing in tqdm(ingredients['ingredient']):
    for word in ing.split():
        _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
        if _aux[-1] == 's':
            _aux = _aux[:-1]
        if isIngredient(_aux):
            corpus.append(_aux)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 22760/22760 [00:00<00:00, 27714.86it/s]

# %% [raw]
# for ing in tqdm(ingredients2['ingredient']):
#     try:
#         for word in ing.split():
#             _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
#             if _aux[-1] == 's':
#                 _aux = _aux[:-1]
#             if isIngredient(_aux):
#                 corpus.append(_aux)
#     except:
#         pass
#         #print (ing)

# %%
print ("Total words in corpus: ", len(corpus))
# Out:
# Total words in corpus:  52349

# %%
set_corpus = set(corpus)

# %%
dict_corpus = dict.fromkeys(set_corpus, 0)
for elem in corpus:
    dict_corpus[elem] += 1

# %%
import operator
sorted_x = sorted(dict_corpus.items(), key=operator.itemgetter(1), reverse= True)

# %%
list_ingr = []
list_num = []
for ingr, num in sorted_x:
    list_ingr.append(ingr)
    list_num.append(num)

# %%
d = {'Ingredient': list_ingr, 'numTimes': list_num}
df = pd.DataFrame(data=d)
df_reduced = df[df['numTimes'] >10]

# %%
len(set_corpus)
# Out:
# 1811

# %%
recepies_dict = {}
for _id, _ing in tqdm(zip(ingredients['id'], ingredients['ingredient'])):
    if not _id in recepies_dict:
        recepies_dict[_id] = []
    for word in _ing.split():
        _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
        if _aux[-1] == 's':
            _aux = _aux[:-1]
        if _aux in set_corpus:
            recepies_dict[_id].append(_aux)
    
#recepies_dict
# Out:
# 22760it [00:00, 107073.76it/s]

# %% [raw]
# for _id, _ing in tqdm(zip(ingredients2['id'], ingredients2['ingredient'])):
#     try:
#         if not _id in recepies_dict:
#             recepies_dict[_id] = []
#         for word in _ing.split():
#             _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
#             if _aux[-1] == 's':
#                 _aux = _aux[:-1]
#             if _aux in set_copus:
#                 recepies_dict[_id].append(_aux)
#     except:
#         pass

# %%
ids = list(set(ingredients['id']))# + list(set(ingredients2['id']))

# %%
matrix = pd.DataFrame(np.full((len(ids), len(set_corpus)), False, dtype=bool), index=ids, columns=set_corpus)

# %%
for key in tqdm(recepies_dict):
    for ingr in recepies_dict[key]:
        matrix[ingr][key] = True
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2467/2467 [00:04<00:00, 521.87it/s]

# %%
matrix
# Out:
#                                               chiller  beefsteak  serrano  \
# crispy-sesame-pork                              False      False    False
# baked-mexican-eggs                              False      False    False
# pasta-with-broad-beans-cheese                   False      False    False
# cheats-lasagne                                  False      False    False
# chilli-prawn-skewers                            False      False    False
# nectarine-tiramisu                              False      False    False
# prawn-linguine                                  False      False    False
# tombstone-biscuits                              False      False    False
# victoria-sponge-cake                            False      False    False
# jerk-grilled-sea-bream                          False      False    False
# lobster-tails-with-avocado-salad                False      False    False
# pickled-strawberries-recipe                     False      False    False
# cheese-quesadillas                              False      False    False
# tilly-ramsays-chicken-skewers                   False      False    False
# thai-cod-curry-with-cauliflower-rice            False      False    False
# creme-caramel                                   False      False    False
# pulled-mushroom-dogs                            False      False    False
# broad-bean-rocket-on-butter-bean-pate           False      False    False
# peperoni-rossi-arrostiti-roasted-red-peppers    False      False    False
# classic-paella                                  False      False    False
# chocolate-beetroot-cake                         False      False    False
# gooey-christmas-pudding-cookies                 False      False    False
# tenderstem-muffins                              False      False    False
# beef-squash-sweet-potato-tagine                 False      False    False
# halloumi-skewers                                False      False    False
# south-african-bobotie                           False      False    False
# crispy-lobster-cocktail                         False      False    False
# picnic-sausage-rolls                            False      False    False
# pork-belly-with-rhubarb-puree                   False      False    False
# crispy-sweet-potato-and-pea-risotto             False      False    False
# ...                                               ...        ...      ...
# butternut-squash-pepper-chickpea-curry          False      False    False
# squash-spinach-goats-cheese-risotto             False      False    False
# frozen-lychee-yoghurt                           False      False    False
# cheese-spinach-lasagne                          False      False    False
# grilled-salmon-with-salsa-verde                 False      False    False
# banoffee-mountain                               False      False    False
# roasted-vegetable-halloumi-pittas               False      False    False
# giant-chocolate-swirl-meringues                 False      False    False
# caribbean-curry-patties-and-zingy-salsa         False      False    False
# chinese-salad                                   False      False    False
# orange-semolina-cake                            False      False    False
# tomato-chilli-chutney                           False      False    False
# paprika-pulled-pork                             False      False    False
# mediterranean-open-lasagne                      False      False    False
# easiest-ever-ice-cream                          False      False    False
# blackberry-almond-cake                          False      False    False
# mince-pie-cheesecake                            False      False    False
# potato-chicken-pad-thai                         False      False    False
# baked-fish-with-pepper-topping                  False      False    False
# chunky-chilli                                   False      False    False
# duck-breast-with-orange-sauce                   False      False    False
# baked-fish-and-chips-with-mushy-peas            False      False    False
# fresh-chocolate-dipping-sauce                   False      False    False
# bolognese-rigatoni-pie                          False      False    False
# melt-in-the-middle-beefburger                   False      False    False
# beetroot-feta-flan                              False      False    False
# christmas-pudding-ice-cream                     False      False    False
# warm-prawn-kale-noodle-salad                    False      False    False
# chocolate-beetroot-brownies                     False      False    False
# turkey-meatballs-with-spaghetti                 False      False    False
#
#                                               azera  stroganoff    lea  ancho  \
# crispy-sesame-pork                            False       False  False  False
# baked-mexican-eggs                            False       False  False  False
# pasta-with-broad-beans-cheese                 False       False  False  False
# cheats-lasagne                                False       False  False  False
# chilli-prawn-skewers                          False       False  False  False
# nectarine-tiramisu                            False       False  False  False
# prawn-linguine                                False       False  False  False
# tombstone-biscuits                            False       False  False  False
# victoria-sponge-cake                          False       False  False  False
# jerk-grilled-sea-bream                        False       False  False  False
# lobster-tails-with-avocado-salad              False       False  False  False
# pickled-strawberries-recipe                   False       False  False  False
# cheese-quesadillas                            False       False  False  False
# tilly-ramsays-chicken-skewers                 False       False  False  False
# thai-cod-curry-with-cauliflower-rice          False       False  False  False
# creme-caramel                                 False       False  False  False
# pulled-mushroom-dogs                          False       False  False  False
# broad-bean-rocket-on-butter-bean-pate         False       False  False  False
# peperoni-rossi-arrostiti-roasted-red-peppers  False       False  False  False
# classic-paella                                False       False  False  False
# chocolate-beetroot-cake                       False       False  False  False
# gooey-christmas-pudding-cookies               False       False  False  False
# tenderstem-muffins                            False       False  False  False
# beef-squash-sweet-potato-tagine               False       False  False  False
# halloumi-skewers                              False       False  False  False
# south-african-bobotie                         False       False  False  False
# crispy-lobster-cocktail                       False       False  False  False
# picnic-sausage-rolls                          False       False  False  False
# pork-belly-with-rhubarb-puree                 False       False  False  False
# crispy-sweet-potato-and-pea-risotto           False       False  False  False
# ...                                             ...         ...    ...    ...
# butternut-squash-pepper-chickpea-curry        False       False  False  False
# squash-spinach-goats-cheese-risotto           False       False  False  False
# frozen-lychee-yoghurt                         False       False  False  False
# cheese-spinach-lasagne                        False       False  False  False
# grilled-salmon-with-salsa-verde               False       False  False  False
# banoffee-mountain                             False       False  False  False
# roasted-vegetable-halloumi-pittas             False       False  False  False
# giant-chocolate-swirl-meringues               False       False  False  False
# caribbean-curry-patties-and-zingy-salsa       False       False  False  False
# chinese-salad                                 False       False  False  False
# orange-semolina-cake                          False       False  False  False
# tomato-chilli-chutney                         False       False  False  False
# paprika-pulled-pork                           False       False  False  False
# mediterranean-open-lasagne                    False       False  False  False
# easiest-ever-ice-cream                        False       False  False  False
# blackberry-almond-cake                        False       False  False  False
# mince-pie-cheesecake                          False       False  False  False
# potato-chicken-pad-thai                       False       False  False  False
# baked-fish-with-pepper-topping                False       False  False  False
# chunky-chilli                                 False       False  False  False
# duck-breast-with-orange-sauce                 False       False  False  False
# baked-fish-and-chips-with-mushy-peas          False       False  False  False
# fresh-chocolate-dipping-sauce                 False       False  False  False
# bolognese-rigatoni-pie                        False       False  False  False
# melt-in-the-middle-beefburger                 False       False  False  False
# beetroot-feta-flan                            False       False  False  False
# christmas-pudding-ice-cream                   False       False  False  False
# warm-prawn-kale-noodle-salad                  False       False  False  False
# chocolate-beetroot-brownies                   False       False  False  False
# turkey-meatballs-with-spaghetti               False       False  False  False
#
#                                               gressingham     ye  camembert  \
# crispy-sesame-pork                                  False  False      False
# baked-mexican-eggs                                  False  False      False
# pasta-with-broad-beans-cheese                       False  False      False
# cheats-lasagne                                      False  False      False
# chilli-prawn-skewers                                False  False      False
# nectarine-tiramisu                                  False  False      False
# prawn-linguine                                      False  False      False
# tombstone-biscuits                                  False  False      False
# victoria-sponge-cake                                False  False      False
# jerk-grilled-sea-bream                              False  False      False
# lobster-tails-with-avocado-salad                    False  False      False
# pickled-strawberries-recipe                         False  False      False
# cheese-quesadillas                                  False  False      False
# tilly-ramsays-chicken-skewers                       False  False      False
# thai-cod-curry-with-cauliflower-rice                False  False      False
# creme-caramel                                       False  False      False
# pulled-mushroom-dogs                                False  False      False
# broad-bean-rocket-on-butter-bean-pate               False  False      False
# peperoni-rossi-arrostiti-roasted-red-peppers        False  False      False
# classic-paella                                      False  False      False
# chocolate-beetroot-cake                             False  False      False
# gooey-christmas-pudding-cookies                     False  False      False
# tenderstem-muffins                                  False  False      False
# beef-squash-sweet-potato-tagine                     False  False      False
# halloumi-skewers                                    False  False      False
# south-african-bobotie                               False  False      False
# crispy-lobster-cocktail                             False  False      False
# picnic-sausage-rolls                                False  False      False
# pork-belly-with-rhubarb-puree                       False  False      False
# crispy-sweet-potato-and-pea-risotto                 False  False      False
# ...                                                   ...    ...        ...
# butternut-squash-pepper-chickpea-curry              False  False      False
# squash-spinach-goats-cheese-risotto                 False  False      False
# frozen-lychee-yoghurt                               False  False      False
# cheese-spinach-lasagne                              False  False      False
# grilled-salmon-with-salsa-verde                     False  False      False
# banoffee-mountain                                   False  False      False
# roasted-vegetable-halloumi-pittas                   False  False      False
# giant-chocolate-swirl-meringues                     False  False      False
# caribbean-curry-patties-and-zingy-salsa             False  False      False
# chinese-salad                                       False  False      False
# orange-semolina-cake                                False  False      False
# tomato-chilli-chutney                               False  False      False
# paprika-pulled-pork                                 False  False      False
# mediterranean-open-lasagne                          False  False      False
# easiest-ever-ice-cream                              False  False      False
# blackberry-almond-cake                              False  False      False
# mince-pie-cheesecake                                False  False      False
# potato-chicken-pad-thai                             False  False      False
# baked-fish-with-pepper-topping                      False  False      False
# chunky-chilli                                       False  False      False
# duck-breast-with-orange-sauce                       False  False      False
# baked-fish-and-chips-with-mushy-peas                False  False      False
# fresh-chocolate-dipping-sauce                       False  False      False
# bolognese-rigatoni-pie                              False  False      False
# melt-in-the-middle-beefburger                       False  False      False
# beetroot-feta-flan                                  False  False      False
# christmas-pudding-ice-cream                         False  False      False
# warm-prawn-kale-noodle-salad                        False  False      False
# chocolate-beetroot-brownies                         False  False      False
# turkey-meatballs-with-spaghetti                     False  False      False
#
#                                                ...      made  grapefruit  \
# crispy-sesame-pork                             ...     False       False
# baked-mexican-eggs                             ...     False       False
# pasta-with-broad-beans-cheese                  ...     False       False
# cheats-lasagne                                 ...     False       False
# chilli-prawn-skewers                           ...     False       False
# nectarine-tiramisu                             ...     False       False
# prawn-linguine                                 ...     False       False
# tombstone-biscuits                             ...     False       False
# victoria-sponge-cake                           ...     False       False
# jerk-grilled-sea-bream                         ...     False       False
# lobster-tails-with-avocado-salad               ...     False       False
# pickled-strawberries-recipe                    ...     False       False
# cheese-quesadillas                             ...     False       False
# tilly-ramsays-chicken-skewers                  ...     False       False
# thai-cod-curry-with-cauliflower-rice           ...     False       False
# creme-caramel                                  ...     False       False
# pulled-mushroom-dogs                           ...     False       False
# broad-bean-rocket-on-butter-bean-pate          ...     False       False
# peperoni-rossi-arrostiti-roasted-red-peppers   ...     False       False
# classic-paella                                 ...     False       False
# chocolate-beetroot-cake                        ...     False       False
# gooey-christmas-pudding-cookies                ...     False       False
# tenderstem-muffins                             ...     False       False
# beef-squash-sweet-potato-tagine                ...     False       False
# halloumi-skewers                               ...     False       False
# south-african-bobotie                          ...     False       False
# crispy-lobster-cocktail                        ...     False       False
# picnic-sausage-rolls                           ...     False       False
# pork-belly-with-rhubarb-puree                  ...     False       False
# crispy-sweet-potato-and-pea-risotto            ...     False       False
# ...                                            ...       ...         ...
# butternut-squash-pepper-chickpea-curry         ...     False       False
# squash-spinach-goats-cheese-risotto            ...     False       False
# frozen-lychee-yoghurt                          ...     False       False
# cheese-spinach-lasagne                         ...     False       False
# grilled-salmon-with-salsa-verde                ...     False       False
# banoffee-mountain                              ...     False       False
# roasted-vegetable-halloumi-pittas              ...     False       False
# giant-chocolate-swirl-meringues                ...     False       False
# caribbean-curry-patties-and-zingy-salsa        ...     False       False
# chinese-salad                                  ...     False       False
# orange-semolina-cake                           ...     False       False
# tomato-chilli-chutney                          ...     False       False
# paprika-pulled-pork                            ...     False       False
# mediterranean-open-lasagne                     ...     False       False
# easiest-ever-ice-cream                         ...     False       False
# blackberry-almond-cake                         ...     False       False
# mince-pie-cheesecake                           ...     False       False
# potato-chicken-pad-thai                        ...     False       False
# baked-fish-with-pepper-topping                 ...     False       False
# chunky-chilli                                  ...      True       False
# duck-breast-with-orange-sauce                  ...      True       False
# baked-fish-and-chips-with-mushy-peas           ...     False       False
# fresh-chocolate-dipping-sauce                  ...     False       False
# bolognese-rigatoni-pie                         ...     False       False
# melt-in-the-middle-beefburger                  ...     False       False
# beetroot-feta-flan                             ...     False       False
# christmas-pudding-ice-cream                    ...     False       False
# warm-prawn-kale-noodle-salad                   ...     False       False
# chocolate-beetroot-brownies                    ...     False       False
# turkey-meatballs-with-spaghetti                ...     False       False
#
#                                               toffee    nib  dominican  \
# crispy-sesame-pork                             False  False      False
# baked-mexican-eggs                             False  False      False
# pasta-with-broad-beans-cheese                  False  False      False
# cheats-lasagne                                 False  False      False
# chilli-prawn-skewers                           False  False      False
# nectarine-tiramisu                             False  False      False
# prawn-linguine                                 False  False      False
# tombstone-biscuits                             False  False      False
# victoria-sponge-cake                           False  False      False
# jerk-grilled-sea-bream                         False  False      False
# lobster-tails-with-avocado-salad               False  False      False
# pickled-strawberries-recipe                    False  False      False
# cheese-quesadillas                             False  False      False
# tilly-ramsays-chicken-skewers                  False  False      False
# thai-cod-curry-with-cauliflower-rice           False  False      False
# creme-caramel                                  False  False      False
# pulled-mushroom-dogs                           False  False      False
# broad-bean-rocket-on-butter-bean-pate          False  False      False
# peperoni-rossi-arrostiti-roasted-red-peppers   False  False      False
# classic-paella                                 False  False      False
# chocolate-beetroot-cake                        False  False      False
# gooey-christmas-pudding-cookies                False  False      False
# tenderstem-muffins                             False  False      False
# beef-squash-sweet-potato-tagine                False  False      False
# halloumi-skewers                               False  False      False
# south-african-bobotie                          False  False      False
# crispy-lobster-cocktail                        False  False      False
# picnic-sausage-rolls                           False  False      False
# pork-belly-with-rhubarb-puree                  False  False      False
# crispy-sweet-potato-and-pea-risotto            False  False      False
# ...                                              ...    ...        ...
# butternut-squash-pepper-chickpea-curry         False  False      False
# squash-spinach-goats-cheese-risotto            False  False      False
# frozen-lychee-yoghurt                          False  False      False
# cheese-spinach-lasagne                         False  False      False
# grilled-salmon-with-salsa-verde                False  False      False
# banoffee-mountain                              False  False      False
# roasted-vegetable-halloumi-pittas              False  False      False
# giant-chocolate-swirl-meringues                False  False      False
# caribbean-curry-patties-and-zingy-salsa        False  False      False
# chinese-salad                                  False  False      False
# orange-semolina-cake                           False  False      False
# tomato-chilli-chutney                          False  False      False
# paprika-pulled-pork                            False  False      False
# mediterranean-open-lasagne                     False  False      False
# easiest-ever-ice-cream                         False  False      False
# blackberry-almond-cake                         False  False      False
# mince-pie-cheesecake                           False  False      False
# potato-chicken-pad-thai                        False  False      False
# baked-fish-with-pepper-topping                 False  False      False
# chunky-chilli                                  False  False      False
# duck-breast-with-orange-sauce                  False  False      False
# baked-fish-and-chips-with-mushy-peas           False  False      False
# fresh-chocolate-dipping-sauce                  False  False      False
# bolognese-rigatoni-pie                         False  False      False
# melt-in-the-middle-beefburger                  False  False      False
# beetroot-feta-flan                             False  False      False
# christmas-pudding-ice-cream                    False  False      False
# warm-prawn-kale-noodle-salad                   False  False      False
# chocolate-beetroot-brownies                    False  False      False
# turkey-meatballs-with-spaghetti                False  False      False
#
#                                               snowman  brioche   core    taj  \
# crispy-sesame-pork                              False    False  False  False
# baked-mexican-eggs                              False    False  False  False
# pasta-with-broad-beans-cheese                   False    False  False  False
# cheats-lasagne                                  False    False  False  False
# chilli-prawn-skewers                            False    False  False  False
# nectarine-tiramisu                              False    False  False  False
# prawn-linguine                                  False    False  False  False
# tombstone-biscuits                              False    False  False  False
# victoria-sponge-cake                            False    False  False  False
# jerk-grilled-sea-bream                          False    False  False  False
# lobster-tails-with-avocado-salad                False    False  False  False
# pickled-strawberries-recipe                     False    False  False  False
# cheese-quesadillas                              False    False  False  False
# tilly-ramsays-chicken-skewers                   False    False  False  False
# thai-cod-curry-with-cauliflower-rice            False    False  False  False
# creme-caramel                                   False    False  False  False
# pulled-mushroom-dogs                            False    False  False  False
# broad-bean-rocket-on-butter-bean-pate           False    False  False  False
# peperoni-rossi-arrostiti-roasted-red-peppers    False    False  False  False
# classic-paella                                  False    False  False  False
# chocolate-beetroot-cake                         False    False  False  False
# gooey-christmas-pudding-cookies                 False    False  False  False
# tenderstem-muffins                              False    False  False  False
# beef-squash-sweet-potato-tagine                 False    False  False  False
# halloumi-skewers                                False    False  False  False
# south-african-bobotie                           False    False  False  False
# crispy-lobster-cocktail                         False    False  False  False
# picnic-sausage-rolls                            False    False  False  False
# pork-belly-with-rhubarb-puree                   False    False  False  False
# crispy-sweet-potato-and-pea-risotto             False    False  False  False
# ...                                               ...      ...    ...    ...
# butternut-squash-pepper-chickpea-curry          False    False  False  False
# squash-spinach-goats-cheese-risotto             False    False  False  False
# frozen-lychee-yoghurt                           False    False  False  False
# cheese-spinach-lasagne                          False    False  False  False
# grilled-salmon-with-salsa-verde                 False    False  False  False
# banoffee-mountain                               False    False  False  False
# roasted-vegetable-halloumi-pittas               False    False  False  False
# giant-chocolate-swirl-meringues                 False    False  False  False
# caribbean-curry-patties-and-zingy-salsa         False    False  False  False
# chinese-salad                                   False    False  False  False
# orange-semolina-cake                            False    False  False  False
# tomato-chilli-chutney                           False    False  False  False
# paprika-pulled-pork                             False    False  False  False
# mediterranean-open-lasagne                      False    False  False  False
# easiest-ever-ice-cream                          False    False  False  False
# blackberry-almond-cake                          False    False  False  False
# mince-pie-cheesecake                            False    False  False  False
# potato-chicken-pad-thai                         False    False  False  False
# baked-fish-with-pepper-topping                  False    False  False  False
# chunky-chilli                                   False    False  False  False
# duck-breast-with-orange-sauce                   False    False  False  False
# baked-fish-and-chips-with-mushy-peas            False    False  False  False
# fresh-chocolate-dipping-sauce                   False    False  False  False
# bolognese-rigatoni-pie                          False    False  False  False
# melt-in-the-middle-beefburger                   False     True  False  False
# beetroot-feta-flan                              False    False  False  False
# christmas-pudding-ice-cream                     False    False  False  False
# warm-prawn-kale-noodle-salad                    False    False  False  False
# chocolate-beetroot-brownies                     False    False  False  False
# turkey-meatballs-with-spaghetti                 False    False  False  False
#
#                                               wrapper
# crispy-sesame-pork                              False
# baked-mexican-eggs                              False
# pasta-with-broad-beans-cheese                   False
# cheats-lasagne                                  False
# chilli-prawn-skewers                            False
# nectarine-tiramisu                              False
# prawn-linguine                                  False
# tombstone-biscuits                              False
# victoria-sponge-cake                            False
# jerk-grilled-sea-bream                          False
# lobster-tails-with-avocado-salad                False
# pickled-strawberries-recipe                     False
# cheese-quesadillas                              False
# tilly-ramsays-chicken-skewers                   False
# thai-cod-curry-with-cauliflower-rice            False
# creme-caramel                                   False
# pulled-mushroom-dogs                            False
# broad-bean-rocket-on-butter-bean-pate           False
# peperoni-rossi-arrostiti-roasted-red-peppers    False
# classic-paella                                  False
# chocolate-beetroot-cake                         False
# gooey-christmas-pudding-cookies                 False
# tenderstem-muffins                              False
# beef-squash-sweet-potato-tagine                 False
# halloumi-skewers                                False
# south-african-bobotie                           False
# crispy-lobster-cocktail                         False
# picnic-sausage-rolls                            False
# pork-belly-with-rhubarb-puree                   False
# crispy-sweet-potato-and-pea-risotto             False
# ...                                               ...
# butternut-squash-pepper-chickpea-curry          False
# squash-spinach-goats-cheese-risotto             False
# frozen-lychee-yoghurt                           False
# cheese-spinach-lasagne                          False
# grilled-salmon-with-salsa-verde                 False
# banoffee-mountain                               False
# roasted-vegetable-halloumi-pittas               False
# giant-chocolate-swirl-meringues                 False
# caribbean-curry-patties-and-zingy-salsa         False
# chinese-salad                                   False
# orange-semolina-cake                            False
# tomato-chilli-chutney                           False
# paprika-pulled-pork                             False
# mediterranean-open-lasagne                      False
# easiest-ever-ice-cream                          False
# blackberry-almond-cake                          False
# mince-pie-cheesecake                            False
# potato-chicken-pad-thai                         False
# baked-fish-with-pepper-topping                  False
# chunky-chilli                                   False
# duck-breast-with-orange-sauce                   False
# baked-fish-and-chips-with-mushy-peas            False
# fresh-chocolate-dipping-sauce                   False
# bolognese-rigatoni-pie                          False
# melt-in-the-middle-beefburger                   False
# beetroot-feta-flan                              False
# christmas-pudding-ice-cream                     False
# warm-prawn-kale-noodle-salad                    False
# chocolate-beetroot-brownies                     False
# turkey-meatballs-with-spaghetti                 False
#
# [2467 rows x 1811 columns]
