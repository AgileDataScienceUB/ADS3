# %% [markdown]
# # Connected Recommenders

# %%
import pandas as pd
import pymongo

def _connect_mongo():
    """ Connects to Mongo """
    global conn
    try:
        #use your database name, user and password here:
        #mongodb://<dbuser>:<dbpassword>@<mlab_url>.mlab.com:57066/<database_name>
        with open("credentials.txt", 'r') as f:
            [name,password,url,dbname]=f.read().splitlines()
        conn=pymongo.MongoClient("mongodb://{}:{}@{}/{}".format(name,password,url,dbname))
        
        print ("Connected successfully to", dbname)

    except pymongo.errors.ConnectionFailure as e:
        print ("Could not connect to MongoDB: %s" % e) 
        
    print(conn)
    db=conn["agile_data_science_group_3"]
    
    return db


def read_collection_as_df(collection_name, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = _connect_mongo()
    
    collection = db[collection_name]
    
    # Make a query to the specific DB and Collection
    cursor = collection.find()

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor)) 
    
   # for col in df.columns.values:
    #    df[col] = df[col].values.astype(str)

    conn.close()
    
    return df

def read_collection_as_dict(collection_name):
    """ Read from Mongo and Store into dict """

    # Connect to MongoDB
    db = _connect_mongo()
    
    collection = db[collection_name]

    l=list()
    for d in collection.find():
        l.append(d)
      
    dic=dict()
    for d in l:
        for key, value in d.items():
            if key!='_id':
                dic[key] = value
    
    conn.close()
    
    return dic


def read_collection_objid_as_dict(collection_name):
    """ 
    Read from Mongo and Store into dict 
    Collection format: {'_id': ObjectId('5a29a690166d3310bc82f132'), 'recepie_id' : ObjectId ('....), 'ingridients':....}
    """

    # Connect to MongoDB
    db = _connect_mongo()
    
    collection = db[collection_name]

    dic = {d["recipe_id"]:d['ingredients'] for d in collection.find()}
      
    conn.close()
    
    return dic

# %% [markdown]
# ### Search Engine

# %%
import operator
def search_engine(recipes_input, recipes_dict=read_collection_objid_as_dict("RecIng")):
    """
    Given a list of ingredients from user and the "recipes: [ingredients]" dictionary, order the recipes by a score of suitability.
    It also provides those matching ingredients and missing ingredients for each recommendation. 
    
    Input: 
    - user_input as list. Example:["ingedient1", "ingredient2", ...]
    - recipes_dict as dictionary. Example: "{recipe1: [ingredients], recipe2: [ingredients] recipe3: [ingredients], ...}"
    
    *recipes_dict can be read from Mongo collection: recipes_dict = read_collection_objid_as_dict(recipes_ingredients)
    
    The output are: 
    - recomendations as list. Example: [recipe134, recipe43234, recipe544, ...]
    - missings as list of sets. Example: [{}, {ingredient43}, {ingredient32, ingredient45}, ...]
    """
    
    matching = dict()
    missing = dict()
    score = dict()
    
    user_ingredients = set(recipes_input)
    
    for recipe in recipes_dict.keys():
        
        recipe_ingredients = set(recipes_dict[recipe])   # ingredients of recipe
        
        matching[recipe] = user_ingredients.intersection(recipe_ingredients) # ingredients in user_input & in recipe  
        missing[recipe] = recipe_ingredients.difference(user_ingredients)  # ingredients of recipe that user_input doesnt have
        score[recipe] = float(len(matching[recipe]))/(len(missing[recipe])+1)
    
    recommendations_sorted = sorted(score.items(), key=operator.itemgetter(1), reverse=True)
    recommendations_sorted = [recipe_score[0] for recipe_score in recommendations_sorted]
    missing_sorted = [missing[rec] for rec in recommendations_sorted]
    
    return recommendations_sorted, missing_sorted
# Out:
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)

# %%
grocery = ["egg", "chicken"]

search_list, missings_ingredients = search_engine(grocery)

# %%
search_list
# Out:
# [ObjectId('59fb0d77eee3642f3c068478'),
#  ObjectId('59fb0d77eee3642f3c06881b'),
#  ObjectId('59fb0d77eee3642f3c0689cb'),
#  ObjectId('59fb0d77eee3642f3c0685e5'),
#  ObjectId('59fb0d77eee3642f3c06891d'),
#  ObjectId('59fb0d77eee3642f3c0688f0'),
#  ObjectId('59fb0d77eee3642f3c068b78'),
#  ObjectId('59fb0d77eee3642f3c068628'),
#  ObjectId('59fb0d77eee3642f3c06855c'),
#  ObjectId('59fb0d77eee3642f3c0685d8'),
#  ObjectId('59fb0d77eee3642f3c068a9e'),
#  ObjectId('59fb0d77eee3642f3c068745'),
#  ObjectId('59fb0d77eee3642f3c068c1a'),
#  ObjectId('59fb0d77eee3642f3c068d69'),
#  ObjectId('59fb0d77eee3642f3c068862'),
#  ObjectId('59fb0d77eee3642f3c068d9a'),
#  ObjectId('59fb0d77eee3642f3c0686b1'),
#  ObjectId('59fb0d77eee3642f3c068464'),
#  ObjectId('59fb0d77eee3642f3c0685d3'),
#  ObjectId('59fb0d77eee3642f3c068d99'),
#  ObjectId('59fb0d77eee3642f3c068470'),
#  ObjectId('59fb0d77eee3642f3c068586'),
#  ObjectId('59fb0d77eee3642f3c068cfd'),
#  ObjectId('59fb0d77eee3642f3c06891c'),
#  ObjectId('59fb0d77eee3642f3c068865'),
#  ObjectId('59fb0d77eee3642f3c06877f'),
#  ObjectId('59fb0d77eee3642f3c06885d'),
#  ObjectId('59fb0d77eee3642f3c068a2f'),
#  ObjectId('59fb0d77eee3642f3c0684fb'),
#  ObjectId('59fb0d77eee3642f3c068a7d'),
#  ObjectId('59fb0d77eee3642f3c0687f3'),
#  ObjectId('59fb0d77eee3642f3c068932'),
#  ObjectId('59fb0d77eee3642f3c06865e'),
#  ObjectId('59fb0d77eee3642f3c0689db'),
#  ObjectId('59fb0d77eee3642f3c0685c7'),
#  ObjectId('59fb0d77eee3642f3c068ce4'),
#  ObjectId('59fb0d77eee3642f3c06857e'),
#  ObjectId('59fb0d77eee3642f3c0688da'),
#  ObjectId('59fb0d77eee3642f3c0688a0'),
#  ObjectId('59fb0d77eee3642f3c068434'),
#  ObjectId('59fb0d77eee3642f3c068bd4'),
#  ObjectId('59fb0d77eee3642f3c0686fa'),
#  ObjectId('59fb0d77eee3642f3c0685be'),
#  ObjectId('59fb0d77eee3642f3c0687f0'),
#  ObjectId('59fb0d77eee3642f3c068530'),
#  ObjectId('59fb0d77eee3642f3c0685a6'),
#  ObjectId('59fb0d77eee3642f3c0685b5'),
#  ObjectId('59fb0d77eee3642f3c068b5a'),
#  ObjectId('59fb0d77eee3642f3c0687d6'),
#  ObjectId('59fb0d77eee3642f3c068a4f'),
#  ObjectId('59fb0d77eee3642f3c06866e'),
#  ObjectId('59fb0d77eee3642f3c068948'),
#  ObjectId('59fb0d77eee3642f3c068cea'),
#  ObjectId('59fb0d77eee3642f3c068c2b'),
#  ObjectId('59fb0d77eee3642f3c068666'),
#  ObjectId('59fb0d77eee3642f3c068604'),
#  ObjectId('59fb0d77eee3642f3c0687bc'),
#  ObjectId('59fb0d77eee3642f3c0686b9'),
#  ObjectId('59fb0d77eee3642f3c068629'),
#  ObjectId('59fb0d77eee3642f3c068ab3'),
#  ObjectId('59fb0d77eee3642f3c0685c0'),
#  ObjectId('59fb0d77eee3642f3c06891e'),
#  ObjectId('59fb0d77eee3642f3c068475'),
#  ObjectId('59fb0d77eee3642f3c068d7b'),
#  ObjectId('59fb0d77eee3642f3c068779'),
#  ObjectId('59fb0d77eee3642f3c068474'),
#  ObjectId('59fb0d77eee3642f3c068809'),
#  ObjectId('59fb0d77eee3642f3c0685db'),
#  ObjectId('59fb0d77eee3642f3c06845d'),
#  ObjectId('59fb0d77eee3642f3c0685a0'),
#  ObjectId('59fb0d77eee3642f3c068677'),
#  ObjectId('59fb0d77eee3642f3c0685ce'),
#  ObjectId('59fb0d77eee3642f3c068b23'),
#  ObjectId('59fb0d77eee3642f3c068d84'),
#  ObjectId('59fb0d77eee3642f3c0684fd'),
#  ObjectId('59fb0d77eee3642f3c068cbc'),
#  ObjectId('59fb0d77eee3642f3c06865a'),
#  ObjectId('59fb0d77eee3642f3c068ac4'),
#  ObjectId('59fb0d77eee3642f3c06880d'),
#  ObjectId('59fb0d77eee3642f3c068bb6'),
#  ObjectId('59fb0d77eee3642f3c0685c5'),
#  ObjectId('59fb0d77eee3642f3c068b59'),
#  ObjectId('59fb0d77eee3642f3c068b73'),
#  ObjectId('59fb0d77eee3642f3c068cbb'),
#  ObjectId('59fb0d77eee3642f3c068782'),
#  ObjectId('59fb0d77eee3642f3c0685a5'),
#  ObjectId('59fb0d77eee3642f3c0685b1'),
#  ObjectId('59fb0d77eee3642f3c0685f2'),
#  ObjectId('59fb0d77eee3642f3c068d7d'),
#  ObjectId('59fb0d77eee3642f3c068427'),
#  ObjectId('59fb0d77eee3642f3c068ced'),
#  ObjectId('59fb0d77eee3642f3c068906'),
#  ObjectId('59fb0d77eee3642f3c0684ff'),
#  ObjectId('59fb0d77eee3642f3c068cdc'),
#  ObjectId('59fb0d77eee3642f3c068d7c'),
#  ObjectId('59fb0d77eee3642f3c0687ea'),
#  ObjectId('59fb0d77eee3642f3c068c64'),
#  ObjectId('59fb0d77eee3642f3c068b67'),
#  ObjectId('59fb0d77eee3642f3c068ae4'),
#  ObjectId('59fb0d77eee3642f3c0686cb'),
#  ObjectId('59fb0d77eee3642f3c0689a7'),
#  ObjectId('59fb0d77eee3642f3c068b5e'),
#  ObjectId('59fb0d77eee3642f3c06892d'),
#  ObjectId('59fb0d77eee3642f3c068bc5'),
#  ObjectId('59fb0d77eee3642f3c0689ad'),
#  ObjectId('59fb0d77eee3642f3c068b40'),
#  ObjectId('59fb0d77eee3642f3c068c8b'),
#  ObjectId('59fb0d77eee3642f3c06863c'),
#  ObjectId('59fb0d77eee3642f3c068839'),
#  ObjectId('59fb0d77eee3642f3c068940'),
#  ObjectId('59fb0d77eee3642f3c0686c1'),
#  ObjectId('59fb0d77eee3642f3c068ac9'),
#  ObjectId('59fb0d77eee3642f3c068670'),
#  ObjectId('59fb0d77eee3642f3c0688ac'),
#  ObjectId('59fb0d77eee3642f3c0685c8'),
#  ObjectId('59fb0d77eee3642f3c068957'),
#  ObjectId('59fb0d77eee3642f3c0686ee'),
#  ObjectId('59fb0d77eee3642f3c06883e'),
#  ObjectId('59fb0d77eee3642f3c0688a3'),
#  ObjectId('59fb0d77eee3642f3c06879f'),
#  ObjectId('59fb0d77eee3642f3c0685b8'),
#  ObjectId('59fb0d77eee3642f3c0685ea'),
#  ObjectId('59fb0d77eee3642f3c0686bd'),
#  ObjectId('59fb0d77eee3642f3c068460'),
#  ObjectId('59fb0d77eee3642f3c06841d'),
#  ObjectId('59fb0d77eee3642f3c068747'),
#  ObjectId('59fb0d77eee3642f3c0685cf'),
#  ObjectId('59fb0d77eee3642f3c068b91'),
#  ObjectId('59fb0d77eee3642f3c068a3a'),
#  ObjectId('59fb0d77eee3642f3c0684db'),
#  ObjectId('59fb0d77eee3642f3c06853f'),
#  ObjectId('59fb0d77eee3642f3c068a46'),
#  ObjectId('59fb0d77eee3642f3c0689b3'),
#  ObjectId('59fb0d77eee3642f3c068595'),
#  ObjectId('59fb0d77eee3642f3c068a09'),
#  ObjectId('59fb0d77eee3642f3c068600'),
#  ObjectId('59fb0d77eee3642f3c0684e8'),
#  ObjectId('59fb0d77eee3642f3c06846a'),
#  ObjectId('59fb0d77eee3642f3c0684eb'),
#  ObjectId('59fb0d77eee3642f3c068938'),
#  ObjectId('59fb0d77eee3642f3c0685b0'),
#  ObjectId('59fb0d77eee3642f3c0686ec'),
#  ObjectId('59fb0d77eee3642f3c06894f'),
#  ObjectId('59fb0d77eee3642f3c0688ec'),
#  ObjectId('59fb0d77eee3642f3c06885a'),
#  ObjectId('59fb0d77eee3642f3c068ab0'),
#  ObjectId('59fb0d77eee3642f3c068a7b'),
#  ObjectId('59fb0d77eee3642f3c068a51'),
#  ObjectId('59fb0d77eee3642f3c068a7c'),
#  ObjectId('59fb0d77eee3642f3c068c10'),
#  ObjectId('59fb0d77eee3642f3c068603'),
#  ObjectId('59fb0d77eee3642f3c0686e9'),
#  ObjectId('59fb0d77eee3642f3c068bcd'),
#  ObjectId('59fb0d77eee3642f3c068414'),
#  ObjectId('59fb0d77eee3642f3c068439'),
#  ObjectId('59fb0d77eee3642f3c0688df'),
#  ObjectId('59fb0d77eee3642f3c06851a'),
#  ObjectId('59fb0d77eee3642f3c06855e'),
#  ObjectId('59fb0d77eee3642f3c068888'),
#  ObjectId('59fb0d77eee3642f3c068655'),
#  ObjectId('59fb0d77eee3642f3c068d04'),
#  ObjectId('59fb0d77eee3642f3c06870d'),
#  ObjectId('59fb0d77eee3642f3c06858f'),
#  ObjectId('59fb0d77eee3642f3c068476'),
#  ObjectId('59fb0d77eee3642f3c068466'),
#  ObjectId('59fb0d77eee3642f3c06864e'),
#  ObjectId('59fb0d77eee3642f3c06870b'),
#  ObjectId('59fb0d77eee3642f3c068707'),
#  ObjectId('59fb0d77eee3642f3c068704'),
#  ObjectId('59fb0d77eee3642f3c0684b4'),
#  ObjectId('59fb0d77eee3642f3c068b62'),
#  ObjectId('59fb0d77eee3642f3c0684ec'),
#  ObjectId('59fb0d77eee3642f3c068ad8'),
#  ObjectId('59fb0d77eee3642f3c068715'),
#  ObjectId('59fb0d77eee3642f3c06894a'),
#  ObjectId('59fb0d77eee3642f3c0688aa'),
#  ObjectId('59fb0d77eee3642f3c0685b9'),
#  ObjectId('59fb0d77eee3642f3c0686ed'),
#  ObjectId('59fb0d77eee3642f3c0688e8'),
#  ObjectId('59fb0d77eee3642f3c068757'),
#  ObjectId('59fb0d77eee3642f3c068d7f'),
#  ObjectId('59fb0d77eee3642f3c0685bc'),
#  ObjectId('59fb0d77eee3642f3c068a77'),
#  ObjectId('59fb0d77eee3642f3c068898'),
#  ObjectId('59fb0d77eee3642f3c0689a4'),
#  ObjectId('59fb0d77eee3642f3c068c11'),
#  ObjectId('59fb0d77eee3642f3c0684e3'),
#  ObjectId('59fb0d77eee3642f3c068d2e'),
#  ObjectId('59fb0d77eee3642f3c068a2c'),
#  ObjectId('59fb0d77eee3642f3c068bc4'),
#  ObjectId('59fb0d77eee3642f3c068a3c'),
#  ObjectId('59fb0d77eee3642f3c068d36'),
#  ObjectId('59fb0d77eee3642f3c0684a6'),
#  ObjectId('59fb0d77eee3642f3c0688fe'),
#  ObjectId('59fb0d77eee3642f3c0686df'),
#  ObjectId('59fb0d77eee3642f3c0685bf'),
#  ObjectId('59fb0d77eee3642f3c06891b'),
#  ObjectId('59fb0d77eee3642f3c068893'),
#  ObjectId('59fb0d77eee3642f3c068436'),
#  ObjectId('59fb0d77eee3642f3c068c45'),
#  ObjectId('59fb0d77eee3642f3c068998'),
#  ObjectId('59fb0d77eee3642f3c0689a0'),
#  ObjectId('59fb0d77eee3642f3c0685ad'),
#  ObjectId('59fb0d77eee3642f3c068d80'),
#  ObjectId('59fb0d77eee3642f3c068a87'),
#  ObjectId('59fb0d77eee3642f3c0684dc'),
#  ObjectId('59fb0d77eee3642f3c068894'),
#  ObjectId('59fb0d77eee3642f3c068c91'),
#  ObjectId('59fb0d77eee3642f3c068d8a'),
#  ObjectId('59fb0d77eee3642f3c06841e'),
#  ObjectId('59fb0d77eee3642f3c068401'),
#  ObjectId('59fb0d77eee3642f3c068a22'),
#  ObjectId('59fb0d77eee3642f3c068975'),
#  ObjectId('59fb0d77eee3642f3c068d89'),
#  ObjectId('59fb0d77eee3642f3c0686db'),
#  ObjectId('59fb0d77eee3642f3c0685ca'),
#  ObjectId('59fb0d77eee3642f3c068706'),
#  ObjectId('59fb0d77eee3642f3c0685e1'),
#  ObjectId('59fb0d77eee3642f3c06854b'),
#  ObjectId('59fb0d77eee3642f3c06897c'),
#  ObjectId('59fb0d77eee3642f3c068d93'),
#  ObjectId('59fb0d77eee3642f3c0687b6'),
#  ObjectId('59fb0d77eee3642f3c06840b'),
#  ObjectId('59fb0d77eee3642f3c068d72'),
#  ObjectId('59fb0d77eee3642f3c068687'),
#  ObjectId('59fb0d77eee3642f3c0686aa'),
#  ObjectId('59fb0d77eee3642f3c068d6f'),
#  ObjectId('59fb0d77eee3642f3c0684d1'),
#  ObjectId('59fb0d77eee3642f3c0688eb'),
#  ObjectId('59fb0d77eee3642f3c0686d6'),
#  ObjectId('59fb0d77eee3642f3c06862d'),
#  ObjectId('59fb0d77eee3642f3c068534'),
#  ObjectId('59fb0d77eee3642f3c0685c6'),
#  ObjectId('59fb0d77eee3642f3c068d95'),
#  ObjectId('59fb0d77eee3642f3c068683'),
#  ObjectId('59fb0d77eee3642f3c0689af'),
#  ObjectId('59fb0d77eee3642f3c0688bb'),
#  ObjectId('59fb0d77eee3642f3c068766'),
#  ObjectId('59fb0d77eee3642f3c068b26'),
#  ObjectId('59fb0d77eee3642f3c06861e'),
#  ObjectId('59fb0d77eee3642f3c06894d'),
#  ObjectId('59fb0d77eee3642f3c0689cd'),
#  ObjectId('59fb0d77eee3642f3c068c6f'),
#  ObjectId('59fb0d77eee3642f3c068d2f'),
#  ObjectId('59fb0d77eee3642f3c068812'),
#  ObjectId('59fb0d77eee3642f3c0687df'),
#  ObjectId('59fb0d77eee3642f3c068567'),
#  ObjectId('59fb0d77eee3642f3c06874a'),
#  ObjectId('59fb0d77eee3642f3c0689b0'),
#  ObjectId('59fb0d77eee3642f3c068669'),
#  ObjectId('59fb0d77eee3642f3c068b32'),
#  ObjectId('59fb0d77eee3642f3c068b35'),
#  ObjectId('59fb0d77eee3642f3c068a12'),
#  ObjectId('59fb0d77eee3642f3c068811'),
#  ObjectId('59fb0d77eee3642f3c068411'),
#  ObjectId('59fb0d77eee3642f3c06897d'),
#  ObjectId('59fb0d77eee3642f3c068577'),
#  ObjectId('59fb0d77eee3642f3c0689b8'),
#  ObjectId('59fb0d77eee3642f3c068c73'),
#  ObjectId('59fb0d77eee3642f3c0684c0'),
#  ObjectId('59fb0d77eee3642f3c068be6'),
#  ObjectId('59fb0d77eee3642f3c068a10'),
#  ObjectId('59fb0d77eee3642f3c068c94'),
#  ObjectId('59fb0d77eee3642f3c068b3a'),
#  ObjectId('59fb0d77eee3642f3c068805'),
#  ObjectId('59fb0d77eee3642f3c06879e'),
#  ObjectId('59fb0d77eee3642f3c06886b'),
#  ObjectId('59fb0d77eee3642f3c06864a'),
#  ObjectId('59fb0d77eee3642f3c0689b1'),
#  ObjectId('59fb0d77eee3642f3c0684cc'),
#  ObjectId('59fb0d77eee3642f3c0684c9'),
#  ObjectId('59fb0d77eee3642f3c068a08'),
#  ObjectId('59fb0d77eee3642f3c068422'),
#  ObjectId('59fb0d77eee3642f3c0687dc'),
#  ObjectId('59fb0d77eee3642f3c068c13'),
#  ObjectId('59fb0d77eee3642f3c068a1b'),
#  ObjectId('59fb0d77eee3642f3c0686c9'),
#  ObjectId('59fb0d77eee3642f3c068840'),
#  ObjectId('59fb0d77eee3642f3c068884'),
#  ObjectId('59fb0d77eee3642f3c0685df'),
#  ObjectId('59fb0d77eee3642f3c0686d2'),
#  ObjectId('59fb0d77eee3642f3c068d85'),
#  ObjectId('59fb0d77eee3642f3c06863f'),
#  ObjectId('59fb0d77eee3642f3c068576'),
#  ObjectId('59fb0d77eee3642f3c068ae7'),
#  ObjectId('59fb0d77eee3642f3c068a14'),
#  ObjectId('59fb0d77eee3642f3c068632'),
#  ObjectId('59fb0d77eee3642f3c068887'),
#  ObjectId('59fb0d77eee3642f3c068ae2'),
#  ObjectId('59fb0d77eee3642f3c068c65'),
#  ObjectId('59fb0d77eee3642f3c068ad1'),
#  ObjectId('59fb0d77eee3642f3c0685d7'),
#  ObjectId('59fb0d77eee3642f3c0686bc'),
#  ObjectId('59fb0d77eee3642f3c06865d'),
#  ObjectId('59fb0d77eee3642f3c0685e6'),
#  ObjectId('59fb0d77eee3642f3c068b69'),
#  ObjectId('59fb0d77eee3642f3c068a2e'),
#  ObjectId('59fb0d77eee3642f3c0685d2'),
#  ObjectId('59fb0d77eee3642f3c06846e'),
#  ObjectId('59fb0d77eee3642f3c068794'),
#  ObjectId('59fb0d77eee3642f3c068636'),
#  ObjectId('59fb0d77eee3642f3c068741'),
#  ObjectId('59fb0d77eee3642f3c068ac6'),
#  ObjectId('59fb0d77eee3642f3c0686e3'),
#  ObjectId('59fb0d77eee3642f3c06898c'),
#  ObjectId('59fb0d77eee3642f3c068aef'),
#  ObjectId('59fb0d77eee3642f3c068a0c'),
#  ObjectId('59fb0d77eee3642f3c068c3a'),
#  ObjectId('59fb0d77eee3642f3c0684be'),
#  ObjectId('59fb0d77eee3642f3c06862c'),
#  ObjectId('59fb0d77eee3642f3c06840d'),
#  ObjectId('59fb0d77eee3642f3c068973'),
#  ObjectId('59fb0d77eee3642f3c068c02'),
#  ObjectId('59fb0d77eee3642f3c068605'),
#  ObjectId('59fb0d77eee3642f3c068bf6'),
#  ObjectId('59fb0d77eee3642f3c068c1f'),
#  ObjectId('59fb0d77eee3642f3c068a35'),
#  ObjectId('59fb0d77eee3642f3c068653'),
#  ObjectId('59fb0d77eee3642f3c068c50'),
#  ObjectId('59fb0d77eee3642f3c068510'),
#  ObjectId('59fb0d77eee3642f3c068bdc'),
#  ObjectId('59fb0d77eee3642f3c068780'),
#  ObjectId('59fb0d77eee3642f3c06859b'),
#  ObjectId('59fb0d77eee3642f3c068490'),
#  ObjectId('59fb0d77eee3642f3c06876e'),
#  ObjectId('59fb0d77eee3642f3c068994'),
#  ObjectId('59fb0d77eee3642f3c068900'),
#  ObjectId('59fb0d77eee3642f3c068688'),
#  ObjectId('59fb0d77eee3642f3c068a01'),
#  ObjectId('59fb0d77eee3642f3c068820'),
#  ObjectId('59fb0d77eee3642f3c068a00'),
#  ObjectId('59fb0d77eee3642f3c0688f6'),
#  ObjectId('59fb0d77eee3642f3c06864f'),
#  ObjectId('59fb0d77eee3642f3c068618'),
#  ObjectId('59fb0d77eee3642f3c068897'),
#  ObjectId('59fb0d77eee3642f3c068cae'),
#  ObjectId('59fb0d77eee3642f3c0687ed'),
#  ObjectId('59fb0d77eee3642f3c068a8a'),
#  ObjectId('59fb0d77eee3642f3c06847b'),
#  ObjectId('59fb0d77eee3642f3c068c04'),
#  ObjectId('59fb0d77eee3642f3c0689c2'),
#  ObjectId('59fb0d77eee3642f3c0684ef'),
#  ObjectId('59fb0d77eee3642f3c068aa2'),
#  ObjectId('59fb0d77eee3642f3c068488'),
#  ObjectId('59fb0d77eee3642f3c068af1'),
#  ObjectId('59fb0d77eee3642f3c068909'),
#  ObjectId('59fb0d77eee3642f3c068ce5'),
#  ObjectId('59fb0d77eee3642f3c068cff'),
#  ObjectId('59fb0d77eee3642f3c068834'),
#  ObjectId('59fb0d77eee3642f3c0688fc'),
#  ObjectId('59fb0d77eee3642f3c0689fa'),
#  ObjectId('59fb0d77eee3642f3c06877d'),
#  ObjectId('59fb0d77eee3642f3c068611'),
#  ObjectId('59fb0d77eee3642f3c0687e9'),
#  ObjectId('59fb0d77eee3642f3c068635'),
#  ObjectId('59fb0d77eee3642f3c068ce9'),
#  ObjectId('59fb0d77eee3642f3c0686a9'),
#  ObjectId('59fb0d77eee3642f3c068679'),
#  ObjectId('59fb0d77eee3642f3c0686ca'),
#  ObjectId('59fb0d77eee3642f3c0684dd'),
#  ObjectId('59fb0d77eee3642f3c06859a'),
#  ObjectId('59fb0d77eee3642f3c0683ff'),
#  ObjectId('59fb0d77eee3642f3c0688e7'),
#  ObjectId('59fb0d77eee3642f3c068445'),
#  ObjectId('59fb0d77eee3642f3c068d02'),
#  ObjectId('59fb0d77eee3642f3c06864b'),
#  ObjectId('59fb0d77eee3642f3c068992'),
#  ObjectId('59fb0d77eee3642f3c068438'),
#  ObjectId('59fb0d77eee3642f3c0689b6'),
#  ObjectId('59fb0d77eee3642f3c06845f'),
#  ObjectId('59fb0d77eee3642f3c06847a'),
#  ObjectId('59fb0d77eee3642f3c068848'),
#  ObjectId('59fb0d77eee3642f3c0686ac'),
#  ObjectId('59fb0d77eee3642f3c06840f'),
#  ObjectId('59fb0d77eee3642f3c068cd8'),
#  ObjectId('59fb0d77eee3642f3c068c06'),
#  ObjectId('59fb0d77eee3642f3c0685cb'),
#  ObjectId('59fb0d77eee3642f3c06899e'),
#  ObjectId('59fb0d77eee3642f3c0687c4'),
#  ObjectId('59fb0d77eee3642f3c068b46'),
#  ObjectId('59fb0d77eee3642f3c068c4e'),
#  ObjectId('59fb0d77eee3642f3c0688cb'),
#  ObjectId('59fb0d77eee3642f3c06870a'),
#  ObjectId('59fb0d77eee3642f3c06846d'),
#  ObjectId('59fb0d77eee3642f3c0684e7'),
#  ObjectId('59fb0d77eee3642f3c0686e1'),
#  ObjectId('59fb0d77eee3642f3c06861d'),
#  ObjectId('59fb0d77eee3642f3c068615'),
#  ObjectId('59fb0d77eee3642f3c068702'),
#  ObjectId('59fb0d77eee3642f3c068cfe'),
#  ObjectId('59fb0d77eee3642f3c06883f'),
#  ObjectId('59fb0d77eee3642f3c068790'),
#  ObjectId('59fb0d77eee3642f3c0686f1'),
#  ObjectId('59fb0d77eee3642f3c068a47'),
#  ObjectId('59fb0d77eee3642f3c068606'),
#  ObjectId('59fb0d77eee3642f3c0689fd'),
#  ObjectId('59fb0d77eee3642f3c0688f2'),
#  ObjectId('59fb0d77eee3642f3c068866'),
#  ObjectId('59fb0d77eee3642f3c0689c7'),
#  ObjectId('59fb0d77eee3642f3c068c7a'),
#  ObjectId('59fb0d77eee3642f3c0689ab'),
#  ObjectId('59fb0d77eee3642f3c06857c'),
#  ObjectId('59fb0d77eee3642f3c068bbb'),
#  ObjectId('59fb0d77eee3642f3c068953'),
#  ObjectId('59fb0d77eee3642f3c068b44'),
#  ObjectId('59fb0d77eee3642f3c068ab1'),
#  ObjectId('59fb0d77eee3642f3c068c60'),
#  ObjectId('59fb0d77eee3642f3c068571'),
#  ObjectId('59fb0d77eee3642f3c06844c'),
#  ObjectId('59fb0d77eee3642f3c06858e'),
#  ObjectId('59fb0d77eee3642f3c068842'),
#  ObjectId('59fb0d77eee3642f3c068c68'),
#  ObjectId('59fb0d77eee3642f3c0686a0'),
#  ObjectId('59fb0d77eee3642f3c0687c6'),
#  ObjectId('59fb0d77eee3642f3c06888b'),
#  ObjectId('59fb0d77eee3642f3c0689b4'),
#  ObjectId('59fb0d77eee3642f3c068793'),
#  ObjectId('59fb0d77eee3642f3c068bd2'),
#  ObjectId('59fb0d77eee3642f3c06853c'),
#  ObjectId('59fb0d77eee3642f3c068540'),
#  ObjectId('59fb0d77eee3642f3c0684c1'),
#  ObjectId('59fb0d77eee3642f3c06860a'),
#  ObjectId('59fb0d77eee3642f3c068708'),
#  ObjectId('59fb0d77eee3642f3c068ad4'),
#  ObjectId('59fb0d77eee3642f3c0685b2'),
#  ObjectId('59fb0d77eee3642f3c068825'),
#  ObjectId('59fb0d77eee3642f3c0687d3'),
#  ObjectId('59fb0d77eee3642f3c068bf2'),
#  ObjectId('59fb0d77eee3642f3c0684e4'),
#  ObjectId('59fb0d77eee3642f3c0689e4'),
#  ObjectId('59fb0d77eee3642f3c068792'),
#  ObjectId('59fb0d77eee3642f3c068a2b'),
#  ObjectId('59fb0d77eee3642f3c0685b3'),
#  ObjectId('59fb0d77eee3642f3c0684b8'),
#  ObjectId('59fb0d77eee3642f3c068637'),
#  ObjectId('59fb0d77eee3642f3c0686d0'),
#  ObjectId('59fb0d77eee3642f3c0689e8'),
#  ObjectId('59fb0d77eee3642f3c068bda'),
#  ObjectId('59fb0d77eee3642f3c068400'),
#  ObjectId('59fb0d77eee3642f3c068b86'),
#  ObjectId('59fb0d77eee3642f3c068a9c'),
#  ObjectId('59fb0d77eee3642f3c0689a3'),
#  ObjectId('59fb0d77eee3642f3c06850f'),
#  ObjectId('59fb0d77eee3642f3c068b2f'),
#  ObjectId('59fb0d77eee3642f3c0688ad'),
#  ObjectId('59fb0d77eee3642f3c068d79'),
#  ObjectId('59fb0d77eee3642f3c0686cf'),
#  ObjectId('59fb0d77eee3642f3c06889f'),
#  ObjectId('59fb0d77eee3642f3c068626'),
#  ObjectId('59fb0d77eee3642f3c0686de'),
#  ObjectId('59fb0d77eee3642f3c068959'),
#  ObjectId('59fb0d77eee3642f3c0687cb'),
#  ObjectId('59fb0d77eee3642f3c068724'),
#  ObjectId('59fb0d77eee3642f3c0688d8'),
#  ObjectId('59fb0d77eee3642f3c068413'),
#  ObjectId('59fb0d77eee3642f3c0685b6'),
#  ObjectId('59fb0d77eee3642f3c068c87'),
#  ObjectId('59fb0d77eee3642f3c06882b'),
#  ObjectId('59fb0d77eee3642f3c0685a2'),
#  ObjectId('59fb0d77eee3642f3c068b76'),
#  ObjectId('59fb0d77eee3642f3c06853e'),
#  ObjectId('59fb0d77eee3642f3c068abf'),
#  ObjectId('59fb0d77eee3642f3c068c74'),
#  ObjectId('59fb0d77eee3642f3c06843e'),
#  ObjectId('59fb0d77eee3642f3c068ae5'),
#  ObjectId('59fb0d77eee3642f3c068d45'),
#  ObjectId('59fb0d77eee3642f3c0686d7'),
#  ObjectId('59fb0d77eee3642f3c068609'),
#  ObjectId('59fb0d77eee3642f3c06899c'),
#  ObjectId('59fb0d77eee3642f3c06880c'),
#  ObjectId('59fb0d77eee3642f3c0686a1'),
#  ObjectId('59fb0d77eee3642f3c068446'),
#  ObjectId('59fb0d77eee3642f3c068c71'),
#  ObjectId('59fb0d77eee3642f3c06878f'),
#  ObjectId('59fb0d77eee3642f3c068c8c'),
#  ObjectId('59fb0d77eee3642f3c068750'),
#  ObjectId('59fb0d77eee3642f3c068c08'),
#  ObjectId('59fb0d77eee3642f3c06859e'),
#  ObjectId('59fb0d77eee3642f3c068a5f'),
#  ObjectId('59fb0d77eee3642f3c068a7a'),
#  ObjectId('59fb0d77eee3642f3c068c9e'),
#  ObjectId('59fb0d77eee3642f3c0685e8'),
#  ObjectId('59fb0d77eee3642f3c0684e9'),
#  ObjectId('59fb0d77eee3642f3c068753'),
#  ObjectId('59fb0d77eee3642f3c0684f9'),
#  ObjectId('59fb0d77eee3642f3c068748'),
#  ObjectId('59fb0d77eee3642f3c0685de'),
#  ObjectId('59fb0d77eee3642f3c068755'),
#  ObjectId('59fb0d77eee3642f3c0685a1'),
#  ObjectId('59fb0d77eee3642f3c068412'),
#  ObjectId('59fb0d77eee3642f3c068c5a'),
#  ObjectId('59fb0d77eee3642f3c068596'),
#  ObjectId('59fb0d77eee3642f3c068b95'),
#  ObjectId('59fb0d77eee3642f3c0689a1'),
#  ObjectId('59fb0d77eee3642f3c068b8b'),
#  ObjectId('59fb0d77eee3642f3c068c09'),
#  ObjectId('59fb0d77eee3642f3c06860e'),
#  ObjectId('59fb0d77eee3642f3c0685ac'),
#  ObjectId('59fb0d77eee3642f3c068465'),
#  ObjectId('59fb0d77eee3642f3c068497'),
#  ObjectId('59fb0d77eee3642f3c068b13'),
#  ObjectId('59fb0d77eee3642f3c06877e'),
#  ObjectId('59fb0d77eee3642f3c068685'),
#  ObjectId('59fb0d77eee3642f3c068739'),
#  ObjectId('59fb0d77eee3642f3c068ca5'),
#  ObjectId('59fb0d77eee3642f3c068b75'),
#  ObjectId('59fb0d77eee3642f3c06881a'),
#  ObjectId('59fb0d77eee3642f3c068627'),
#  ObjectId('59fb0d77eee3642f3c068972'),
#  ObjectId('59fb0d77eee3642f3c068bd0'),
#  ObjectId('59fb0d77eee3642f3c068cb1'),
#  ObjectId('59fb0d77eee3642f3c068a55'),
#  ObjectId('59fb0d77eee3642f3c068641'),
#  ObjectId('59fb0d77eee3642f3c0688ef'),
#  ObjectId('59fb0d77eee3642f3c06894c'),
#  ObjectId('59fb0d77eee3642f3c068c0f'),
#  ObjectId('59fb0d77eee3642f3c0689a5'),
#  ObjectId('59fb0d77eee3642f3c068902'),
#  ObjectId('59fb0d77eee3642f3c068ab8'),
#  ObjectId('59fb0d77eee3642f3c06870c'),
#  ObjectId('59fb0d77eee3642f3c068732'),
#  ObjectId('59fb0d77eee3642f3c0684b2'),
#  ObjectId('59fb0d77eee3642f3c0685bb'),
#  ObjectId('59fb0d77eee3642f3c068729'),
#  ObjectId('59fb0d77eee3642f3c068cd4'),
#  ObjectId('59fb0d77eee3642f3c068d05'),
#  ObjectId('59fb0d77eee3642f3c068ac5'),
#  ObjectId('59fb0d77eee3642f3c068c14'),
#  ObjectId('59fb0d77eee3642f3c068642'),
#  ObjectId('59fb0d77eee3642f3c0685dc'),
#  ObjectId('59fb0d77eee3642f3c068c0a'),
#  ObjectId('59fb0d77eee3642f3c068c9a'),
#  ObjectId('59fb0d77eee3642f3c068712'),
#  ObjectId('59fb0d77eee3642f3c068c29'),
#  ObjectId('59fb0d77eee3642f3c0688f7'),
#  ObjectId('59fb0d77eee3642f3c0689d7'),
#  ObjectId('59fb0d77eee3642f3c068597'),
#  ObjectId('59fb0d77eee3642f3c068cc0'),
#  ObjectId('59fb0d77eee3642f3c0688dd'),
#  ObjectId('59fb0d77eee3642f3c068a91'),
#  ObjectId('59fb0d77eee3642f3c0689a6'),
#  ObjectId('59fb0d77eee3642f3c0684b7'),
#  ObjectId('59fb0d77eee3642f3c068479'),
#  ObjectId('59fb0d77eee3642f3c0684f4'),
#  ObjectId('59fb0d77eee3642f3c06863e'),
#  ObjectId('59fb0d77eee3642f3c068b89'),
#  ObjectId('59fb0d77eee3642f3c0686ad'),
#  ObjectId('59fb0d77eee3642f3c068a83'),
#  ObjectId('59fb0d77eee3642f3c0684d6'),
#  ObjectId('59fb0d77eee3642f3c068432'),
#  ObjectId('59fb0d77eee3642f3c068764'),
#  ObjectId('59fb0d77eee3642f3c068684'),
#  ObjectId('59fb0d77eee3642f3c068650'),
#  ObjectId('59fb0d77eee3642f3c068ada'),
#  ObjectId('59fb0d77eee3642f3c068a56'),
#  ObjectId('59fb0d77eee3642f3c0688ea'),
#  ObjectId('59fb0d77eee3642f3c06851f'),
#  ObjectId('59fb0d77eee3642f3c0685dd'),
#  ObjectId('59fb0d77eee3642f3c06843b'),
#  ObjectId('59fb0d77eee3642f3c068c51'),
#  ObjectId('59fb0d77eee3642f3c0688f3'),
#  ObjectId('59fb0d77eee3642f3c068cd5'),
#  ObjectId('59fb0d77eee3642f3c068d0d'),
#  ObjectId('59fb0d77eee3642f3c068a6e'),
#  ObjectId('59fb0d77eee3642f3c068abd'),
#  ObjectId('59fb0d77eee3642f3c068519'),
#  ObjectId('59fb0d77eee3642f3c06841f'),
#  ObjectId('59fb0d77eee3642f3c068d70'),
#  ObjectId('59fb0d77eee3642f3c068856'),
#  ObjectId('59fb0d77eee3642f3c068cb0'),
#  ObjectId('59fb0d77eee3642f3c068b74'),
#  ObjectId('59fb0d77eee3642f3c06894b'),
#  ObjectId('59fb0d77eee3642f3c068613'),
#  ObjectId('59fb0d77eee3642f3c068883'),
#  ObjectId('59fb0d77eee3642f3c0686cd'),
#  ObjectId('59fb0d77eee3642f3c068b2d'),
#  ObjectId('59fb0d77eee3642f3c06865c'),
#  ObjectId('59fb0d77eee3642f3c068adc'),
#  ObjectId('59fb0d77eee3642f3c0689ae'),
#  ObjectId('59fb0d77eee3642f3c0684d9'),
#  ObjectId('59fb0d77eee3642f3c06866d'),
#  ObjectId('59fb0d77eee3642f3c068a28'),
#  ObjectId('59fb0d77eee3642f3c0688e3'),
#  ObjectId('59fb0d77eee3642f3c06892e'),
#  ObjectId('59fb0d77eee3642f3c06863d'),
#  ObjectId('59fb0d77eee3642f3c0686ef'),
#  ObjectId('59fb0d77eee3642f3c068855'),
#  ObjectId('59fb0d77eee3642f3c0685d1'),
#  ObjectId('59fb0d77eee3642f3c0687d7'),
#  ObjectId('59fb0d77eee3642f3c068693'),
#  ObjectId('59fb0d77eee3642f3c068a30'),
#  ObjectId('59fb0d77eee3642f3c068d83'),
#  ObjectId('59fb0d77eee3642f3c068a6c'),
#  ObjectId('59fb0d77eee3642f3c068506'),
#  ObjectId('59fb0d77eee3642f3c068b80'),
#  ObjectId('59fb0d77eee3642f3c06846f'),
#  ObjectId('59fb0d77eee3642f3c06857b'),
#  ObjectId('59fb0d77eee3642f3c06860c'),
#  ObjectId('59fb0d77eee3642f3c068bd8'),
#  ObjectId('59fb0d77eee3642f3c068ca0'),
#  ObjectId('59fb0d77eee3642f3c068d46'),
#  ObjectId('59fb0d77eee3642f3c0689dc'),
#  ObjectId('59fb0d77eee3642f3c068791'),
#  ObjectId('59fb0d77eee3642f3c068b38'),
#  ObjectId('59fb0d77eee3642f3c06878c'),
#  ObjectId('59fb0d77eee3642f3c068656'),
#  ObjectId('59fb0d77eee3642f3c0685e4'),
#  ObjectId('59fb0d77eee3642f3c06867a'),
#  ObjectId('59fb0d77eee3642f3c0689bd'),
#  ObjectId('59fb0d77eee3642f3c068beb'),
#  ObjectId('59fb0d77eee3642f3c068630'),
#  ObjectId('59fb0d77eee3642f3c0683f7'),
#  ObjectId('59fb0d77eee3642f3c068d54'),
#  ObjectId('59fb0d77eee3642f3c068d6d'),
#  ObjectId('59fb0d77eee3642f3c068afe'),
#  ObjectId('59fb0d77eee3642f3c068787'),
#  ObjectId('59fb0d77eee3642f3c06859f'),
#  ObjectId('59fb0d77eee3642f3c068cf7'),
#  ObjectId('59fb0d77eee3642f3c06859c'),
#  ObjectId('59fb0d77eee3642f3c068d25'),
#  ObjectId('59fb0d77eee3642f3c068afa'),
#  ObjectId('59fb0d77eee3642f3c068c23'),
#  ObjectId('59fb0d77eee3642f3c068bd3'),
#  ObjectId('59fb0d77eee3642f3c068614'),
#  ObjectId('59fb0d77eee3642f3c06887c'),
#  ObjectId('59fb0d77eee3642f3c068ac3'),
#  ObjectId('59fb0d77eee3642f3c068651'),
#  ObjectId('59fb0d77eee3642f3c068590'),
#  ObjectId('59fb0d77eee3642f3c068b98'),
#  ObjectId('59fb0d77eee3642f3c068d2a'),
#  ObjectId('59fb0d77eee3642f3c068ab9'),
#  ObjectId('59fb0d77eee3642f3c0686e0'),
#  ObjectId('59fb0d77eee3642f3c068448'),
#  ObjectId('59fb0d77eee3642f3c0685d4'),
#  ObjectId('59fb0d77eee3642f3c0688c9'),
#  ObjectId('59fb0d77eee3642f3c0684c6'),
#  ObjectId('59fb0d77eee3642f3c068730'),
#  ObjectId('59fb0d77eee3642f3c0686ff'),
#  ObjectId('59fb0d77eee3642f3c0685c3'),
#  ObjectId('59fb0d77eee3642f3c068889'),
#  ObjectId('59fb0d77eee3642f3c068c95'),
#  ObjectId('59fb0d77eee3642f3c068bf1'),
#  ObjectId('59fb0d77eee3642f3c068559'),
#  ObjectId('59fb0d77eee3642f3c068a6b'),
#  ObjectId('59fb0d77eee3642f3c0688a5'),
#  ObjectId('59fb0d77eee3642f3c06872b'),
#  ObjectId('59fb0d77eee3642f3c068b8a'),
#  ObjectId('59fb0d77eee3642f3c068c15'),
#  ObjectId('59fb0d77eee3642f3c068662'),
#  ObjectId('59fb0d77eee3642f3c068a1e'),
#  ObjectId('59fb0d77eee3642f3c068cb5'),
#  ObjectId('59fb0d77eee3642f3c068660'),
#  ObjectId('59fb0d77eee3642f3c0688f1'),
#  ObjectId('59fb0d77eee3642f3c068a80'),
#  ObjectId('59fb0d77eee3642f3c0687d2'),
#  ObjectId('59fb0d77eee3642f3c06852f'),
#  ObjectId('59fb0d77eee3642f3c068b27'),
#  ObjectId('59fb0d77eee3642f3c068a1c'),
#  ObjectId('59fb0d77eee3642f3c068b8f'),
#  ObjectId('59fb0d77eee3642f3c068aed'),
#  ObjectId('59fb0d77eee3642f3c068592'),
#  ObjectId('59fb0d77eee3642f3c06881d'),
#  ObjectId('59fb0d77eee3642f3c068bd1'),
#  ObjectId('59fb0d77eee3642f3c0684f5'),
#  ObjectId('59fb0d77eee3642f3c068923'),
#  ObjectId('59fb0d77eee3642f3c068582'),
#  ObjectId('59fb0d77eee3642f3c06888a'),
#  ObjectId('59fb0d77eee3642f3c068bf9'),
#  ObjectId('59fb0d77eee3642f3c06880b'),
#  ObjectId('59fb0d77eee3642f3c068b81'),
#  ObjectId('59fb0d77eee3642f3c0684c8'),
#  ObjectId('59fb0d77eee3642f3c06871e'),
#  ObjectId('59fb0d77eee3642f3c068c4f'),
#  ObjectId('59fb0d77eee3642f3c0685f3'),
#  ObjectId('59fb0d77eee3642f3c068c54'),
#  ObjectId('59fb0d77eee3642f3c068adb'),
#  ObjectId('59fb0d77eee3642f3c068aee'),
#  ObjectId('59fb0d77eee3642f3c0686a5'),
#  ObjectId('59fb0d77eee3642f3c06852b'),
#  ObjectId('59fb0d77eee3642f3c0687e8'),
#  ObjectId('59fb0d77eee3642f3c06860b'),
#  ObjectId('59fb0d77eee3642f3c0684a0'),
#  ObjectId('59fb0d77eee3642f3c068d97'),
#  ObjectId('59fb0d77eee3642f3c06885c'),
#  ObjectId('59fb0d77eee3642f3c06867c'),
#  ObjectId('59fb0d77eee3642f3c068b6e'),
#  ObjectId('59fb0d77eee3642f3c068a3b'),
#  ObjectId('59fb0d77eee3642f3c068944'),
#  ObjectId('59fb0d77eee3642f3c068943'),
#  ObjectId('59fb0d77eee3642f3c068d57'),
#  ObjectId('59fb0d77eee3642f3c068d82'),
#  ObjectId('59fb0d77eee3642f3c068686'),
#  ObjectId('59fb0d77eee3642f3c06893f'),
#  ObjectId('59fb0d77eee3642f3c068760'),
#  ObjectId('59fb0d77eee3642f3c068695'),
#  ObjectId('59fb0d77eee3642f3c068901'),
#  ObjectId('59fb0d77eee3642f3c0689c1'),
#  ObjectId('59fb0d77eee3642f3c068d14'),
#  ObjectId('59fb0d77eee3642f3c068cd7'),
#  ObjectId('59fb0d77eee3642f3c0688fb'),
#  ObjectId('59fb0d77eee3642f3c0686d5'),
#  ObjectId('59fb0d77eee3642f3c068823'),
#  ObjectId('59fb0d77eee3642f3c068ade'),
#  ObjectId('59fb0d77eee3642f3c0689ca'),
#  ObjectId('59fb0d77eee3642f3c0687ef'),
#  ObjectId('59fb0d77eee3642f3c06894e'),
#  ObjectId('59fb0d77eee3642f3c068c20'),
#  ObjectId('59fb0d77eee3642f3c06845c'),
#  ObjectId('59fb0d77eee3642f3c068c2a'),
#  ObjectId('59fb0d77eee3642f3c06889e'),
#  ObjectId('59fb0d77eee3642f3c0689c6'),
#  ObjectId('59fb0d77eee3642f3c068c40'),
#  ObjectId('59fb0d77eee3642f3c068aa4'),
#  ObjectId('59fb0d77eee3642f3c068bcf'),
#  ObjectId('59fb0d77eee3642f3c06840e'),
#  ObjectId('59fb0d77eee3642f3c068899'),
#  ObjectId('59fb0d77eee3642f3c068911'),
#  ObjectId('59fb0d77eee3642f3c068709'),
#  ObjectId('59fb0d77eee3642f3c06876a'),
#  ObjectId('59fb0d77eee3642f3c068d92'),
#  ObjectId('59fb0d77eee3642f3c068afb'),
#  ObjectId('59fb0d77eee3642f3c06884f'),
#  ObjectId('59fb0d77eee3642f3c068c03'),
#  ObjectId('59fb0d77eee3642f3c068535'),
#  ObjectId('59fb0d77eee3642f3c068cbe'),
#  ObjectId('59fb0d77eee3642f3c0687a9'),
#  ObjectId('59fb0d77eee3642f3c06898f'),
#  ObjectId('59fb0d77eee3642f3c0685a3'),
#  ObjectId('59fb0d77eee3642f3c068572'),
#  ObjectId('59fb0d77eee3642f3c068a92'),
#  ObjectId('59fb0d77eee3642f3c068ce1'),
#  ObjectId('59fb0d77eee3642f3c068c8a'),
#  ObjectId('59fb0d77eee3642f3c068b2c'),
#  ObjectId('59fb0d77eee3642f3c068568'),
#  ObjectId('59fb0d77eee3642f3c06895d'),
#  ObjectId('59fb0d77eee3642f3c0685cc'),
#  ObjectId('59fb0d77eee3642f3c068744'),
#  ObjectId('59fb0d77eee3642f3c068c2f'),
#  ObjectId('59fb0d77eee3642f3c0688c0'),
#  ObjectId('59fb0d77eee3642f3c068b9c'),
#  ObjectId('59fb0d77eee3642f3c068bac'),
#  ObjectId('59fb0d77eee3642f3c0684a1'),
#  ObjectId('59fb0d77eee3642f3c0688a6'),
#  ObjectId('59fb0d77eee3642f3c068523'),
#  ObjectId('59fb0d77eee3642f3c068ca3'),
#  ObjectId('59fb0d77eee3642f3c068420'),
#  ObjectId('59fb0d77eee3642f3c06892a'),
#  ObjectId('59fb0d77eee3642f3c06889b'),
#  ObjectId('59fb0d77eee3642f3c068ad9'),
#  ObjectId('59fb0d77eee3642f3c0685ab'),
#  ObjectId('59fb0d77eee3642f3c068bc0'),
#  ObjectId('59fb0d77eee3642f3c068993'),
#  ObjectId('59fb0d77eee3642f3c068458'),
#  ObjectId('59fb0d77eee3642f3c068ab5'),
#  ObjectId('59fb0d77eee3642f3c06875c'),
#  ObjectId('59fb0d77eee3642f3c06862b'),
#  ObjectId('59fb0d77eee3642f3c06896c'),
#  ObjectId('59fb0d77eee3642f3c0685a4'),
#  ObjectId('59fb0d77eee3642f3c0685e3'),
#  ObjectId('59fb0d77eee3642f3c068d3a'),
#  ObjectId('59fb0d77eee3642f3c068543'),
#  ObjectId('59fb0d77eee3642f3c068d2d'),
#  ObjectId('59fb0d77eee3642f3c068997'),
#  ObjectId('59fb0d77eee3642f3c068a72'),
#  ObjectId('59fb0d77eee3642f3c06854e'),
#  ObjectId('59fb0d77eee3642f3c068663'),
#  ObjectId('59fb0d77eee3642f3c068d33'),
#  ObjectId('59fb0d77eee3642f3c0684c7'),
#  ObjectId('59fb0d77eee3642f3c068c1e'),
#  ObjectId('59fb0d77eee3642f3c068546'),
#  ObjectId('59fb0d77eee3642f3c068796'),
#  ObjectId('59fb0d77eee3642f3c068403'),
#  ObjectId('59fb0d77eee3642f3c0685a7'),
#  ObjectId('59fb0d77eee3642f3c068d76'),
#  ObjectId('59fb0d77eee3642f3c0684e5'),
#  ObjectId('59fb0d77eee3642f3c068c96'),
#  ObjectId('59fb0d77eee3642f3c068a67'),
#  ObjectId('59fb0d77eee3642f3c068822'),
#  ObjectId('59fb0d77eee3642f3c0687ab'),
#  ObjectId('59fb0d77eee3642f3c06883d'),
#  ObjectId('59fb0d77eee3642f3c0687a0'),
#  ObjectId('59fb0d77eee3642f3c068588'),
#  ObjectId('59fb0d77eee3642f3c0688c7'),
#  ObjectId('59fb0d77eee3642f3c068633'),
#  ObjectId('59fb0d77eee3642f3c068ba7'),
#  ObjectId('59fb0d77eee3642f3c068a59'),
#  ObjectId('59fb0d77eee3642f3c068b66'),
#  ObjectId('59fb0d77eee3642f3c0684de'),
#  ObjectId('59fb0d77eee3642f3c068b61'),
#  ObjectId('59fb0d77eee3642f3c068d48'),
#  ObjectId('59fb0d77eee3642f3c068d75'),
#  ObjectId('59fb0d77eee3642f3c068c53'),
#  ObjectId('59fb0d77eee3642f3c068c07'),
#  ObjectId('59fb0d77eee3642f3c068c52'),
#  ObjectId('59fb0d77eee3642f3c0689e0'),
#  ObjectId('59fb0d77eee3642f3c068619'),
#  ObjectId('59fb0d77eee3642f3c068aca'),
#  ObjectId('59fb0d77eee3642f3c068951'),
#  ObjectId('59fb0d77eee3642f3c0686f0'),
#  ObjectId('59fb0d77eee3642f3c068cac'),
#  ObjectId('59fb0d77eee3642f3c0689f3'),
#  ObjectId('59fb0d77eee3642f3c068718'),
#  ObjectId('59fb0d77eee3642f3c068a9b'),
#  ObjectId('59fb0d77eee3642f3c068ab6'),
#  ObjectId('59fb0d77eee3642f3c068405'),
#  ObjectId('59fb0d77eee3642f3c068aac'),
#  ObjectId('59fb0d77eee3642f3c068bdb'),
#  ObjectId('59fb0d77eee3642f3c0688a7'),
#  ObjectId('59fb0d77eee3642f3c0688d6'),
#  ObjectId('59fb0d77eee3642f3c0687d9'),
#  ObjectId('59fb0d77eee3642f3c068697'),
#  ObjectId('59fb0d77eee3642f3c068517'),
#  ObjectId('59fb0d77eee3642f3c06857a'),
#  ObjectId('59fb0d77eee3642f3c068a79'),
#  ObjectId('59fb0d77eee3642f3c0684aa'),
#  ObjectId('59fb0d77eee3642f3c068a97'),
#  ObjectId('59fb0d77eee3642f3c068d40'),
#  ObjectId('59fb0d77eee3642f3c068918'),
#  ObjectId('59fb0d77eee3642f3c06890d'),
#  ObjectId('59fb0d77eee3642f3c068c44'),
#  ObjectId('59fb0d77eee3642f3c068c0b'),
#  ObjectId('59fb0d77eee3642f3c068c1c'),
#  ObjectId('59fb0d77eee3642f3c068ce6'),
#  ObjectId('59fb0d77eee3642f3c068621'),
#  ObjectId('59fb0d77eee3642f3c068734'),
#  ObjectId('59fb0d77eee3642f3c0685a9'),
#  ObjectId('59fb0d77eee3642f3c068983'),
#  ObjectId('59fb0d77eee3642f3c068b8d'),
#  ObjectId('59fb0d77eee3642f3c06868e'),
#  ObjectId('59fb0d77eee3642f3c068996'),
#  ObjectId('59fb0d77eee3642f3c0687b3'),
#  ObjectId('59fb0d77eee3642f3c06879c'),
#  ObjectId('59fb0d77eee3642f3c0685b4'),
#  ObjectId('59fb0d77eee3642f3c068463'),
#  ObjectId('59fb0d77eee3642f3c06843f'),
#  ObjectId('59fb0d77eee3642f3c068740'),
#  ObjectId('59fb0d77eee3642f3c06841c'),
#  ObjectId('59fb0d77eee3642f3c0688a1'),
#  ObjectId('59fb0d77eee3642f3c06899d'),
#  ObjectId('59fb0d77eee3642f3c068558'),
#  ObjectId('59fb0d77eee3642f3c068cc1'),
#  ObjectId('59fb0d77eee3642f3c068c00'),
#  ObjectId('59fb0d77eee3642f3c068a78'),
#  ObjectId('59fb0d77eee3642f3c068ac2'),
#  ObjectId('59fb0d77eee3642f3c068c43'),
#  ObjectId('59fb0d77eee3642f3c0685fc'),
#  ObjectId('59fb0d77eee3642f3c068585'),
#  ObjectId('59fb0d77eee3642f3c06862f'),
#  ObjectId('59fb0d77eee3642f3c068d16'),
#  ObjectId('59fb0d77eee3642f3c068cc5'),
#  ObjectId('59fb0d77eee3642f3c068659'),
#  ObjectId('59fb0d77eee3642f3c0686c8'),
#  ObjectId('59fb0d77eee3642f3c0686f8'),
#  ObjectId('59fb0d77eee3642f3c068b36'),
#  ObjectId('59fb0d77eee3642f3c068d06'),
#  ObjectId('59fb0d77eee3642f3c068c97'),
#  ObjectId('59fb0d77eee3642f3c068a27'),
#  ObjectId('59fb0d77eee3642f3c068622'),
#  ObjectId('59fb0d77eee3642f3c068970'),
#  ObjectId('59fb0d77eee3642f3c0685ae'),
#  ObjectId('59fb0d77eee3642f3c068942'),
#  ObjectId('59fb0d77eee3642f3c068d73'),
#  ObjectId('59fb0d77eee3642f3c068b8e'),
#  ObjectId('59fb0d77eee3642f3c0689fe'),
#  ObjectId('59fb0d77eee3642f3c068496'),
#  ObjectId('59fb0d77eee3642f3c0684d7'),
#  ObjectId('59fb0d77eee3642f3c0685ba'),
#  ObjectId('59fb0d77eee3642f3c0685b7'),
#  ObjectId('59fb0d77eee3642f3c068482'),
#  ObjectId('59fb0d77eee3642f3c068a75'),
#  ObjectId('59fb0d77eee3642f3c068c42'),
#  ObjectId('59fb0d77eee3642f3c068bb8'),
#  ObjectId('59fb0d77eee3642f3c0689a8'),
#  ObjectId('59fb0d77eee3642f3c0685c2'),
#  ObjectId('59fb0d77eee3642f3c0685af'),
#  ObjectId('59fb0d77eee3642f3c068c86'),
#  ObjectId('59fb0d77eee3642f3c0689c9'),
#  ObjectId('59fb0d77eee3642f3c068c5e'),
#  ObjectId('59fb0d77eee3642f3c068d61'),
#  ObjectId('59fb0d77eee3642f3c06897b'),
#  ObjectId('59fb0d77eee3642f3c0684da'),
#  ObjectId('59fb0d77eee3642f3c06849d'),
#  ObjectId('59fb0d77eee3642f3c06845a'),
#  ObjectId('59fb0d77eee3642f3c068673'),
#  ObjectId('59fb0d77eee3642f3c068d38'),
#  ObjectId('59fb0d77eee3642f3c068b3e'),
#  ObjectId('59fb0d77eee3642f3c068a5d'),
#  ObjectId('59fb0d77eee3642f3c068d18'),
#  ObjectId('59fb0d77eee3642f3c0685d0'),
#  ObjectId('59fb0d77eee3642f3c068570'),
#  ObjectId('59fb0d77eee3642f3c06888d'),
#  ObjectId('59fb0d77eee3642f3c068965'),
#  ObjectId('59fb0d77eee3642f3c0685c4'),
#  ObjectId('59fb0d77eee3642f3c068c05'),
#  ObjectId('59fb0d77eee3642f3c0686ce'),
#  ObjectId('59fb0d77eee3642f3c068d8d'),
#  ObjectId('59fb0d77eee3642f3c0689eb'),
#  ObjectId('59fb0d77eee3642f3c068a71'),
#  ObjectId('59fb0d77eee3642f3c068ad0'),
#  ObjectId('59fb0d77eee3642f3c068c85'),
#  ObjectId('59fb0d77eee3642f3c068ca7'),
#  ObjectId('59fb0d77eee3642f3c0689d3'),
#  ObjectId('59fb0d77eee3642f3c068c55'),
#  ObjectId('59fb0d77eee3642f3c068aaf'),
#  ObjectId('59fb0d77eee3642f3c068746'),
#  ObjectId('59fb0d77eee3642f3c0685a8'),
#  ObjectId('59fb0d77eee3642f3c068a44'),
#  ObjectId('59fb0d77eee3642f3c0688f8'),
#  ObjectId('59fb0d77eee3642f3c068a60'),
#  ObjectId('59fb0d77eee3642f3c068d5f'),
#  ObjectId('59fb0d77eee3642f3c068837'),
#  ObjectId('59fb0d77eee3642f3c0687c9'),
#  ObjectId('59fb0d77eee3642f3c068850'),
#  ObjectId('59fb0d77eee3642f3c068804'),
#  ObjectId('59fb0d77eee3642f3c068cab'),
#  ObjectId('59fb0d77eee3642f3c068d34'),
#  ObjectId('59fb0d77eee3642f3c068bb3'),
#  ObjectId('59fb0d77eee3642f3c06895f'),
#  ObjectId('59fb0d77eee3642f3c06857f'),
#  ObjectId('59fb0d77eee3642f3c068d55'),
#  ObjectId('59fb0d77eee3642f3c06851b'),
#  ObjectId('59fb0d77eee3642f3c0683fe'),
#  ObjectId('59fb0d77eee3642f3c068410'),
#  ObjectId('59fb0d77eee3642f3c068ce3'),
#  ObjectId('59fb0d77eee3642f3c0685c9'),
#  ObjectId('59fb0d77eee3642f3c068cad'),
#  ObjectId('59fb0d77eee3642f3c068967'),
#  ObjectId('59fb0d77eee3642f3c068b31'),
#  ObjectId('59fb0d77eee3642f3c068450'),
#  ObjectId('59fb0d77eee3642f3c068624'),
#  ObjectId('59fb0d77eee3642f3c068b64'),
#  ObjectId('59fb0d77eee3642f3c0685e7'),
#  ObjectId('59fb0d77eee3642f3c068569'),
#  ObjectId('59fb0d77eee3642f3c06862a'),
#  ObjectId('59fb0d77eee3642f3c06848a'),
#  ObjectId('59fb0d77eee3642f3c0685e9'),
#  ObjectId('59fb0d77eee3642f3c0689ff'),
#  ObjectId('59fb0d77eee3642f3c068cec'),
#  ObjectId('59fb0d77eee3642f3c068524'),
#  ObjectId('59fb0d77eee3642f3c068ba5'),
#  ObjectId('59fb0d77eee3642f3c0685aa'),
#  ObjectId('59fb0d77eee3642f3c068cf3'),
#  ObjectId('59fb0d77eee3642f3c068966'),
#  ObjectId('59fb0d77eee3642f3c06848f'),
#  ObjectId('59fb0d77eee3642f3c0685cd'),
#  ObjectId('59fb0d77eee3642f3c06856e'),
#  ObjectId('59fb0d77eee3642f3c068499'),
#  ObjectId('59fb0d77eee3642f3c068672'),
#  ObjectId('59fb0d77eee3642f3c068925'),
#  ObjectId('59fb0d77eee3642f3c068b41'),
#  ObjectId('59fb0d77eee3642f3c0688d9'),
#  ObjectId('59fb0d77eee3642f3c068731'),
#  ObjectId('59fb0d77eee3642f3c068a73'),
#  ObjectId('59fb0d77eee3642f3c068d5d'),
#  ObjectId('59fb0d77eee3642f3c068cc3'),
#  ObjectId('59fb0d77eee3642f3c068767'),
#  ObjectId('59fb0d77eee3642f3c068863'),
#  ObjectId('59fb0d77eee3642f3c068bde'),
#  ObjectId('59fb0d77eee3642f3c068508'),
#  ObjectId('59fb0d77eee3642f3c0688b4'),
#  ObjectId('59fb0d77eee3642f3c068917'),
#  ObjectId('59fb0d77eee3642f3c06879b'),
#  ObjectId('59fb0d77eee3642f3c068859'),
#  ObjectId('59fb0d77eee3642f3c068c1d'),
#  ObjectId('59fb0d77eee3642f3c068813'),
#  ObjectId('59fb0d77eee3642f3c068554'),
#  ObjectId('59fb0d77eee3642f3c068518'),
#  ObjectId('59fb0d77eee3642f3c068af2'),
#  ObjectId('59fb0d77eee3642f3c06847c'),
#  ObjectId('59fb0d77eee3642f3c06846b'),
#  ObjectId('59fb0d77eee3642f3c06859d'),
#  ObjectId('59fb0d77eee3642f3c068d03'),
#  ObjectId('59fb0d77eee3642f3c0685c1'),
#  ObjectId('59fb0d77eee3642f3c06867b'),
#  ObjectId('59fb0d77eee3642f3c0689b2'),
#  ObjectId('59fb0d77eee3642f3c0689d0'),
#  ObjectId('59fb0d77eee3642f3c068922'),
#  ObjectId('59fb0d77eee3642f3c068654'),
#  ObjectId('59fb0d77eee3642f3c068c77'),
#  ObjectId('59fb0d77eee3642f3c068539'),
#  ObjectId('59fb0d77eee3642f3c068652'),
#  ObjectId('59fb0d77eee3642f3c068d2b'),
#  ObjectId('59fb0d77eee3642f3c068495'),
#  ObjectId('59fb0d77eee3642f3c068cb4'),
#  ObjectId('59fb0d77eee3642f3c0685bd'),
#  ObjectId('59fb0d77eee3642f3c0686b2'),
#  ObjectId('59fb0d77eee3642f3c068714'),
#  ObjectId('59fb0d77eee3642f3c0686e6'),
#  ObjectId('59fb0d77eee3642f3c06876b'),
#  ObjectId('59fb0d77eee3642f3c0684ca'),
#  ObjectId('59fb0d77eee3642f3c0683fa'),
#  ObjectId('59fb0d77eee3642f3c068d0f'),
#  ObjectId('59fb0d77eee3642f3c068d56'),
#  ObjectId('59fb0d77eee3642f3c06890c'),
#  ObjectId('59fb0d77eee3642f3c068aec'),
#  ObjectId('59fb0d77eee3642f3c068d37'),
#  ObjectId('59fb0d77eee3642f3c068b57'),
#  ObjectId('59fb0d77eee3642f3c068ca6'),
#  ObjectId('59fb0d77eee3642f3c0685e2'),
#  ObjectId('59fb0d77eee3642f3c0684fc'),
#  ...]

# %%
missings_ingredients
# Out:
# [{'sugar'},
#  {'sugar'},
#  {'butter', 'potatoe', 'stock'},
#  {'breadcrumb',
#   'breast',
#   'butter',
#   'fillet',
#   'flour',
#   'lemon',
#   'parmesan',
#   'sprig',
#   'thyme'},
#  {'cherrie', 'cream', 'double', 'strawberrie', 'sugar'},
#  {'flour', 'frozen', 'juice', 'roast', 'stock'},
#  {'bread', 'butter', 'milk', 'serve', 'wholegrain'},
#  {'chocolate', 'cream', 'dark', 'free-range', 'yolk'},
#  {'cauliflower', 'floret', 'flour', 'milk', 'oil'},
#  {'bag',
#   'bistro',
#   'case',
#   'cream',
#   'double',
#   'leftover',
#   'pastry',
#   'potato',
#   'salad',
#   'savoury',
#   'sweetcorn',
#   'wedge'},
#  {'asparagu', 'chosen', 'grower’', 'pack', 'prosciutto', 'serve'},
#  {'flour', 'free-range', 'milk', 'oil', 'pinch', 'salt'},
#  {'butter', 'caster', 'extract', 'flour', 'sugar', 'vanilla'},
#  {'butter', 'caster', 'flour', 'jam', 'raspberry', 'sugar'},
#  {'beaten', 'butter', 'flour', 'salt', 'warm', 'water'},
#  {'asda',
#   'chilli',
#   'free',
#   'fry',
#   'leftover',
#   'mix',
#   'noodle',
#   'oil',
#   'rainbow',
#   'range',
#   'sauce',
#   'stir',
#   'sweet'},
#  {'courgette', 'flour', 'lengthwise', 'milk', 'polenta', 'stick'},
#  {'banana', 'blueberrie', 'pack', 'raspberrie', 'ripe', 'strawberrie'},
#  {'asda',
#   'bag',
#   'dry',
#   'grower’',
#   'hoisin',
#   'noodle',
#   'oil',
#   'pack',
#   'sauce',
#   'stir-fry',
#   'sunday',
#   'vegetable',
#   'weight'},
#  {'butter', 'caster', 'flour', 'free-range', 'lemon', 'powder', 'sugar'},
#  {'bag', 'beaten', 'flour', 'fruit', 'spice', 'sugar', 'tea'},
#  {'cheese', 'leftover', 'mix', 'mushroom', 'pasta', 'tin', 'tomatoe'},
#  {'butter', 'caster', 'chocolate', 'decorate', 'flour', 'sugar', 'yolk'},
#  {'caster',
#   'jam',
#   'raspberrie',
#   'raspberry',
#   'seedles',
#   'strawberrie',
#   'sugar'},
#  {'almond', 'decorate', 'extract', 'french', 'royal', 'special', 'sugar'},
#  {'asda', 'caster', 'coconut', 'free-range', 'plu', 'roll', 'sugar'},
#  {'flour', 'free-range', 'milk', 'oil', 'pinch', 'salt', 'sunflower'},
#  {'butter', 'caster', 'flour', 'jam', 'raspberrie', 'raspberry', 'sugar'},
#  {'asda',
#   'breadcrumb',
#   'butter',
#   'cayenne',
#   'cheese',
#   'coarse-grain',
#   'drumstick',
#   'free-range',
#   'grana',
#   'herb',
#   'mustard',
#   'pack',
#   'padano',
#   'pepper',
#   'salad',
#   'serve'},
#  {'beansprout',
#   'beaten',
#   'breast',
#   'chilli',
#   'clove',
#   'coriander',
#   'garlic',
#   'ginger',
#   'oil',
#   'onion',
#   'peanut',
#   'potatoe',
#   'sauce',
#   'sesame',
#   'soy',
#   'sunflower'},
#  {'approx',
#   'boneles',
#   'cayenne',
#   'chive',
#   'cornflake',
#   'flour',
#   'handful',
#   'ketchup',
#   'low-fat',
#   'natural',
#   'parsley',
#   'pepper',
#   'skinles',
#   'thigh',
#   'tomato',
#   'yogurt'},
#  {'feta', 'frozen', 'handful', 'oil', 'olive', 'onion', 'pea', 'spinach'},
#  {'butter', 'caster', 'clementine', 'juice', 'lemon', 'sugar', 'yolk', 'zest'},
#  {'asda',
#   'boneles',
#   'can',
#   'fillet',
#   'flat-leaf',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'paprika',
#   'parsley',
#   'pepper',
#   'serve',
#   'skin',
#   'sunflower',
#   'thigh',
#   'tomatoe'},
#  {'asda',
#   'breast',
#   'chilli',
#   'chosen',
#   'fry',
#   'light',
#   'mushroom',
#   'noodle',
#   'oil',
#   'pack',
#   'piece',
#   'sauce',
#   'soy',
#   'stir',
#   'sweet',
#   'third',
#   'vegetable'},
#  {'caster',
#   'cherrie',
#   'free-range',
#   'marsala',
#   'sherry',
#   'sugar',
#   'sweet',
#   'yolk'},
#  {'cheese', 'cheshire', 'chosen', 'milk', 'oil', 'olive', 'onion', 'plu'},
#  {'almond',
#   'butter',
#   'caster',
#   'corn',
#   'extract',
#   'flour',
#   'sugar',
#   'vanilla'},
#  {'beaten', 'butter', 'caster', 'cube', 'juice', 'lemon', 'sugar', 'zest'},
#  {'apple', 'butter', 'caster', 'english', 'flour', 'russet', 'self', 'sugar'},
#  {'free-range', 'frozen', 'oil', 'olive', 'onion', 'pea', 'pepper', 'potatoe'},
#  {'butter',
#   'caster',
#   'cube',
#   'juice',
#   'lemon',
#   'lightlybeaten',
#   'sugar',
#   'zest'},
#  {'beaten',
#   'bread',
#   'breadcrumb',
#   'breast',
#   'butter',
#   'clove',
#   'flour',
#   'garlic',
#   'juice',
#   'lemon',
#   'made',
#   'parsley',
#   'salad',
#   'serve',
#   'squeeze',
#   'stale',
#   'tomatoe'},
#  {'beaten',
#   'bread',
#   'butter',
#   'easy-bake',
#   'flour',
#   'glaze',
#   'strong',
#   'yeast'},
#  {'butter', 'caster', 'drop', 'extract', 'flour', 'sugar', 'vanilla', 'yolk'},
#  {'asda',
#   'bread',
#   'breast',
#   'caesar',
#   'ciabatta',
#   'day',
#   'fillet',
#   'free-range',
#   'heart',
#   'lettuce',
#   'oil',
#   'old',
#   'olive',
#   'parmesan',
#   'peeler',
#   'plu',
#   'romaine'},
#  {'asda',
#   'bread',
#   'butter',
#   'cornflake',
#   'crust',
#   'day',
#   'drumstick',
#   'dry',
#   'flour',
#   'free-range',
#   'mustard',
#   'old',
#   'pack',
#   'paprika',
#   'parmesan',
#   'powder',
#   'preferable',
#   'sesame'},
#  {'asda',
#   'beaten',
#   'flour',
#   'frankfurter',
#   'jar',
#   'mustard',
#   'pastry',
#   'puff',
#   'squeezy'},
#  {'cheddar',
#   'frozen',
#   'ham',
#   'mature',
#   'oil',
#   'onion',
#   'pea',
#   'slice',
#   'sunflower'},
#  {'beaten',
#   'butter',
#   'cinnamon',
#   'cornflour',
#   'flour',
#   'glaze',
#   'plu',
#   'plum',
#   'sugar'},
#  {'broken',
#   'chocolate',
#   'chosen',
#   'coffee',
#   'dark',
#   'granule',
#   'instant',
#   'square',
#   'sugar'},
#  {'almond',
#   'butter',
#   'caster',
#   'cherrie',
#   'cube',
#   'flour',
#   'glace',
#   'marzipan',
#   'sugar'},
#  {'butter',
#   'caster',
#   'cream',
#   'double',
#   'pistachio',
#   'plu',
#   'sauce',
#   'sugar',
#   'toffee'},
#  {'butter',
#   'caster',
#   'essence',
#   'flour',
#   'golden',
#   'hard',
#   'sugar',
#   'sweet',
#   'vanilla'},
#  {'caster',
#   'coconut',
#   'flora',
#   'flour',
#   'jam',
#   'milk',
#   'original',
#   'raspberry',
#   'sugar'},
#  {'almond',
#   'berrie',
#   'caster',
#   'chocolate',
#   'cream',
#   'double',
#   'frozen',
#   'happy',
#   'sugar'},
#  {'almond',
#   'caster',
#   'food',
#   'jam',
#   'jar',
#   'raspberry',
#   'sugar',
#   'sugarflair',
#   '‘liquorice’*'},
#  {'bake-it-fresh',
#   'butter',
#   'chive',
#   'croissant',
#   'ham',
#   'jus-roll',
#   'milk',
#   'pack',
#   'slice'},
#  {'black’',
#   'butter',
#   'caster',
#   'chocolate',
#   'dark',
#   'free-range',
#   'green',
#   'plu',
#   'sugar'},
#  {'asda',
#   'butter',
#   'cake',
#   'caster',
#   'decoration',
#   'flour',
#   'free-range',
#   'sugar',
#   'sultana'},
#  {'asda',
#   'beaten',
#   'breast',
#   'butter',
#   'carrot',
#   'chantenay',
#   'crème',
#   'cube',
#   'fillet',
#   'flat-leaf',
#   'flour',
#   'fraîche',
#   'leek',
#   'pack',
#   'parsley',
#   'plu',
#   'stilton',
#   'stock',
#   'thyme'},
#  {'caster',
#   'cream',
#   'double',
#   'edible',
#   'flake',
#   'glitter',
#   'optional',
#   'pack',
#   'sugar'},
#  {'beaten',
#   'butter',
#   'cake',
#   'caster',
#   'extract',
#   'flour',
#   'sugar',
#   'tin',
#   'vanilla'},
#  {'butter',
#   'caster',
#   'decorate',
#   'flour',
#   'pinch',
#   'salt',
#   'spice',
#   'sugar',
#   'sultana'},
#  {'breast',
#   'clove',
#   'fillet',
#   'garlic',
#   'lemon',
#   'oil',
#   'olive',
#   'rosemary',
#   'stalk'},
#  {'beaten',
#   'butter',
#   'cake',
#   'caster',
#   'extract',
#   'flour',
#   'sugar',
#   'tin',
#   'vanilla'},
#  {'asda',
#   'butter',
#   'caster',
#   'flour',
#   'free-range',
#   'honey',
#   'self',
#   'sugar',
#   'walnut'},
#  {'beef',
#   'bread',
#   'cornichon',
#   'houmou',
#   'pepper',
#   'pickle',
#   'salad',
#   'slice',
#   'tomato'},
#  {'banana',
#   'butter',
#   'caster',
#   'flour',
#   'fork',
#   'free-range',
#   'plu',
#   'powder',
#   'sugar'},
#  {'asda',
#   'bean',
#   'can',
#   'cashew',
#   'chestnut',
#   'corn',
#   'jar',
#   'noodle',
#   'nut',
#   'oak',
#   'oil',
#   'olde',
#   'onion',
#   'pack',
#   'roll',
#   'sauce',
#   'sharwood',
#   'stir-fry',
#   'water',
#   'ye'},
#  {'asda',
#   'beaten',
#   'breast',
#   'butcher',
#   'cheddar',
#   'chillie',
#   'cornflake',
#   'cube',
#   'fillet',
#   'flour',
#   'leek',
#   'mature',
#   'oil',
#   'olive',
#   'optional',
#   'pack',
#   'pea',
#   'piece',
#   'potatoe',
#   'serve',
#   'sweetcorn'},
#  {'asda',
#   'beaten',
#   'bread',
#   'coarse',
#   'day',
#   'french',
#   'grain',
#   'mayonnaise',
#   'mustard',
#   'oil',
#   'old',
#   'optional',
#   'parsley',
#   'potatoe',
#   'real',
#   'salad',
#   'serve',
#   'skin',
#   'sunflower',
#   'tomatoe',
#   'weight'},
#  {'butter',
#   'caster',
#   'flour',
#   'juice',
#   'lemon',
#   'plu',
#   'rosemary',
#   'sprig',
#   'sugar',
#   'zest'},
#  {'caster',
#   'chocolate',
#   'cointreau',
#   'favourite',
#   'fruit',
#   'juice',
#   'mango',
#   'orange',
#   'passion',
#   'sugar'},
#  {'asda',
#   'brioche',
#   'butter',
#   'chive',
#   'free-range',
#   'milk',
#   'roll',
#   'salmon',
#   'serve',
#   'tomatoe'},
#  {'beaten',
#   'butter',
#   'caster',
#   'flour',
#   'pinch',
#   'royal',
#   'salt',
#   'sugar',
#   'tube',
#   'yolk'},
#  {'apricot',
#   'butter',
#   'caster',
#   'cube',
#   'flour',
#   'milk',
#   'piece',
#   'sugar',
#   'sultana',
#   'sunflower'},
#  {'butter',
#   'caster',
#   'cocoa',
#   'extract',
#   'flour',
#   'plu',
#   'powder',
#   'raspberrie',
#   'sugar',
#   'vanilla'},
#  {'beaten',
#   'butter',
#   'cube',
#   'decorate',
#   'flour',
#   'fruit',
#   'marzipan',
#   'milk',
#   'spice',
#   'sugar'},
#  {'chosen',
#   'dip',
#   'leftover',
#   'mexican',
#   'oil',
#   'onion',
#   'pepper',
#   'rice',
#   'stacker',
#   'tortilla'},
#  {'bacon',
#   'drizzle',
#   'leftover',
#   'mushroom',
#   'oil',
#   'pack',
#   'parmesan',
#   'rice',
#   'risotto',
#   'rocket'},
#  {'beaten',
#   'cheese',
#   'cherry',
#   'cumberland',
#   'fat',
#   'muffin',
#   'sausage',
#   'slice',
#   'special',
#   'tomatoe'},
#  {'asda',
#   'breadcrumb',
#   'butter',
#   'flour',
#   'free',
#   'pack',
#   'pork',
#   'range',
#   'sausage',
#   'special'},
#  {'brown',
#   'currant',
#   'flour',
#   'hot',
#   'marmalade',
#   'soft',
#   'spice',
#   'sugar',
#   'sultana',
#   'tea'},
#  {'asda',
#   'beaten',
#   'bread',
#   'mix',
#   'packet',
#   'pinch',
#   'powder',
#   'rock',
#   'salt',
#   'yolk'},
#  {'breast',
#   'caesar',
#   'chosen',
#   'eat',
#   'kit',
#   'pack',
#   'ready',
#   'salad',
#   'slice',
#   'taste'},
#  {'asda',
#   'ciabatta',
#   'frie',
#   'garlic',
#   'home-style',
#   'iceberg',
#   'leftover',
#   'lettuce',
#   'loaf',
#   'mayonnaise'},
#  {'butter',
#   'caster',
#   'chillie',
#   'cocoa',
#   'extract',
#   'flour',
#   'free-range',
#   'powder',
#   'sugar',
#   'vanilla'},
#  {'butter',
#   'caster',
#   'currant',
#   'flour',
#   'milk',
#   'pinch',
#   'salt',
#   'spice',
#   'sugar',
#   'sultana'},
#  {'asda',
#   'asparagu',
#   'bread',
#   'crusty',
#   'free-range',
#   'pack',
#   'parmesan',
#   'samphire',
#   'serve',
#   'special'},
#  {'bread',
#   'butter',
#   'nutmeg',
#   'oil',
#   'olive',
#   'pepper',
#   'salt',
#   'slice',
#   'sourdough',
#   'spinach'},
#  {'caramel',
#   'cream',
#   'double',
#   'extract',
#   'nielsen-massey',
#   'optional',
#   'serve',
#   'sugar',
#   'vanilla',
#   'wafer'},
#  {'caster',
#   'flour',
#   'grease',
#   'lemon',
#   'milk',
#   'oil',
#   'quarter',
#   'serve',
#   'sugar',
#   'sunflower'},
#  {'caster',
#   'cherrie',
#   'chocolate',
#   'cream',
#   'dark',
#   'double',
#   'dust',
#   'plu',
#   'stalk',
#   'sugar'},
#  {'butter',
#   'caster',
#   'flour',
#   'jam',
#   'milk',
#   'pinch',
#   'plu',
#   'raspberry',
#   'salt',
#   'sugar'},
#  {'breadcrumb',
#   'butter',
#   'lemon',
#   'milk',
#   'oil',
#   'onion',
#   'parsley',
#   'sage',
#   'sunflower',
#   'thyme'},
#  {'caster',
#   'cream',
#   'double',
#   'drop',
#   'extract',
#   'free-range',
#   'pistachio',
#   'strawberrie',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'drumstick',
#   'honey',
#   'juice',
#   'lemon',
#   'oil',
#   'pack',
#   'sauce',
#   'soy',
#   'sunflower'},
#  {'ball',
#   'butter',
#   'cream',
#   'flour',
#   'free-range',
#   'ginger',
#   'rhubarb',
#   'serve',
#   'stem',
#   'sugar'},
#  {'beaten',
#   'butter',
#   'frozen',
#   'garam',
#   'green',
#   'masala',
#   'onion',
#   'pea',
#   'pepper',
#   'tomatoe'},
#  {'baguette',
#   'bakery',
#   'butter',
#   'chive',
#   'free-range',
#   'herb',
#   'in-store',
#   'parsley',
#   'tarragon',
#   'thyme'},
#  {'apple',
#   'beaten',
#   'butcher',
#   'fat',
#   'flour',
#   'les',
#   'pastry',
#   'pork',
#   'puff',
#   'sausage'},
#  {'clove',
#   'garlic',
#   'mushroom',
#   'oil',
#   'olive',
#   'onion',
#   'orzo',
#   'pasta',
#   'skin',
#   'thigh'},
#  {'bacon',
#   'beaten',
#   'clove',
#   'cream',
#   'garlic',
#   'oil',
#   'rasher',
#   'single',
#   'spaghetti',
#   'yolk'},
#  {'butter',
#   'cadbury',
#   'caster',
#   'cocoa',
#   'creme',
#   'extract',
#   'flour',
#   'powder',
#   'sugar',
#   'vanilla'},
#  {'almond',
#   'asda',
#   'cherry',
#   'chilli',
#   'clove',
#   'coriander',
#   'curry',
#   'garlic',
#   'garnish',
#   'leftover',
#   'mild',
#   'oil',
#   'olive',
#   'onion',
#   'pea',
#   'plu',
#   'powder',
#   'quinoa',
#   'salmon',
#   'stock',
#   'sugarsnap',
#   'tomatoe'},
#  {'asda',
#   'bean',
#   'beaten',
#   'breadcrumb',
#   'cornflour',
#   'cranberry',
#   'crème',
#   'dill',
#   'fat',
#   'fraîche',
#   'green',
#   'hot',
#   'oil',
#   'pack',
#   'parsley',
#   'pork',
#   'potatoe',
#   'sauce',
#   'serve',
#   'spice',
#   'stock',
#   'sunflower'},
#  {'asda',
#   'casero',
#   'chilli',
#   'choi',
#   'chorizo',
#   'coriander',
#   'corn',
#   'cube',
#   'noodle',
#   'onion',
#   'pack',
#   'pak',
#   'pea',
#   'pepper',
#   'sauce',
#   'serve',
#   'snap',
#   'soy',
#   'special',
#   'stock',
#   'sugar',
#   'sweet'},
#  {'asda',
#   'breast',
#   'bunch',
#   'butcher’',
#   'butter',
#   'fillet',
#   'flour',
#   'full-fat',
#   'grower’',
#   'milk',
#   'mushroom',
#   'oil',
#   'onion',
#   'parsley',
#   'pastry',
#   'pepper',
#   'plu',
#   'puff',
#   'ready',
#   'salt',
#   'wash',
#   'yolk'},
#  {'ball',
#   'butcher’',
#   'clove',
#   'cold',
#   'coriander',
#   'cornflour',
#   'fish',
#   'garlic',
#   'light',
#   'noodle',
#   'oil',
#   'oyster',
#   'pack',
#   'pepper',
#   'sauce',
#   'skin',
#   'soy',
#   'stalk',
#   'sugar',
#   'thigh',
#   'water',
#   'wonton'},
#  {'asda',
#   'beaten',
#   'bread',
#   'breadcrumb',
#   'breast',
#   'butcher',
#   'cube',
#   'day',
#   'fillet',
#   'flour',
#   'frozen',
#   'grain',
#   'knorr',
#   'long',
#   'made',
#   'old',
#   'paprika',
#   'parmesan',
#   'pea',
#   'rice',
#   'stock',
#   'sweetcorn'},
#  {'beaten',
#   'cornflour',
#   'frozen',
#   'just-roll',
#   'pack',
#   'pastry',
#   'raspberrie',
#   'rhubarb',
#   'sheet',
#   'shortcrust',
#   'sugar'},
#  {'bacon',
#   'butter',
#   'cabbage',
#   'nutmeg',
#   'pepper',
#   'pinch',
#   'potatoe',
#   'salt',
#   'slice',
#   'streaky',
#   'yolk'},
#  {'asda',
#   'lemon',
#   'oil',
#   'olive',
#   'pepper',
#   'rub',
#   'salt',
#   'sea',
#   'special',
#   'sprig',
#   'thyme'},
#  {'asda',
#   'bread',
#   'breast',
#   'crisp',
#   'crème',
#   'day',
#   'fillet',
#   'fraîche',
#   'frozen',
#   'ketchup',
#   'mint',
#   'oil',
#   'old',
#   'olive',
#   'pack',
#   'pea',
#   'potato',
#   'reduced-fat',
#   'serve',
#   'sesame',
#   'sprig',
#   'tomato',
#   'wholemeal'},
#  {'cheese',
#   'fat',
#   'free-range',
#   'frozen',
#   'greek-style',
#   'milk',
#   'mint',
#   'oil',
#   'onion',
#   'pea',
#   'potatoe'},
#  {'butter',
#   'caster',
#   'chosen',
#   'easy-bake',
#   'flour',
#   'glaze',
#   'milk',
#   'plu',
#   'sachet',
#   'sugar',
#   'yeast'},
#  {'butter',
#   'caster',
#   'cream',
#   'double',
#   'flour',
#   'jam',
#   'little',
#   'plu',
#   'raspberry',
#   'strawberry',
#   'sugar'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'cube',
#   'flour',
#   'juice',
#   'lemon',
#   'plu',
#   'sugar',
#   'yolk',
#   'zest'},
#  {'butter',
#   'cream',
#   'flour',
#   'gluten-free',
#   'ice',
#   'make',
#   'milk',
#   'non',
#   'pear',
#   'serve',
#   'water'},
#  {'arborio',
#   'butter',
#   'celery',
#   'clove',
#   'garlic',
#   'mushroom',
#   'onion',
#   'rice',
#   'stick',
#   'stock',
#   'vegetable'},
#  {'asda',
#   'caesar',
#   'cherry',
#   'crouton',
#   'lettuce',
#   'pack',
#   'parmesan',
#   'salad',
#   'serve',
#   'tomatoe',
#   'tortilla'},
#  {'beaten',
#   'breast',
#   'butcher’',
#   'choice',
#   'cornflake',
#   'cornflour',
#   'crumb',
#   'fillet',
#   'grower’',
#   'lettuce',
#   'oil',
#   'optional',
#   'pack',
#   'paprika',
#   'parsley',
#   'potatoe',
#   'sauce',
#   'serve',
#   'side',
#   'skin',
#   'sweet',
#   'torn',
#   'wedge'},
#  {'banana',
#   'beaten',
#   'caster',
#   'cinnamon',
#   'flour',
#   'golden',
#   'milk',
#   'oil',
#   'powder',
#   'sugar',
#   'sunflower'},
#  {'asparagu',
#   'beaten',
#   'beetroot',
#   'garnish',
#   'mozzarella',
#   'pastry',
#   'puff',
#   'sheet',
#   'thyme',
#   'tip',
#   'torn'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'drop',
#   'essence',
#   'extract',
#   'flour',
#   'food',
#   'plu',
#   'sugar',
#   'vanilla'},
#  {'amoy',
#   'bean',
#   'breast',
#   'butter',
#   'chillie',
#   'chosen',
#   'coconut',
#   'cube',
#   'dunn',
#   'flame',
#   'frozen',
#   'green',
#   'noodle',
#   'onion',
#   'pack',
#   'peanut',
#   'river',
#   'salt',
#   'sauce',
#   'soy',
#   'stock',
#   'strip',
#   'sweetcorn'},
#  {'asda',
#   'caster',
#   'cornflour',
#   'flour',
#   'juice',
#   'lemon',
#   'pastry',
#   'ready-to-roll',
#   'shortcrust',
#   'sugar',
#   'zest'},
#  {'asda',
#   'caster',
#   'conserve',
#   'cream',
#   'double',
#   'drop',
#   'food',
#   'pink',
#   'strawberrie',
#   'strawberry',
#   'sugar'},
#  {'bean',
#   'brown',
#   'butter',
#   'cranberrie',
#   'extract',
#   'flour',
#   'pecan',
#   'soft',
#   'special',
#   'sugar',
#   'vanilla'},
#  {'beaten',
#   'bread',
#   'cream',
#   'double',
#   'oil',
#   'onion',
#   'pepper',
#   'salt',
#   'slice',
#   'stilton',
#   'taste'},
#  {'almond',
#   'butter',
#   'caster',
#   'flour',
#   'lemon',
#   'medium-size',
#   'plu',
#   'plum',
#   'redcurrant',
#   'sugar',
#   'zest'},
#  {'butter',
#   'caster',
#   'cube',
#   'free-range',
#   'juice',
#   'lemon',
#   'orange',
#   'plu',
#   'sugar',
#   'yolk',
#   'zest'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cherrie',
#   'cornflour',
#   'cube',
#   'farm',
#   'flour',
#   'plu',
#   'store',
#   'sugar'},
#  {'butter',
#   'caster',
#   'eat',
#   'grower’',
#   'juice',
#   'lemon',
#   'peache',
#   'plu',
#   'ready',
#   'sugar',
#   'yolk'},
#  {'beansprout',
#   'free-range',
#   'frozen',
#   'groundnut',
#   'long-grain',
#   'oil',
#   'onion',
#   'optional',
#   'pea',
#   'rice',
#   'sesame'},
#  {'blueberrie',
#   'butter',
#   'caster',
#   'flour',
#   'lemon',
#   'low-fat',
#   'milk',
#   'natural',
#   'powder',
#   'sugar',
#   'yogurt'},
#  {'asda',
#   'block',
#   'butter',
#   'carrot',
#   'chilli',
#   'cider',
#   'crunchy',
#   'cucumber',
#   'dark',
#   'groundnut',
#   'honey',
#   'matchstick',
#   'noodle',
#   'oil',
#   'onion',
#   'peanut',
#   'piece',
#   'sauce',
#   'sesame',
#   'soy',
#   'sweet',
#   'turkey',
#   'vinegar'},
#  {'bay',
#   'bone',
#   'carrot',
#   'celery',
#   'onion',
#   'peppercorn',
#   'piece',
#   'roast',
#   'sprig',
#   'stick',
#   'thyme'},
#  {'can',
#   'courgette',
#   'feta',
#   'flour',
#   'handful',
#   'matchstick',
#   'oil',
#   'olive',
#   'rocket',
#   'sweetcorn',
#   'well'},
#  {'asda',
#   'bean',
#   'breast',
#   'chilli',
#   'clove',
#   'fillet',
#   'garlic',
#   'ginger',
#   'groundnut',
#   'lengthway',
#   'light',
#   'mangetout',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'pepper',
#   'piece',
#   'root',
#   'sauce',
#   'soy',
#   'sprout',
#   'strip',
#   'sweet'},
#  {'asda',
#   'basil',
#   'breast',
#   'button',
#   'cheddar',
#   'cheese',
#   'chosen',
#   'chunk',
#   'eat',
#   'ham',
#   'honey',
#   'lasagne',
#   'leftover',
#   'mature',
#   'mushroom',
#   'oil',
#   'olive',
#   'pack',
#   'pot',
#   'ready',
#   'roast',
#   'sauce',
#   'sheet',
#   'tomato'},
#  {'asda',
#   'bean',
#   'beaten',
#   'bread',
#   'breadcrumb',
#   'butter',
#   'free-range',
#   'granule',
#   'gravy',
#   'green',
#   'herb',
#   'little',
#   'made',
#   'mince',
#   'oil',
#   'pack',
#   'potato',
#   'sausage',
#   'serve',
#   'shallot',
#   'slice',
#   'smart',
#   'sunflower',
#   'turkey'},
#  {'back',
#   'bacon',
#   'banana',
#   'bean',
#   'breadcrumb',
#   'breast',
#   'butter',
#   'can',
#   'cornflake',
#   'courgette',
#   'fat',
#   'fillet',
#   'frozen',
#   'just',
#   'oil',
#   'olive',
#   'onion',
#   'paprika',
#   'pepper',
#   'piece',
#   'rasher',
#   'ripe',
#   'sweetcorn',
#   'thyme'},
#  {'best',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'jam',
#   'raspberry',
#   'seedles',
#   'smooth',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'allspice',
#   'cinnamon',
#   'english',
#   'filo',
#   'flesh',
#   'ginger',
#   'happy',
#   'heather',
#   'honey',
#   'pastry',
#   'pumpkin',
#   'sheet'},
#  {'beaten',
#   'butter',
#   'cream',
#   'dill',
#   'double',
#   'flour',
#   'lemon',
#   'milk',
#   'plu',
#   'potato',
#   'salmon',
#   'sprig'},
#  {'asda',
#   'asparagu',
#   'balsamic',
#   'ciabatta',
#   'free-range',
#   'italian',
#   'oil',
#   'prosciutto',
#   'slice',
#   'special',
#   'tip',
#   'vinegar'},
#  {'bacon',
#   'butter',
#   'flour',
#   'green',
#   'mari',
#   'onion',
#   'parsley',
#   'piper',
#   'potatoe',
#   'salmon',
#   'serve',
#   'streaky'},
#  {'asda',
#   'beaten',
#   'butter',
#   'feta',
#   'filo',
#   'frozen',
#   'greek',
#   'onion',
#   'oregano',
#   'pack',
#   'pastry',
#   'spinach'},
#  {'almond',
#   'caster',
#   'chocolate',
#   'chosen',
#   'cocoa',
#   'cream',
#   'curl',
#   'dark',
#   'decorate',
#   'double',
#   'solid',
#   'sugar'},
#  {'almond',
#   'blackberrie',
#   'blueberrie',
#   'extract',
#   'flour',
#   'milk',
#   'oil',
#   'raspberrie',
#   'serve',
#   'sugar',
#   'sunflower',
#   'vanilla'},
#  {'can',
#   'giant',
#   'green',
#   'oil',
#   'onion',
#   'pepper',
#   'piece',
#   'potatoe',
#   'sunflower',
#   'sweet',
#   'sweetcorn',
#   'tomatoe'},
#  {'apricot',
#   'butter',
#   'demerara',
#   'flour',
#   'milk',
#   'nut',
#   'piece',
#   'pistachio',
#   'plu',
#   'spice',
#   'sugar',
#   'sultana'},
#  {'bacon',
#   'block',
#   'chosen',
#   'chutney',
#   'flour',
#   'jus-rol',
#   'milk',
#   'oil',
#   'onion',
#   'pastry',
#   'shortcrust',
#   'tomato'},
#  {'butter',
#   'caster',
#   'cream',
#   'double',
#   'flour',
#   'free-range',
#   'juice',
#   'lime',
#   'mangoe',
#   'powder',
#   'sugar',
#   'zest'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'drop',
#   'essence',
#   'flour',
#   'food',
#   'marshmallow',
#   'pink',
#   'sprinkle',
#   'sugar',
#   'vanilla'},
#  {'almond',
#   'beaten',
#   'butter',
#   'cauliflower',
#   'chutney',
#   'coriander',
#   'garlic',
#   'granule',
#   'pistachio',
#   'serve',
#   'sultana',
#   'tomato'},
#  {'asda',
#   'butter',
#   'cream',
#   'cube',
#   'flour',
#   'free-range',
#   'gruyère',
#   'leek',
#   'plu',
#   'single',
#   'thyme',
#   'yolk'},
#  {'caster',
#   'flour',
#   'free-range',
#   'lemon',
#   'milk',
#   'oil',
#   'pinch',
#   'plu',
#   'salt',
#   'serve',
#   'sugar',
#   'sunflower'},
#  {'beaten',
#   'butter',
#   'fat',
#   'flour',
#   'free-range',
#   'onion',
#   'piece',
#   'plu',
#   'potato',
#   'rump',
#   'steak',
#   'swede'},
#  {'bacon',
#   'banana',
#   'beaten',
#   'bread',
#   'butter',
#   'farmhouse',
#   'maple',
#   'milk',
#   'ripe',
#   'slice',
#   'streaky',
#   'syrup'},
#  {'almond',
#   'butter',
#   'caster',
#   'cherrie',
#   'demerara',
#   'flour',
#   'free-range',
#   'nut',
#   'pine',
#   'powder',
#   'redcurrant',
#   'sugar'},
#  {'beaten',
#   'butter',
#   'cake',
#   'caster',
#   'extract',
#   'flour',
#   'room',
#   'square',
#   'sugar',
#   'temperature',
#   'tin',
#   'vanilla'},
#  {'banana',
#   'beaten',
#   'brown',
#   'butter',
#   'flour',
#   'honey',
#   'pecan',
#   'ripe',
#   'soft',
#   'spice',
#   'sugar',
#   'weight'},
#  {'asda',
#   'caster',
#   'cream',
#   'double',
#   'flour',
#   'free-range',
#   'lemon',
#   'orange',
#   'pastry',
#   'pot',
#   'shortcrust',
#   'sugar'},
#  {'avocado',
#   'caster',
#   'cherry',
#   'flour',
#   'milk',
#   'oil',
#   'powder',
#   'serve',
#   'sugar',
#   'tomatoe',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'beaten',
#   'frozen',
#   'grain',
#   'ham',
#   'long',
#   'micro',
#   'oil',
#   'onion',
#   'pea',
#   'ready',
#   'rice'},
#  {'butter',
#   'chorizo',
#   'coconut',
#   'courgette',
#   'firm',
#   'handful',
#   'little',
#   'mozzarella',
#   'oil',
#   'onion',
#   'piece',
#   'spinach'},
#  {'berrie',
#   'blueberrie',
#   'caster',
#   'cream',
#   'double',
#   'extract',
#   'pinch',
#   'raspberrie',
#   'strawberrie',
#   'sugar',
#   'tartar',
#   'vanilla'},
#  {'apricot',
#   'beaten',
#   'breadcrumb',
#   'chestnut',
#   'oil',
#   'onion',
#   'parsley',
#   'pork',
#   'sage',
#   'sausagemeat',
#   'special',
#   'sunflower'},
#  {'butter',
#   'caster',
#   'cinnamon',
#   'flour',
#   'ginger',
#   'happy',
#   'milk',
#   'nutmeg',
#   'pinch',
#   'salt',
#   'self',
#   'sugar'},
#  {'butter',
#   'caster',
#   'cinnamon',
#   'extract',
#   'flour',
#   'little',
#   'milk',
#   'plu',
#   'plum',
#   'serve',
#   'sugar',
#   'vanilla'},
#  {'can',
#   'chickpea',
#   'clove',
#   'coriander',
#   'cumin',
#   'flat-leaf',
#   'garlic',
#   'oil',
#   'olive',
#   'onion',
#   'parsley',
#   'yolk'},
#  {'asda',
#   'butter',
#   'cheese',
#   'chive',
#   'free-range',
#   'ham',
#   'leicester',
#   'milk',
#   'piece',
#   'salad',
#   'serve',
#   'sweetcorn'},
#  {'asda',
#   'breast',
#   'honey',
#   'juice',
#   'lemon',
#   'oil',
#   'olive',
#   'potatoe',
#   'skinles',
#   'sweet',
#   'thyme',
#   'zest'},
#  {'asda',
#   'beaten',
#   'breadcrumb',
#   'breast',
#   'bun',
#   'burger',
#   'butcher’',
#   'chosen',
#   'crisp',
#   'fillet',
#   'heinz',
#   'ketchup',
#   'oil',
#   'pack',
#   'potatoe',
#   'salad',
#   'salt',
#   'serve',
#   'sesame',
#   'sugar',
#   'sunflower',
#   'sweet',
#   'tomato',
#   'vinegar',
#   'wholemeal'},
#  {'butter',
#   'caster',
#   'currant',
#   'flour',
#   'free-range',
#   'lemon',
#   'mini',
#   'plu',
#   'royal',
#   'sugar',
#   'yolk',
#   'zest'},
#  {'butter',
#   'caster',
#   'chunky',
#   'flour',
#   'marmalade',
#   'milk',
#   'oat',
#   'plu',
#   'porridge',
#   'powder',
#   'sugar',
#   'wholemeal'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cheese',
#   'free-range',
#   'frozen',
#   'goat',
#   'hard',
#   'onion',
#   'pea',
#   'potatoe',
#   'thyme'},
#  {'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'flour',
#   'golden',
#   'happy',
#   'milk',
#   'piece',
#   'powder',
#   'self',
#   'sugar'},
#  {'beaten',
#   'breadcrumb',
#   'breast',
#   'brown',
#   'butcher',
#   'chip',
#   'chosen',
#   'curry',
#   'fillet',
#   'ketchup',
#   'leek',
#   'lengthway',
#   'light',
#   'long-grain',
#   'mangetout',
#   'mix',
#   'oil',
#   'olive',
#   'pack',
#   'portion',
#   'rice',
#   'sauce',
#   'shop',
#   'soy',
#   'tomato'},
#  {'asda',
#   'butcher’',
#   'coleslaw',
#   'grower’',
#   'kit',
#   'marinade',
#   'oil',
#   'pack',
#   'piri',
#   'sauce',
#   'sweetcorn',
#   'twin'},
#  {'beaten',
#   'curd',
#   'flour',
#   'good-quality',
#   'juice',
#   'lemon',
#   'milk',
#   'plu',
#   'poppy',
#   'serve',
#   'wedge',
#   'zest'},
#  {'brown',
#   'extract',
#   'flour',
#   'light',
#   'oat',
#   'oil',
#   'porridge',
#   'raisin',
#   'soft',
#   'spread',
#   'sugar',
#   'vanilla'},
#  {'bag',
#   'beaten',
#   'butter',
#   'free-range',
#   'oil',
#   'olive',
#   'parmesan',
#   'pepper',
#   'serve',
#   'spinach',
#   'tomatoe',
#   'weight'},
#  {'asda',
#   'blueberrie',
#   'caster',
#   'drop',
#   'extract',
#   'flour',
#   'free-range',
#   'milk',
#   'oil',
#   'sugar',
#   'sunflower',
#   'vanilla'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cornflour',
#   'crème',
#   'dijon',
#   'flour',
#   'fraîche',
#   'free-range',
#   'gammon',
#   'lean',
#   'lengthway',
#   'mushroom',
#   'mustard',
#   'oil',
#   'pastry',
#   'puff',
#   'ready',
#   'reduced-fat',
#   'roll',
#   'shallot',
#   'size',
#   'stock',
#   'sunflower',
#   'thyme',
#   'turkey'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cumberland',
#   'flour',
#   'free-range',
#   'ju',
#   'pack',
#   'pastry',
#   'puff',
#   'roll',
#   'sausage',
#   'special'},
#  {'cheddar',
#   'chilli',
#   'free',
#   'mature',
#   'milk',
#   'oil',
#   'pepper',
#   'ricotta',
#   'spaghetti',
#   'spinach',
#   'tomatoe',
#   'tub',
#   'well'},
#  {'breast',
#   'chosen',
#   'fillet',
#   'frozen',
#   'light',
#   'mayonnaise',
#   'oil',
#   'paprika',
#   'piri',
#   'potato',
#   'salad',
#   'serve',
#   'sunflower'},
#  {'asda',
#   'carrot',
#   'granule',
#   'gravy',
#   'mince',
#   'onion',
#   'pack',
#   'parsnip',
#   'pastry',
#   'ready',
#   'roll',
#   'shortcrust',
#   'turkey'},
#  {'beetroot',
#   'crème',
#   'flour',
#   'fraîche',
#   'garnish',
#   'jus-rol',
#   'leicester',
#   'pastry',
#   'plu',
#   'reduced-fat',
#   'shortcrust',
#   'sprig',
#   'thyme'},
#  {'asda',
#   'broccoli',
#   'gravy',
#   'lemon',
#   'marbell',
#   'oil',
#   'olive',
#   'potatoe',
#   'serve',
#   'special',
#   'sprig',
#   'tenderstem',
#   'thyme'},
#  {'asda',
#   'crème',
#   'dill',
#   'flour',
#   'fraîche',
#   'free-range',
#   'milk',
#   'oil',
#   'powder',
#   'salmon',
#   'special',
#   'sprig',
#   'sunflower'},
#  {'asda',
#   'beaten',
#   'breast',
#   'butcher',
#   'butter',
#   'chunk',
#   'crème',
#   'cube',
#   'eat',
#   'fillet',
#   'flour',
#   'fraîche',
#   'ham',
#   'honey',
#   'leek',
#   'lemon',
#   'pack',
#   'pastry',
#   'puff',
#   'ready',
#   'reduced-fat',
#   'roast',
#   'slice',
#   'sprig',
#   'stock',
#   'thyme',
#   'zest'},
#  {'beaten',
#   'breadcrumb',
#   'cheddar',
#   'coarse',
#   'cod',
#   'flour',
#   'frozen',
#   'oil',
#   'parsley',
#   'pea',
#   'potatoe',
#   'salad',
#   'sunflower'},
#  {'bread',
#   'butter',
#   'caster',
#   'extract',
#   'free',
#   'leftover',
#   'marmalade',
#   'milk',
#   'range',
#   'raspberrie',
#   'slice',
#   'sugar',
#   'vanilla'},
#  {'angel',
#   'butter',
#   'cake',
#   'caster',
#   'flour',
#   'food',
#   'mallow',
#   'milk',
#   'mini',
#   'powder',
#   'ready-to-roll',
#   'sugar',
#   'tub'},
#  {'asda',
#   'caster',
#   'clementine',
#   'flora',
#   'flour',
#   'juice',
#   'marmalade',
#   'orange',
#   'plu',
#   'spread',
#   'sugar',
#   'thick-cut',
#   'zest'},
#  {'blueberrie',
#   'cinnamon',
#   'extract',
#   'flour',
#   'low-fat',
#   'milk',
#   'natural',
#   'nielsen-massey',
#   'oil',
#   'plu',
#   'powder',
#   'vanilla',
#   'yogurt'},
#  {'cheese',
#   'demerara',
#   'fat',
#   'flour',
#   'gluten-free',
#   'hazelnut',
#   'les',
#   'nutella',
#   'oil',
#   'powder',
#   'soft',
#   'sugar',
#   'sunflower'},
#  {'asda',
#   'bean',
#   'butter',
#   'can',
#   'chorizo',
#   'clove',
#   'cornflour',
#   'garlic',
#   'orange',
#   'rosemary',
#   'sprig',
#   'stock',
#   'thigh'},
#  {'asda',
#   'butter',
#   'cardamom',
#   'caster',
#   'chocolate',
#   'coconut',
#   'decorate',
#   'flour',
#   'milk',
#   'mini',
#   'orange',
#   'sugar',
#   'zest'},
#  {'bacon',
#   'best',
#   'butter',
#   'edward',
#   'flour',
#   'mari',
#   'oil',
#   'piper',
#   'plu',
#   'potatoe',
#   'salad',
#   'serve',
#   'sunfower'},
#  {'asda',
#   'chilli',
#   'ketchup',
#   'kg',
#   'pack',
#   'pork',
#   'redcurrant',
#   'rib',
#   'sauce',
#   'smart',
#   'sweet',
#   'vinegar',
#   'wine'},
#  {'barley',
#   'cabbage',
#   'carrot',
#   'cube',
#   'homemade',
#   'leek',
#   'leftover',
#   'made',
#   'oil',
#   'onion',
#   'pearl',
#   'savoy',
#   'stock'},
#  {'alpen',
#   'cinnamon',
#   'favourite',
#   'flour',
#   'honey',
#   'jam',
#   'milk',
#   'mum’',
#   'plu',
#   'powder',
#   'serve',
#   'thousand',
#   'top'},
#  {'butter',
#   'caster',
#   'colour',
#   'dr',
#   'extract',
#   'flour',
#   'food',
#   'gel',
#   'oetker',
#   'royal',
#   'sugar',
#   'vanilla',
#   'whitworth'},
#  {'asparagu',
#   'beaten',
#   'bunch',
#   'butter',
#   'cheese',
#   'flour',
#   'free-range',
#   'frozen',
#   'gorgonzola',
#   'jus-rol',
#   'mascarpone',
#   'pastry',
#   'puff'},
#  {'asda',
#   'cajun',
#   'deep',
#   'fat',
#   'flour',
#   'fryer',
#   'ketchup',
#   'milk',
#   'oil',
#   'onion',
#   'serve',
#   'tomato',
#   'yolk'},
#  {'anise',
#   'butter',
#   'dill',
#   'fillet',
#   'lemon',
#   'parsley',
#   'peppercorn',
#   'salmon',
#   'sprig',
#   'star',
#   'vinegar',
#   'wine',
#   'yolk'},
#  {'brioche',
#   'butter',
#   'free-range',
#   'fruit',
#   'ham',
#   'hollandaise',
#   'juice',
#   'loaf',
#   'mug',
#   'sauce',
#   'serve',
#   'slice',
#   'tea'},
#  {'apricot',
#   'caster',
#   'crème',
#   'flour',
#   'fraîche',
#   'milk',
#   'oil',
#   'peache',
#   'plu',
#   'serve',
#   'sugar',
#   'sunflower',
#   'wholemeal'},
#  {'butter',
#   'caster',
#   'chosen',
#   'extract',
#   'flour',
#   'jam',
#   'milk',
#   'oil',
#   'raspberry',
#   'seedles',
#   'sugar',
#   'sunflower',
#   'vanilla'},
#  {'breast',
#   'butcher',
#   'ciabatta',
#   'fillet',
#   'green',
#   'loaf',
#   'oil',
#   'olive',
#   'onion',
#   'pesto',
#   'rocket',
#   'tomatoe',
#   'wild'},
#  {'all-butter',
#   'chunky',
#   'cranberry',
#   'dash',
#   'happy',
#   'hard',
#   'milk',
#   'pastry',
#   'pork',
#   'puff',
#   'sauce',
#   'sausage',
#   'skin'},
#  {'balsamic',
#   'chilli',
#   'dark',
#   'flake',
#   'honey',
#   'ketchup',
#   'pack',
#   'sauce',
#   'soy',
#   'sweet',
#   'tomato',
#   'vinegar',
#   'worcestershire'},
#  {'beaten',
#   'beetroot',
#   'carrot',
#   'coriander',
#   'cumin',
#   'flour',
#   'mint',
#   'oil',
#   'onion',
#   'salad',
#   'serve',
#   'vegetable',
#   'yogurt'},
#  {'asda',
#   'baker',
#   'bread',
#   'brown',
#   'butter',
#   'dollop',
#   'free-range',
#   'gold',
#   'ketchup',
#   'milk',
#   'mushroom',
#   'sauce',
#   'slice'},
#  {'caster',
#   'dust',
#   'essence',
#   'flour',
#   'greek',
#   'juice',
#   'lemon',
#   'oil',
#   'style',
#   'sugar',
#   'vanilla',
#   'yogurt',
#   'zest'},
#  {'almond',
#   'asda',
#   'bean',
#   'beaten',
#   'breadcrumb',
#   'flour',
#   'green',
#   'lemon',
#   'mustard',
#   'optional',
#   'pack',
#   'powder',
#   'zest'},
#  {'apple',
#   'bramley',
#   'caster',
#   'cream',
#   'decorate',
#   'double',
#   'juice',
#   'lemon',
#   'mint',
#   'piece',
#   'sprig',
#   'sugar',
#   'zest'},
#  {'allspice',
#   'asda',
#   'back',
#   'bacon',
#   'beaten',
#   'british',
#   'butter',
#   'fat',
#   'flour',
#   'good',
#   'hot',
#   'loin',
#   'made',
#   'onion',
#   'pack',
#   'pastry',
#   'piece',
#   'pinch',
#   'plu',
#   'pork',
#   'rasher',
#   'ready',
#   'sage',
#   'shortcrust',
#   'steak',
#   'stock',
#   'thin'},
#  {'breadcrumb',
#   'chive',
#   'courgette',
#   'cream',
#   'firm',
#   'flour',
#   'fry',
#   'litre',
#   'oil',
#   'panko',
#   'parmesan',
#   'sour',
#   'vegetable'},
#  {'blueberrie',
#   'butter',
#   'caster',
#   'custard',
#   'extract',
#   'milk',
#   'plu',
#   'pure',
#   'raspberrie',
#   'serve',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'caster',
#   'chocolate',
#   'cornflour',
#   'cream',
#   'extract',
#   'golden',
#   'halve',
#   'juice',
#   'lemon',
#   'milk',
#   'sugar',
#   'vanila',
#   'walnut'},
#  {'blackberrie',
#   'caramel',
#   'caster',
#   'cream',
#   'free-range',
#   'plu',
#   'pod',
#   'pot',
#   'single',
#   'size',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'butter',
#   'caster',
#   'cocoa',
#   'flour',
#   'milk',
#   'mini',
#   'orange',
#   'pack',
#   'plu',
#   'powder',
#   'self',
#   'sugar',
#   'zest'},
#  {'caster',
#   'chocolate',
#   'cocoa',
#   'dark',
#   'decorate',
#   'flour',
#   'juice',
#   'orange',
#   'pastry',
#   'puff',
#   'ready-made',
#   'solid',
#   'sugar'},
#  {'almond',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'dark',
#   'free-range',
#   'juice',
#   'orange',
#   'plu',
#   'solid',
#   'sugar',
#   'zest'},
#  {'anchovy',
#   'asda',
#   'bacon',
#   'bread',
#   'breast',
#   'ciabatta',
#   'clove',
#   'dijon',
#   'dry',
#   'fillet',
#   'garlic',
#   'head',
#   'heart',
#   'lettuce',
#   'mustard',
#   'oak',
#   'oil',
#   'olive',
#   'pack',
#   'parmesan',
#   'rasher',
#   'romaine',
#   'special',
#   'streaky',
#   'water',
#   'wine',
#   'yolk'},
#  {'asda',
#   'breast',
#   'can',
#   'coconut',
#   'coriander',
#   'corn',
#   'fillet',
#   'fish',
#   'juice',
#   'kit',
#   'lime',
#   'mangetout',
#   'milk',
#   'nam',
#   'noodle',
#   'pack',
#   'pepper',
#   'piece',
#   'pla',
#   'pouch',
#   'sauce',
#   'soy',
#   'special',
#   'stock',
#   'thai',
#   'turmeric',
#   'zest'},
#  {'arrowroot',
#   'biscuit',
#   'butter',
#   'caster',
#   'cheese',
#   'cream',
#   'digestive',
#   'essence',
#   'rhubarb',
#   'sour',
#   'sugar',
#   'vanilla',
#   'yorkshire'},
#  {'butter',
#   'cayenne',
#   'cheddar',
#   'cheese',
#   'courgette',
#   'dry',
#   'flour',
#   'free-range',
#   'mature',
#   'milk',
#   'mustard',
#   'powder',
#   'salt'},
#  {'asda',
#   'butter',
#   'caster',
#   'flour',
#   'free-range',
#   'juice',
#   'marmalade',
#   'orange',
#   'plu',
#   'powder',
#   'special',
#   'sugar',
#   'zest'},
#  {'asda',
#   'butter',
#   'caster',
#   'finelt',
#   'flour',
#   'free-range',
#   'juice',
#   'lemon',
#   'lime',
#   'milk',
#   'plu',
#   'sugar',
#   'zest'},
#  {'beaten',
#   'butter',
#   'caster',
#   'choice',
#   'flour',
#   'milk',
#   'pinch',
#   'powder',
#   'salt',
#   'self',
#   'sprinkle',
#   'strawberry',
#   'sugar'},
#  {'beaten',
#   'blackberrie',
#   'brown',
#   'butter',
#   'caster',
#   'cheese',
#   'cornflour',
#   'flour',
#   'light',
#   'milk',
#   'plu',
#   'soft',
#   'sugar'},
#  {'broken',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'dark',
#   'flour',
#   'piece',
#   'plu',
#   'powder',
#   'solid',
#   'sugar',
#   'yolk'},
#  {'caster',
#   'colour',
#   'cornflour',
#   'cream',
#   'double',
#   'green',
#   'optional',
#   'professional',
#   'strawberrie',
#   'sugar',
#   'top',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'beansprout',
#   'beaten',
#   'brown',
#   'cayenne',
#   'chilli',
#   'coriander',
#   'dry',
#   'flake',
#   'frozen',
#   'groundnut',
#   'juice',
#   'lime',
#   'noodle',
#   'oil',
#   'onion',
#   'optional',
#   'peanut',
#   'piece',
#   'plu',
#   'quorn',
#   'roast',
#   'sauce',
#   'soy',
#   'style',
#   'sugar',
#   'zest'},
#  {'cheddar',
#   'cheese',
#   'chive',
#   'edward',
#   'ham',
#   'mari',
#   'milk',
#   'oil',
#   'piper',
#   'potatoe',
#   'sunflower',
#   'sweetcorn',
#   'thick-cut'},
#  {'beaten',
#   'breadcrumb',
#   'clove',
#   'coriander',
#   'cornflour',
#   'cube',
#   'curry',
#   'flour',
#   'garam',
#   'garlic',
#   'ketchup',
#   'masala',
#   'mild',
#   'oil',
#   'onion',
#   'optional',
#   'powder',
#   'rice',
#   'sauce',
#   'serve',
#   'soy',
#   'steak',
#   'stock',
#   'tomato',
#   'turkey',
#   'vegetable',
#   'water',
#   'wholemeal'},
#  {'asda',
#   'balsamic',
#   'bite-size',
#   'breast',
#   'chillie',
#   'corn',
#   'cornflour',
#   'fillet',
#   'ginger',
#   'hot',
#   'mushroom',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'pepper',
#   'piece',
#   'root',
#   'sauce',
#   'shiitake',
#   'skinles',
#   'snap',
#   'soy',
#   'special',
#   'stock',
#   'sugar',
#   'sunflower',
#   'vinegar'},
#  {'beaten',
#   'breadcrumb',
#   'breast',
#   'butter',
#   'cal',
#   'drumstick',
#   'flavour',
#   'frylight',
#   'garlic',
#   'granule',
#   'herb',
#   'ketchup',
#   'mari',
#   'mustard',
#   'oil',
#   'olive',
#   'onion',
#   'paprika',
#   'piece',
#   'piper',
#   'potatoe',
#   'powder',
#   'sauce',
#   'serve',
#   'skin',
#   'spray',
#   'wedge',
#   'worcestershire'},
#  {'asda',
#   'beaten',
#   'breast',
#   'broccoli',
#   'chestnut',
#   'cornflour',
#   'crème',
#   'cube',
#   'fat',
#   'fillet',
#   'flour',
#   'fraîche',
#   'free',
#   'herb',
#   'leek',
#   'made',
#   'mushroom',
#   'oil',
#   'pastry',
#   'piece',
#   'potatoe',
#   'range',
#   'ready',
#   'serve',
#   'shortcrust',
#   'skin',
#   'stock',
#   'sunflower'},
#  {'apricot',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'food',
#   'free-range',
#   'jam',
#   'milk',
#   'plu',
#   'powder',
#   'ready-to-roll',
#   'sugar',
#   'vanilla'},
#  {'butter',
#   'carrot',
#   'cream',
#   'double',
#   'juice',
#   'light',
#   'orange',
#   'pot',
#   'potato',
#   'shallot',
#   'stock',
#   'sugar',
#   'vegetable',
#   'zest'},
#  {'bacon',
#   'basil',
#   'cheese',
#   'clove',
#   'cod',
#   'cream',
#   'fillet',
#   'garlic',
#   'haddock',
#   'light',
#   'norwegian',
#   'parmesan',
#   'skin',
#   'tagliatelle'},
#  {'beaten',
#   'clove',
#   'cumin',
#   'fillet',
#   'garlic',
#   'leaf',
#   'oil',
#   'olive',
#   'pack',
#   'pastry',
#   'puff',
#   'salmon',
#   'slice',
#   'spinach'},
#  {'beaten',
#   'bunch',
#   'butter',
#   'courgette',
#   'creme',
#   'fillet',
#   'fraiche',
#   'haddock',
#   'parsley',
#   'pepper',
#   'potatoe',
#   'salmon',
#   'serve',
#   'skinles'},
#  {'bicarbonate',
#   'brown',
#   'butter',
#   'caster',
#   'cream',
#   'crunchy',
#   'ice',
#   'peanut',
#   'serve',
#   'soda',
#   'soft',
#   'strawberry',
#   'sugar',
#   'walnut'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'cream',
#   'decorate',
#   'double',
#   'flour',
#   'juice',
#   'lemon',
#   'milk',
#   'plu',
#   'ramekin',
#   'sugar',
#   'zest'},
#  {'apricot',
#   'caster',
#   'chocolate',
#   'cider',
#   'cream',
#   'dark',
#   'double',
#   'drop',
#   'extract',
#   'hazelnut',
#   'ready-to-eat',
#   'sugar',
#   'vanilla',
#   'vinegar'},
#  {'asda',
#   'bean',
#   'beaten',
#   'butter',
#   'can',
#   'cheese',
#   'flageolet',
#   'flour',
#   'leek',
#   'mushroom',
#   'pastry',
#   'pot',
#   'puff',
#   'sauce'},
#  {'butter',
#   'cayenne',
#   'cheddar',
#   'flour',
#   'good',
#   'mature',
#   'mustard',
#   'parmesan',
#   'pinch',
#   'plu',
#   'poppy',
#   'powder',
#   'salt',
#   'sesame'},
#  {'almond',
#   'beaten',
#   'butter',
#   'caster',
#   'extract',
#   'free-range',
#   'juice',
#   'orange',
#   'plu',
#   'powder',
#   'semolina',
#   'sugar',
#   'vanilla',
#   'zest'},
#  {'back',
#   'bacon',
#   'beaten',
#   'breadcrumb',
#   'butter',
#   'courgette',
#   'free-range',
#   'lean',
#   'lengthway',
#   'mushroom',
#   'oil',
#   'olive',
#   'onion',
#   'parsley'},
#  {'back',
#   'bacon',
#   'bean',
#   'bread',
#   'crusty',
#   'free-range',
#   'mushroom',
#   'oil',
#   'pork',
#   'rasher',
#   'sausage',
#   'serve',
#   'sunflower',
#   'tomatoe'},
#  {'allspice',
#   'almond',
#   'cashew',
#   'caster',
#   'cayenne',
#   'chilli',
#   'cumin',
#   'macadamia',
#   'nut',
#   'pecan',
#   'powder',
#   'raw',
#   'salt',
#   'sugar'},
#  {'almond',
#   'asda',
#   'extract',
#   'honey',
#   'oil',
#   'pack',
#   'pastry',
#   'peache',
#   'ready',
#   'ricotta',
#   'shortcrust',
#   'sprig',
#   'thyme',
#   'vanilla'},
#  {'broccoli',
#   'butter',
#   'cheddar',
#   'cheese',
#   'creme',
#   'fraiche',
#   'half-fat',
#   'mature',
#   'milk',
#   'nutmeg',
#   'onion',
#   'pepper',
#   'potatoe',
#   'sweet'},
#  {'broccoli',
#   'butter',
#   'can',
#   'cheddar',
#   'fillet',
#   'floret',
#   'flour',
#   'mature',
#   'milk',
#   'oil',
#   'pack',
#   'salmon',
#   'sunflower',
#   'sweetcorn'},
#  {'asda',
#   'butter',
#   'can',
#   'chunk',
#   'coconut',
#   'flour',
#   'golden',
#   'honey',
#   'orange',
#   'pineapple',
#   'plu',
#   'powder',
#   'well',
#   'zest'},
#  {'almond',
#   'asda',
#   'caster',
#   'clementine',
#   'decorate',
#   'dr',
#   'flour',
#   'free',
#   'fruit',
#   'gluten',
#   'oetker',
#   'powder',
#   'satsuma',
#   'sugar'},
#  {'bone',
#   'bulb',
#   'butcher',
#   'flour',
#   'garlic',
#   'garnish',
#   'lamb',
#   'leg',
#   'pack',
#   'plu',
#   'rosemary',
#   'salt',
#   'serve',
#   'sprig'},
#  {'berrie',
#   'brioche',
#   'chocolate',
#   'cinnamon',
#   'extract',
#   'milk',
#   'oil',
#   'olive',
#   'optional',
#   'pinch',
#   'sauce',
#   'serve',
#   'slice',
#   'vanilla'},
#  {'almond',
#   'asda',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'free-range',
#   'juice',
#   'orange',
#   'plu',
#   'powder',
#   'special',
#   'sugar',
#   'zest'},
#  {'almond',
#   'asda',
#   'blackberrie',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'free-range',
#   'lemon',
#   'milk',
#   'special',
#   'sugar',
#   'vanilla',
#   'zest'},
#  {'asda',
#   'cake',
#   'caster',
#   'cherry',
#   'chocolate',
#   'conserve',
#   'cream',
#   'ice',
#   'madeira',
#   'scoop',
#   'slice',
#   'special',
#   'sugar',
#   'thick'},
#  {'all-butter',
#   'almond',
#   'basil',
#   'butter',
#   'caster',
#   'dust',
#   'handful',
#   'jam',
#   'pastry',
#   'peache',
#   'plu',
#   'shortcrust',
#   'strawberry',
#   'sugar'},
#  {'asda',
#   'asparagu',
#   'beaten',
#   'butter',
#   'cheese',
#   'fat',
#   'frozen',
#   'full',
#   'parmesan',
#   'pastry',
#   'puff',
#   'sheet',
#   'smart',
#   'soft'},
#  {'almond',
#   'beaten',
#   'butter',
#   'caster',
#   'cinnamon',
#   'currant',
#   'glaze',
#   'nutmeg',
#   'pastry',
#   'peel',
#   'plu',
#   'puff',
#   'sprinkle',
#   'sugar'},
#  {'bag',
#   'blue',
#   'butter',
#   'cheese',
#   'cream',
#   'double',
#   'flour',
#   'free-range',
#   'leaf',
#   'milk',
#   'mushroom',
#   'nutmeg',
#   'parsley',
#   'spinach'},
#  {'almond',
#   'apricot',
#   'butter',
#   'case',
#   'caster',
#   'essence',
#   'flour',
#   'jam',
#   'pastry',
#   'pear',
#   'ripe',
#   'smooth',
#   'special',
#   'sugar'},
#  {'asda',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'food',
#   'free-range',
#   'milk',
#   'pearl',
#   'posh',
#   'powder',
#   'sprinkle',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'basil',
#   'bunch',
#   'clove',
#   'garlic',
#   'oil',
#   'olive',
#   'pasta',
#   'penne',
#   'special',
#   'sprig',
#   'thyme',
#   'tomatoe',
#   'tomkin'},
#  {'blue',
#   'butter',
#   'cheese',
#   'cream',
#   'flour',
#   'free-range',
#   'leek',
#   'lengthway',
#   'little',
#   'pastry',
#   'ready-made',
#   'roquefort',
#   'shortcrust',
#   'single'},
#  {'barley',
#   'breast',
#   'butter',
#   'carrot',
#   'celery',
#   'fillet',
#   'leek',
#   'oil',
#   'olive',
#   'pearl',
#   'potato',
#   'stick',
#   'stock',
#   'thyme'},
#  {'almond',
#   'caster',
#   'chocolate',
#   'chosen',
#   'cocoa',
#   'cream',
#   'dark',
#   'date',
#   'double',
#   'green',
#   'organic',
#   'raspberrie',
#   'solid',
#   'sugar'},
#  {'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'double',
#   'dr',
#   'dust',
#   'giant',
#   'oetker',
#   'plu',
#   'powder',
#   'raspberrie',
#   'star',
#   'sugar'},
#  {'bacon',
#   'butter',
#   'cinnamon',
#   'cream',
#   'maple',
#   'nutmeg',
#   'optional',
#   'panettone',
#   'plu',
#   'rasher',
#   'single',
#   'streaky',
#   'sugar',
#   'syrup'},
#  {'butter',
#   'cauliflower',
#   'cheddar',
#   'cheese',
#   'cream',
#   'dijon',
#   'double',
#   'floret',
#   'flour',
#   'mature',
#   'milk',
#   'mustard',
#   'plu',
#   'weight'},
#  {'apple',
#   'caster',
#   'cheese',
#   'cream',
#   'custard',
#   'ice',
#   'juice',
#   'pastry',
#   'puff',
#   'rhubarb',
#   'serve',
#   'soft',
#   'sugar',
#   'yolk'},
#  {'blueberrie',
#   'butter',
#   'caster',
#   'crème',
#   'flour',
#   'fraîche',
#   'milk',
#   'oil',
#   'peanut',
#   'powder',
#   'serve',
#   'smooth',
#   'strawberrie',
#   'sugar'},
#  {'asda',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'dark',
#   'milk',
#   'organic',
#   'pod',
#   'single',
#   'solid',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'asda',
#   'bacon',
#   'butter',
#   'cayenne',
#   'cheddar',
#   'colman',
#   'flour',
#   'leek',
#   'mature',
#   'milk',
#   'mustard',
#   'pepper',
#   'powder',
#   'rasher'},
#  {'caster',
#   'cream',
#   'jam',
#   'milk',
#   'piece',
#   'plu',
#   'pod',
#   'raspberry',
#   'rhubarb',
#   'seedles',
#   'single',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'asda',
#   'caster',
#   'cream',
#   'double',
#   'drop',
#   'extract',
#   'flour',
#   'free-range',
#   'nut',
#   'pistachio',
#   'powder',
#   'strawberrie',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'bacon',
#   'beef',
#   'beetroot',
#   'can',
#   'free-range',
#   'gherkin',
#   'oil',
#   'onion',
#   'parsley',
#   'potatoe',
#   'rasher',
#   'streaky',
#   'sunflower'},
#  {'breast',
#   'chunk',
#   'courgette',
#   'honey',
#   'juice',
#   'lemon',
#   'oil',
#   'onion',
#   'pepper',
#   'plu',
#   'sprig',
#   'sweetcorn',
#   'thyme',
#   'wedge'},
#  {'butter',
#   'cayenne',
#   'cheddar',
#   'cheese',
#   'dry',
#   'flour',
#   'mature',
#   'mustard',
#   'parmesan',
#   'pepper',
#   'piece',
#   'poppy',
#   'powder',
#   'sesame'},
#  {'almond',
#   'asda',
#   'beaten',
#   'bread',
#   'butter',
#   'clementine',
#   'cointreau',
#   'cream',
#   'double',
#   'dust',
#   'flour',
#   'satsuma',
#   'strong',
#   'sugar'},
#  {'breadcrumb',
#   'breast',
#   'fillet',
#   'frozen',
#   'oil',
#   'parmesan',
#   'pesto',
#   'plu',
#   'portion',
#   'potatoe',
#   'smart',
#   'sunflower',
#   'sweetcorn',
#   'wedge'},
#  {'caster',
#   'cheddar',
#   'flour',
#   'herb',
#   'mature',
#   'milk',
#   'oil',
#   'olive',
#   'oregano',
#   'piece',
#   'powder',
#   'shallot',
#   'sugar',
#   'tomatoe'},
#  {'butter',
#   'caster',
#   'chocolate',
#   'cornflour',
#   'cream',
#   'extract',
#   'flour',
#   'golden',
#   'milk',
#   'pinch',
#   'salt',
#   'sugar',
#   'syrup',
#   'vanilla'},
#  {'bay',
#   'breast',
#   'clove',
#   'fillet',
#   'garlic',
#   'honey',
#   'juice',
#   'lemon',
#   'light',
#   'oil',
#   'olive',
#   'sauce',
#   'soy',
#   'wedge'},
#  {'banana',
#   'butter',
#   'can',
#   'caramel',
#   'carnation',
#   'cream',
#   'cube',
#   'double',
#   'flour',
#   'free-range',
#   'milk',
#   'plu',
#   'sugar',
#   'yolk'},
#  {'asda',
#   'beaten',
#   'bicarbonate',
#   'butter',
#   'caster',
#   'cinnamon',
#   'flour',
#   'ginger',
#   'golden',
#   'pearl',
#   'posh',
#   'soda',
#   'sugar',
#   'syrup'},
#  {'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'dark',
#   'dash',
#   'flour',
#   'generou',
#   'handful',
#   'milk',
#   'powder',
#   'single',
#   'sugar'},
#  {'asda',
#   'beaten',
#   'breadcrumb',
#   'butter',
#   'edward',
#   'free-range',
#   'mari',
#   'oil',
#   'pack',
#   'parsley',
#   'piper',
#   'potatoe',
#   'salmon',
#   'sunflower'},
#  {'asda',
#   'beaten',
#   'butter',
#   'caster',
#   'cocoa',
#   'cream',
#   'extract',
#   'flour',
#   'little',
#   'powder',
#   'punnet',
#   'raspberrie',
#   'sugar',
#   'vanilla'},
#  {'butter',
#   'carrot',
#   'celery',
#   'chunk',
#   'clove',
#   'duck',
#   'flour',
#   'frozen',
#   'garlic',
#   'gravy',
#   'green',
#   'herb',
#   'leftover',
#   'mari',
#   'mixture',
#   'oil',
#   'olive',
#   'onion',
#   'parsnip',
#   'pea',
#   'piper',
#   'potatoe',
#   'purée',
#   'stick',
#   'stock',
#   'thyme',
#   'tomato',
#   'tomatoe',
#   'vine',
#   'yolk'},
#  {'banana',
#   'blueberrie',
#   'brown',
#   'flour',
#   'light',
#   'milk',
#   'oat',
#   'oil',
#   'porridge',
#   'powder',
#   'raspberrie',
#   'ripe',
#   'soft',
#   'sugar',
#   'sunflower'},
#  {'asda',
#   'caster',
#   'chocolate',
#   'cream',
#   'dark',
#   'double',
#   'flour',
#   'ginger',
#   'milk',
#   'mini',
#   'natural',
#   'pinch',
#   'powder',
#   'special',
#   'sugar'},
#  {'asda',
#   'can',
#   'caster',
#   'fat',
#   'fruit',
#   'full',
#   'greek',
#   'juice',
#   'lemon',
#   'peache',
#   'plu',
#   'raspberrie',
#   'sugar',
#   'yogurt',
#   'yolk'},
#  {'asda',
#   'beaten',
#   'cheese',
#   'fillet',
#   'free-range',
#   'oil',
#   'olive',
#   'pack',
#   'pastry',
#   'potatoe',
#   'puff',
#   'ready',
#   'serve',
#   'steak',
#   'stilton'},
#  {'back',
#   'bacon',
#   'beaten',
#   'butter',
#   'cabbage',
#   'edward',
#   'lean',
#   'mari',
#   'oil',
#   'onion',
#   'piper',
#   'potatoe',
#   'rasher',
#   'savoy',
#   'weight'},
#  {'apple',
#   'asda',
#   'brandy',
#   'butter',
#   'caster',
#   'cocoa',
#   'extract',
#   'flour',
#   'juice',
#   'macadamia',
#   'nut',
#   'plu',
#   'prune',
#   'sugar',
#   'vanilla'},
#  {'almond',
#   'apricot',
#   'asda',
#   'butter',
#   'can',
#   'caster',
#   'drop',
#   'extract',
#   'flour',
#   'free-range',
#   'lemon',
#   'milk',
#   'special',
#   'sugar',
#   'zest'},
#  {'asda',
#   'beaten',
#   'brown',
#   'chunk',
#   'cinnamon',
#   'food',
#   'oil',
#   'pack',
#   'pastry',
#   'pumpkin',
#   'ready',
#   'roll',
#   'shortcrust',
#   'soft',
#   'sugar'},
#  {'asda',
#   'clove',
#   'coriander',
#   'fat',
#   'free',
#   'garlic',
#   'greek',
#   'handful',
#   'jar',
#   'oil',
#   'pepper',
#   'sauce',
#   'spicy',
#   'tomato',
#   'yoghurt'},
#  {'almond',
#   'biscuit',
#   'chocolate',
#   'cream',
#   'dark',
#   'double',
#   'drop',
#   'extract',
#   'raspberrie',
#   'sauce',
#   'serve',
#   'special',
#   'sugar',
#   'thin',
#   'vanilla'},
#  {'bean',
#   'cashew',
#   'chillie',
#   'choi',
#   'clove',
#   'garlic',
#   'ginger',
#   'green',
#   'oil',
#   'onion',
#   'pak',
#   'piece',
#   'sauce',
#   'soy',
#   'sunflower'},
#  {'asda',
#   'asparagu',
#   'balsamic',
#   'basil',
#   'bread',
#   'end',
#   'modena',
#   'oil',
#   'onion',
#   'optional',
#   'serve',
#   'tomatoe',
#   'vine',
#   'vinegar',
#   'woody'},
#  {'butter',
#   'caster',
#   'cold',
#   'core',
#   'cornflour',
#   'flour',
#   'free',
#   'juice',
#   'lemon',
#   'pineapple',
#   'plu',
#   'range',
#   'skin',
#   'sugar',
#   'yolk'},
#  {'asda',
#   'caster',
#   'cream',
#   'double',
#   'dust',
#   'flour',
#   'free-range',
#   'juice',
#   'lemon',
#   'pastry',
#   'ready',
#   'roll',
#   'shortcrust',
#   'sugar',
#   'zest'},
#  {'asda',
#   'butter',
#   'cayenne',
#   'cheddar',
#   'dry',
#   'flour',
#   'mature',
#   'mustard',
#   'pepper',
#   'pinch',
#   'poppy',
# ...
#   'bright',
#   'butcher',
#   'carrot',
#   'cheese',
#   'colour',
#   'crudite',
#   'decoration',
#   'dijon',
#   'dr',
#   'fat',
#   'food',
#   'gel',
#   'gherkin',
#   'mince',
#   'mustard',
#   'oetker',
#   'orange',
#   'pepper',
#   'rest',
#   'rocket',
#   'roll',
#   'sauce',
#   'slice',
#   'top',
#   'warburton',
#   'worcestershire'},
#  {'asda',
#   'breast',
#   'cabbage',
#   'carrot',
#   'chilli',
#   'clove',
#   'crusty',
#   'fry',
#   'garlic',
#   'ginger',
#   'growers’',
#   'kickin’',
#   'korean',
#   'lettuce',
#   'matchstick',
#   'oil',
#   'onion',
#   'pack',
#   'powder',
#   'radishe',
#   'roll',
#   'root',
#   'sauce',
#   'savoy',
#   'sesame',
#   'stir',
#   'sugar',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'bottom',
#   'breast',
#   'butcher’',
#   'celery',
#   'chunk',
#   'coarse',
#   'cornflour',
#   'crème',
#   'fat',
#   'fillet',
#   'fraiche',
#   'french',
#   'garnish',
#   'grain',
#   'leek',
#   'les',
#   'mini',
#   'mustard',
#   'oil',
#   'olive',
#   'optional',
#   'parsley',
#   'potato',
#   'serve',
#   'slice',
#   'stick',
#   'stock',
#   'sweet'},
#  {'amoy',
#   'bean',
#   'broccoli',
#   'can',
#   'chestnut',
#   'chilli',
#   'chosen',
#   'clove',
#   'floret',
#   'freshnes',
#   'frozen',
#   'garlic',
#   'ginger',
#   'green',
#   'kidney',
#   'mushroom',
#   'noodle',
#   'oil',
#   'pack',
#   'piece',
#   'plu',
#   'pumpkin',
#   'root',
#   'salt',
#   'sauce',
#   'serve',
#   'smart',
#   'soy',
#   'sunflower'},
#  {'aubergine',
#   'bay',
#   'butternut',
#   'chilli',
#   'chunk',
#   'coconut',
#   'coriander',
#   'drumstick',
#   'hot',
#   'juice',
#   'lime',
#   'mango',
#   'milk',
#   'mustard',
#   'oil',
#   'onion',
#   'optional',
#   'papaya',
#   'paste',
#   'piece',
#   'potatoe',
#   'reduced-fat',
#   'ripe',
#   'rum',
#   'squash',
#   'tamarind',
#   'thigh',
#   'turmeric',
#   'waxy'},
#  {'asda',
#   'bicarbonate',
#   'brown',
#   'butter',
#   'carrot',
#   'cheese',
#   'coconut',
#   'creamy',
#   'drop',
#   'extract',
#   'fat',
#   'flour',
#   'full',
#   'juice',
#   'lemon',
#   'light',
#   'oil',
#   'orange',
#   'pecan',
#   'soda',
#   'soft',
#   'special',
#   'spice',
#   'sugar',
#   'sultana',
#   'sunflower',
#   'vanilla',
#   'weight',
#   'zest'},
#  {'asda',
#   'banana',
#   'bar',
#   'caster',
#   'chocolate',
#   'dairy',
#   'dark',
#   'extract',
#   'flour',
#   'free',
#   'free-range',
#   'gluten',
#   'gluten-free',
#   'gum',
#   'kinnerton',
#   'luxury',
#   'make',
#   'nut',
#   'pecan',
#   'powder',
#   'ripe',
#   'spread',
#   'sugar',
#   'thi',
#   'vanilla',
#   'vitalite',
#   'weight',
#   'well',
#   'xantham'},
#  {'asda',
#   'boneles',
#   'british',
#   'butcher’',
#   'cashew',
#   'chilli',
#   'clove',
#   'coleslaw',
#   'crunchy',
#   'fillet',
#   'garlic',
#   'green',
#   'grower’',
#   'jerk',
#   'juice',
#   'kit',
#   'lime',
#   'mango',
#   'mint',
#   'nut',
#   'onion',
#   'pepper',
#   'piece',
#   'purée',
#   'rice',
#   'serve',
#   'sweet',
#   'thigh',
#   'tomato'},
#  {'asparagu',
#   'bean',
#   'british',
#   'butcher’',
#   'can',
#   'carrot',
#   'coconut',
#   'coriander',
#   'cornflour',
#   'curry',
#   'fat',
#   'kidney',
#   'milk',
#   'naan',
#   'oil',
#   'onion',
#   'pack',
#   'paste',
#   'pepper',
#   'radishe',
#   'rice',
#   'serve',
#   'spear',
#   'spinach',
#   'stock',
#   'sunflower',
#   'thigh',
#   'vegetable',
#   'water'},
#  {'balsamic',
#   'chestnut',
#   'chilli',
#   'chosen',
#   'corn',
#   'cube',
#   'ginger',
#   'hot',
#   'juice',
#   'leftover',
#   'light',
#   'lime',
#   'made',
#   'mushroom',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'plu',
#   'sauce',
#   'serve',
#   'soy',
#   'stock',
#   'turkey',
#   'udon',
#   'vegetable',
#   'vinegar',
#   'wedge',
#   'zest'},
#  {'broken',
#   'brown',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'dark',
#   'decorate',
#   'double',
#   'dr',
#   'drop',
#   'extract',
#   'flat-leaf',
#   'flora',
#   'flour',
#   'food',
#   'gel',
#   'light',
#   'milk',
#   'oetker',
#   'parsley',
#   'powder',
#   'soft',
#   'spread',
#   'sprig',
#   'square',
#   'sugar',
#   'tube',
#   'vanilla'},
#  {'asda',
#   'belt',
#   'biscuit',
#   'butter',
#   'caster',
#   'choco',
#   'chocolate',
#   'chosen',
#   'coconut',
#   'crunchie',
#   'drop',
#   'extract',
#   'finger',
#   'flour',
#   'food',
#   'fruittella',
#   'milk',
#   'pack',
#   'pink',
#   'plu',
#   'pot',
#   'powder',
#   'rainbow',
#   'ready',
#   'roll',
#   'rowntree’',
#   'sprinkle',
#   'sugar',
#   'tot',
#   'vanilla'},
#  {'asda',
#   'bay',
#   'bean',
#   'bread',
#   'can',
#   'cannellini',
#   'carton',
#   'chosen',
#   'clove',
#   'crusty',
#   'fat',
#   'flat',
#   'garlic',
#   'haricot',
#   'italian',
#   'leaf',
#   'mustard',
#   'oil',
#   'olive',
#   'onion',
#   'pack',
#   'parsley',
#   'passata',
#   'pork',
#   'sausage',
#   'serve',
#   'stock',
#   'vinegar',
#   'wholegrain',
#   'wine'},
#  {'bake',
#   'biscuit',
#   'blue',
#   'butter',
#   'caster',
#   'chosen',
#   'colour',
#   'create',
#   'digestive',
#   'dr',
#   'dust',
#   'extract',
#   'flour',
#   'golden',
#   'green',
#   'jam',
#   'marzipan',
#   'milk',
#   'oetkerregal-ice',
#   'pack',
#   'plu',
#   'powder',
#   'raspberry',
#   'ready',
#   'roll',
#   'sugar',
#   'tube',
#   'vanilla',
#   'water',
#   'yougreat'},
#  {'baguette',
#   'bird',
#   'carrot',
#   'caster',
#   'chilli',
#   'coriander',
#   'cucumber',
#   'day-old',
#   'eye',
#   'fish',
#   'gem',
#   'halve',
#   'juice',
#   'leftover',
#   'lettuce',
#   'lime',
#   'little',
#   'mint',
#   'oil',
#   'piece',
#   'radishe',
#   'rice',
#   'sauce',
#   'serve',
#   'shallot',
#   'sugar',
#   'sweet',
#   'torn',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'avocado',
#   'bacon',
#   'bag',
#   'balsamic',
#   'bitesize',
#   'bread',
#   'breast',
#   'cherry',
#   'coarse',
#   'crusty',
#   'fillet',
#   'grain',
#   'honey',
#   'juice',
#   'leaf',
#   'lemon',
#   'mini',
#   'mustard',
#   'oil',
#   'olive',
#   'pack',
#   'piece',
#   'rasher',
#   'ripe',
#   'salad',
#   'serve',
#   'streaky',
#   'tomatoe',
#   'vinegar'},
#  {'almond',
#   'apricot',
#   'brandy',
#   'brown',
#   'butter',
#   'cherrie',
#   'cranberrie',
#   'dr',
#   'flour',
#   'glacé',
#   'jam',
#   'lemon',
#   'marzipan',
#   'natural',
#   'oetker',
#   'orange',
#   'pack',
#   'pecan',
#   'plu',
#   'raisin',
#   'ready',
#   'regal-ice',
#   'roll',
#   'rum',
#   'seedles',
#   'soft',
#   'spice',
#   'sugar',
#   'sultana',
#   'zest'},
#  {'asda',
#   'basmati',
#   'breast',
#   'butcher',
#   'chosen',
#   'clove',
#   'coriander',
#   'curry',
#   'fat',
#   'fillet',
#   'free',
#   'frozen',
#   'garlic',
#   'greek',
#   'italian',
#   'madra',
#   'natural',
#   'oil',
#   'onion',
#   'optional',
#   'pack',
#   'paste',
#   'pea',
#   'piece',
#   'rice',
#   'serve',
#   'style',
#   'tomatoe',
#   'vegetable',
#   'yogurt'},
#  {'apricot',
#   'breast',
#   'can',
#   'chosen',
#   'cucumber',
#   'del',
#   'fat',
#   'fillet',
#   'free',
#   'grain',
#   'greek',
#   'juice',
#   'korma',
#   'lemon',
#   'light',
#   'long',
#   'mayonnaise',
#   'monte',
#   'onion',
#   'pack',
#   'paste',
#   'peach',
#   'purée',
#   'rice',
#   'sharwood’',
#   'slice',
#   'smart',
#   'style',
#   'tomato',
#   'yogurt'},
#  {'biscuit',
#   'butter',
#   'caster',
#   'cheese',
#   'chocolate',
#   'chosen',
#   'cocoa',
#   'cold',
#   'cornflour',
#   'cream',
#   'creme',
#   'decorate',
#   'digestive',
#   'double',
#   'extract',
#   'fat',
#   'fraiche',
#   'juice',
#   'les',
#   'light',
#   'orange',
#   'plu',
#   'powder',
#   'soft',
#   'special',
#   'sugar',
#   'terry',
#   'valencian',
#   'water',
#   'zest'},
#  {'arborio',
#   'asda',
#   'chorizo',
#   'chosen',
#   'clove',
#   'drumstick',
#   'eat',
#   'frozen',
#   'garlic',
#   'generou',
#   'green',
#   'hot',
#   'litre',
#   'oil',
#   'olive',
#   'onion',
#   'optional',
#   'pack',
#   'paella',
#   'paprika',
#   'pea',
#   'pepper',
#   'piece',
#   'pinch',
#   'ready',
#   'rice',
#   'saffron',
#   'seafood',
#   'stock',
#   'wine'},
#  {'avocado',
#   'bean',
#   'breast',
#   'can',
#   'chilli',
#   'chunk',
#   'concentrate',
#   'coriander',
#   'fajita',
#   'frozen',
#   'gem',
#   'good',
#   'juice',
#   'lemon',
#   'lettuce',
#   'lime',
#   'little',
#   'mexican',
#   'mix',
#   'oil',
#   'olive',
#   'onion',
#   'optional',
#   'ripe',
#   'schwartz',
#   'serve',
#   'style',
#   'torn',
#   'water',
#   'wedge'},
#  {'asda',
#   'bean',
#   'broad',
#   'chorizo',
#   'clove',
#   'frozen',
#   'garlic',
#   'green',
#   'hot',
#   'litre',
#   'live',
#   'mayonnaise',
#   'mussel',
#   'oil',
#   'olive',
#   'onion',
#   'pack',
#   'paella',
#   'paprika',
#   'pinche',
#   'prawn',
#   'raw',
#   'rice',
#   'saffron',
#   'serve',
#   'spanish',
#   'special',
#   'stock',
#   'thigh',
#   'tomatoe'},
#  {'asda',
#   'breast',
#   'bunch',
#   'butcher',
#   'can',
#   'carrot-',
#   'chilli',
#   'coriander',
#   'couscou',
#   'cube',
#   'cumin',
#   'flat',
#   'kg',
#   'leaf',
#   'made',
#   'mild',
#   'mince',
#   'napolina',
#   'oil',
#   'onion',
#   'paprika',
#   'parsley',
#   'pepper',
#   'powder',
#   'sold',
#   'stock',
#   'sultana',
#   'sunflower',
#   'tomatoe',
#   'turkey'},
#  {'butter',
#   'camp',
#   'case',
#   'caster',
#   'chicory',
#   'chocolate',
#   'cocoa',
#   'coffee',
#   'colour',
#   'cupcake',
#   'dark',
#   'dr',
#   'drop',
#   'esssence',
#   'extract',
#   'flour',
#   'food',
#   'gel',
#   'green',
#   'lime',
#   'milk',
#   'oetker',
#   'paper',
#   'plu',
#   'powder',
#   'room',
#   'solid',
#   'sugar',
#   'temperature',
#   'vanilla'},
#  {'almond',
#   'apple',
#   'asda',
#   'breast',
#   'chutney',
#   'coriander',
#   'corn',
#   'crème',
#   'cube',
#   'curry',
#   'dlsigny',
#   'fillet',
#   'fraîche',
#   'french',
#   'garnish',
#   'ginger',
#   'grape',
#   'greek',
#   'made',
#   'mango',
#   'oil',
#   'plu',
#   'pot',
#   'powder',
#   'purée',
#   'special',
#   'stock',
#   'style',
#   'sunflower',
#   'tomato',
#   'yogurt'},
#  {'beaten',
#   'butter',
#   'can',
#   'cayenne',
#   'cheddar',
#   'cranberry',
#   'dijon',
#   'flour',
#   'gammon',
#   'giant',
#   'green',
#   'ham',
#   'jus-rol',
#   'mature',
#   'milk',
#   'mustard',
#   'optional',
#   'pastry',
#   'piece',
#   'pinch',
#   'plu',
#   'ready-to-roll',
#   'roast',
#   'salt',
#   'sauce',
#   'shortcrust',
#   'sprig',
#   'sugar',
#   'sweetcorn',
#   'thyme',
#   'turkey'},
#  {'asda',
#   'bag',
#   'basil',
#   'beef',
#   'butcher',
#   'chilli',
#   'chive',
#   'clove',
#   'coriander',
#   'couscou',
#   'cucumber',
#   'fat',
#   'free',
#   'garlic',
#   'giant',
#   'lean',
#   'lemon',
#   'mince',
#   'mint',
#   'natural',
#   'onion',
#   'parsley',
#   'pesto',
#   'pomegranate',
#   'quinoa',
#   'steam',
#   'tomato',
#   'tortilla',
#   'wholemeal',
#   'yoghurt',
#   'zest'},
#  {'bird',
#   'breast',
#   'bunch',
#   'caster',
#   'chilli',
#   'cinnamon',
#   'clove',
#   'coriander',
#   'eye',
#   'fat',
#   'garam',
#   'garlic',
#   'ginger',
#   'greek',
#   'green',
#   'hot',
#   'juice',
#   'lemon',
#   'lime',
#   'masala',
#   'mint',
#   'oil',
#   'pinch',
#   'powder',
#   'skin',
#   'squeeze',
#   'stalk',
#   'sugar',
#   'thumb',
#   'vegetable',
#   'yogurt'},
#  {'asda',
#   'beansprout',
#   'breast',
#   'british',
#   'carrot',
#   'chilli',
#   'coriander',
#   'cucumber',
#   'fillet',
#   'ginger',
#   'grower’',
#   'iceberg',
#   'japan',
#   'jasmine',
#   'juice',
#   'katsu',
#   'lettuce',
#   'lime',
#   'mini',
#   'oil',
#   'pack',
#   'piece',
#   'rice',
#   'sauce',
#   'simmer',
#   'spice',
#   'sweet',
#   'taste',
#   'thai',
#   'vinegar',
#   'weight'},
#  {'beaten',
#   'brandy',
#   'breadcrumb',
#   'cherry',
#   'chive',
#   'chosen',
#   'cracker',
#   'cres',
#   'flour',
#   'gem',
#   'gherkin',
#   'lemon',
#   'little',
#   'lobster',
#   'marie',
#   'paprika',
#   'parsley',
#   'portion',
#   'prawn',
#   'rose',
#   'sauce',
#   'serve',
#   'shallot',
#   'special',
#   'spicy',
#   'splash',
#   'tail',
#   'tarragon',
#   'tomatoe',
#   'vodka',
#   'wedge'},
#  {'beef',
#   'butcher',
#   'can',
#   'cheddar',
#   'cherry',
#   'chosen',
#   'cream',
#   'fajita',
#   'guacamole',
#   'iceberg',
#   'jalapeño',
#   'lettuce',
#   'lime',
#   'mature',
#   'mix',
#   'oil',
#   'onion',
#   'pack',
#   'pepper',
#   'prime',
#   'recipe',
#   'salsa',
#   'schwartz',
#   'sirloin',
#   'spicy',
#   'steak',
#   'sweetcorn',
#   'tortilla',
#   'vegetable',
#   'wedge',
#   'weight',
#   'youhot'},
#  {'asda',
#   'bean',
#   'breast',
#   'carrot',
#   'chilli',
#   'chinese',
#   'clove',
#   'coriander',
#   'duck',
#   'fillet',
#   'garlic',
#   'garnish',
#   'ginger',
#   'honey',
#   'juice',
#   'leaf',
#   'lime',
#   'mangetout',
#   'oil',
#   'optional',
#   'pea',
#   'plu',
#   'sesame',
#   'skin',
#   'snap',
#   'sprig',
#   'sprout',
#   'stock',
#   'strip',
#   'sugar',
#   'sunflower',
#   'tamarind'},
#  {'brown',
#   'butter',
#   'buttercream',
#   'cake',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'colour',
#   'different',
#   'extract',
#   'flour',
#   'food',
#   'gel',
#   'gelatine',
#   'glaze',
#   'glucose',
#   'golden',
#   'good-quality',
#   'light',
#   'milk',
#   'mirror',
#   'oil',
#   'powder',
#   'self',
#   'semi',
#   'soft',
#   'star',
#   'sugar',
#   'sunflower',
#   'syrup',
#   'vanilla',
#   'yolk'},
#  {'almond',
#   'asda',
#   'bicarbonate',
#   'brown',
#   'butter',
#   'buttermilk',
#   'cherrie',
#   'cherry',
#   'chocolate',
#   'chosen',
#   'coast',
#   'cocoa',
#   'conserve',
#   'cream',
#   'dark',
#   'decorate',
#   'double',
#   'extract',
#   'flour',
#   'frozen',
#   'ivory',
#   'jar',
#   'light',
#   'morello',
#   'pack',
#   'powder',
#   'soda',
#   'soft',
#   'solid',
#   'special',
#   'sugar',
#   'vanilla'},
#  {'angel',
#   'apricot',
#   'beaten',
#   'bicarbonate',
#   'blue',
#   'brown',
#   'butter',
#   'cake',
#   'caster',
#   'cinnamon',
#   'cocoa',
#   'flour',
#   'ginger',
#   'golden',
#   'green',
#   'jam',
#   'light',
#   'mallow',
#   'milk',
#   'nutella',
#   'pack',
#   'plu',
#   'pot',
#   'powder',
#   'ready',
#   'roll',
#   'self',
#   'soda',
#   'soft',
#   'spice',
#   'sugar',
#   'syrup'},
#  {'bean',
#   'biscuit',
#   'butter',
#   'caster',
#   'chosen',
#   'coconut',
#   'cornflour',
#   'cream',
#   'decorate',
#   'digestive',
#   'extract',
#   'fat',
#   'fruit',
#   'full',
#   'italian',
#   'juice',
#   'lime',
#   'malibu',
#   'mango',
#   'mascarpone',
#   'mint',
#   'pack',
#   'pineapple',
#   'plu',
#   'pomegranate',
#   'slice',
#   'special',
#   'sugar',
#   'urban',
#   'vanilla',
#   'yolk',
#   'zest'},
#  {'asda',
#   'beansprout',
#   'blue',
#   'broccoli',
#   'brown',
#   'chilli',
#   'dragon',
#   'fish',
#   'floret',
#   'free-range',
#   'groundnut',
#   'juice',
#   'ketchup',
#   'lime',
#   'little',
#   'mushroom',
#   'noodle',
#   'oil',
#   'onion',
#   'ordinary',
#   'pack',
#   'peanut',
#   'plu',
#   'sauce',
#   'shiitake',
#   'special',
#   'sugar',
#   'sunflower',
#   'sweet',
#   'taste',
#   'thai',
#   'tomato'},
#  {'antony',
#   'asda',
#   'back',
#   'bacon',
#   'basil',
#   'beef',
#   'bread',
#   'carton',
#   'cube',
#   'free',
#   'free-range',
#   'fusilli',
#   'gluten',
#   'lean',
#   'mince',
#   'oil',
#   'olive',
#   'onion',
#   'pack',
#   'parsley',
#   'passata',
#   'pepper',
#   'roll',
#   'spaghetti',
#   'sprig',
#   'steak',
#   'stock',
#   'sugar',
#   'sweet',
#   'thompson',
#   'torn',
#   'worrall'},
#  {'asda',
#   'breast',
#   'brown',
#   'butcher’',
#   'cook',
#   'easy',
#   'fat-free',
#   'fillet',
#   'flat-leaf',
#   'gem',
#   'grain',
#   'greek-style',
#   'grower’',
#   'juice',
#   'lemon',
#   'lettuce',
#   'little',
#   'long',
#   'meli',
#   'mini',
#   'natural',
#   'oil',
#   'onion',
#   'parsley',
#   'pomegranate',
#   'quarter',
#   'rice',
#   'sauce',
#   'sesame',
#   'torn',
#   'yogurt',
#   'zest'},
#  {'asda',
#   'breast',
#   'brown',
#   'butter',
#   'can',
#   'chillie',
#   'coconut',
#   'coriander',
#   'crunchy',
#   'dark',
#   'fish',
#   'groundnut',
#   'juice',
#   'lime',
#   'milk',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'peanut',
#   'piece',
#   'plu',
#   'sauce',
#   'serve',
#   'soft',
#   'soy',
#   'steak',
#   'sugar',
#   'sunflower',
#   'thai',
#   'turkey',
#   'zest'},
#  {'bean',
#   'butcher',
#   'butter',
#   'can',
#   'carrot',
#   'carton',
#   'chosen',
#   'clove',
#   'cornflour',
#   'cube',
#   'cumberland',
#   'fat',
#   'garlic',
#   'hot',
#   'lea',
#   'oil',
#   'onion',
#   'pack',
#   'paprika',
#   'perrin',
#   'pork',
#   'potatoe',
#   'sauce',
#   'sausage',
#   'sprig',
#   'stock',
#   'sugar',
#   'sunflower',
#   'thyme',
#   'tomatoe',
#   'water',
#   'worcestershire'},
#  {'amoy',
#   'asda',
#   'bite-size',
#   'breast',
#   'carrot',
#   'chilli',
#   'cider',
#   'core',
#   'cornflour',
#   'fillet',
#   'honey',
#   'juice',
#   'lengthway',
#   'mangetout',
#   'oil',
#   'onion',
#   'orange',
#   'pack',
#   'pepper',
#   'piece',
#   'pineapple',
#   'rice',
#   'salt',
#   'sauce',
#   'serve',
#   'short',
#   'skin',
#   'soy',
#   'stick',
#   'strip',
#   'sunflower',
#   'sweet',
#   'vinegar'},
#  {'asda',
#   'blue',
#   'butler’',
#   'celery',
#   'cheese',
#   'chilli',
#   'chipotle',
#   'cider',
#   'clove',
#   'cream',
#   'dijon',
#   'farmhouse',
#   'fat',
#   'flake',
#   'garlic',
#   'honey',
#   'joint',
#   'juice',
#   'ketchup',
#   'lemon',
#   'les',
#   'light',
#   'mayonnaise',
#   'mustard',
#   'optional',
#   'parsley',
#   'sauce',
#   'special',
#   'stick',
#   'tip',
#   'tomato',
#   'vinegar',
#   'worcestershire'},
#  {'asda',
#   'breadcrumb',
#   'chip',
#   'cod',
#   'crisp',
#   'crumb',
#   'crème',
#   'flora',
#   'frozen',
#   'frâiche',
#   'good',
#   'lemon',
#   'loin',
#   'mari',
#   'mild',
#   'mint',
#   'oil',
#   'olive',
#   'original',
#   'pack',
#   'paprika',
#   'pea',
#   'pinch',
#   'piper',
#   'plu',
#   'potatoe',
#   'ready',
#   'reduced-fat',
#   'serve',
#   'sesame',
#   'thick',
#   'weight',
#   'zest'},
#  ...]

# %%
map(len, missings_ingredients)

# %% [markdown]
# ### Best Rated

# %%
import numpy as np
import pandas as pd
import csv
import bson
from bson.objectid import ObjectId

# %%
def best_rated(data=read_collection_as_df("ratings"), n=10):
    """
    Return top n recipes by maximum mean rating. In case of draw, then by minimum standard deviation rating.
    """
    # top rated
    data["rating"] = data["rating"].astype(float)
    recipe_rating_mean = data.groupby(['recipe_id'])['rating'].mean()
    recipe_rating_std = data.groupby(['recipe_id'])['rating'].std()
    recipe_rating = pd.concat([recipe_rating_mean, recipe_rating_std], axis=1)
    recipe_rating.columns=["mean", "std"]
    recs = recipe_rating.sort(["mean", "std"], ascending=[0,1])
    
    return list(map(ObjectId,list(recs.index.values)[:n]))
# Out:
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)

# %%
best_rated()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8fe3823dc2ca> in <module>()
# ----> 1 best_rated()
#
# <ipython-input-8-d04f6ff4fc8d> in best_rated(data, n)
#       9     recipe_rating = pd.concat([recipe_rating_mean, recipe_rating_std], axis=1)
#      10     recipe_rating.columns=["mean", "std"]
# ---> 11     recs = recipe_rating.sort(["mean", "std"], ascending=[0,1])
#      12
#      13     return list(map(ObjectId,list(recs.index.values)[:n]))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# ### Collaborative filtering

# %% [markdown]
# Collaborative filtering uses the graphlab library because is faster than any manual implementation. It uses internal datastructures based in order to avoid sparse matrices and therefore provide fast recommendations.

# %% [markdown]
# This library works on Python 2.7, create a new environment in case you are working in other version.

# %%
conda create -n gl-env python=2.7 anaconda=4.0.0
source activate gl-env

# %% [markdown]
# You can install this package using my account. Just need the following pip install:

# %%
pip install --upgrade --no-cache-dir https://get.graphlab.com/GraphLab-Create/2.1/gonzaloespinosaduelo@gmail.com/47BC-178E-7242-F049-6C93-DD34-BC02-7E32/GraphLab-Create-License.tar.gz

# %%
import numpy as np
import pandas as pd
import csv
import graphlab as gl
import bson
from bson.objectid import ObjectId

# %%
def collaborative_filtering(user_id, data=read_collection_as_df("ratings"), n=10):
    """
    Collaborative filtering using item pearson correlation.
    
    data 
    """
    
    # select only user, recipe, ratings (what we need)
    data["rating"] = data["rating"].astype(float)
    data["user_name"] = data["user_id"].map(str)
    data["recipe_name"] = data["recipe_id"].map(str)

    df = data[["user_name","recipe_name", "rating"]]    
    
    sf = gl.SFrame(df)
                                       
    collaborative_filtering = gl.item_similarity_recommender.create(sf, 
                                                                    user_id='user_name', 
                                                                    item_id='recipe_name', 
                                                                    target='rating', 
                                                                    similarity_type='pearson', verbose=False)
    
    u = [str(user_id)]
    recs_itemitem_pearson = collaborative_filtering.recommend(users=u, k=n)     # top 10 collaborative filtering recomendations
    
    recs = [x for x in list(recs_itemitem_pearson["recipe_name"]) if str(x) != 'nan']
    
    return list(map(ObjectId, recs))
# Out:
# ('Connected successfully to', 'agile_data_science_group_3')
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)

# %%
recs = collaborative_filtering(user_id = ObjectId("5a1aa2cb2cfaa80d6ff251f7"), n=10)
print(recs)
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to gonzaloespinosaduelo@gmail.com and will expire on November 08, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1513177137.log
# Recsys training: model = item_similarity
# [ObjectId('5a073c312cfaa84d14996063'), ObjectId('5a073c312cfaa84d14994d7d'), ObjectId('5a073c312cfaa84d14993958'), ObjectId('5a073c312cfaa84d1499560f'), ObjectId('5a073c312cfaa84d14996a77'), ObjectId('5a073c312cfaa84d14995758'), ObjectId('5a073c312cfaa84d14996080'), ObjectId('5a073c312cfaa84d149953f0'), ObjectId('5a073c312cfaa84d14995366')]
