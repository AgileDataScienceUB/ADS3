# %% [markdown]
# # Connected Recommenders

# %%
import pandas as pd
import pymongo
import operator

def _connect_mongo():
    """ Connects to Mongo """
    global conn
    try:
        #use your database name, user and password here:
        #mongodb://<dbuser>:<dbpassword>@<mlab_url>.mlab.com:57066/<database_name>
        with open("credentials.txt", 'r') as f:
            [name,password,url,dbname]=f.read().splitlines()
        conn=pymongo.MongoClient("mongodb://{}:{}@{}/{}".format(name,password,url,dbname))
        
        print ("Connected successfully to", dbname)

    except pymongo.errors.ConnectionFailure as e:
        print ("Could not connect to MongoDB: %s" % e) 
        
    print(conn)
    db=conn["agile_data_science_group_3"]
    
    return db


def read_collection_as_df(collection_name, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = _connect_mongo()
    
    collection = db[collection_name]
    
    # Make a query to the specific DB and Collection
    cursor = collection.find()

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor)) 

    conn.close()
    
    return df

def read_collection_as_dict(collection_name):
    """ Read from Mongo and Store into dict """

    # Connect to MongoDB
    db = _connect_mongo()
    
    collection = db[collection_name]

    l=list()
    for d in collection.find():
        l.append(d)
      
    dic=dict()
    for d in l:
        for key, value in d.items():
            if key!='_id':
                dic[key] = value
    
    conn.close()
    
    return dic

# %%
users_recipes_ratings_df = read_collection_as_df("users_recipes_ratings")
recipes_ingredients_dic = read_collection_as_dict("recipes_ingredients")
# Out:
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)

# %%
recipes_ingredients_dic.keys()
# Out:
# dict_keys(['chicken-pumpkin-curry', 'masterclass-pulled-ham-creamy-herb-salad', 'banana-pecan-date-muffins', 'easy-peasy-fish-cakes', 'fruity-fro-yo-bombe', 'salmon-fillets-with-pink-grapefruit-salsa', 'mac-n-cheese-salad', 'ginger-cake', 'nadiya-hussain-berry-breakfast-muffins', 'three-bean-salad', 'glazed-chicken-vegetable-roast', 'beetroot-potato-chorizo-hash', 'spinach-prawn-mango-salad', 'chocolate-bread-butter-pudding', 'tuna-with-couscous', 'chicken-broccoli-pie', 'pork-chops-with-mushroom-sauce', 'chicken-bean-hotpot', 'baked-parma-ham-and-gorgonzola-figs', 'fondant-fancies', 'crepe-in-orange-liqueur', 'summer-fruit-pudding-with-basil', 'carrot-shaped-chocolate-cake', 'moules-marinieres', 'tomato-quiche', 'pea-ham-soup', 'spiced-persian-turkey', 'chicken-and-chickpea-hotpot', 'tunisian-style-omelette', 'smoky-mexican-pork-fajitas', 'chicken-couscous-salad', 'butternut-squash-quesadillas', 'orange-carrot-soup', 'greek-style-slow-roasted-leg-of-lamb', 'rich-chocolate-ginger-cupcakes', 'beef-noodle-stir-fry', 'fruity-rice-puddings', 'pan-fried-pork-with-apple-wedges', 'savoury-ferrero-rocher-style-nibbles-with-extra-special-crostini', 'roasted-red-peppers-with-tomatoes', 'steak-kidney-pudding', 'plum-brandy', 'easy-goulash', 'maple-tropical-pork-skewers', 'roast-chicken-with-pork-stuffing', 'scar-pies', 'carrot-soup', 'leek-risotto', 'indian-style-lentil-soup', 'spiced-salmon-skewers', 'fish-pie-recipe', 'mini-koftas', 'mexican-style-tuna-melt', 'korean-style-pork-fillet', 'rhubarb-chutney', 'sweet-sour-chicken', 'spotted-dick', 'lamb-tagine', 'beetroot-sweet-potato-feta-cheese-salad', 'totally-loaded-chilli-chips', 'butternut-beetroot-tarts-with-creamy-camembert', 'red-lentil-vegetable-curry', 'zesty-baked-whole-salmon', 'coconut-ice-snowmen', 'mushroom-bacon-soup', 'squab-pie', 'paprika-pulled-pork', 'pulled-pork', 'smoked-salmon-terrine', 'homemade-plum-crumble', 'house-of-horrors-cake', 'baked-figs-with-honey', 'fish-pie-with-root-vegetable-topping', 'winter-chunky-vegetable-soup', 'caesar-salad-with-ranch-dressing', 'hasselback-potatoes', 'fajitas', 'mushroom-broccoli-filo-pie', 'apricot-chocolate-tart', 'roasted-banana-smash-toast', 'cucumber-prawn-gazpacho', 'chicken-tzaziki-wraps', 'chocolate-popcorn-shards', 'mango-banana-trifle', 'peach-melba-semifreddo', 'rack-of-venison', 'shredded-brussels-sprouts-with-pancetta', 'cauliflower-chickpea-curry', 'south-pacific-fish', 'salmon-fishcakes', 'prawn-stir-fry', 'salmon-pasta', 'the-ultimate-chocolate-brownie', 'stained-glass-biscuits', 'picnic-sausage-rolls', 'cornflake-chicken-nuggets-with-spicy-potato-cubes', 'nectarine-goats-cheese-honeyed-pecan-salad', 'baked-potatoes-stuffed-with-tuna-cheese', 'cod-haddock-tagliatelle-carbonara', 'miguel-barclays-green-shakshuka', 'healthy-fish-chips', 'james-martins-slow-cooked-lamb', 'apple-crumble-parmesan-cake', 'pear-crumbles', 'chicken-rissoles', 'pineapple-mess', 'poached-apricots', 'cheats-steak-ale-pie', 'triple-berry-compote-with-porridge', 'polenta-with-mushrooms-in-a-creamy-garlic-sauce', 'spinach-curry', 'salmon-en-croute-by-nick-nairn', 'tour-de-yorkshire-parkin-cake', 'beef-wellington-empanadas', 'roast-lamb-with-herby-stuffing', 'spider-web-doughnuts', 'irish-onion-soup-with-soda-bread-croutons', 'ghost-emoji-gingerbread-biscuit-recipe', 'chilli-prawn-skewers', 'crushed-meringue-with-pears', 'chicken-pie', 'berry-pie-recipe', 'summer-fruit-trifle', 'crispy-cauliflower-parmesan-snack-bites', 'duck-salad', 'egg-biscuits', 'traditional-rich-fruit-cake', 'zesty-chicken-burger', 'jumbo-jammie-dodger', 'spinach-ricotta-filo-pastry-parcels', 'rhubarb-orange-trifle', 'buttermilk-onion-rings', 'sweet-potato-chicken-curry', 'hot-sour-soup-with-carrot-noodles', 'healthier-macaroni-cheese-with-veg1', 'sausage-stuffed-onions', 'raspberry-tiramisu', 'lamb-hotpot', 'shoestring-fries-with-turmeric-mayo', 'wagyu-steak-with-kimchi-pickled-vegetables', 'pumpkin-pies', 'witches-broomsticks', 'bacon-mushroom-risotto', 'salmon-with-filo ...

# %%
recipes_ingredients_dic
# Out:
# {'chicken-pumpkin-curry': ['ghee',
#   'oil',
#   'onion',
#   'pack',
#   'asda',
#   'chicken',
#   'thigh',
#   'fillet',
#   'skin',
#   'garlic',
#   'clove',
#   'ginger',
#   'turmeric',
#   'cumin',
#   'asda',
#   'garam',
#   'masala',
#   'chillie',
#   'can',
#   'coconut',
#   'milk',
#   'pumpkin',
#   'skin',
#   'fibre',
#   'cornflour',
#   'cold',
#   'water',
#   'make',
#   'paste',
#   'coriander',
#   'rice',
#   'serve'],
#  'masterclass-pulled-ham-creamy-herb-salad': ['butcher’',
#   'gammon',
#   'joint',
#   'cider',
#   'bag',
#   'asda',
#   'tender',
#   'leaf',
#   'salad',
#   'caper',
#   'frozen',
#   'pea',
#   'minute',
#   'radishe',
#   'chosen',
#   'gherkin',
#   'cider',
#   'vinegar',
#   'olive',
#   'oil',
#   'fat',
#   'crème',
#   'fraîche',
#   'dijon',
#   'mustard',
#   'parsley'],
#  'banana-pecan-date-muffins': ['butter',
#   'plu',
#   'light',
#   'soft',
#   'brown',
#   'sugar',
#   'ripe',
#   'banana',
#   'weight',
#   'egg',
#   'beaten',
#   'flour',
#   'salt',
#   'powder',
#   'cinnamon',
#   'plu',
#   'pecan',
#   'date',
#   'raisin-size',
#   'piece',
#   'sugar'],
#  'easy-peasy-fish-cakes': ['pack',
#   'smash',
#   'instant',
#   'mash',
#   'potato',
#   'can',
#   'asda',
#   'tuna',
#   'chunk',
#   'water',
#   'chive',
#   'pinch',
#   'cayenne',
#   'egg',
#   'beaten',
#   'butter',
#   'asda',
#   'cornflake',
#   'breadcrumb',
#   'filippo',
#   'berio',
#   'spray',
#   'oil',
#   'asparagu',
#   'serve',
#   'pea',
#   'serve',
#   'sweetcorn',
#   'serve'],
#  'fruity-fro-yo-bombe': ['banana',
#   'frozen',
#   'solid',
#   'can',
#   'ambrosia',
#   'light',
#   'devon',
#   'custard',
#   'frozen',
#   'hr',
#   'pot',
#   'yeo',
#   'valley',
#   'fat',
#   'greek',
#   'style',
#   'honey',
#   'asda',
#   'natural',
#   'food',
#   'green',
#   'frozen',
#   'raspberrie',
#   'chocolate',
#   'chip'],
#  'salmon-fillets-with-pink-grapefruit-salsa': ['pink',
#   'grapefruit',
#   'ripe',
#   'avocado',
#   'piece',
#   'chilli',
#   'onion',
#   'coriander',
#   'mild',
#   'olive',
#   'oil',
#   'plu',
#   'zest',
#   'lime',
#   'plu',
#   'juice',
#   'basmati',
#   'rice',
#   'salmon',
#   'fillet'],
#  'mac-n-cheese-salad': ['macaroni',
#   'olive',
#   'oil',
#   'asda',
#   'light',
#   'mayonnaise',
#   'sour',
#   'cream',
#   'chive',
#   'american-style',
#   'mustard',
#   'chosen',
#   'crispy',
#   'bacon',
#   'asda',
#   'cheddar',
#   'leicester',
#   'pepper',
#   'special',
#   'sweet',
#   'aromatico',
#   'tomatoe'],
#  'ginger-cake': ['butter',
#   'plu',
#   'treacle',
#   'plu',
#   'serve',
#   'optional',
#   'golden',
#   'syrup',
#   'ball',
#   'opie',
#   'stem',
#   'ginger',
#   'syrup',
#   'flour',
#   'ginger',
#   'spice',
#   'dark',
#   'soft',
#   'brown',
#   'sugar',
#   'sultana',
#   'optional',
#   'egg',
#   'milk',
#   'stem',
#   'ginger',
#   'syrup',
#   'jar',
#   'serve',
#   'optional'],
#  'nadiya-hussain-berry-breakfast-muffins': ['flour',
#   'porridge',
#   'oat',
#   'soft',
#   'light',
#   'brown',
#   'sugar',
#   'powder',
#   'egg',
#   'ripe',
#   'banana',
#   'sunflower',
#   'oil',
#   'milk',
#   'blueberrie',
#   'raspberrie'],
#  'three-bean-salad': ['olive',
#   'oil',
#   'balsamic',
#   'vinegar',
#   'dijon',
#   'mustard',
#   'oil',
#   'jar',
#   'tomatoe',
#   'frozen',
#   'broad',
#   'bean',
#   'tomatoe',
#   'can',
#   'kidney',
#   'bean',
#   'can',
#   'cannellini',
#   'bean',
#   'celery',
#   'stick',
#   'bunch',
#   'onion'],
#  'glazed-chicken-vegetable-roast': ['pack',
#   'asda',
#   'butcher',
#   'chicken',
#   'pack',
#   'redcurrant',
#   'clove',
#   'garlic',
#   'asda',
#   'paprika',
#   'wine',
#   'vinegar',
#   'worcestershire',
#   'sauce',
#   'oregano',
#   'olive',
#   'oil',
#   'sweet',
#   'potato',
#   'weight',
#   'chunk',
#   'pepper',
#   'pepper',
#   'onion',
#   'wedge',
#   'salad',
#   'serve'],
#  'beetroot-potato-chorizo-hash': ['edward',
#   'potatoe',
#   'weight',
#   'sweet',
#   'potato',
#   'weight',
#   'pack',
#   'asda',
#   'vacuum',
#   'beetroot',
#   'onion',
#   'wedge',
#   'asda',
#   'special',
#   'spanish',
#   'chorizo',
#   'casero',
#   'cube',
#   'sunflower',
#   'oil',
#   'plu',
#   'wholegrain',
#   'mustard',
#   'worcestershire',
#   'sauce',
#   'free-range',
#   'egg'],
#  'spinach-prawn-mango-salad': ['groundnut',
#   'oil',
#   'sunflower',
#   'oil',
#   'lemon',
#   'juice',
#   'light',
#   'soy',
#   'sauce',
#   'honey',
#   'root',
#   'ginger',
#   'chilli',
#   'optional',
#   'ripe',
#   'mangoe',
#   'bag',
#   'asda',
#   'spinach',
#   'bag',
#   'asda',
#   'wild',
#   'rocket',
#   'pack',
#   'asda',
#   'prawn'],
#  'chocolate-bread-butter-pudding': ['butter',
#   'leftover',
#   'hot',
#   'cros',
#   'bun',
#   'doesnt',
#   'matter',
#   'stale',
#   'can',
#   'mandarin',
#   'segment',
#   'juice',
#   'chocolate',
#   'easter',
#   'egg',
#   'full-fat',
#   'milk',
#   'caster',
#   'sugar',
#   'drop',
#   'vanilla',
#   'extract',
#   'egg'],
#  'tuna-with-couscous': ['couscou',
#   'lemon',
#   'olive',
#   'oil',
#   'olive',
#   'onion',
#   'tomatoe',
#   'parsley',
#   'tuna',
#   'steak'],
#  'chicken-broccoli-pie': ['chicken',
#   'breast',
#   'fillet',
#   'gammon',
#   'steak',
#   'rind',
#   'fat',
#   'chicken',
#   'stock',
#   'cube',
#   'sprig',
#   'thyme',
#   'pack',
#   'asda',
#   'special',
#   'purple',
#   'broccoli',
#   'cornflour',
#   'pot',
#   'asda',
#   'crème',
#   'fraîche',
#   'pack',
#   'filo',
#   'pastry',
#   'butter'],
#  'pork-chops-with-mushroom-sauce': ['porcini',
#   'mushroom',
#   'asda',
#   'pork',
#   'chop',
#   'oil',
#   'plu',
#   'sprig',
#   'rosemary',
#   'butter',
#   'shallot',
#   'chestnut',
#   'mushroom',
#   'balsamic',
#   'vinegar',
#   'crème',
#   'fraîche',
#   'coarse',
#   'grain',
#   'mustard',
#   'parsley',
#   'cabbage',
#   'serve'],
#  'chicken-bean-hotpot': ['rasher',
#   'streaky',
#   'bacon',
#   'butter',
#   'leek',
#   'lengthway',
#   'flour',
#   'hot',
#   'chicken',
#   'stock',
#   'flat-leaf',
#   'parsley',
#   'thyme',
#   'pack',
#   'chicken',
#   'boneles',
#   'thigh',
#   'fillet',
#   'can',
#   'butter',
#   'bean',
#   'potatoe',
#   'weight'],
#  'baked-parma-ham-and-gorgonzola-figs': ['fig',
#   'slice',
#   'special',
#   'parma',
#   'ham',
#   'special',
#   'gorgonzola',
#   'honey',
#   'virgin',
#   'olive',
#   'oil',
#   'balsamic',
#   'vinegar',
#   'pine',
#   'nut',
#   'basil',
#   'rocket',
#   'serve'],
#  'fondant-fancies': ['butter',
#   'plu',
#   'caster',
#   'sugar',
#   'free-range',
#   'egg',
#   'flour',
#   'powder',
#   'sugar',
#   'vanilla',
#   'extract',
#   'milk',
#   'apricot',
#   'jam',
#   'ready-to-roll',
#   'food'],
#  'crepe-in-orange-liqueur': ['asda',
#   'flour',
#   'free-range',
#   'egg',
#   'milk',
#   'butter',
#   'sunflower',
#   'oil',
#   'butter',
#   'caster',
#   'sugar',
#   'orange',
#   'juice',
#   'orange',
#   'zest',
#   'grand',
#   'marnier',
#   'cointreau',
#   'asda',
#   'almond'],
#  'summer-fruit-pudding-with-basil': ['frozen',
#   'summer',
#   'fruit',
#   'blackberrie',
#   'raspberrie',
#   'strawberrie',
#   'slice',
#   'bread',
#   'caster',
#   'sugar',
#   'bunch',
#   'basil',
#   'olive',
#   'oil'],
#  'carrot-shaped-chocolate-cake': ['egg',
#   'flora',
#   'light',
#   'spread',
#   'caster',
#   'sugar',
#   'flour',
#   'cocoa',
#   'powder',
#   'tube',
#   'dr',
#   'oetker',
#   'gel',
#   'food',
#   'dark',
#   'chocolate',
#   'broken',
#   'square',
#   'double',
#   'cream',
#   'butter',
#   'vanilla',
#   'extract',
#   'milk',
#   'light',
#   'brown',
#   'soft',
#   'sugar',
#   'decorate',
#   'chocolate',
#   'drop',
#   'decorate',
#   'flat-leaf',
#   'parsley',
#   'sprig'],
#  'moules-marinieres': ['pack',
#   'live',
#   'mussel',
#   'butter',
#   'shallot',
#   'garlic',
#   'clove',
#   'dry',
#   'wine',
#   'sprig',
#   'parsley',
#   'plu',
#   'sprig',
#   'thyme',
#   'bay',
#   'leaf',
#   'crusty',
#   'bread',
#   'serve'],
#  'tomato-quiche': ['ready',
#   'made',
#   'shortcrust',
#   'pastry',
#   'bunch',
#   'onion',
#   'butter',
#   'crème',
#   'fraîche',
#   'single',
#   'cream',
#   'free-range',
#   'egg',
#   'mature',
#   'cheddar',
#   'cheese',
#   'plum',
#   'tomatoe',
#   'sprig',
#   'thyme',
#   'optional'],
#  'pea-ham-soup': ['olive',
#   'oil',
#   'pack',
#   'asda',
#   'leek',
#   'frozen',
#   'pea',
#   'knorr',
#   'ham',
#   'cube',
#   'water',
#   'mint',
#   'herb',
#   'milk',
#   'frozen',
#   'chosen',
#   'mash',
#   'chosen',
#   'honey',
#   'roast',
#   'ham',
#   'chunk',
#   'bread',
#   'serve'],
#  'spiced-persian-turkey': ['chosen',
#   'korma',
#   'paste',
#   'lemon',
#   'juice',
#   'chosen',
#   'natural',
#   'yogurt',
#   'chosen',
#   'honey',
#   'chosen',
#   'mayonnaise',
#   'sumac',
#   'powder',
#   'baharat',
#   'see',
#   'recipe',
#   'coriander',
#   'plu',
#   'go',
#   'carrot',
#   'asda',
#   'special',
#   'corn',
#   'turkey',
#   'carrot',
#   'ribbon',
#   'splash',
#   'lemon',
#   'juice',
#   'virgin',
#   'olive',
#   'oil',
#   'chosen',
#   'almond',
#   'serve',
#   'pomegranate',
#   'serve',
#   'medjool',
#   'date',
#   'serve',
#   'coriander',
#   'serve',
#   'flat',
#   'bread',
#   'serve',
#   'peppercorn',
#   'cumin',
#   'coriander',
#   'clove',
#   'cardamom',
#   'allspice',
#   'paprika',
#   'cinnamon',
#   'nutmeg'],
#  'chicken-and-chickpea-hotpot': ['skinles',
#   'boneles',
#   'chicken',
#   'thigh',
#   'olive',
#   'oil',
#   'reduced-salt',
#   'chicken',
#   'stock',
#   'cube',
#   'water',
#   'carrot',
#   'stick',
#   'celery',
#   'herb',
#   'tomato',
#   'purée',
#   'redcurrant',
#   'can',
#   'chickpea',
#   'potatoe',
#   'serve'],
#  'tunisian-style-omelette': ['sweet',
#   'potato',
#   'weight',
#   'cube',
#   'smart',
#   'pea',
#   'frozen',
#   'sunflower',
#   'oil',
#   'onion',
#   'pepper',
#   'cumin',
#   'asda',
#   'chillie',
#   'can',
#   'chickpea',
#   'egg',
#   'beaten',
#   'salad',
#   'serve',
#   'bread',
#   'serve'],
#  'smoky-mexican-pork-fajitas': ['leftover',
#   'butcher',
#   'roast',
#   'bag',
#   'mexican',
#   'pork',
#   'loin',
#   'joint',
#   'sunflower',
#   'oil',
#   'onion',
#   'green',
#   'pepper',
#   'pepper',
#   'packet',
#   'fajita',
#   'mix',
#   'tortilla',
#   'wrap',
#   'cream',
#   'serve',
#   'salsa',
#   'serve'],
#  'chicken-couscous-salad': ['couscou',
#   'paprika',
#   'oil',
#   'tomatoe',
#   'wine',
#   'vinegar',
#   'stick',
#   'celery',
#   'asda',
#   'special',
#   'tomatoe',
#   'jar',
#   'piece',
#   'asda',
#   'special',
#   'pepper',
#   'jar',
#   'onion',
#   'pack',
#   'asda',
#   'chicken',
#   'breast',
#   'coriander'],
#  'butternut-squash-quesadillas': ['butternut',
#   'squash',
#   'cube',
#   'olive',
#   'oil',
#   'pack',
#   'chosen',
#   'mexican',
#   'style',
#   'corn',
#   'tortilla',
#   'mild',
#   'cheddar',
#   'can',
#   'napolina',
#   'kidney',
#   'bean',
#   'onion',
#   'pepper',
#   'coriander',
#   'mild',
#   'chilli',
#   'optional',
#   'salsa',
#   'serve'],
#  'orange-carrot-soup': ['butter',
#   'carrot',
#   'potato',
#   'shallot',
#   'sugar',
#   'light',
#   'vegetable',
#   'stock',
#   'chicken',
#   'stock',
#   'orange',
#   'zest',
#   'juice',
#   'pot',
#   'double',
#   'cream'],
#  'greek-style-slow-roasted-leg-of-lamb': ['head',
#   'garlic',
#   'butcher’',
#   'lamb',
#   'leg',
#   'lemon',
#   'juice',
#   'olive',
#   'oil',
#   'oregano',
#   'cinnamon',
#   'wine',
#   'wine',
#   'onion',
#   'segment',
#   'cherry',
#   'tomatoe',
#   'vine'],
#  'rich-chocolate-ginger-cupcakes': ['asda',
#   'special',
#   'dark',
#   'chocolate',
#   'milk',
#   'flour',
#   'powder',
#   'pinch',
#   'ginger',
#   'caster',
#   'sugar',
#   'egg',
#   'natural',
#   'ginger',
#   'asda',
#   'dark',
#   'chocolate',
#   'double',
#   'cream',
#   'asda',
#   'mini',
#   'egg'],
#  'beef-noodle-stir-fry': ['pack',
#   'asda',
#   'egg',
#   'noodle',
#   'sesame',
#   'oil',
#   'sunflower',
#   'oil',
#   'asda',
#   'butcher',
#   'rump',
#   'steak',
#   'fat',
#   'strip',
#   'leek',
#   'leek',
#   'mushroom',
#   'pepper',
#   'soy',
#   'sauce',
#   'oyster',
#   'sauce',
#   'worcester',
#   'sauce'],
#  'fruity-rice-puddings': ['rice',
#   'reduced-fat',
#   'coconut',
#   'milk',
#   'milk',
#   'coconut',
#   'cinnamon',
#   'golden',
#   'caster',
#   'sugar',
#   'zest',
#   'lemon',
#   'pineapple',
#   'mango',
#   'stone',
#   'pomegranate'],
#  'pan-fried-pork-with-apple-wedges': ['courgette',
#   'lengthway',
#   'orange',
#   'pepper',
#   'sunflower',
#   'oil',
#   'pack',
#   'butcher',
#   'pork',
#   'loin',
#   'steak',
#   'third',
#   'chicken',
#   'stock',
#   'made',
#   'stock',
#   'cube',
#   'herb',
#   'apple',
#   'wedge',
#   'reduced-fat',
#   'crème',
#   'fraîche',
#   'cornflour',
#   'cold',
#   'water',
#   'crusty',
#   'bread',
#   'serve'],
#  'savoury-ferrero-rocher-style-nibbles-with-extra-special-crostini': ['special',
#   'brussel',
#   'pâté',
#   'hazelnut',
#   'hazelnut',
#   'nib',
#   'nut',
#   'choice',
#   'asda',
#   'special',
#   'crostini',
#   'mini',
#   'paper',
#   'case',
#   'gold',
#   'foil',
#   'sheet',
#   'serve'],
#  'roasted-red-peppers-with-tomatoes': ['orange',
#   'pepper',
#   'onion',
#   'wedge',
#   'aubergine',
#   'chunk',
#   'olive',
#   'oil',
#   'pack',
#   'plum',
#   'tomatoe',
#   'balsamic',
#   'vinegar',
#   'handful',
#   'basil',
#   'lamb',
#   'cutlet',
#   'chicken',
#   'serve'],
#  'steak-kidney-pudding': ['olive',
#   'oil',
#   'onion',
#   'carrot',
#   'pack',
#   'butcher',
#   'beef',
#   'steak',
#   'beef',
#   'lamb',
#   'kidney',
#   'thyme',
#   'flour',
#   'worcestershire',
#   'sauce',
#   'ale',
#   'knorr',
#   'beef',
#   'stock',
#   'pot',
#   'water',
#   'flour',
#   'atora',
#   'original',
#   'beef',
#   'suet',
#   'pinch',
#   'mustard',
#   'powder'],
#  'plum-brandy': ['plum', 'sugar', 'bottle', 'brandy'],
#  'easy-goulash': ['onion',
#   'sunflower',
#   'oil',
#   'asda',
#   'casserole',
#   'beef',
#   'beef',
#   'stock',
#   'cube',
#   'can',
#   'asda',
#   'tomatoe',
#   'can',
#   'asda',
#   'tomatoe',
#   'chillie',
#   'pepper',
#   'herb',
#   'carrot',
#   'cornflour',
#   'pepper',
#   'green',
#   'pepper',
#   'paprika',
#   'tomato',
#   'purée',
#   'sour',
#   'cream',
#   'serve'],
#  'maple-tropical-pork-skewers': ['butcher',
#   'roast',
#   'bag',
#   'maple',
#   'pork',
#   'loin',
#   'joint',
#   'peache',
#   'banana',
#   'streaky',
#   'bacon',
#   'rasher',
#   'packet',
#   'wooden',
#   'skewer',
#   'sweet',
#   'chilli',
#   'lime',
#   'relish',
#   'serve'],
#  'roast-chicken-with-pork-stuffing': ['butter',
#   'shallot',
#   'asda',
#   'special',
#   'pork',
#   'leek',
#   'sausage',
#   'skin',
#   'pack',
#   'thyme',
#   'breadcrumb',
#   'parsley',
#   'asda',
#   'chicken',
#   'edward',
#   'potatoe',
#   'mari',
#   'piper',
#   'potatoe',
#   'olive',
#   'oil',
#   'asda',
#   'special',
#   'chicken',
#   'gravy',
#   'serve'],
#  'scar-pies': ['olive',
#   'oil',
#   'onion',
#   'pepper',
#   'orange',
#   'pepper',
#   'asda',
#   'special',
#   'iberico',
#   'chorizo',
#   'can',
#   'asda',
#   'tomatoe',
#   'garlic',
#   'pack',
#   'asda',
#   'ready',
#   'roll',
#   'shortcrust',
#   'pastry',
#   'flour'],
#  'carrot-soup': ['onion',
#   'sunflower',
#   'oil',
#   'butter',
#   'carrot',
#   'weight',
#   'potato',
#   'bay',
#   'leaf',
#   'vegetable',
#   'stock',
#   'parsley'],
#  'leek-risotto': ['vegetable',
#   'stock',
#   'cube',
#   'olive',
#   'oil',
#   'butter',
#   'leek',
#   'arborio',
#   'risotto',
#   'rice',
#   'wine',
#   'optional',
#   'thyme',
#   'frozen',
#   'pea',
#   'pancetta',
#   'parmesan'],
#  'indian-style-lentil-soup': ['onion',
#   'sunflower',
#   'oil',
#   'clove',
#   'garlic',
#   'piece',
#   'root',
#   'ginger',
#   'asda',
#   'korma',
#   'curry',
#   'paste',
#   'paprika',
#   'lentil',
#   'vegetable',
#   'stock',
#   'cube',
#   'carton',
#   'asda',
#   'tomatoe',
#   'pepper',
#   'tomato',
#   'purée',
#   'coriander',
#   'serve'],
#  'spiced-salmon-skewers': ['natural',
#   'yogurt',
#   'clove',
#   'garlic',
#   'honey',
#   'chilli',
#   'juice',
#   'lemon',
#   'vegetable',
#   'oil',
#   'mild',
#   'curry',
#   'powder',
#   'salmon',
#   'fillet',
#   'cube',
#   'coriander',
#   'serve'],
#  'fish-pie-recipe': ['cornflour',
#   'dijon',
#   'mustard',
#   'mild',
#   'curry',
#   'powder',
#   'milk',
#   'pack',
#   'fishmonger’',
#   'fish',
#   'pie',
#   'mix',
#   'raw',
#   'prawn',
#   'spinach',
#   'packet',
#   'instruction',
#   'reduced-fat',
#   'crème',
#   'fraîche',
#   'dill',
#   'sheet',
#   'filo',
#   'pastry',
#   'frozen',
#   'butter',
#   'sesame'],
#  'mini-koftas': ['asda',
#   'butcher',
#   'beef',
#   'mince',
#   'garlic',
#   'clove',
#   'mint',
#   'flat-leaf',
#   'parsley',
#   'coriander',
#   'cumin'],
#  'mexican-style-tuna-melt': ['jar',
#   'asda',
#   'tex',
#   'mex',
#   'hot',
#   'salsa',
#   'can',
#   'kidney',
#   'bean',
#   'asda',
#   'wrap',
#   'can',
#   'asda',
#   'tuna',
#   'brine',
#   'well',
#   'onion',
#   'mature',
#   'cheddar',
#   'coriander',
#   'olive',
#   'oil',
#   'sour',
#   'cream',
#   'serve',
#   'salad',
#   'serve'],
#  'korean-style-pork-fillet': ['butcher’',
#   'pork',
#   'fillet',
#   'slice',
#   'streaky',
#   'bacon',
#   'chosen',
#   'smoky',
#   'chilli',
#   'garlic',
#   'paste',
#   'salt',
#   'soy',
#   'sauce',
#   'rice',
#   'wine',
#   'vinegar',
#   'honey',
#   'cucumber',
#   'thin',
#   'onion',
#   'sesame',
#   'oil',
#   'sesame'],
#  'rhubarb-chutney': ['rhubarb',
#   'piece',
#   'orange',
#   'zest',
#   'juice',
#   'bramley',
#   'apple',
#   'piece',
#   'onion',
#   'wine',
#   'vinegar',
#   'sugar',
#   'apricot',
#   'piece',
#   'sultana',
#   'mustard',
#   'root',
#   'ginger',
#   'salt'],
#  'sweet-sour-chicken': ['amoy',
#   'salt',
#   'soy',
#   'sauce',
#   'asda',
#   'sweet',
#   'chilli',
#   'sauce',
#   'cider',
#   'vinegar',
#   'honey',
#   'orange',
#   'juice',
#   'cornflour',
#   'sunflower',
#   'oil',
#   'chicken',
#   'breast',
#   'fillet',
#   'bite-size',
#   'piece',
#   'carrot',
#   'short',
#   'stick',
#   'pepper',
#   'strip',
#   'onion',
#   'pack',
#   'mangetout',
#   'lengthway',
#   'pineapple',
#   'skin',
#   'core',
#   'bite-size',
#   'piece',
#   'rice',
#   'serve'],
#  'spotted-dick': ['flour',
#   'powder',
#   'suet',
#   'soft',
#   'brown',
#   'sugar',
#   'currant',
#   'lemon',
#   'zest',
#   'spice',
#   'milk'],
#  'lamb-tagine': ['olive',
#   'oil',
#   'pack',
#   'asda',
#   'butcher',
#   'lamb',
#   'neck',
#   'fillet',
#   'fat',
#   'onion',
#   'cinnamon',
#   'ginger',
#   'cumin',
#   'paprika',
#   'can',
#   'asda',
#   'tomatoe',
#   'chilli',
#   'pepper',
#   'carrot',
#   'honey',
#   'pepper',
#   'coriander',
#   'plu',
#   'serve',
#   'ready-to-eat',
#   'prune',
#   'ready-to-eat',
#   'apricot',
#   'almond',
#   'couscou',
#   'serve'],
#  'beetroot-sweet-potato-feta-cheese-salad': ['olive',
#   'oil',
#   'honey',
#   'sweet',
#   'potatoe',
#   'weight',
#   'thick',
#   'slice',
#   'onion',
#   'pack',
#   'asda',
#   'long',
#   'life',
#   'beetroot',
#   'thick',
#   'slice',
#   'walnut',
#   'halve',
#   'wine',
#   'vinegar',
#   'dijon',
#   'mustard',
#   'pack',
#   'rocket',
#   'feta',
#   'cheese',
#   'broken',
#   'piece'],
#  'totally-loaded-chilli-chips': ['butcher’',
#   'lean',
#   'beef',
#   'mince',
#   'onion',
#   'plu',
#   'slice',
#   'serve',
#   'can',
#   'asda',
#   'bean',
#   'tomato',
#   'sauce',
#   'asda',
#   'chilli',
#   'con',
#   'carne',
#   'mix',
#   'asda',
#   'steak',
#   'oven',
#   'chip',
#   'cream',
#   'tomatoe',
#   'asda',
#   'fat',
#   'cheddar',
#   'leicester',
#   'coriander'],
#  'butternut-beetroot-tarts-with-creamy-camembert': ['butternut',
#   'squash',
#   'olive',
#   'oil',
#   'balsamic',
#   'vinegar',
#   'flour',
#   'jus-rol',
#   'light',
#   'puff',
#   'pastry',
#   'sheet',
#   'grower',
#   'beetroot',
#   'camembert',
#   'egg',
#   'beaten',
#   'double',
#   'cream',
#   'thyme'],
#  'red-lentil-vegetable-curry': ['onion',
#   'cauliflower',
#   'green',
#   'bean',
#   'piece',
#   'ginger',
#   'vegetable',
#   'oil',
#   'mild',
#   'curry',
#   'powder',
#   'plump',
#   'clove',
#   'garlic',
#   'reduced-salt',
#   'vegetable',
#   'stock',
#   'cube',
#   'lentil',
#   'balsamic',
#   'vinegar',
#   'pinche',
#   'salt'],
#  'zesty-baked-whole-salmon': ['fishmonger’',
#   'salmon',
#   'head',
#   'fennel',
#   'garlic',
#   'clove',
#   'oil',
#   'lemon',
#   'lime',
#   'pink',
#   'grapefruit',
#   'grapefruit',
#   'orange',
#   'bay',
#   'sprig',
#   'dill',
#   'juice',
#   'lemon',
#   'juice',
#   'lime',
#   'oil',
#   'shallot',
#   'honey'],
#  'coconut-ice-snowmen': ['carnation', 'milk', 'sugar', 'coconut', 'decorate'],
#  'mushroom-bacon-soup': ['olive',
#   'oil',
#   'onion',
#   'clove',
#   'garlic',
#   'mushroom',
#   'vegetable',
#   'stock',
#   'made',
#   'vegetable',
#   'stock',
#   'cube',
#   'milk',
#   'thyme',
#   'plu',
#   'sprig',
#   'garnish',
#   'rasher',
#   'streaky',
#   'bacon',
#   'single',
#   'cream',
#   'chive'],
#  'squab-pie': ['cornflour',
#   'spice',
#   'soft',
#   'brown',
#   'sugar',
#   'lamb',
#   'steak',
#   'piece',
#   'onion',
#   'apple',
#   'cold',
#   'lamb',
#   'stock',
#   'asda',
#   'ready',
#   'roll',
#   'shortcrust',
#   'pastry',
#   'flour',
#   'free-range',
#   'egg',
#   'beaten'],
#  'paprika-pulled-pork': ['joint',
#   'boneles',
#   'pork',
#   'shoulder',
#   'sea',
#   'salt',
#   'dark',
#   'brown',
#   'sugar',
#   'paprika'],
#  'pulled-pork': ['pork',
#   'joint',
#   'passata',
#   'sweet',
#   'chilli',
#   'sauce',
#   'worcestershire',
#   'sauce',
#   'balsamic',
#   'vinegar',
#   'treacle',
#   'english',
#   'mustard',
#   'paprika',
#   'asda',
#   'garlic',
#   'watercres',
#   'serve',
#   'special',
#   'coleslaw',
#   'serve',
#   'roll',
#   'serve'],
#  'smoked-salmon-terrine': ['pack',
#   'special',
#   'asparagu',
#   'tip',
#   'pack',
#   'special',
#   'scottish',
#   'salmon',
#   'pack',
#   'special',
#   'golden',
#   'roast',
#   'scottish',
#   'salmon',
#   'pack',
#   'asda',
#   'prawn',
#   'butter',
#   'chosen',
#   'original',
#   'soft',
#   'cheese',
#   'dill',
#   'zest',
#   'lemon',
#   'plu',
#   'juice',
#   'salad',
#   'serve',
#   'dill',
#   'serve',
#   'lemon',
#   'wedge',
#   'serve'],
#  'homemade-plum-crumble': ['asda',
#   'hazelnut',
#   'plum',
#   'demerara',
#   'sugar',
#   'cinnamon',
#   'asda',
#   'butter',
#   'asda',
#   'flour',
#   'caster',
#   'sugar'],
#  'house-of-horrors-cake': ['flour',
#   'sugar',
#   'cocoa',
#   'powder',
#   'plu',
#   'decorate',
#   'powder',
#   'bicarbonate',
#   'soda',
#   'egg',
#   'oil',
#   'apple',
#   'juice',
#   'butter',
#   'soft',
#   'cheese',
#   'sugar',
#   'peanut',
#   'butter',
#   'nutella',
#   'butter',
#   'muscovado',
#   'sugar',
#   'golden',
#   'syrup',
#   'flour',
#   'bicarbonate',
#   'soda',
#   'ginger',
#   'fox’',
#   'glacier',
#   'mint',
#   'coco',
#   'pop',
#   'dark',
#   'chocolate',
#   'ready',
#   'roll',
#   'orange',
#   'food',
#   'dr',
#   'oetker',
#   'gel',
#   'food',
#   'colour',
#   'ultra',
#   'violet',
#   'golden',
#   'syrup',
#   'matchmaker',
#   'bag',
#   'malteser',
#   'dark',
#   'brown',
#   'sugar'],
#  'baked-figs-with-honey': ['fig',
#   'butter',
#   'plu',
#   'asda',
#   'squeezy',
#   'pure',
#   'acacia',
#   'honey',
#   'honey',
#   'apple',
#   'juice',
#   'sweet',
#   'sherry',
#   'pinch',
#   'cinnamon',
#   'pot',
#   'asda',
#   'fat',
#   'free',
#   'greek',
#   'style',
#   'yogurt'],
#  'fish-pie-with-root-vegetable-topping': ['carrot',
#   'parsnip',
#   'potatoe',
#   'butter',
#   'pack',
#   'asda',
#   'fish',
#   'pie',
#   'mix',
#   'pack',
#   'asda',
#   'boneles',
#   'skinles',
#   'river',
#   'cobbler',
#   'fillet',
#   'chunk',
#   'milk',
#   'onion',
#   'flour',
#   'dry',
#   'mustard',
#   'powder',
#   'les',
#   'fat',
#   'mature',
#   'cheese',
#   'parsley',
#   'pea',
#   'serve',
#   'carrot',
#   'serve'],
#  'winter-chunky-vegetable-soup': ['olive',
#   'oil',
#   'onion',
#   'celery',
#   'stick',
#   'pack',
#   'kale',
#   'spinach',
#   'pak',
#   'choi',
#   'garlic',
#   'clove',
#   'tomatoe',
#   'tomato',
#   'purée',
#   'hot',
#   'vegetable',
#   'stock',
#   'can',
#   'borlotti',
#   'bean',
#   'frozen',
#   'broad',
#   'bean',
#   'frozen',
#   'pea',
#   'sprig',
#   'thyme',
#   'baguette',
#   'parmesan'],
#  'caesar-salad-with-ranch-dressing': ['ciabatta',
#   'roll',
#   'approx',
#   'olive',
#   'oil',
#   'little',
#   'gem',
#   'lettuce',
#   'radishe',
#   'lemon',
#   'low-fat',
#   'greek',
#   'yogurt',
#   'wholegrain',
#   'mustard',
#   'balsamic',
#   'vinegar',
#   'pepper',
#   'pecorino',
#   'cheese',
#   'parmesan',
#   'cheese'],
#  'hasselback-potatoes': ['potatoe', 'butter', 'oil'],
#  'fajitas': ['pack',
#   'schwartz',
#   'chicken',
#   'fajita',
#   'recipe',
#   'mix',
#   'vegetable',
#   'oil',
#   'pack',
#   'butcher',
#   'prime',
#   'beef',
#   'sirloin',
#   'steak',
#   'pepper',
#   'pepper',
#   'onion',
#   'cream',
#   'pack',
#   'chosen',
#   'guacamole',
#   'pack',
#   'chosen',
#   'youhot',
#   'spicy',
#   'salsa',
#   'mature',
#   'cheddar',
#   'iceberg',
#   'lettuce',
#   'cherry',
#   'sweetcorn',
#   'can',
#   'weight',
#   'jalapeño',
#   'lime',
#   'wedge',
#   'chosen',
#   'tortilla'],
#  'mushroom-broccoli-filo-pie': ['broccoli',
#   'floret',
#   'olive',
#   'oil',
#   'plu',
#   'onion',
#   'pack',
#   'mushroom',
#   'clove',
#   'garlic',
#   'can',
#   'batchelor',
#   'low',
#   'fat',
#   'mushroom',
#   'soup',
#   'sheet',
#   'filo',
#   'pastry'],
#  'apricot-chocolate-tart': ['flour',
#   'plu',
#   'sugar',
#   'cocoa',
#   'powder',
#   'butter',
#   'apricot',
#   'jam',
#   'special',
#   'cocoa',
#   'solid',
#   'ivory',
#   'coast',
#   'dark',
#   'chocolate',
#   'butter',
#   'caster',
#   'sugar',
#   'egg',
#   'almond',
#   'apricot'],
#  'roasted-banana-smash-toast': ['banana',
#   'honey',
#   'slice',
#   'bread',
#   'light',
#   'mascarpone',
#   'pistachio'],
#  'cucumber-prawn-gazpacho': ['cucumber',
#   'double',
#   'cream',
#   'greek-style',
#   'yogurt',
#   'asda',
#   'special',
#   'horseradish',
#   'sauce',
#   'vegetable',
#   'stock',
#   'prawn',
#   'asda',
#   'garlic',
#   'coriander',
#   'naan',
#   'serve',
#   'pot',
#   'asda',
#   'tzatziki',
#   'serve'],
#  'chicken-tzaziki-wraps': ['skinles',
#   'chicken',
#   'fillet',
#   'lemon',
#   'juice',
#   'olive',
#   'oil',
#   'oregano',
#   'oregano',
#   'garlic',
#   'clove',
#   'pot',
#   'asda',
#   'tzatziki',
#   'dip',
#   'pack',
#   'asda',
#   'tortilla',
#   'wrap',
#   'rocket',
#   'watercres',
#   'serve'],
#  'chocolate-popcorn-shards': ['asda',
#   'dark',
#   'chocolate',
#   'cocoa',
#   'solid',
#   'special',
#   'dark',
#   'chocolate',
#   'cocoa',
#   'solid',
#   'popcorn',
#   'asda',
#   'cherry',
#   'berry',
#   'mix'],
#  'mango-banana-trifle': ['boudoir',
#   'finger',
#   'sponge',
#   'finger',
#   'rum',
#   'asda',
#   'pure',
#   'orange',
#   'mango',
#   'passionfruit',
#   'juice',
#   'concentrate',
#   'mango',
#   'ripe',
#   'banana',
#   'asda',
#   'mascarpone',
#   'asda',
#   'custard',
#   'double',
#   'cream',
#   'almond'],
#  'peach-melba-semifreddo': ['can',
#   'peache',
#   'fruit',
#   'juice',
#   'egg',
#   'yolk',
#   'plu',
#   'egg',
#   'caster',
#   'sugar',
#   'raspberrie',
#   'lemon',
#   'juice',
#   'asda',
#   'full',
#   'fat',
#   'greek',
#   'yogurt'],
#  'rack-of-venison': ['special',
#   'rack',
#   'venison',
#   'french',
#   'oil',
#   'dijon',
#   'mustard',
#   'pistachio',
#   'nut',
#   'special',
#   'beef',
#   'concentrate',
#   'special',
#   'redcurrant',
#   'sauce',
#   'port',
#   'butter',
#   'olive',
#   'oil',
#   'plu',
#   'crouton',
#   'slice',
#   'bread',
#   'parsley',
#   'vegetable',
#   'serve'],
#  'shredded-brussels-sprouts-with-pancetta': ['brussel',
#   'sprout',
#   'pine',
#   'nut',
#   'chosen',
#   'pancetta',
#   'sunflower',
#   'oil',
#   'butter'],
#  'cauliflower-chickpea-curry': ['cauliflower',
#   'floret',
#   'sunflower',
#   'oil',
#   'onion',
#   'garlic',
#   'clove',
#   'root',
#   'ginger',
#   'coriander',
#   'cumin',
#   'turmeric',
#   'chillie',
#   'garam',
#   'masala',
#   'can',
#   'asda',
#   'tomatoe',
#   'chilli',
#   'pepper',
#   'can',
#   'asda',
#   'chickpea',
#   'asda',
#   'naan',
#   'bread',
#   'serve'],
#  'south-pacific-fish': ['vegetable',
#   'oil',
#   'onion',
#   'garlic',
#   'clove',
#   'piece',
#   'root',
#   'ginger',
#   'coriander',
#   'turmeric',
#   'sweet',
#   'potatoe',
#   'chunk',
#   'can',
#   'coconut',
#   'milk',
#   'can',
#   'tomatoe',
#   'chilli',
#   'pepper',
#   'pepper',
#   'fish',
#   'chunky',
#   'piece',
#   'macadamia',
#   'nut',
#   'coriander',
#   'chilli',
#   'rice',
#   'serve'],
#  'salmon-fishcakes': ['can',
#   'asda',
#   'salmon',
#   'pack',
#   'asda',
#   'special',
#   'creamy',
#   'mash',
#   'mayonnaise',
#   'horseradish',
#   'sauce',
#   'flat-leaf',
#   'parsley',
#   'chive',
#   'lemon',
#   'juice',
#   'free-range',
#   'egg',
#   'beaten',
#   'asda',
#   'breadcrumb',
#   'sunflower',
#   'oil',
#   'mangetout',
#   'serve',
#   'sugar',
#   'snap',
#   'serve',
#   'lemon',
#   'wedge',
#   'serve'],
#  'prawn-stir-fry': ['cornflour',
#   'light',
#   'soy',
#   'sauce',
#   'sweet',
#   'chilli',
#   'sauce',
#   'orange',
#   'juice',
#   'asda',
#   'egg',
#   'noodle',
#   'asda',
#   'stir-fry',
#   'oil',
#   'pepper',
#   'pepper',
#   'carrot',
#   'stick',
#   'pack',
#   'mangetout',
#   'onion',
#   'can',
#   'water',
#   'chestnut',
#   'pack',
#   'asda',
#   'raw',
#   'tiger',
#   'prawn'],
#  'salmon-pasta': ['pack',
#   'asda',
#   'tagliatelle',
#   'pack',
#   'asda',
#   'smart',
#   'salmon',
#   'slice',
#   'asda',
#   'fat',
#   'crème',
#   'fraîche',
#   'dill',
#   'parmesan'],
#  'the-ultimate-chocolate-brownie': ['special',
#   'dark',
#   'chocolate',
#   'cocoa',
#   'solid',
#   'broken',
#   'piece',
#   'butter',
#   'egg',
#   'plu',
#   'yolk',
#   'golden',
#   'caster',
#   'sugar',
#   'flour',
#   'powder',
#   'sugar',
#   'dust'],
#  'stained-glass-biscuits': ['flour',
#   'plu',
#   'ginger',
#   'cinnamon',
#   'butter',
#   'cube',
#   'golden',
#   'syrup',
#   'fox',
#   'glacier',
#   'fruit'],
#  'picnic-sausage-rolls': ['pack',
#   'ju',
#   'roll',
#   'butter',
#   'puff',
#   'pastry',
#   'flour',
#   'pack',
#   'asda',
#   'special',
#   'cumberland',
#   'sausage',
#   'free-range',
#   'egg',
#   'beaten'],
#  'cornflake-chicken-nuggets-with-spicy-potato-cubes': ['potatoe',
#   'cube',
#   'olive',
#   'oil',
#   'asda',
#   'chillie',
#   'optional',
#   'asda',
#   'cornflake',
#   'mature',
#   'cheddar',
#   'flour',
#   'pack',
#   'asda',
#   'butcher',
#   'chicken',
#   'breast',
#   'fillet',
#   'piece',
#   'egg',
#   'beaten',
#   'leek',
#   'serve',
#   'sweetcorn',
#   'serve',
#   'pea',
#   'serve'],
#  'nectarine-goats-cheese-honeyed-pecan-salad': ['pecan',
#   'nut',
#   'asda',
#   'honey',
#   'salt',
#   'caster',
#   'sugar',
#   'plu',
#   'walnut',
#   'oil',
#   'wine',
#   'vinegar',
#   'dijon',
#   'mustard',
#   'salad',
#   'nectarine',
#   'piece',
#   'asda',
#   'english',
#   'goat’',
#   'cheese'],
#  'baked-potatoes-stuffed-with-tuna-cheese': ['potatoe',
#   'leek',
#   'butter',
#   'milk',
#   'can',
#   'asda',
#   'tuna',
#   'chunk',
#   'water',
#   'mature',
#   'cheddar'],
#  'cod-haddock-tagliatelle-carbonara': ['norwegian',
#   'cod',
#   'fillet',
#   'skin',
#   'norwegian',
#   'haddock',
#   'fillet',
#   'skin',
#   'tagliatelle',
#   'bacon',
#   'clove',
#   'garlic',
#   'egg',
#   'light',
#   'cream',
#   'parmesan',
#   'cheese',
#   'basil'],
#  'miguel-barclays-green-shakshuka': ['onion',
#   'handful',
#   'frozen',
#   'pea',
#   'handful',
#   'spinach',
#   'egg',
#   'feta',
#   'olive',
#   'oil'],
#  'healthy-fish-chips': ['pack',
#   'asda',
#   'frozen',
#   'cod',
#   'loin',
#   'fillet',
#   'lemon',
#   'zest',
#   'juice',
#   'butter',
#   'olive',
#   'oil',
#   'breadcrumb',
#   'flat-leaf',
#   'parsley',
#   'thyme',
#   'onion',
#   'asda',
#   'special',
#   'frozen',
#   'oven',
#   'chip',
#   'serve',
#   'asda',
#   'frozen',
#   'pea',
#   'frozen',
#   'mushy',
#   'pea',
#   'serve'],
#  'james-martins-slow-cooked-lamb': ['butcher',
#   'british',
#   'lamb',
#   'shoulder',
#   'fillet',
#   'special',
#   'cold',
#   'oil',
#   'onion',
#   'garlic',
#   'clove',
#   'chipotle',
#   'paste',
#   'harissa',
#   'paste',
#   'sprig',
#   'rosemary',
#   'bay',
#   'asda',
#   'tomato',
#   'purée',
#   'asda',
#   'tomato',
#   'ketchup',
#   'worcestershire',
#   'sauce',
#   'salt',
#   'soy',
#   'sauce',
#   'special',
#   'beef',
#   'stock',
#   'brioche',
#   'bun',
#   'slice',
#   'sourdough',
#   'bread',
#   'cabbage',
#   'bunch',
#   'coriander',
#   'juice',
#   'lime',
#   'virgin',
#   'olive',
#   'oil',
#   'crisp',
#   'onion'],
#  'apple-crumble-parmesan-cake': ['butter',
#   'plu',
#   'soft',
#   'light',
#   'brown',
#   'sugar',
#   'egg',
#   'beaten',
#   'almond',
#   'parmesan',
#   'flour',
#   'cinnamon',
#   'allspice',
#   'apple',
#   'chunk',
#   'zest',
#   'juice',
#   'lemon',
#   'asda',
#   'crumble',
#   'hazelnut',
#   'oat',
#   'pine',
#   'nut'],
#  'pear-crumbles': ['conference',
#   'pear',
#   'bottle',
#   'wine',
#   'caster',
#   'sugar',
#   'butter',
#   'flour',
#   'sugar'],
#  'chicken-rissoles': ['chicken',
#   'weight',
#   'skin',
#   'bread',
#   'day',
#   'old',
#   'egg',
#   'beaten',
#   'asda',
#   'real',
#   'mayonnaise',
#   'parsley',
#   'asda',
#   'coarse',
#   'grain',
#   'french',
#   'mustard',
#   'tomatoe',
#   'optional',
#   'sunflower',
#   'oil',
#   'potatoe',
#   'serve',
#   'salad',
#   'serve'],
#  'pineapple-mess': ['asda',
#   'ready',
#   'pineapple',
#   'asda',
#   'special',
#   'mini',
#   'meringue',
#   'cream',
#   'orange',
#   'liqueur',
#   'optional'],
#  'poached-apricots': ['sugar',
#   'apple',
#   'juice',
#   'juice',
#   'zest',
#   'lemon',
#   'peeler',
#   'cardamom',
#   'pod',
#   'vanilla',
#   'pod',
#   'apricot',
#   'firm'],
#  'cheats-steak-ale-pie': ['pack',
#   'asda',
#   'beef',
#   'steak',
#   'flour',
#   'onion',
#   'oil',
#   'butter',
#   'asda',
#   'special',
#   'whitechapel',
#   'porter',
#   'ale',
#   'hot',
#   'beef',
#   'stock',
#   'ready',
#   'roll',
#   'puff',
#   'pastry',
#   'egg',
#   'beaten',
#   'cabbage',
#   'serve',
#   'potatoe',
#   'serve'],
#  'triple-berry-compote-with-porridge': ['berrie',
#   'blueberrie',
#   'raspberrie',
#   'blackberrie',
#   'frozen',
#   'caster',
#   'sugar',
#   'cinnamon',
#   'stick',
#   'optional',
#   'porridge',
#   'serve'],
#  'polenta-with-mushrooms-in-a-creamy-garlic-sauce': ['merchant',
#   'gourmet',
#   'porcini',
#   'mushroom',
#   'pack',
#   'chestnut',
#   'mushroom',
#   'clove',
#   'garlic',
#   'herb',
#   'butter',
#   'brandy',
#   'optional',
#   'crème',
#   'fraîche',
#   'italfresco',
#   'ready',
#   'made',
#   'polenta',
#   'parsley',
#   'garnish'],
#  'spinach-curry': ['chicken',
#   'breast',
#   'piece',
#   'lemon',
#   'juice',
#   'sunflower',
#   'oil',
#   'onion',
#   'clove',
#   'garlic',
#   'piece',
#   'root',
#   'ginger',
#   'chilli',
#   'turmeric',
#   'coriander',
#   'cumin',
#   'asda',
#   'garam',
#   'masala',
#   'tomatoe',
#   'sweet',
#   'potato',
#   'weight',
#   'cube',
#   'can',
#   'chickpea',
#   'bag',
#   'asda',
#   'spinach',
#   'asda',
#   'chosen',
#   'mini',
#   'poppadom',
#   'serve',
#   'tomato',
#   'coriander',
#   'onion',
#   'side',
#   'salad',
#   'serve'],
#  'salmon-en-croute-by-nick-nairn': ['olive',
#   'oil',
#   'garlic',
#   'clove',
#   'leaf',
#   'spinach',
#   'pack',
#   'puff',
#   'pastry',
#   'salmon',
#   'fillet',
#   'slice',
#   'salmon',
#   'egg',
#   'beaten',
#   'cumin'],
#  'tour-de-yorkshire-parkin-cake': ['golden',
#   'syrup',
#   'butter',
#   'milk',
#   'egg',
#   'beaten',
#   'flour',
#   'oatmeal',
#   'caster',
#   'sugar',
#   'ginger',
#   'betty',
#   'crocker',
#   'vanilla',
#   'buttercream',
#   'style',
#   'rind',
#   'orange',
#   'special',
#   'valencian',
#   'orange',
#   'extract',
#   'bake',
#   'create',
#   'ready',
#   'roll',
#   'green',
#   'egg',
#   'sugar',
#   'plu',
#   'ice',
#   'cream',
#   'cone',
#   'mini',
#   'marshmallow',
#   'cadbury',
#   'chocolate',
#   'flake',
#   'asda',
#   'chosen',
#   'green',
#   'food',
#   'food',
#   'honey',
#   'oreo',
#   'cookie',
#   'cream',
#   'matchmaker',
#   'mini',
#   'salt',
#   'cake',
#   'board'],
#  'beef-wellington-empanadas': ['button',
#   'mushroom',
#   'onion',
#   'thyme',
#   'olive',
#   'oil',
#   'sirloin',
#   'steak',
#   'thin',
#   'strip',
#   'special',
#   'brussel',
#   'pate',
#   'egg',
#   'milk',
#   'turmeric',
#   'paprika',
#   'pack',
#   'chosen',
#   'ready',
#   'puff',
#   'pastry'],
#  'roast-lamb-with-herby-stuffing': ['shallot',
#   'sunflower',
#   'oil',
#   'plu',
#   'butter',
#   'shallot',
#   'shallot',
#   'breadcrumb',
#   'lemon',
#   'zest',
#   'thyme',
#   'parsley',
#   'mint',
#   'leg',
#   'lamb',
#   'bone',
#   'gravy',
#   'serve',
#   'mintto',
#   'serve',
#   'roast',
#   'potatoe',
#   'serve'],
#  'spider-web-doughnuts': ['asda',
#   'wholemeal',
#   'bread',
#   'flour',
#   'plu',
#   'caster',
#   'sugar',
#   'butter',
#   'sachet',
#   'asda',
#   'easy',
#   'bake',
#   'yeast',
#   'egg',
#   'beaten',
#   'milk',
#   'sugar',
#   'food',
#   'orange',
#   'food'],
#  'irish-onion-soup-with-soda-bread-croutons': ['oil',
#   'onion',
#   'clove',
#   'garlic',
#   'parsley',
#   'thyme',
#   'sugar',
#   'guinnes',
#   'vegetable',
#   'stock',
#   'cube',
#   'slice',
#   'soda',
#   'bread',
#   'les',
#   'fat',
#   'mature',
#   'cheese',
#   'sprig',
#   'thyme',
#   'garnish'],
#  'ghost-emoji-gingerbread-biscuit-recipe': ['light',
#   'muscovado',
#   'sugar',
#   'golden',
#   'syrup',
#   'flour',
#   'bicarbonate',
#   'soda',
#   'ginger',
#   'egg',
#   'yolk',
#   'egg',
#   'sugar',
#   'apricot',
#   'jam',
#   'ready',
#   'roll',
#   'ready',
#   'roll',
#   'royal',
#   'gel',
#   'food',
#   'pink',
#   'gel',
#   'food'],
#  'chilli-prawn-skewers': ['special',
#   'jumbo',
#   'prawn',
#   'juice',
#   'lime',
#   'onion',
#   'length',
#   'mango',
#   'strip',
#   'chilli',
#   'coriander',
#   'sweet',
#   'chilli',
#   'sauce',
#   'fish',
#   'sauce',
#   'special',
#   'oil'],
#  'crushed-meringue-with-pears': ['asda',
#   'meringue',
#   'nest',
#   'broken',
#   'piece',
#   'can',
#   'asda',
#   'pear',
#   'halve',
#   'syrup',
#   'pot',
#   'asda',
#   'greek',
#   'style',
#   'yogurt',
#   'drop',
#   'asda',
#   'special',
#   'vanilla',
#   'extract',
#   'honey',
#   'dark',
#   'chocolate'],
#  'chicken-pie': ['halve',
#   'chestnut',
#   'mushroom',
#   'thick-cut',
#   'gammon',
#   'steak',
#   'piece',
#   'butter',
#   'flour',
#   'chicken',
#   'stock',
#   'single',
#   'cream',
#   'chicken',
#   'ready-to-roll',
#   'puff',
#   'pastry',
#   'shortcrust',
#   'pastry'],
#  'berry-pie-recipe': ['butter',
#   'frozen',
#   'freshnes',
#   'summer',
#   'fruit',
#   'caster',
#   'sugar',
#   'vanilla',
#   'pod',
#   'cornflour',
#   'ready',
#   'shortcrust',
#   'pastry',
#   'egg',
#   'beaten',
#   'double',
#   'cream',
#   'optional',
#   'sugar'],
#  'summer-fruit-trifle': ['smart',
#   'raspberry',
#   'swis',
#   'roll',
#   'asda',
#   'strawberrie',
#   'asda',
#   'raspberrie',
#   'asda',
#   'fruit',
#   'forest',
#   'fruit',
#   'juice',
#   'asda',
#   'ready-made',
#   'custard',
#   'asda',
#   'cream',
#   'strawberrie',
#   'raspberrie',
#   'decorate'],
#  'crispy-cauliflower-parmesan-snack-bites': ['cauliflower',
#   'floret',
#   'sprig',
#   'rosemary',
#   'english',
#   'mustard',
#   'powder',
#   'clove',
#   'garlic',
#   'olive',
#   'oil',
#   'parmesan',
#   'mature',
#   'cheddar',
#   'vegetarian',
#   'version'],
#  'duck-salad': ['tamarind',
#   'optional',
#   'ginger',
#   'sesame',
#   'oil',
#   'garlic',
#   'clove',
#   'lime',
#   'juice',
#   'honey',
#   'asda',
#   'duck',
#   'breast',
#   'fillet',
#   'skin',
#   'sunflower',
#   'oil',
#   'carrot',
#   'strip',
#   'mangetout',
#   'sugar',
#   'snap',
#   'pea',
#   'chilli',
#   'chicken',
#   'stock',
#   'chinese',
#   'leaf',
#   'bean',
#   'sprout',
#   'sprig',
#   'coriander',
#   'plu',
#   'garnish'],
#  'egg-biscuits': ['butter',
#   'caster',
#   'sugar',
#   'drop',
#   'vanilla',
#   'extract',
#   'flour',
#   'cornflour',
#   'cocoa',
#   'powder',
#   'royal',
#   'sugar',
#   'gel',
#   'decorate'],
#  'traditional-rich-fruit-cake': ['asda',
#   'fruit',
#   'sultana',
#   'currant',
#   'rum',
#   'brandy',
#   'sherry',
#   'glacé',
#   'cherrie',
#   'flour',
#   'spice',
#   'butter',
#   'soft',
#   'brown',
#   'sugar',
#   'free-range',
#   'egg',
#   'orange',
#   'zest',
#   'lemon',
#   'zest',
#   'asda',
#   'almond',
#   'paper',
#   'brown',
#   'paper',
#   'deep',
#   'cake',
#   'tin',
#   'square',
#   'cake',
#   'tin'],
#  'zesty-chicken-burger': ['lemon',
#   'clove',
#   'garlic',
#   'parsley',
#   'butcher’',
#   'british',
#   'chicken',
#   'breast',
#   'mini',
#   'fillet',
#   'gem',
#   'lettuce',
#   'wholemeal',
#   'burger',
#   'bun',
#   'tomatoe',
#   'sweet',
#   'potato',
#   'chip',
#   'light',
#   'mayonnaise',
#   'serve'],
#  'jumbo-jammie-dodger': ['caster',
#   'sugar',
#   'butter',
#   'egg',
#   'yolk',
#   'flour',
#   'sugar',
#   'vanilla',
#   'extract',
#   'raspberry',
#   'jam',
#   'smooth',
#   'seedles',
#   'best'],
#  'spinach-ricotta-filo-pastry-parcels': ['olive',
#   'oil',
#   'onion',
#   'bag',
#   'ready',
#   'spinach',
#   'asda',
#   'ricotta',
#   'mature',
#   'cheddar',
#   'cheese',
#   'pack',
#   'jus-rol',
#   'filo',
#   'sheet'],
#  'rhubarb-orange-trifle': ['orange',
#   'caster',
#   'sugar',
#   'rhubarb',
#   'weight',
#   'piece',
#   'asda',
#   'trifle',
#   'sponge',
#   'asda',
#   'shredles',
#   'orange',
#   'marmalade',
#   'cointreau',
#   'orange',
#   'liqueur',
#   'orange',
#   'juice',
#   'pot',
#   'asda',
#   'special',
#   'creamy',
#   'custard',
#   'pot',
#   'asda',
#   'mascarpone',
#   'double',
#   'cream'],
#  'buttermilk-onion-rings': ['buttermilk',
#   'flour',
#   'light',
#   'soy',
#   'sauce',
#   'breadcrumb',
#   'olive',
#   'oil',
#   'pinch',
#   'cayenne',
#   'pepper',
#   'onion',
#   'thick'],
#  'sweet-potato-chicken-curry': ['onion',
#   'sunflower',
#   'oil',
#   'asda',
#   'tikka',
#   'curry',
#   'paste',
#   'can',
#   'coconut',
#   'milk',
#   'pack',
#   'asda',
#   'chicken',
#   'thigh',
#   'fillet',
#   'piece',
#   'slit',
#   'lentil',
#   'sweet',
#   'potato',
#   'bag',
#   'leaf',
#   'spinach',
#   'naan',
#   'bread',
#   'rice',
#   'serve'],
#  'hot-sour-soup-with-carrot-noodles': ['sunflower',
#   'oil',
#   'onion',
#   'clove',
#   'garlic',
#   'hot',
#   'vegetable',
#   'stock',
#   'made',
#   'cube',
#   'carrot',
#   'long',
#   'strip',
#   'resemble',
#   'noodle',
#   'special',
#   'exotic',
#   'mushroom',
#   'pack',
#   'cauldron',
#   'original',
#   'tofu',
#   'can',
#   'bamboo',
#   'shoot',
#   'light',
#   'soy',
#   'sauce',
#   'wine',
#   'vinegar',
#   'lime',
#   'juice',
#   'lime',
#   'zest',
#   'chilli',
#   'chive'],
#  'healthier-macaroni-cheese-with-veg1': ['macaroni',
#   'chosen',
#   'frozen',
#   'freshnes',
#   'broccoli',
#   'cauliflower',
#   'floret',
#   'butter',
#   'flour',
#   'pinch',
#   'cayenne',
#   'pepper',
#   'pinch',
#   'mustard',
#   'powder',
#   'milk',
#   'chosen',
#   'les',
#   'fat',
#   'mature',
#   'british',
#   'cheese',
#   'parmesan',
#   'fine',
#   'breadcrumb',
#   'cherry',
#   'tomatoe'],
#  'sausage-stuffed-onions': ['onion',
#   'top',
#   'base',
#   'olive',
#   'oil',
#   'clove',
#   'garlic',
#   'pork',
#   'sausage',
#   'meat',
#   'skin',
#   'stalk',
#   'thyme',
#   'plu',
#   'sprig',
#   'garnish',
#   'zest',
#   'lemon',
#   'breadcrumb',
#   'flat-leaf',
#   'parsley',
#   'parmesan'],
#  'raspberry-tiramisu': ['trifle',
#   'sponge',
#   'asda',
#   'special',
#   'raspberry',
#   'jam',
#   'sweet',
#   'sherry',
#   'marsala',
#   'can',
#   'peache',
#   'juice',
#   'raspberrie',
#   'mascarpone',
#   'asda',
#   'special',
#   'creamy',
#   'custard',
#   'double',
#   'cream',
#   'dark',
#   'chocolate',
#   'decorate'],
#  'lamb-hotpot': ['lamb',
#   'leg',
#   'steak',
#   'sunflower',
#   'oil',
#   'onion',
#   'carrot',
#   'celery',
#   'stick',
#   'potatoe',
#   'bay',
#   'leaf',
#   'thyme',
#   'plu',
#   'sprig',
#   'chunk',
#   'worcestershire',
#   'sauce',
#   'hot',
#   'lamb',
#   'stock',
#   'butter'],
#  'shoestring-fries-with-turmeric-mayo': ['asda',
#   'real',
#   'mayonnaise',
#   'turmeric',
#   'clove',
#   'garlic',
#   'juice',
#   'lemon',
#   'grower’',
#   'british',
#   'potatoe',
#   'sunflower',
#   'oil'],
#  'wagyu-steak-with-kimchi-pickled-vegetables': ['wagyu',
#   'fillet',
#   'steak',
#   'mooli',
#   'weight',
#   'chinese',
#   'chilli',
#   'bean',
#   'paste',
#   'onion',
#   'cornish',
#   'sea',
#   'salt',
#   'luxury',
#   'pepper',
#   'dulse',
#   'flake',
#   'shichimi',
#   'togarashi',
#   'sesame',
#   'pak',
#   'choi',
#   'radishe'],
#  'pumpkin-pies': ['sheet',
#   'filo',
#   'pastry',
#   'pumpkin',
#   'flesh',
#   'happy',
#   'egg',
#   'happy',
#   'egg',
#   'english',
#   'heather',
#   'honey',
#   'allspice',
#   'ginger',
#   'cinnamon'],
#  'witches-broomsticks': ['asda',
#   'dark',
#   'chocolate',
#   'cocoa',
#   'solid',
#   'asda',
#   'milk',
#   'chocolate',
#   'asda',
#   'smooth',
#   'peanut',
#   'butter',
#   'quality',
#   'street',
#   'matchmaker',
#   'handle',
#   'mikado',
#   'milk',
#   'chocolate',
#   'biscuit',
#   'stick',
#   'elizabeth',
#   'shaw',
#   'dark',
#   'chocolate',
#   'cappuccino',
#   'flute'],
#  'bacon-mushroom-risotto': ['reduced-salt',
#   'chicken',
#   'stock',
#   'cube',
#   'olive',
#   'oil',
#   'onion',
#   'butcher’',
#   'bacon',
#   'medallion',
#   'butter',
#   'mushroom',
#   'arborio',
#   'risotto',
#   'rice',
#   'carnaroli',
#   'risotto',
#   'rice',
#   'herb',
#   'frozen',
#   'pea',
#   'parmesan'],
#  'salmon-with-filo-topping': ['asda',
#   'full',
#   'fat',
#   'soft',
#   'creamy',
#   'cheese',
#   'frozen',
#   'asda',
#   'north',
#   'atlantic',
#   'prawn',
#   'dill',
#   'asda',
#   'frozen',
#   'salmon',
#   'steak',
#   'sheet',
#   'filo',
#   'pastry',
#   'butter',
#   'parmesan',
#   'potatoe',
#   'serve',
#   'green',
#   'bean',
#   'serve'],
#  'rosemary-drizzle-cake': ['butter',
#   'plu',
#   'lemon',
#   'juice',
#   'lemon',
#   'caster',
#   'sugar',
#   'sprig',
#   'rosemary',
#   'rosemary',
#   'flour',
#   'flour',
#   'egg',
#   'lemon',
#   'zest'],
#  'potato-blinis-smoked-salmon-sour-cream': ['potato',
#   'double',
#   'cream',
#   'plu',
#   'double',
#   'cream',
#   'milk',
#   'flour',
#   'egg',
#   'beaten',
#   'lemon',
#   'salmon',
#   'sprig',
#   'dill',
#   'butter'],
#  'veggie-lasagne': ['pack',
#   'asda',
#   'leaf',
#   'spinach',
#   'olive',
#   'oil',
#   'onion',
#   'garlic',
#   'clove',
#   'mushroom',
#   'butter',
#   'thyme',
#   'litre',
#   'milk',
#   'flour',
#   'asda',
#   'coarse',
#   'grain',
#   'mustard',
#   'dry',
#   'lasagne',
#   'sheet',
#   'pre-cook',
#   'mature',
#   'cheddar',
#   'cheese'],
#  'triple-melon-iced-slushie': ['watermelon',
#   'cantaloupe',
#   'melon',
#   'honeydew',
#   'melon',
#   'pineapple',
#   'juice',
#   'lime',
#   'ice',
#   'cube',
#   'juice',
#   'lemon',
#   'strawberrie'],
#  'spanish-style-tortilla-wedges': ['onion',
#   'pepper',
#   'olive',
#   'oil',
#   'charlotte',
#   'potatoe',
#   'left',
#   'cool',
#   'frozen',
#   'pea',
#   'egg',
#   'milk',
#   'chosen',
#   'les',
#   'fat',
#   'mature',
#   'light',
#   'british',
#   'cheese',
#   'salad',
#   'serve'],
#  'tuscan-white-bean-soup': ['olive',
#   'oil',
#   'butter',
#   'onion',
#   'carrot',
#   'clove',
#   'garlic',
#   'herb',
#   'chicken',
#   'stock',
#   'can',
#   'cannellini',
#   'bean',
#   'cherry',
#   'tomatoe',
#   'leftover',
#   'ham',
#   'torn',
#   'piece',
#   'flat-leaf',
#   'parsley',
#   'optional',
#   'crusty',
#   'bread',
#   'serve'],
#  'pea-soup': ['butter',
#   'shallot',
#   'vegetable',
#   'stock',
#   'cube',
#   'potato',
#   'frozen',
#   'pea',
#   'sprig',
#   'mint',
#   'milk',
#   'pack',
#   'asda',
#   'pepper',
#   'sea',
#   'salt',
#   'crouton',
#   'serve'],
#  'stilton-leek-and-mushroom-risotto': ['litre',
#   'hot',
#   'chicken',
#   'stock',
#   'leek',
#   'butter',
#   'olive',
#   'oil',
#   'garlic',
#   'clove',
#   'mushroom',
#   'asda',
#   'arborio',
#   'risotto',
#   'rice',
#   'wine',
#   'optional',
#   'frozen',
#   'pea',
#   'stilton'],
#  'squash-and-spinach-curry': ['scratch',
#   'cook',
#   'butternut',
#   'squash',
#   'chunk',
#   'scratch',
#   'cook',
#   'onion',
#   'balti',
#   'paste',
#   'mango',
#   'chutney',
#   'can',
#   'asda',
#   'chickpea',
#   'reduced-fat',
#   'coconut',
#   'milk',
#   'hot',
#   'stock',
#   'made',
#   'veggie',
#   'stock',
#   'cube',
#   'pack',
#   'grower',
#   'leaf',
#   'spinach',
#   'long-grain',
#   'brown',
#   'rice',
#   'serve',
#   'poppadom',
#   'serve',
#   'optional'],
#  'pasta-with-roasted-butternut-squash': ['butternut',
#   'squash',
#   'onion',
#   'mushroom',
#   'asda',
#   'smart',
#   'herb',
#   'asda',
#   'penne',
#   'pasta',
#   'asda',
#   'lancashire',
#   'cheese',
#   'oil'],
#  'stollen': ['strong',
#   'flour',
#   'plu',
#   'sachet',
#   'asda',
#   'easy',
#   'bake',
#   'yeast',
#   'caster',
#   'sugar',
#   'pinch',
#   'spice',
#   'milk',
#   'lukewarm',
#   'vanilla',
#   'extract',
#   'egg',
#   'beaten',
#   'butter',
#   'lemon',
#   'sultana',
#   'currant',
#   'glacé',
#   'cherrie',
#   'peel',
#   'almond',
#   'marzipan',
#   'sugar',
#   'decorate'],
#  'thyme-walnut-shortbread': ['butter',
#   'still',
#   'firm',
#   'caster',
#   'sugar',
#   'flour',
#   'thyme',
#   'walnut',
#   'choice',
#   'nut'],
#  'masterclass-focaccia': ['asda',
#   'strong',
#   'bread',
#   'flour',
#   'plu',
#   'salt',
#   'sachet',
#   'asda',
#   'easy',
#   'bake',
#   'yeast',
#   'olive',
#   'oil',
#   'plu',
#   'onion',
#   'thyme',
#   'sea',
#   'salt'],
#  'chocolate-truffle-fondant': ['sunflower',
#   'spread',
#   'cocoa',
#   'powder',
#   'special',
#   'fairtrade',
#   'organic',
#   'dominican',
#   'republic',
#   'dark',
#   'chocolate',
#   'sunflower',
#   'spread',
#   'egg',
#   'egg',
#   'yolk',
#   'caster',
#   'sugar',
#   'flour',
#   'special',
#   'italian',
#   'chocolate',
#   'truffle'],
#  'sausage-mummies': ['asda',
#   'puff',
#   'pastry',
#   'flour',
#   'frankfurter',
#   'jar',
#   'egg',
#   'beaten',
#   'asda',
#   'squeezy',
#   'mustard'],
#  'cheesy-sausage-salsa-rollovers': ['special',
#   'pork',
#   'chilli',
#   'sausage',
#   'mission',
#   'deli',
#   'original',
#   'mini',
#   'tortilla',
#   'wrap',
#   'spinach',
#   'mild',
#   'cheddar',
#   'onion',
#   'asda',
#   'cool',
#   'tomato',
#   'salsa'],
#  'salmon-and-avocado-caesar-salad': ['thick',
#   'slice',
#   'bread',
#   'butter',
#   'olive',
#   'oil',
#   'heart',
#   'romaine',
#   'lettuce',
#   'pack',
#   'asda',
#   'special',
#   'salmon',
#   'ripe',
#   'avocado',
#   'asda',
#   'caesar',
#   'bottle',
#   'parmesan',
#   'cheese'],
#  'halloumi-lime-kebabs': ['zest',
#   'lime',
#   'lime',
#   'juice',
#   'olive',
#   'oil',
#   'coriander',
#   'garlic',
#   'clove',
#   'pack',
#   'halloumi',
#   'cube',
#   'plum',
#   'tomatoe',
#   'pepper',
#   'pepper',
#   'courgette',
#   'onion',
#   'wedge'],
#  'farfalle-pasta-with-pea-ham-sauce': ['asda',
#   'chosen',
#   'farfalle',
#   'pasta',
#   'frozen',
#   'pea',
#   'asda',
#   'lighter',
#   'soft',
#   'cheese',
#   'milk',
#   'parmesan',
#   'thick-cut',
#   'ham',
#   'piece'],
#  'brandy-snap-rhubarb-cups': ['rhubarb',
#   'weight',
#   'piece',
#   'caster',
#   'sugar',
#   'butter',
#   'plu',
#   'golden',
#   'syrup',
#   'flour',
#   'ginger',
#   'lemon',
#   'juice',
#   'pot',
#   'asda',
#   'mascarpone',
#   'ball',
#   'stem',
#   'ginger',
#   'syrup',
#   'plu',
#   'syrup'],
#  'chicken-casserole': ['sunflower',
#   'oil',
#   'leek',
#   'onion',
#   'pack',
#   'asda',
#   'chicken',
#   'thigh',
#   'fillet',
#   'skinles',
#   'chicken',
#   'stock',
#   'cube',
#   'dijon',
#   'mustard',
#   'pack',
#   'asda',
#   'chantenay',
#   'carrot',
#   'chestnut',
#   'mushroom',
#   'pack',
#   'asda',
#   'tarragon',
#   'cornflour',
#   'pot',
#   'fat',
#   'crème',
#   'fraîche'],
#  'key-lime-pie-with-blueberries': ['asda',
#   'rich',
#   'highland',
#   'shortie',
#   'anchor',
#   'butter',
#   'egg',
#   'yolk',
#   'asda',
#   'les',
#   'fat',
#   'light',
#   'soft',
#   'cheese',
#   'caster',
#   'sugar',
#   'lime',
#   'zest',
#   'juice',
#   'asda',
#   'double',
#   'cream',
#   'asda',
#   'double',
#   'cream',
#   'asda',
#   'blueberrie',
#   'lime',
#   'zest',
#   'sliver'],
#  'warm-roasted-vegetable-chicken-pasta-salad': ['aubergine',
#   'olive',
#   'oil',
#   'pepper',
#   'plum',
#   'tomatoe',
#   'asda',
#   'special',
#   'fusilli',
#   'giganti',
#   'pasta',
#   'balsamic',
#   'vinegar',
#   'asda',
#   'chosen',
#   'dijon',
#   'mustard',
#   'onion',
#   'chicken',
#   'skin',
#   'torn',
#   'piece',
#   'basil',
#   'leavesto',
#   'serve'],
#  'mini-venison-sausage-rolls-with-cherry-conserve': ['ready',
#   'all-butter',
#   'puff',
#   'pastry',
#   'special',
#   'venison',
#   'burger',
#   'special',
#   'cherry',
#   'conserve'],
#  'lamb-pepper-and-red-onion-stir-fry': ['olive',
#   'oil',
#   'onion',
#   'sweet',
#   'potato',
#   'pepper',
#   'pack',
#   'lamb',
#   'leg',
#   'steak',
#   'pack',
#   'sugar',
#   'snap',
#   'pea',
#   'can',
#   'water',
#   'chestnut',
#   'frozen',
#   'sweetcorn',
#   'pack',
#   'amoy',
#   'straight',
#   'wok',
#   'udon',
#   'thick',
#   'noodle',
#   'pack',
#   'grower’',
#   'sizzlin’',
#   'singapore',
#   'stir-fry',
#   'sauce',
#   'lime',
#   'wedge',
# ...
#   'asda',
#   'smart',
#   'butter',
#   'asda',
#   'smart',
#   'sausage',
#   'pack',
#   'asda',
#   'turkey',
#   'mince',
#   'slice',
#   'bread',
#   'made',
#   'breadcrumb',
#   'asda',
#   'herb',
#   'free-range',
#   'egg',
#   'beaten',
#   'little',
#   'sunflower',
#   'oil',
#   'green',
#   'bean',
#   'serve',
#   'potato',
#   'serve',
#   'gravy',
#   'made',
#   'asda',
#   'chicken',
#   'gravy',
#   'granule',
#   'serve'],
#  'cheats-pad-thai': ['free-range',
#   'egg',
#   'groundnut',
#   'oil',
#   'sunflower',
#   'oil',
#   'bunch',
#   'onion',
#   'frozen',
#   'pea',
#   'bean',
#   'sprout',
#   'pack',
#   'asda',
#   'raw',
#   'prawn',
#   'pack',
#   'asda',
#   'taste',
#   'rice',
#   'noodle',
#   'asda',
#   'soy',
#   'sauce',
#   'asda',
#   'sweet',
#   'chilli',
#   'sauce',
#   'peanut',
#   'lime',
#   'juice',
#   'lime',
#   'wedge',
#   'serve'],
#  'blood-red-ribs-wings': ['asda',
#   'sweet',
#   'chilli',
#   'sauce',
#   'wine',
#   'vinegar',
#   'ketchup',
#   'redcurrant',
#   'pack',
#   'asda',
#   'pork',
#   'rib',
#   'kg',
#   'pack',
#   'asda',
#   'smart',
#   'chicken'],
#  'individual-baked-alaskas': ['powder',
#   'flour',
#   'butter',
#   'caster',
#   'sugar',
#   'egg',
#   'plu',
#   'special',
#   'raspberry',
#   'conserve',
#   'raspberrie',
#   'pack',
#   'chosen',
#   'vanilla',
#   'ice',
#   'cream'],
#  'slow-cooker-chicken-fajitas': ['butcher’',
#   'british',
#   'chicken',
#   'boneles',
#   'thigh',
#   'fillet',
#   'butternut',
#   'squash',
#   'pepper',
#   'soup',
#   'mix',
#   'can',
#   'asda',
#   'mexican',
#   'style',
#   'bean',
#   'mix',
#   'water',
#   'schwartz',
#   'fajita',
#   'coriander',
#   'baker’',
#   'wholemeal',
#   'tortilla'],
#  'sizzling-steak-pizza-with-parsnip-fries': ['asda',
#   'grower’',
#   'parsnip',
#   'thin',
#   'frie',
#   'virgin',
#   'olive',
#   'oil',
#   'asda',
#   'tomatoe',
#   'tomato',
#   'puree',
#   'garlic',
#   'clove',
#   'asda',
#   'herb',
#   'asda',
#   'butcher’',
#   'beef',
#   'steak',
#   'ball',
#   'asda',
#   'light',
#   'mozzarella',
#   'salad',
#   'bag',
#   'serve',
#   'basil',
#   'garnish',
#   'optional'],
#  'simon-rimmers-no-bread-burritos': ['onion',
#   'chilli',
#   'beef',
#   'tomato',
#   'ripe',
#   'avocado',
#   'juice',
#   'lime',
#   'brown',
#   'rice',
#   'tin',
#   'kidney',
#   'bean',
#   'tin',
#   'tomatoe',
#   'jalapeno',
#   'slice',
#   'british',
#   'lion',
#   'egg',
#   'parsley',
#   'oil',
#   'coriander',
#   'optional',
#   'fat',
#   'sour',
#   'cream',
#   'optional',
#   'lime',
#   'optional'],
#  'herby-pork-bake': ['onion',
#   'wedge',
#   'pack',
#   'butcher',
#   'pork',
#   'loin',
#   'steak',
#   'piece',
#   'potatoe',
#   'chantenay',
#   'carrot',
#   'olive',
#   'oil',
#   'herb',
#   'jar',
#   'chosen',
#   'creamy',
#   'apple',
#   'cider',
#   'pour',
#   'sauce'],
#  'bean-and-pesto-soup': ['olive',
#   'oil',
#   'onion',
#   'clove',
#   'garlic',
#   'chillie',
#   'carrot',
#   'vegetable',
#   'stock',
#   'made',
#   'stock',
#   'cube',
#   'can',
#   'cannellini',
#   'bean',
#   'asda',
#   'green',
#   'pesto',
#   'bag',
#   'spinach',
#   'parmesan'],
#  'chicken-ciabatta-sandwich-chunky-chips': ['leftover',
#   'chicken',
#   'ciabatta',
#   'loaf',
#   'asda',
#   'home-style',
#   'frie',
#   'asda',
#   'garlic',
#   'mayonnaise',
#   'iceberg',
#   'lettuce'],
#  'crumpet-pizza': ['crumpet',
#   'ketchup',
#   'slice',
#   'ham',
#   'sweetcorn',
#   'mozzarella',
#   'pepper',
#   'cherry',
#   'tomatoe',
#   'serve',
#   'lettuce',
#   'serve'],
#  'prawn-cod-laksa': ['sunfower',
#   'oil',
#   'clove',
#   'garlic',
#   'piece',
#   'ginger',
#   'coriander',
#   'can',
#   'amoy',
#   'fat',
#   'coconut',
#   'milk',
#   'pack',
#   'chosen',
#   'udon',
#   'noodle',
#   'chosen',
#   'malaysian',
#   'style',
#   'massaman',
#   'paste',
#   'thai',
#   'fish',
#   'sauce',
#   'lime',
#   'zest',
#   'juice',
#   'sugar',
#   'onion',
#   'pack',
#   'beansprout',
#   'pack',
#   'asda',
#   'skinles',
#   'boneles',
#   'line',
#   'caught',
#   'cod',
#   'fillet',
#   'strip',
#   'pack',
#   'raw',
#   'prawn',
#   'chilli',
#   'plu',
#   'slice',
#   'garnish',
#   'coriander',
#   'serve'],
#  'caramelised-french-apple-tart': ['flour',
#   'plu',
#   'butter',
#   'piece',
#   'sugar',
#   'egg',
#   'yolk',
#   'granny',
#   'smith',
#   'apple',
#   'caster',
#   'sugar',
#   'lemon',
#   'juice',
#   'bramley',
#   'apple',
#   'butter',
#   'hartley',
#   'smooth',
#   'apricot',
#   'jam'],
#  'cheats-falafel': ['chickpea',
#   'garlic',
#   'clove',
#   'breadcrumb',
#   'coriander',
#   'parsley',
#   'sesame',
#   'oil',
#   'soy',
#   'sauce',
#   'curry',
#   'paste',
#   'sesame',
#   'vegetable',
#   'oil',
#   'wrap',
#   'serve',
#   'cucumber',
#   'serve',
#   'houmou',
#   'serve'],
#  'butternut-squash-pepper-chickpea-curry': ['vegetable',
#   'oil',
#   'onion',
#   'pepper',
#   'grower’',
#   'butternut',
#   'squash',
#   'sweet',
#   'potato',
#   'slice',
#   'piece',
#   'asda',
#   'balti',
#   'curry',
#   'paste',
#   'can',
#   'chickpea',
#   'can',
#   'tomatoe',
#   'can',
#   'reduced-fat',
#   'coconut',
#   'milk',
#   'sugar',
#   'coriander',
#   'serve',
#   'optional',
#   'rice',
#   'naan',
#   'bread',
#   'serve'],
#  'hot-dog-bean-pies': ['potatoe',
#   'slice',
#   'sunflower',
#   'oil',
#   'onion',
#   'mushroom',
#   'bottle',
#   'asda',
#   'special',
#   'smooth',
#   'passata',
#   'freeze',
#   'rest',
#   'plastic',
#   'container',
#   'another',
#   'day',
#   'cornflour',
#   'can',
#   'cannellini',
#   'bean',
#   'tomato',
#   'ketchup',
#   'asda',
#   'brown',
#   'sauce',
#   'can',
#   'asda',
#   'great',
#   'stuff',
#   'hot',
#   'dog',
#   'butter'],
#  'strawberry-crunch-sundaes': ['asda',
#   'strawberry',
#   'crisp',
#   'cereal',
#   'asda',
#   'double',
#   'cream',
#   'asda',
#   'raspberry',
#   'yogurt',
#   'asda',
#   'strawberrie',
#   'reserve',
#   'strawberrie',
#   'top',
#   'asda',
#   'sprinkle',
#   'decorate'],
#  'fusilli-with-broccoli-marscapone': ['fusilli',
#   'pack',
#   'asda',
#   'special',
#   'purple',
#   'broccoli',
#   'stem',
#   'butter',
#   'onion',
#   'clove',
#   'garlic',
#   'pot',
#   'asda',
#   'mascarpone',
#   'asda',
#   'mature',
#   'cheddar',
#   'asda',
#   'coarse',
#   'grain',
#   'mustard'],
#  'mexican-bean-wraps': ['sunflower',
#   'oil',
#   'onion',
#   'stick',
#   'celery',
#   'pack',
#   'pepper',
#   'pepper',
#   'carton',
#   'asda',
#   'tomatoe',
#   'garlic',
#   'chilli',
#   'powder',
#   'cumin',
#   'can',
#   'asda',
#   'bean',
#   'tomato',
#   'sauce',
#   'asda',
#   'tortilla',
#   'wrap',
#   'serve',
#   'cream',
#   'serve',
#   'cherry',
#   'tomatoe',
#   'serve'],
#  'james-martin-chicken-and-mushroom-pie': ['oil',
#   'asda',
#   'butcher’',
#   'chicken',
#   'breast',
#   'fillet',
#   'onion',
#   'grower’',
#   'mushroom',
#   'butter',
#   'flour',
#   'full-fat',
#   'milk',
#   'bunch',
#   'parsley',
#   'salt',
#   'pepper',
#   'asda',
#   'ready',
#   'puff',
#   'pastry',
#   'egg',
#   'yolk',
#   'plu',
#   'egg',
#   'egg',
#   'wash'],
#  'classic-tomato-bruschetta': ['ciabatta',
#   'loaf',
#   'virgin',
#   'olive',
#   'oil',
#   'plu',
#   'garlic',
#   'clove',
#   'tomatoe',
#   'onion',
#   'basil',
#   'torn',
#   'balsamic',
#   'vinegar',
#   'serve'],
#  'lamb-cooked-in-a-salt-crust': ['butcher',
#   'bone',
#   'lamb',
#   'leg',
#   'pack',
#   'rosemary',
#   'plu',
#   'sprig',
#   'garnish',
#   'flour',
#   'salt',
#   'egg',
#   'flour',
#   'garlic',
#   'bulb',
#   'serve'],
#  'beef-in-oyster-sauce': ['broccoli',
#   'sirloin',
#   'steak',
#   'rump',
#   'steak',
#   'oil',
#   'onion',
#   'mushroom',
#   'soy',
#   'sauce',
#   'oyster',
#   'sauce'],
#  'frankfurter-tomato-soup': ['can',
#   'asda',
#   'great',
#   'stuff',
#   'hot',
#   'dog',
#   'pack',
#   'asda',
#   'micro',
#   'ready',
#   'long',
#   'rice',
#   'can',
#   'asda',
#   'cream',
#   'tomato',
#   'soup',
#   'can',
#   'asda',
#   'sweetcorn',
#   'parsley',
#   'serve'],
#  'sweet-chilli-sauce': ['bird',
#   'eye',
#   'chillie',
#   'pepper',
#   'clove',
#   'garlic',
#   'sugar',
#   'vinegar'],
#  'quick-easy-fritters-recipe': ['asda',
#   'frozen',
#   'vegetable',
#   'onion',
#   'asda',
#   'classic',
#   'mash',
#   'parmesan',
#   'egg',
#   'yolk',
#   'flour',
#   'oil',
#   'reduced-fat',
#   'crème',
#   'fraîche',
#   'pinch',
#   'cayenne',
#   'pepper',
#   'leaf',
#   'spinach'],
#  'sriracha-prawn-lollipops': ['butter',
#   'clove',
#   'garlic',
#   'zest',
#   'lime',
#   'coriander',
#   'sriracha',
#   'fishmonger’',
#   'raw',
#   'prawn',
#   'lime',
#   'wedge'],
#  'broad-bean-rocket-salad-with-bean-butter': ['can',
#   'butter',
#   'bean',
#   'horseradish',
#   'olive',
#   'oil',
#   'lime',
#   'juice',
#   'zest',
#   'broad',
#   'bean',
#   'frozen',
#   'asda',
#   'walnut',
#   'oil',
#   'pack',
#   'asda',
#   'wild',
#   'rocket',
#   'lemon',
#   'wedge',
#   'garnish'],
#  'simnel-cake': ['flour',
#   'flour',
#   'asda',
#   'spice',
#   'glacé',
#   'cherrie',
#   'currant',
#   'sultana',
#   'butter',
#   'caster',
#   'sugar',
#   'plu',
#   'free-range',
#   'egg',
#   'milk',
#   'lemon',
#   'zest',
#   'orange',
#   'zest',
#   'asda',
#   'golden',
#   'marzipan',
#   'apricot',
#   'jam'],
#  'elderflower-rose-and-prosecco-jelly': ['sheet',
#   'leaf',
#   'gelatine',
#   'elderflower',
#   'cordial',
#   'rosewater',
#   'caster',
#   'sugar',
#   'prosecco',
#   'pistachio',
#   'rose',
#   'petal'],
#  'magic-mini-meatloaves-with-slaw': ['asda',
#   'butcher’',
#   'fat',
#   'beef',
#   'mince',
#   'breadcrumb',
#   'onion',
#   'garlic',
#   'clove',
#   'worcestershire',
#   'sauce',
#   'asda',
#   'parsley',
#   'asda',
#   'grower’',
#   'carrot',
#   'wine',
#   'vinegar',
#   'olive',
#   'oil',
#   'honey',
#   'asda',
#   'good',
#   'sunflower',
#   'asda',
#   'chosen',
#   'dijon',
#   'mustard',
#   'asda',
#   'grower’',
#   'kale',
#   'onion',
#   'asda',
#   'grower’',
#   'cabbage',
#   'parsley',
#   'serve'],
#  'Stained-glass-biscuit-recipe': ['butter',
#   'golden',
#   'caster',
#   'sugar',
#   'flour',
#   'egg',
#   'vanilla',
#   'essence',
#   'hard',
#   'sweet'],
#  'chunky-chips': ['potato', 'chunky', 'chip', 'sunflower', 'oil'],
#  'pea-fritters': ['frozen',
#   'pea',
#   'flour',
#   'semi',
#   'milk',
#   'egg',
#   'asda',
#   'halloumi',
#   'cube',
#   'chillie',
#   'flat-leaf',
#   'parsley',
#   'olive',
#   'oil',
#   'salad',
#   'serve'],
#  'greek-style-chicken-pittas': ['pack',
#   'asda',
#   'butcher',
#   'chicken',
#   'breast',
#   'fillet',
#   'piece',
#   'zest',
#   'lemon',
#   'lemon',
#   'juice',
#   'oregano',
#   'olive',
#   'oil',
#   'garlic',
#   'clove',
#   'pack',
#   'asda',
#   'pitta',
#   'bread',
#   'pot',
#   'asda',
#   'tzatziki',
#   'salad',
#   'serve',
#   'onion',
#   'serve',
#   'cherry',
#   'tomatoe',
#   'serve',
#   'pepper',
#   'piece',
#   'serve'],
#  'creole-style-rice-beans': ['sunflower',
#   'oil',
#   'onion',
#   'garlic',
#   'clove',
#   'stick',
#   'celery',
#   'pepper',
#   'green',
#   'pepper',
#   'asda',
#   'chilli',
#   'powder',
#   'mild',
#   'hot',
#   'brown',
#   'long-grain',
#   'rice',
#   'thyme',
#   'coconut',
#   'can',
#   'asda',
#   'pineapple',
#   'chunk',
#   'juice',
#   'can',
#   'kidney',
#   'bean',
#   'dash',
#   'tabasco',
#   'taste'],
#  'gluten-free-crepes': ['gluten-free',
#   'flour',
#   'make',
#   'non',
#   'gluten-free',
#   'flour',
#   'water',
#   'flour',
#   'egg',
#   'milk',
#   'butter',
#   'pear',
#   'gluten-free',
#   'ice',
#   'cream',
#   'serve'],
#  'pork-escalopes-in-creamy-cider-sauce': ['butter',
#   'oil',
#   'pack',
#   'asda',
#   'pork',
#   'escalope',
#   'shallot',
#   'pork',
#   'stock',
#   'made',
#   'pork',
#   'stock',
#   'cube',
#   'dry',
#   'cider',
#   'cider',
#   'thyme',
#   'plu',
#   'serve',
#   'crème',
#   'fraîche',
#   'cornflour',
#   'cox',
#   'apple'],
#  'peach-passion-fruit-creme-fraiche-smash-toast': ['peach',
#   'special',
#   'all-butter',
#   'brioche',
#   'loaf',
#   'reduced-fat',
#   'crème',
#   'fraîche',
#   'special',
#   'mango',
#   'lime',
#   'couli',
#   'passion',
#   'fruit'],
#  'sticky-ribs-with-fried-rice': ['pack',
#   'asda',
#   'pork',
#   'rib',
#   'asda',
#   'sweet',
#   'chilli',
#   'sauce',
#   'honey',
#   'lime',
#   'juice',
#   'five-spice',
#   'powder',
#   'light',
#   'soy',
#   'sauce',
#   'sunflower',
#   'oil',
#   'onion',
#   'asda',
#   'frozen',
#   'rice',
#   'frozen',
#   'pea'],
#  'green-lentils-with-vegetarian-sausages': ['olive',
#   'oil',
#   'onion',
#   'carrot',
#   'stick',
#   'celery',
#   'garlic',
#   'clove',
#   'can',
#   'asda',
#   'tomatoe',
#   'herb',
#   'vegetable',
#   'stock',
#   'cube',
#   'sugar',
#   'asda',
#   'frozen',
#   'meat-free',
#   'lincolnshire',
#   'sausage',
#   'apple',
#   'rosemary',
#   'sausage',
#   'can',
#   'asda',
#   'green',
#   'lentil'],
#  'pumpkin-lasagne': ['olive',
#   'oil',
#   'pumpkin',
#   'skin',
#   'fibre',
#   'asda',
#   'ricotta',
#   'cheese',
#   'garlic',
#   'herb',
#   'soft',
#   'cheese',
#   'butter',
#   'flour',
#   'milk',
#   'pinch',
#   'paprika',
#   'parsley',
#   'mature',
#   'cheddar',
#   'sheet',
#   'asda',
#   'lasagne',
#   'verdi'],
#  'marinated-tuna-steaks': ['cumin',
#   'lime',
#   'zest',
#   'juice',
#   'pack',
#   'micro',
#   'coriander',
#   'olive',
#   'oil',
#   'tuna',
#   'steak',
#   'ripe',
#   'mango',
#   'chillie',
#   'onion',
#   'pinch',
#   'sugar'],
#  'leftover-chicken-barley-broth': ['carrot',
#   'leek',
#   'oil',
#   'onion',
#   'chicken',
#   'stock',
#   'homemade',
#   'made',
#   'stock',
#   'cube',
#   'pearl',
#   'barley',
#   'leftover',
#   'chicken',
#   'savoy',
#   'cabbage'],
#  'miguel-barclays-chicken-fajitas': ['paprika',
#   'cumin',
#   'boneles',
#   'skinles',
#   'chicken',
#   'thigh',
#   'fillet',
#   'onion',
#   'green',
#   'pepper',
#   'cherry',
#   'tomatoe',
#   'reduce',
#   'fat',
#   'crème',
#   'fraîche',
#   'olive',
#   'oil',
#   'flour',
#   'plu'],
#  'chunky-chilli': ['pack',
#   'asda',
#   'butcher',
#   'medallion',
#   'steak',
#   'piece',
#   'sunflower',
#   'oil',
#   'onion',
#   'pack',
#   'asda',
#   'chorizo',
#   'chilli',
#   'powder',
#   'carton',
#   'asda',
#   'tomatoe',
#   'chilli',
#   'hot',
#   'beef',
#   'stock',
#   'made',
#   'stock',
#   'cube',
#   'pepper',
#   'can',
#   'asda',
#   'chilli',
#   'bean',
#   'special',
#   'dark',
#   'chocolate',
#   'cocoa',
#   'solid',
#   'broken',
#   'cream',
#   'serve',
#   'coriander',
#   'serve',
#   'crusty',
#   'bread',
#   'serve'],
#  'chocolate-fridge-cake': ['milk',
#   'chocolate',
#   'chocolate',
#   'broken',
#   'piece',
#   'butter',
#   'madeira',
#   'cake',
#   'asda',
#   'rice',
#   'snap',
#   'asda',
#   'glacé',
#   'cherrie',
#   'digestive',
#   'biscuit',
#   'broken',
#   'asda',
#   'seedles',
#   'raisin',
#   'golden',
#   'syrup',
#   'asda'],
#  'oompa-loompa-cake-pops': ['baker’',
#   'butter',
#   'madeira',
#   'cake',
#   'chosen',
#   'vanilla',
#   'flavour',
#   'drop',
#   'orange',
#   'gel',
#   'food',
#   'chosen',
#   'chocolate',
#   'broken',
#   'piece',
#   'chosen',
#   'cake',
#   'pop',
#   'stick',
#   'chosen',
#   'mini',
#   'marshmallow',
#   'chosen',
#   'dark',
#   'chocolate',
#   'basic',
#   'royal',
#   'see',
#   'left',
#   'green',
#   'orange',
#   'gel',
#   'food',
#   'colour'],
#  'cauliflower-pershwari-naan': ['cauliflower',
#   'egg',
#   'beaten',
#   'garlic',
#   'granule',
#   'almond',
#   'sultana',
#   'pistachio',
#   'butter',
#   'coriander',
#   'tomato',
#   'chutney',
#   'serve'],
#  'heart-biscuits': ['butter',
#   'caster',
#   'sugar',
#   'drop',
#   'vanilla',
#   'extract',
#   'flour',
#   'cornflour',
#   'royal',
#   'sugar',
#   'food',
#   'decorate'],
#  'coronation-chicken': ['pack',
#   'smart',
#   'chicken',
#   'breast',
#   'fillet',
#   'chosen',
#   'apricot',
#   'sharwood’',
#   'korma',
#   'paste',
#   'tomato',
#   'purée',
#   'lemon',
#   'juice',
#   'long',
#   'grain',
#   'rice',
#   'chosen',
#   'light',
#   'mayonnaise',
#   'chosen',
#   'fat',
#   'free',
#   'greek',
#   'style',
#   'yogurt',
#   'can',
#   'del',
#   'monte',
#   'peach',
#   'slice',
#   'juice',
#   'cucumber',
#   'onion'],
#  'spinach-pine-nut-feta-pie': ['bag',
#   'taste',
#   'spinach',
#   'onion',
#   'olive',
#   'oil',
#   'feta',
#   'pine',
#   'nut',
#   'oregano',
#   'dill',
#   'pinch',
#   'nutmeg',
#   'optional',
#   'egg',
#   'beaten',
#   'sheet',
#   'ready-made',
#   'filo',
#   'pastry',
#   'butter'],
#  'gnocchi-with-spinach-tomato': ['pack',
#   'asda',
#   'special',
#   'spinach',
#   'ricotta',
#   'gnocchi',
#   'pot',
#   'asda',
#   'tomato',
#   'basil',
#   'sauce',
#   'mushroom',
#   'bag',
#   'asda',
#   'spinach',
#   'parmesan',
#   'thin',
#   'piece',
#   'vegetable',
#   'peeler',
#   'sharp',
#   'knife',
#   'oil'],
#  'cinnamon-eggy-bread-rabanada': ['egg',
#   'milk',
#   'milk',
#   'vanilla',
#   'extract',
#   'optional',
#   'slice',
#   'brioche',
#   'olive',
#   'oil',
#   'pinch',
#   'cinnamon',
#   'chocolate',
#   'sauce',
#   'serve',
#   'berrie',
#   'serve'],
#  'cheats-lasagne': ['leek',
#   'asda',
#   'butcher',
#   'lean',
#   'beef',
#   'mince',
#   'carrot',
#   'celery',
#   'mushroom',
#   'flour',
#   'knorr',
#   'salt',
#   'beef',
#   'stock',
#   'cube',
#   'can',
#   'tomato',
#   'purée',
#   'oregano',
#   'can',
#   'asda',
#   'green',
#   'lentil',
#   'sheet',
#   'asda',
#   'lasagne',
#   'cornflour',
#   'milk',
#   'english',
#   'mustard',
#   'asda',
#   'mature',
#   'fat',
#   'cheddar',
#   'tomatoe',
#   'basil',
#   'serve',
#   'salad',
#   'serve'],
#  'choux-pastry': ['asda',
#   'strong',
#   'bread',
#   'flour',
#   'butter',
#   'cube',
#   'egg',
#   'beaten',
#   'almond',
#   'ready-to-eat',
#   'apricot',
#   'honey',
#   'drop',
#   'asda',
#   'special',
#   'vanilla',
#   'extract',
#   'double',
#   'cream',
#   'sugar',
#   'dust'],
#  ...}

# %% [markdown]
# ### Search Engine

# %%
def search_engine(user_input, recipes_dict = read_collection_as_dict("recipes_ingredients")):
    """
    Given a list of ingredients from user and the "recipes: [ingredients]" dictionary, order the recipes by a score of suitability.
    It also provides those matching ingredients and missing ingredients for each recommendation. 
    
    Input: 
    - user_input as list. Example:["ingedient1", "ingredient2", ...]
    - recipes_dict as dictionary. Example: "{recipe1: [ingredients], recipe2: [ingredients] recipe3: [ingredients], ...}"
    
    The output are: 
    - recomendations as list. Example: [recipe134, recipe43234, recipe544, ...]
    - matchings as list of sets. Example: [{ingedient1, ingedient2}, {ingedient1}, ...]
    - missings as list of sets. Example: [{}, {ingredient43}, {ingredient32, ingredient45}, ...]
    """
    
    matching = dict()
    missing = dict()
    score = dict()
    
    user_ingredients = set(user_input)
    
    for recipe in recipes_dict.keys():
        
        recom_ingredients = set(recipes_dict[recipe])
        
        matching[recipe] = user_ingredients.intersection(recom_ingredients)   # ingredients in user_input & in recommendation  
        missing[recipe] = recom_ingredients.difference(user_ingredients)   # ingredients from recommendation that user_input not have
        score[recipe] = 10*len(matching[recipe])/(len(missing[recipe])+ len(matching[recipe]))
    
    recommendations_sorted = sorted(score.items(), key=operator.itemgetter(1), reverse=True)
    matching_sorted = [matching[recipe] for recipe, score in dict(recommendations_sorted).items()]
    missing_sorted = [missing[recipe] for recipe, score in dict(recommendations_sorted).items()]
    recommendations_sorted = [recipe_score[0] for recipe_score in recommendations_sorted]
    
    return recommendations_sorted, matching_sorted, missing_sorted
# Out:
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)

# %%
grocery = ["egg", "chicken"]

recom_list, matching_ingredients, missing_ingredients = search_engine(grocery, recipes_ingredients_dic)

# %%
recom_list
# Out:
# ['basic-royal-icing',
#  'icing-recipe',
#  'oven-cooked-new-potatoes',
#  'chicken-with-parmesan-lemon-and-thyme-recipe',
#  'meringue-nests',
#  'masterclass-chicken-gravy',
#  'scrambled-eggs',
#  'chocolate-mousse',
#  'cauliflower-fritters',
#  'prosciutto-wrapped-asparagus',
#  'flipping-fantastic-pancakes',
#  'sponge-recipe',
#  'victoria-sponge-cake',
#  'kluski-polish-dumplings',
#  'chicken-sweetcorn-quiche',
#  'crispy-courgette-sticks',
#  'banana-pancakes',
#  'zesty-lime-coriander-chicken-noodles',
#  'chicken-stir-fry',
#  'zesty-lemon-cupcakes',
#  'bara-brith',
#  'cheesy-chicken-tomato-bake',
#  'tombstone-biscuits',
#  'meringue-bones-and-blood-dip',
#  'kransekake',
#  'ghoulish-ghosts',
#  'kid-friendly-pancakes',
#  'pike',
#  'miguel-barclays-green-shakshuka',
#  'clementine-lemon-curd',
#  'tipsy-cherry-delight',
#  'cheese-red-onion-baked-omelette',
#  'make-your-own-fortune-cookie',
#  'lemon-curd',
#  'autumn-apple-cake',
#  'breaded-chicken-drumsticks',
#  'spanish-tortilla',
#  'potato-chicken-pad-thai',
#  'homemade-chicken-nuggets-with-ranch-dip',
#  'easy-peasy-lemon-curd',
#  'home-baked-rolls',
#  'buttery-biscuits',
#  'paprika-chicken',
#  'chicken-noodle-stir-fry',
#  'chicken-kiev',
#  'chicken-caesar-salad-with-poached-egg',
#  'sausage-mummies',
#  'ham-pea-frittata',
#  'plum-pie',
#  'coffee-nut-meringues',
#  'mini-marzipan-cherry-cake',
#  'toffee-pistachio-meringue',
#  'Stained-glass-biscuit-recipe',
#  'coconut-jam-puddings',
#  'chocolate-almond-mixed-berries-torte',
#  'grey-and-black-macarons',
#  'croissant-with-scrambled-eggs',
#  'chocolate-mud-cake',
#  'queen-cakes',
#  'meringue-pyramid',
#  'basic-20cm-round-madeira-cake',
#  'chicken-drumsticks',
#  'welsh-cakes',
#  'garlic-rosemary-chicken',
#  'basic-15cm-round-madeira-cake',
#  'honey-walnut-cake',
#  'chicken-tomato-red-pepper-houmous-club-sandwich',
#  'banana-bread',
#  'chicken-leek-stilton-pie',
#  'rosemary-drizzle-cake',
#  'white-chocolate-mousse',
#  'brioche-roll-with-smoked-salmon-scrambled-egg',
#  'team-flag-biscuits',
#  'classic-sultana-apricot-tea-bread',
#  'raspberry-chocolate-brownies',
#  'hot-cross-rock-cakes',
#  'smoky-mexican-chicken-fajitas',
#  'chicken-black-bean-stir-fry',
#  'chicken-mushroom-risotto',
#  'sausage-muffins',
#  'scotch-eggs',
#  'tea-bread',
#  'giant-pretzels',
#  'chicken-caesar-salad',
#  'chicken-ciabatta-sandwich-chunky-chips',
#  'chilli-brownies',
#  'welshcakes',
#  'asparagus-samphire-with-parmesan-cheese-soft-boiled-eggs',
#  'tom-daleys-sourdough-french-toast',
#  'masterclass-vanilla-ice-cream',
#  'british-pancakes',
#  'the-ultimate-yule-log',
#  'welsh-cheesecakes',
#  'herb-and-citrus-stuffing',
#  'strawberry-pistachio-mini-meringue-sandwiches',
#  'savoury-drumsticks',
#  'rhubarb-ginger-sponge',
#  'curried-egg',
#  'omelette-baguettes',
#  'sausage-rolls',
#  'miguel-barclays-chicken-and-mushroom-orzo',
#  'spaghetti-carbonara',
#  'oozy-chocolate-egg-brownie',
#  'cornflake-chicken-nuggets-with-spicy-potato-cubes',
#  'chicken-rissoles',
#  'raspberry-rhubarb-pie',
#  'salmon-quinoa-spiced-kedgeree',
#  'colcannon-cakes',
#  'lemon-thyme-roast-chicken',
#  'minted-pea-spring-onion-frittata',
#  'easter-bunny-brioche',
#  'swedish-meatballs',
#  'chorizo-pepper-noodle-pots',
#  'james-martin-sponge-cake',
#  'lemon-meringue-pie',
#  'james-martin-chicken-and-mushroom-pie',
#  'gluten-free-crepes',
#  'chicken-herb-risotto',
#  'chicken-wraps',
#  'banana-fritters',
#  'asparagus-beetroot-tarts',
#  'minced-chicken-with-coriander-fish-sauce',
#  'flowery-egg-tarts',
#  'simple-lemon-meringue-pie',
#  'pink-meringues-with-strawberry-sauce',
#  'blondies',
#  'caramelised-onion-blue-cheese-mini-tarts',
#  'plum-almond-cake',
#  'orange-curd',
#  'cherry-lattice-pie',
#  'peach-curd',
#  'chinese-style-egg-fried-rice',
#  'blueberry-muffins',
#  'crunchy-spiced-chicken',
#  'bone-broth',
#  'miguels-barclays-sweetcorn-and-courgette-feta-fritters',
#  'chicken-nuggets-chunky-chips-mushy-peas',
#  'crunchy-cornflake-chicken-recipe',
#  'chicken-satay-noodle-soup',
#  'bang-bang-turkey-noodles',
#  'jumbo-jammie-dodger',
#  'pumpkin-pies',
#  'potato-blinis-smoked-salmon-sour-cream',
#  'poached-egg-on-toast-with-asparagus-parcels',
#  'potato-cakes-with-spring-greens',
#  'spinach-filo-pie',
#  'chocolate-almond-meringue-gateau',
#  'dutch-baby-pancake',
#  'spanish-omelette',
#  'chicken-chow-mein',
#  'apricot-pistachio-rock-cakes',
#  'easiest-ever-lasagne',
#  'bacon-egg-picnic-pies',
#  'mango-lime-cake',
#  'burrowing-bunnies',
#  'mini-turkey-meat-loaves',
#  'cauliflower-pershwari-naan',
#  'leek-cheese-quiche',
#  'classic-pancakes',
#  'traditional-cornish-pasties',
#  'eggy-bread-with-bacon-banana',
#  'cherry-almond-cake',
#  'basic-20cm-square-madeira-cake',
#  'banana-pecan-honey-loaf',
#  'citrus-tart',
#  'eggs-on-avocado-pancakes',
#  'egg-fried-rice',
#  'egg-and-chorizo-muffins',
#  'berry-meringue-gateau',
#  'sausagemeat-stuffing',
#  'bonfire-muffins',
#  'red-plum-clafoutis',
#  'falafel',
#  'mini-omelettes',
#  'lemon-thyme-chicken',
#  'maryland-chicken',
#  'easter-biscuits',
#  'marmalade-muffins',
#  'frittata',
#  'white-chocolate-brownies',
#  'portuguese-piri-piri-chicken',
#  'lemon-and-poppy-seed-pancakes',
#  'oat-cookies',
#  'spinach-frittata',
#  'blueberry-batter-pudding',
#  'chicken-in-a-bun',
#  'chicken-katsu-curry',
#  'picnic-sausage-rolls',
#  'spaghetti-cake',
#  'piri-piri-chicken-parcel',
#  'turkey-pie',
#  'beetroot-feta-flan',
#  'masterclass-roast-chicken-with-lemon-thyme',
#  'drop-scones-with-smoked-salmon-creme-fraiche',
#  'melt-in-the-middle-fishcakes',
#  'leftover-bread-pudding',
#  'baa-lamb-muffins',
#  'sticky-marmalade-pudding',
#  'no-added-sugar-blueberry-doughnuts',
#  'nutella-cupcakes',
#  'chicken-chorizo-bean-pot-luck-casserole',
#  'white-chocolate-cardamom-cakes',
#  'potato-scones',
#  'blood-red-ribs-wings',
#  'leftover-chicken-barley-broth',
#  'sweet-muesli-muffins',
#  'whopping-party-rings',
#  'asparagus-blue-cheese-slice',
#  'american-style-onion-rings',
#  'perfect-poached-salmon-with-instant-hollandaise-sauce',
#  'turkey-gammon-pie',
#  'mums-special-egg-ham-breakfast',
#  'wholemeal-muffin-pancakes',
#  'doffin',
#  'chicken-pesto-and-sundried-tomato-ciabatta',
#  'egg-cranberry-sausage-plait',
#  'chicken-wings',
#  'carrot-beetroot-fritters',
#  'mushroom-egg-toastie',
#  'yogurt-and-lemon-cake',
#  'green-bean-baked-fries',
#  'apple-snow',
#  'courgette-fries',
#  'creme-caramel',
#  'walnut-topped-pavlova',
#  'blackberry-creme-brulee',
#  'marvellous-mini-egg-cake',
#  'deeply-dark-mousse-with-spiders',
#  'chocolate-orange-cake',
#  'yorkshire-rhubarb-cheesecake',
#  'courgette-cheese-loaf',
#  'orange-cake',
#  'lime-lemon-drizzle-cake',
#  'funfetti-pancakes',
#  'rustic-blackberry-galettes',
#  'chocolate-fondant-puddings',
#  'mini-strawberry-meringues',
#  'stuffed-baked-potatoes',
#  'chicken-leek-pie',
#  'warm-mini-pork-pies',
#  'caesar-salad',
#  'chicken-noodle-soup',
#  'pad-thai',
#  'fondant-fancies',
#  'orange-carrot-soup',
#  'cod-haddock-tagliatelle-carbonara',
#  'salmon-en-croute-by-nick-nairn',
#  'salmon-fish-rosti-recipe',
#  'peanut-butter-cookie-ice-cream-sandwiches',
#  'hot-lemon-souffles',
#  'apricot-hazelnut-meringue',
#  'mushroom-leek-pie',
#  'cheese-dad-biscuits',
#  'turkey-katsu',
#  'orange-semolina-cake',
#  'stuffed-courgettes1',
#  'big-brunch-in-a-pan',
#  'spiced-mixed-nut-selection',
#  'peach-ricotta-and-almond-tart',
#  'sweet-potato-broccoli-gratin',
#  'salmon-pancakes',
#  'honey-pineapple-cake',
#  'gluten-free-clementine-cake',
#  'lamb-cooked-in-a-salt-crust',
#  'cinnamon-eggy-bread-rabanada',
#  'orange-chocolate-cake',
#  'blackberry-almond-cake',
#  'black-forest-baked-alaska',
#  'peach-basil-frangipane-tart',
#  'hot-sour-chicken-noodle-soup',
#  'asparagus-parmesan-slice',
#  'harwich-kitchels',
#  'spinach-mushroom-blue-cheese-roulade',
#  'pear-frangipane-tart-recipe',
#  'cup-cakes',
#  'james-martin-tomkin-tomato-pasta',
#  'leek-blue-cheese-quiche',
#  'chicken-vegetable-soup',
#  'date-chocolate-almond-torte',
#  'white-chocolate-roulade',
#  'christmas-breakfast-eggy-panettone-with-bacon',
#  'cheese-cauliflower-souffles',
#  'rhubarb-tart',
#  'peanut-butter-pancakes',
#  'chocolate-pots',
#  'healthier-chicken-bucket-with-wedges',
#  'leek-cheese-bacon-muffins',
#  'rhubarb-custards',
#  'strawberry-pistachio-roulade',
#  'red-flannel-hash',
#  'chicken-sweetcorn-kebabs',
#  'crunchy-cheese-bites',
#  'clementine-cream-choux-ring',
#  'chicken-with-pesto',
#  'savoury-muffins',
#  'pieclair',
#  'chicken-skewers',
#  'banoffee-pie',
#  'gingerbread-tree-biscuits',
#  'chocolate-sponge-pudding',
#  'cheats-chicken-mushroom-pie',
#  'fishcakes',
#  'raspberry-dark-chocolate-cupcakes',
#  'nadiya-hussain-berry-breakfast-muffins',
#  'rich-chocolate-ginger-cupcakes',
#  'peach-melba-semifreddo',
#  'steak-wellington',
#  'best-ever-bubble-and-squeak',
#  'chocolate-nut-prune-brownies',
#  'apricot-almond-cake',
#  'mummy-pumpkin-pie',
#  'spicy-tomato-shakshuka',
#  'chocolate-almond-parfait',
#  'spicy-eggs-greens-stir-fry',
#  'spring-onion-and-asparagus-frittata',
#  'pineapple-meringue-pie',
#  'classic-lemon-tart',
#  'stilton-and-nut-bites',
#  'bubble-squeak',
#  'speculaas-spiced-cookies',
#  'giant-chocolate-swirl-meringues',
#  'chestnut-walnut-bread',
#  'beef-dippers',
#  'gammon-sweetcorn-and-potato-chowder',
#  'nectarine-tiramisu',
#  'masterclass-scotch-eggs',
#  'courgette-frittata',
#  'pea-fritters-with-poached-egg',
#  'individual-baked-alaskas',
#  'pea-fritters',
#  'masterclass-hollandaise-sauce',
#  'classic-chocolate-eclairs',
#  'chocolate-cream-profiteroles',
#  'leg-of-lamb-on-celeriac-gratin',
#  'sweetcorn-fritters-with-bacon',
#  'hidden-pineapple-pancakes',
#  'potato-sweetcorn-tortilla',
#  'bbq-parkin',
#  'spider-cake',
#  'oriental-nut-stir-fry',
#  'boxing-day-bubble-and-squeak',
#  'prosecco-plum-pavlova',
#  'beef-ale-pie',
#  'rich-fruity-sausage-rolls',
#  'meat-egg-terrine',
#  'tiramisu',
#  'tortilla-pizzas',
#  'jaffa-cake-recipe',
#  'masterclass-pinata-cake',
#  'pavlova',
#  'german-apple-pancake',
#  'duck-cottage-pie',
#  'chocolate-cherry-roulade',
#  'hedgehog-cakes',
#  'chocolate-smarties-cake',
#  'toffee-nut-ice-cream-with-maple-syrup',
#  'creepy-graveyard-cake',
#  'cornish-pasties',
#  'cupcakes',
#  'blood-shots',
#  'cherry-swirl-cupcakes',
#  'american-pancake-stack',
#  'marmalade-cake',
#  'baked-eggs-with-mushrooms',
#  'townie',
#  'cinnamon-grape-muffins',
#  'nectarine-raspberry-crepes',
#  'baby-leaf-chicken-salad',
#  'orange-passion-fruit-meringue-pie',
#  'banana-date-cake',
#  'battenberg-cake',
#  'crepe-in-orange-liqueur',
#  'apricot-chocolate-tart',
#  'the-ultimate-chocolate-brownie',
#  'spider-web-doughnuts',
#  'chicken-pie',
#  'nut-cheese-twists',
#  'grown-up-jaffa-cake',
#  'salmon-tagliatelle',
#  'sticky-toffee-pudding',
#  'macaron-recipe',
#  'eggs-benedict-with-parma-ham',
#  'banoffee-pancakes',
#  'blueberry-gateau',
#  'duck-breast-with-orange-sauce',
#  'chocolate-filled-rosebud-meringues',
#  'chocolate-chip-cookies',
#  'eccles-cakes',
#  'torte-della-nonna',
#  'james-martin-swiss-roll',
#  'gingerbread',
#  'easy-balsamic-roast-chicken',
#  'plum-almond-flan',
#  'chocolate-balloon-cake',
#  'pea-and-sweetcorn-mini-filo-tarts',
#  'james-martins-spatchcock-chicken-recipe',
#  'masterclass-custard-slices',
#  'lamb-beetroot-burgers-with-oven-baked-crisps',
#  'oriental-style-cold-noodle-salad',
#  'sugar-spiced-nuts',
#  'onion-gravy-with-sausages-mash',
#  'cheese-pumpkin-biscuits',
#  'snowmen-cakes',
#  'mint-ice-cream',
#  'salmon-spinach-lasagne',
#  'pumpkin-pine-nut-honey-cake',
#  'strawberry-gateau',
#  'cheats-paella',
#  'baked-mexican-eggs',
#  'cheesy-witches-fingers',
#  'james-martin-yorkshire-parkin-cake',
#  'street-party-mini-quiches',
#  'creamy-chicken-pea-curry',
#  'guinness-cake',
#  'leek-gruyere-flan',
#  'orange-fairy-cakes',
#  'gingerbread-men-skeletons',
#  'spanish-style-omelette',
#  'candy-skull-iced-biscuits',
#  'caramelised-pear-chocolate-upside-down-cake',
#  'bilbos-seed-cake-with-saffron',
#  'chocolate-beetroot-cake',
#  'egg-mayo-sandwiches',
#  'red-onion-bhajis',
#  'chicken-cooked-in-milk-with-garlic-herbs',
#  'injurebread-men',
#  'ham-frittata',
#  'spicy-chicken-salad',
#  'blueberry-burst-pancakes',
#  'parsley-crumbed-chicken',
#  'gingerbread-ice-cream-sandwiches1',
#  'chicken-couscous-salad',
#  'berry-pie-recipe',
#  'chocolate-truffle-fondant',
#  'dairy-free-poppy-seed-and-banana-pancakes',
#  'parsnip-potato-onion-hash-with-egg',
#  'special-spatchcock-chicken',
#  'american-pecan-pie',
#  'shoo-fly-pie',
#  'princess-leia-cinnamon-buns',
#  'oat-coconut-apricot-biscuit-bites',
#  'bubble-and-squeak',
#  'salmon-courgette-quiche-by-glynis-mcguinness',
#  'lemony-prawn-pea-spaghetti',
#  'watercress-soup',
#  'dairy-free-carrot-cake-muffins',
#  'lemon-crumbed-fish-steaks',
#  'chocolate-meringue-with-bananas',
#  'picnic-pie',
#  'dreamy-chocolate-cake',
#  'mixed-berry-blueberry-terrine',
#  'haddock-spinach-bake',
#  'fig-almond-tart',
#  'maids-of-honour',
#  'apricot-pecan-roulade',
#  'chicken-giant-cous-cous-salad',
#  'sunny-med-filo-tarts',
#  'italian-style-chicken',
#  'chicken-breasts-wrapped-in-prosciutto',
#  'scotch-pies-with-beef',
#  'caramelised-french-apple-tart',
#  'rainbow-vegetable-flan',
#  'stuffed-crumbed-portobellos',
#  'bacon-sweetcorn-potato-cakes',
#  'rhubarb-meringue-flan',
#  'union-jack-cake',
#  'devil-emoji-gingerbread-biscuits',
#  'chocolate-beetroot-brownies',
#  'no-pastry-quiche',
#  'hot-cross-loaf',
#  'creamy-chicken-vegetable-curry',
#  'baked-eggs-with-spinach',
#  'stuffed-chicken-breasts',
#  'ginger-treacle-cake',
#  'sweet-and-sticky-drumsticks',
#  'french-fruit-flan',
#  'spinach-blue-cheese-quiche',
#  'chicken-bacon-pearl-barley-vegetable-soup',
#  'pork-chow-mein',
#  'posh-party-sausage-rolls',
#  'sweet-potato-ginger-cake',
#  'chicken-with-spicy-potatoes',
#  'blueberry-seeded-muffins',
#  'french-roasted-chicken',
#  'bread-and-butter-pudding',
#  'fluffy-potato-cakes-with-smoked-salmon',
#  'chicken-vegetable-pilaf',
#  'fresh-frittata-bites',
#  'chicken-breast-in-cabbage',
#  'apricot-mousse',
#  'strawberry-chocolate-flan',
#  'cherry-pistachio-pastries',
#  'skull-pizza',
#  'nutty-avocado-brownies-are-here-to-brighten-up-your-day',
#  'simnel-loaf',
#  'spinach-broccoli-feta-cheese-omelette',
#  'chocolate-caramel-mousse',
#  'chicken-chorizo-and-cauliflower-tray-bake',
#  'banana-pecan-date-muffins',
#  'beef-noodle-stir-fry',
#  'roasted-red-peppers-with-tomatoes',
#  'ghost-emoji-gingerbread-biscuit-recipe',
#  'courgette-feta-filo-tart',
#  'fish-nuggets-with-chunky-chips',
#  'sweet-shortcrust-pastry-for-mince-pies',
#  'scotch-pies',
#  'ice-palace-cake',
#  'chocolate-mint-brownies',
#  'mummy-cake',
#  'spanish-style-chicken',
#  'sweetie-cake',
#  'popcorn-loaded-sticky-toffee-cake',
#  'christmas-pudding-ice-cream',
#  'masterclass-bread',
#  'mini-simnel-cakes',
#  'spinach-feta-tartlets',
#  'oaty-ginger-cake',
#  'masterclass-stuffed-chicken',
#  'quick-easy-fritters-recipe',
#  'eggy-bread-bagels',
#  'fish-finger-butties',
#  'berries-cream-choux-ring',
#  'chicken-jambalaya',
#  'filo-tarts-with-griddled-spring-onions',
#  'the-best-ever-bacon-sandwich',
#  'traditional-pumpkin-pie',
#  'raspberry-chocolate-profiteroles',
#  'spinach-pancakes',
#  'christmas-sausage-rolls',
#  'chicken-tortilla-wraps',
#  'spinach-cheese-rolls',
#  'sweet-potato-chorizo-soup',
#  'extra-quick-one-pan-chicken-roast',
#  'st-patricks-day-cupcakes',
#  'masterclass-key-lime-pie',
#  'pancakes-cherry-sauce',
#  'cherry-profiteroles',
#  'tenderstem-broccoli-fries',
#  'mango-chicken-salad',
#  'prawn-egg-fried-rice',
#  'omelette-arnold-bennett',
#  'berry-pavlova',
#  'basil-strawberry-cupcakes',
#  'braised-broad-beans-peas-artichokes',
#  'chow-mein-with-pork',
#  'sideless-asparagus-quiche',
#  'crepes-suzette',
#  'potato-nests-with-roasted-carrots-courgettes-herb-oil',
#  'blackberry-swirl-yogurt-loaf',
#  'aubergine-tomato-baked-eggs',
#  'fudge-cake-bars',
#  'courgette-corn-fritters-with-red-pepper-salsa',
#  'classic-christmas-cake',
#  'red-velvet-pancakes',
#  'popcorn-turkey-bites',
#  'martha-collison-doughnut-recipe',
#  'butternut-beetroot-tarts-with-creamy-camembert',
#  'chicken-tzaziki-wraps',
#  'bacon-mushroom-risotto',
#  'stilton-leek-and-mushroom-risotto',
#  'masterclass-doughnuts',
#  'the-best-fruit-pudding',
#  'triple-tier-persian-pavlova',
#  'pork-steaks-with-rarebit-topping',
#  'rainbow-cupcakes',
#  'bunny-cupcakes',
#  'asparagus-cherry-tomato-tarts',
#  'warm-asparagus-potato-salad',
#  'john-torode-chocolate-coconut-pie',
#  'sweetcorn-watercress-muffins',
#  'scotch-eggs-with-pimms-ketchup',
#  'mini-quiches',
#  'chocolate-chestnut-roulade',
#  'lebanese-yuletide-turkey-pie',
#  'curried-vegetable-potato-cakes',
#  'salmon-broccoli-filo-tarts',
#  'clean-eating-alices-chicken-and-bacon-traybake-with-new-potatoes',
#  'reduced-sugar-carrot-cake',
#  'orange-and-chocolate-pancakes',
#  'bleeding-ketchup-cheese-bacon-muffins',
#  'coffee-date-pecan-tray-bake',
#  'pesto-crushed-chicken',
#  'maple-roast-turkey',
#  'miguel-barclays-chicken-fajitas',
#  'choux-pastry',
#  'easter-egg-biscuits',
#  'joe-wicks-sweet-potato-shakshuka',
#  'chicken-satay-spring-rolls',
#  'ham-pea-soup',
#  'cowboy-bean-potato-pie',
#  'pimms-cupcakes',
#  'white-chocolate-log',
#  'pork-pie',
#  'broccoli-cheese-souffles',
#  'shakshuka',
#  'bantha-milk-and-cookies',
#  'cheese-potato-pie',
#  'chocolate-cake',
#  'special-occasion-chocolate-cake',
#  'sweet-potato-jackets',
#  'union-jack-tart',
#  'paprika-pork',
#  'gingerbread-emoji-cookies',
#  'salmon-kedgeree',
#  'ginger-pear-upside-down-cake',
#  'classic-pumpkin-pie',
#  'chicken-with-lemon-thyme',
#  'cornish-pasty',
#  'oriental-chicken-skewers',
#  'spiced-snowmen-biscuits',
#  'chocolate-pear-upside-down-pudding',
#  '20-minute-carbonara-with-peas',
#  'vegetable-moussaka',
#  'vivek-singhs-sticky-chicken-wings',
#  'roast-leg-of-pork-with-herb-stuffing-balls',
#  'ginger-cake',
#  'chicken-bean-hotpot',
#  'tomato-quiche',
#  'chicken-and-chickpea-hotpot',
#  'tunisian-style-omelette',
#  'roast-chicken-with-pork-stuffing',
#  'squab-pie',
#  'spanish-style-tortilla-wedges',
#  'chocolate-chilli-flan',
#  'lamb-with-cherry-sauce',
#  'raspberry-cheesecake-brownie',
#  'classic-christmas-pudding',
#  'cherry-almond-trifle',
#  'slow-cooked-duck-with-cherry-sauce',
#  'turkey-courgette-meatloaves',
#  'quick-turkey-pie',
#  'duck-breast',
#  'baked-fish-and-chips-with-mushy-peas',
#  'chicken-summer-vegetable-tray-bake',
#  'mac-and-cheese-with-chicken-and-leeks',
#  'biscotti',
#  'fish-and-chips-with-mushy-peas',
#  'easy-tuna-nicoise-salad',
#  'chicken-mushroom-bake',
#  'leek-chicken-risotto',
#  'sweet-potato-broccoli-quiche',
#  'spicy-chicken-chickpea-tomato-casserole',
#  'caterpillar-cake',
#  'pork-meatballs',
#  'lemon-mousse-with-gin-lemon-jelly',
#  'fiorentina-pizza',
#  'simnel-cake',
#  'spinach-pine-nut-feta-pie',
#  'coconut-chicken-akoho-sy-voanio',
#  'pecan-pie',
#  'tandoori-chicken-kebabs-with-tomato-cucumber-salad',
#  'club-sandwich-pasta',
#  'masterclass-christmas-cake',
#  'potato-crust-pizza',
#  'ham-broccoli-sweetcorn-frittata',
#  'butternut-thyme-bakes',
#  'saffron-rose-water-flan',
#  'pear-tart-recipe',
#  'simple-bread-butter-pudding',
#  'rich-chocolate-cake',
#  'cherry-bakewell-slices',
#  'indian-chicken-rice',
#  'spanish-style-ham-croquettes',
#  'braised-peas-lettuce-with-chicken',
#  'mexican-chicken-bean-soup',
#  'cheesecake-with-blueberries',
#  'leek-crab-turnovers',
#  'spicy-lentil-carrot-patties',
#  'hot-cross-buns',
#  'shakshuka-made-simple',
#  'black-eye-fritters',
#  'fathers-day-giant-cookies',
#  'sticky-toffee-puddings',
#  'chilli-chicken-mixed-vegetable-stir-fry',
#  'stir-fried-chicken-with-peppers',
#  'Red-wine-brownie-recipe',
#  'rich-chocolate-fairy-cakes',
#  'creamy-parsnip-turkey-bacon-pasta',
#  'butternut-squash-ravioli',
#  'hedgehog-buns',
#  'chocolate-bread-butter-pudding',
#  'beef-wellington-empanadas',
#  'zesty-chicken-burger',
#  'key-lime-pie-with-blueberries',
#  'coronation-chicken-skewers-with-mango-lime-mayo',
#  'scampi-chips',
#  'pink-pinata-cake',
#  'mini-hot-cross-buns',
#  'mini-christmas-eccles-cakes',
#  'vegetable-pie',
#  'white-chocolate-coconut-rainbow-brownie',
#  'courgette-flan',
#  'minced-beef-onion-pies',
#  'fruity-meringues',
#  'crab-cakes',
#  'masterclass-spinach-ricotta-ravioli',
#  'oriental-noodle-chicken',
#  'tuna-balls-in-tomato-red-pepper-sauce',
#  'the-fully-loaded-brownie',
#  'masterclass-panettone',
#  'deep-dish-apple-crumble-pie',
#  'individual-venison-wellingtons',
#  'rhubarb-cheesecake',
#  'oven-cooked-creamy-mushroom-risotto',
#  'hoisin-pork-stir-fry',
#  'mini-turkey-burgers',
#  'spring-veg-chicken-pasta-broth-with-parsnip-crisps',
#  'balti-chicken',
#  'stacked-crispy-halloumi-burger',
#  'lemon-creme-fraiche-parmesan-pasta',
#  'oriental-spring-rolls',
#  'steamed-herby-chicken',
#  'pulled-ham-kale-lentil-salad-with-fried-egg',
#  'spanish-spiced-sausage-rolls',
#  'apricot-chicken-with-vegetable-rice',
#  'lemon-cheesecake',
#  'mediterranean-leftover-vegetable-frittata-recipe',
#  'eggs-and-spinach-florentine-cheats-pizza',
#  'gala-pie',
#  'wonkas-gobstopper-cake',
#  'roast-duck-with-cherry-sauce',
#  'jerk-chicken-wings',
#  'spider-bread',
#  'caesar-salad-with-eggs-bacon',
#  'tenderstem-broccoli-base-pizza',
#  'golden-snitch-cake-pops',
#  'nectarine-cream-flan',
#  'chicken-broccoli-pie',
#  'cheats-steak-ale-pie',
#  'prawn-egg-stir-fry',
#  'tilly-ramsays-chicken-skewers',
#  'superbowl-biscuits',
#  'salmon-asparagus-mini-pies',
#  'cheats-cranberry-danish',
#  'monster-cake',
#  'chicken-pomegranate-salad',
#  'flat-ham-pie',
#  'steak-ale-pie',
#  'lisa-faulkners-family-bolognese',
#  'slow-cooker-chicken-fajitas',
#  'smoked-salmon-cheddar-rocket-muffins',
#  'beefburgers',
#  'lemon-olive-chicken-tagine',
#  'butternut-squash-mac-n-cheese',
#  'sweet-potato-spinach-feta-quiche',
#  'asparagus-filo-pie',
#  'microwavable-lime-cheesecake',
#  'lemon-coconut-cake',
#  'red-velvet-bites',
#  'chicken-chorizo',
#  'south-african-bobotie',
#  'nectarine-tart',
#  'bakewell-tart',
#  'quiche-lorraine',
#  'fruit-mascarpone-sandwich-cake',
#  'chocolate-muffin-puddings',
#  'moroccan-style-spatchcock-chicken-with-dill-yogurt',
#  'chicken-butternut-squash-korma',
#  'chicken-with-creamy-asparagus-sauce',
#  'turkey-wellingtons-with-sweet-potato-fries',
#  'caribbean-chicken',
#  'turkey-fricassee',
#  'nicoise-salad',
#  'pork-with-cajun-style-rice',
#  'carrot-cupcakes',
#  'coconut-granola-muffins',
#  'turkey-mince-cottage-pie-with-sweet-potato-topping',
#  'black-bun',
#  'spring-green-chicken-butterbean-soup',
#  'glazed-chicken-vegetable-roast',
#  'apple-crumble-parmesan-cake',
#  'chicken-casserole',
#  'warm-roasted-vegetable-chicken-pasta-salad',
#  'blueberry-cheesecake',
#  'sweet-potato-cakes-with-bulgur-salad',
#  'pork-in-mustard-sauce',
#  'individual-spooky-beef-pies',
#  'gooey-christmas-pudding-cookies',
#  'james-martin-smoked-salmon-tart',
#  'gluten-free-dutch-baby-pancake-with-summer-berries',
#  'cheesy-colcannon-croquettes',
#  'luxury-fish-pie',
#  'chocolate-pudding',
#  'smoked-haddock-fishcakes-with-tartare-sauce',
#  'pork-ball-broth',
#  'savoury-chestnut-mushroom-bake',
#  'bloody-brains',
#  'sausage-twists',
#  'vampire-cakes',
#  'warm-prawn-kale-noodle-salad',
#  'stir-fried-broccoli-with-beef',
#  'spiders-web-cheesecake',
#  'stir-fried-beef-and-noodles-in-a-black-bean-sauce',
#  'parmesan-crusted-haddock',
#  'chocolate-cup-cakes',
#  'raspberry-swirl',
#  'mini-yorkshire-puddings-with-beef',
#  'easter-egg-cake',
#  'sweetcorn-chicken-samosas',
#  'pasta-with-leeks-chorizo-beans',
#  'falafel-wraps-with-sweet-potato-wedges',
#  'primavera-risotto',
#  'quiche-with-salad-leaves-balsamic-dressing',
#  'apple-date-charlotte',
#  'pumpkin-fruit-tea-bread',
#  'caribbean-curry-patties-and-zingy-salsa',
#  'special-steak-wellington',
#  'lemon-parmesan-cod-with-herby-mash',
#  'madras-egg-curry',
#  'ham-pineapple-muffins',
#  'cranberry-and-clementine-cheesecake',
#  'bunny-cake',
#  'cheese-leek-and-potato-pie',
#  'posh-fish-finger-butty',
#  'beetroot-potato-chorizo-hash',
#  'prawn-stir-fry',
#  'tuscan-white-bean-soup',
#  'mega-iced-gems',
#  'meatballs-in-tomato-sauce',
#  'sticky-grilled-ginger-chicken-with-carrot-salad',
#  'spinach-chicken-pasta',
#  'spring-chicken-casserole',
#  'toad-in-the-hole',
#  'chocolate-fudge-tart',
#  'fish-fingers-with-minted-mushy-peas-and-sweet-potato-chips',
#  'chicken-cherry-salad',
#  'mushroom-puffs',
#  'simon-rimmers-bobotie',
#  'cous-cous-kedgeree-summer-salad',
#  'new-york-cheesecake',
#  'greek-style-chicken-pittas',
#  'gluten-free-bread',
#  'chicken-curry',
#  'banana-muffins',
#  'bacon-sweetcorn-sweet-potato-chowder',
#  'fish-wraps',
#  'asian-style-salmon-potato-croquettes',
#  'lemon-ginger-cheesecake',
#  'noodle-pots',
#  'catalan-style-slow-cooker-chicken',
#  'tenderstem-muffins',
#  'spicy-steak-burgers',
#  'posh-fish-finger-butties',
#  'raspberry-candy-cane-cake',
#  'sticky-ginger-cake',
#  'chinese-mushrooms-with-egg-noodles',
#  'cheesy-chicken-pasta',
#  'chocolate-pear-tart',
#  'tuna-fish-cakes',
#  'thai-fish-cakes',
#  'classic-roast-chicken',
#  'cucur-udang-malaysian-prawn-fritters',
#  'easy-peasy-fish-cakes',
#  'salmon-fishcakes',
#  'traditional-rich-fruit-cake',
#  'sweet-potato-chicken-curry',
#  'persian-love-cake',
#  'chocolate-gateau',
#  'moussaka',
#  'chicken-chorizo-salad',
#  'mini-chilli-beef-bean-pies',
#  'warm-noodle-salad',
#  'simon-rimmers-no-bread-burritos',
#  'pea-asparagus-risotto',
#  'beef-mushroom-spider-pie',
#  'blackboard-tombstone-cake',
#  'chicken-in-creamy-mustard-sauce',
#  'chicken-ham-chowder',
#  'bean-mushroom-burgers',
#  'pork-with-prunes',
#  'sticky-drumsticks',
#  'smoky-pork-burgers',
#  'omelette-gateau',
#  'chicken-mango-salad',
#  'chicken-chorizo-skewers-with-rainbow-rice',
#  'sundae-baked-alaska-recipe',
#  'oriental-turkey-meatballs',
#  'strawberry-elderflower-trifle',
#  'vegetarian-toad-in-the-hole-recipe',
#  'mushroom-chestnut-pithivier',
#  'bling-my-brownie',
#  'beef-stir-fry',
#  'balsamic-chicken-with-pasta',
#  'coq-au-vin-blanc',
#  'turkey-satay-stir-fry',
#  'salmon-pie',
#  'pork-burgers-with-sweet-potato-wedges',
#  'tuna-nicoise-salad',
#  'chicken-satay-skewers',
#  'cheats-pad-thai',
#  'leek-mustard-cheese-tart',
#  'moroccan-pulled-pork-with-fruity-couscous',
#  'chicken-mushroom-hotpot',
#  'spider-web-cake',
#  'daffodil-cake',
#  'winter-garden-carrot-and-parsnip-cake',
#  'passion-fruit-lemon-baked-cheese-cake',
#  'pork-with-apple-wedges-ginger',
#  'really-simple-chicken-biryani',
#  'summer-turkey-stew',
#  'sweet-sour-chicken-with-rice',
#  'pan-fried-pork-with-apple-wedges',
#  'stollen',
#  'pumpkin-patch-cake',
#  'flower-bowl-cake',
#  'chicken-chasseur',
#  'plaice-with-spinach-crab-stuffing',
#  'masterclass-maple-roasted-parsnip-risotto-topped-with-pan-fried-chicken-breast',
#  'pork-cider-pot',
#  'vegetarian-floral-flan',
#  'jambalaya',
#  'haddock-parsley-fish-cakes',
#  'jerk-chicken-with-rainbow-rice',
#  'honey-mustard-chicken-with-glazed-carrots',
#  'sweetcorn-cakes-with-avocado-salsa',
#  'turkey-mushroom-pie',
#  'smoky-chicken-fajitas',
#  'moroccan-couscous',
#  'cheese-spinach-bread-bake',
#  'vegetable-nut-loaf',
#  'butter-chicken',
#  'american-meatloaf',
#  'apricot-glazed-chicken',
#  'time-saving-turkey-stroganoff',
#  'chicken-peanut-butter-curry',
#  'sweetcorn-chowder-with-gammon',
#  'moroccan-spiced-lamb-pie',
#  'salmon-en-croute',
#  'baked-salmon-fish-fingers-with-homemade-tartare-sauce-by-lorraine-pascale',
#  'chocolate-gravity-cake',
#  'saussage-and-root-vegetable-stew-recipe',
#  'chicken-with-roasted-tomato-bean-salad',
#  'cheats-croque-madame',
#  'chocolate-muffin-cheesecake',
#  'beef-and-vegetable-lasagne',
#  'chicken-with-tarragon',
#  'pea-croquettes-with-beetroot-salad',
#  'tofu-stir-fry',
#  'butternut-squash-noodles',
#  'smoked-fish-horseradish-fishcakes',
#  'chicken-cherry-tray-bake',
#  'tomato-chicken-sweetcorn-soup',
#  'moroccan-roasted-lamb',
#  'beef-cheese-jalapeno-spring-rolls-with-plum-dip',
#  'chicken-pumpkin-curry',
#  'cheats-moussaka',
#  'beef-schnitzel-with-mustard-mayo-cucumber-pickle',
#  'coq-au-vin',
#  'mexican-lasagne',
#  'salmon-salad-with-caesar-style-dressing',
#  'make-ahead-lasagne',
#  'fish-and-vegetable-pie',
#  'pork-with-caraway-crust',
#  'vegetable-spring-rolls',
#  'thai-chicken-curry',
#  'funky-pumpkin-burgers',
#  'korean-chicken-burgers-with-kimchi',
#  'speedy-chicken-and-leek-casserole',
#  'broccoli-mushroom-noodles',
#  'levi-roots-chicken-curry',
#  'mega-carrot-cake',
#  'gluten-free-banana-pecan-cake',
#  'juicy-jerk-chicken-thighs-with-caribbean-slaw',
#  'spring-chicken-curry-in-a-hurry',
#  'hot-sour-soup',
#  'carrot-shaped-chocolate-cake',
#  'bunny-cakes',
#  'rich-sausage-bean-stew',
#  'beach-hut-cake',
#  'banh-mi-style-chicken-salad-with-pickles',
#  'chicken-bacon-avocado-salad',
#  'traditional-christmas-cake',
#  'chicken-madras',
#  'coronation-chicken',
#  'orange-chocolate-cheesecake',
#  'paella',
#  'mexican-chicken-avocado-and-bean-salad',
#  'classic-paella',
#  'stuffed-peppers1',
#  'camouflage-cupcakes',
#  'classic-coronation-chicken',
#  'turkey-cranberry-mini-pies',
#  'beef-koftas-couscous-tortillas',
#  'tandoori-chicken-breast-with-mint-coriander-chutney',
#  'chicken-katsu-curry-with-salad',
#  'crispy-lobster-cocktail',
#  'fajitas',
#  'duck-salad',
#  'galaxy-mirror-glaze-cake',
#  'black-forest-gateau',
#  'alice-in-wonderland-teapot-cake',
#  'tropical-dried-fruit-cheesecake',
#  'vegetable-pad-thai',
#  'meatballs-in-tomato-red-pepper-sauce',
#  'rice-salad-with-griddled-chicken',
#  'turkey-satay-noodles',
#  'sausage-casserole',
#  'sweet-sour-chicken',
#  'chicken-wings-with-blue-cheese-dressing',
#  'breaded-fish-with-chunky-chips-crushed-peas',
#  ...]

# %%
matching_ingredients
# Out:
# [{'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken', 'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken', 'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'egg'},
#  {'chicken'},
#  {'egg'},
#  {'chicken'},
#  {'chicken'},
#  {'chicken'},
#  {'egg'},
#  ...]

# %%
missing_ingredients
# Out:
# [{'sugar'},
#  {'sugar'},
#  {'butter', 'potatoe', 'stock'},
#  {'breadcrumb',
#   'breast',
#   'butter',
#   'fillet',
#   'flour',
#   'lemon',
#   'parmesan',
#   'sprig',
#   'thyme'},
#  {'cherrie', 'cream', 'double', 'strawberrie', 'sugar'},
#  {'flour', 'frozen', 'juice', 'roast', 'stock'},
#  {'bread', 'butter', 'milk', 'serve', 'wholegrain'},
#  {'chocolate', 'cream', 'dark', 'free-range', 'yolk'},
#  {'cauliflower', 'floret', 'flour', 'milk', 'oil'},
#  {'asparagu', 'chosen', 'grower’', 'pack', 'prosciutto', 'serve'},
#  {'flour', 'free-range', 'milk', 'oil', 'pinch', 'salt'},
#  {'butter', 'caster', 'extract', 'flour', 'sugar', 'vanilla'},
#  {'butter', 'caster', 'flour', 'jam', 'raspberry', 'sugar'},
#  {'beaten', 'butter', 'flour', 'salt', 'warm', 'water'},
#  {'bag',
#   'bistro',
#   'case',
#   'cream',
#   'double',
#   'leftover',
#   'pastry',
#   'potato',
#   'salad',
#   'savoury',
#   'sweetcorn',
#   'wedge'},
#  {'courgette', 'flour', 'lengthwise', 'milk', 'polenta', 'stick'},
#  {'banana', 'blueberrie', 'pack', 'raspberrie', 'ripe', 'strawberrie'},
#  {'asda',
#   'chilli',
#   'free',
#   'fry',
#   'leftover',
#   'mix',
#   'noodle',
#   'oil',
#   'rainbow',
#   'range',
#   'sauce',
#   'stir',
#   'sweet'},
#  {'asda',
#   'bag',
#   'dry',
#   'grower’',
#   'hoisin',
#   'noodle',
#   'oil',
#   'pack',
#   'sauce',
#   'stir-fry',
#   'sunday',
#   'vegetable',
#   'weight'},
#  {'butter', 'caster', 'flour', 'free-range', 'lemon', 'powder', 'sugar'},
#  {'bag', 'beaten', 'flour', 'fruit', 'spice', 'sugar', 'tea'},
#  {'cheese', 'leftover', 'mix', 'mushroom', 'pasta', 'tin', 'tomatoe'},
#  {'butter', 'caster', 'chocolate', 'decorate', 'flour', 'sugar', 'yolk'},
#  {'caster',
#   'jam',
#   'raspberrie',
#   'raspberry',
#   'seedles',
#   'strawberrie',
#   'sugar'},
#  {'almond', 'decorate', 'extract', 'french', 'royal', 'special', 'sugar'},
#  {'asda', 'caster', 'coconut', 'free-range', 'plu', 'roll', 'sugar'},
#  {'flour', 'free-range', 'milk', 'oil', 'pinch', 'salt', 'sunflower'},
#  {'butter', 'caster', 'flour', 'jam', 'raspberrie', 'raspberry', 'sugar'},
#  {'feta', 'frozen', 'handful', 'oil', 'olive', 'onion', 'pea', 'spinach'},
#  {'butter', 'caster', 'clementine', 'juice', 'lemon', 'sugar', 'yolk', 'zest'},
#  {'caster',
#   'cherrie',
#   'free-range',
#   'marsala',
#   'sherry',
#   'sugar',
#   'sweet',
#   'yolk'},
#  {'cheese', 'cheshire', 'chosen', 'milk', 'oil', 'olive', 'onion', 'plu'},
#  {'almond',
#   'butter',
#   'caster',
#   'corn',
#   'extract',
#   'flour',
#   'sugar',
#   'vanilla'},
#  {'beaten', 'butter', 'caster', 'cube', 'juice', 'lemon', 'sugar', 'zest'},
#  {'apple', 'butter', 'caster', 'english', 'flour', 'russet', 'self', 'sugar'},
#  {'asda',
#   'breadcrumb',
#   'butter',
#   'cayenne',
#   'cheese',
#   'coarse-grain',
#   'drumstick',
#   'free-range',
#   'grana',
#   'herb',
#   'mustard',
#   'pack',
#   'padano',
#   'pepper',
#   'salad',
#   'serve'},
#  {'free-range', 'frozen', 'oil', 'olive', 'onion', 'pea', 'pepper', 'potatoe'},
#  {'beansprout',
#   'beaten',
#   'breast',
#   'chilli',
#   'clove',
#   'coriander',
#   'garlic',
#   'ginger',
#   'oil',
#   'onion',
#   'peanut',
#   'potatoe',
#   'sauce',
#   'sesame',
#   'soy',
#   'sunflower'},
#  {'approx',
#   'boneles',
#   'cayenne',
#   'chive',
#   'cornflake',
#   'flour',
#   'handful',
#   'ketchup',
#   'low-fat',
#   'natural',
#   'parsley',
#   'pepper',
#   'skinles',
#   'thigh',
#   'tomato',
#   'yogurt'},
#  {'butter',
#   'caster',
#   'cube',
#   'juice',
#   'lemon',
#   'lightlybeaten',
#   'sugar',
#   'zest'},
#  {'beaten',
#   'bread',
#   'butter',
#   'easy-bake',
#   'flour',
#   'glaze',
#   'strong',
#   'yeast'},
#  {'butter', 'caster', 'drop', 'extract', 'flour', 'sugar', 'vanilla', 'yolk'},
#  {'asda',
#   'boneles',
#   'can',
#   'fillet',
#   'flat-leaf',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'paprika',
#   'parsley',
#   'pepper',
#   'serve',
#   'skin',
#   'sunflower',
#   'thigh',
#   'tomatoe'},
#  {'asda',
#   'breast',
#   'chilli',
#   'chosen',
#   'fry',
#   'light',
#   'mushroom',
#   'noodle',
#   'oil',
#   'pack',
#   'piece',
#   'sauce',
#   'soy',
#   'stir',
#   'sweet',
#   'third',
#   'vegetable'},
#  {'beaten',
#   'bread',
#   'breadcrumb',
#   'breast',
#   'butter',
#   'clove',
#   'flour',
#   'garlic',
#   'juice',
#   'lemon',
#   'made',
#   'parsley',
#   'salad',
#   'serve',
#   'squeeze',
#   'stale',
#   'tomatoe'},
#  {'asda',
#   'bread',
#   'breast',
#   'caesar',
#   'ciabatta',
#   'day',
#   'fillet',
#   'free-range',
#   'heart',
#   'lettuce',
#   'oil',
#   'old',
#   'olive',
#   'parmesan',
#   'peeler',
#   'plu',
#   'romaine'},
#  {'asda',
#   'beaten',
#   'flour',
#   'frankfurter',
#   'jar',
#   'mustard',
#   'pastry',
#   'puff',
#   'squeezy'},
#  {'cheddar',
#   'frozen',
#   'ham',
#   'mature',
#   'oil',
#   'onion',
#   'pea',
#   'slice',
#   'sunflower'},
#  {'beaten',
#   'butter',
#   'cinnamon',
#   'cornflour',
#   'flour',
#   'glaze',
#   'plu',
#   'plum',
#   'sugar'},
#  {'broken',
#   'chocolate',
#   'chosen',
#   'coffee',
#   'dark',
#   'granule',
#   'instant',
#   'square',
#   'sugar'},
#  {'almond',
#   'butter',
#   'caster',
#   'cherrie',
#   'cube',
#   'flour',
#   'glace',
#   'marzipan',
#   'sugar'},
#  {'butter',
#   'caster',
#   'cream',
#   'double',
#   'pistachio',
#   'plu',
#   'sauce',
#   'sugar',
#   'toffee'},
#  {'butter',
#   'caster',
#   'essence',
#   'flour',
#   'golden',
#   'hard',
#   'sugar',
#   'sweet',
#   'vanilla'},
#  {'caster',
#   'coconut',
#   'flora',
#   'flour',
#   'jam',
#   'milk',
#   'original',
#   'raspberry',
#   'sugar'},
#  {'almond',
#   'berrie',
#   'caster',
#   'chocolate',
#   'cream',
#   'double',
#   'frozen',
#   'happy',
#   'sugar'},
#  {'almond',
#   'caster',
#   'food',
#   'jam',
#   'jar',
#   'raspberry',
#   'sugar',
#   'sugarflair',
#   '‘liquorice’*'},
#  {'bake-it-fresh',
#   'butter',
#   'chive',
#   'croissant',
#   'ham',
#   'jus-roll',
#   'milk',
#   'pack',
#   'slice'},
#  {'black’',
#   'butter',
#   'caster',
#   'chocolate',
#   'dark',
#   'free-range',
#   'green',
#   'plu',
#   'sugar'},
#  {'asda',
#   'butter',
#   'cake',
#   'caster',
#   'decoration',
#   'flour',
#   'free-range',
#   'sugar',
#   'sultana'},
#  {'caster',
#   'cream',
#   'double',
#   'edible',
#   'flake',
#   'glitter',
#   'optional',
#   'pack',
#   'sugar'},
#  {'beaten',
#   'butter',
#   'cake',
#   'caster',
#   'extract',
#   'flour',
#   'sugar',
#   'tin',
#   'vanilla'},
#  {'asda',
#   'bread',
#   'butter',
#   'cornflake',
#   'crust',
#   'day',
#   'drumstick',
#   'dry',
#   'flour',
#   'free-range',
#   'mustard',
#   'old',
#   'pack',
#   'paprika',
#   'parmesan',
#   'powder',
#   'preferable',
#   'sesame'},
#  {'butter',
#   'caster',
#   'decorate',
#   'flour',
#   'pinch',
#   'salt',
#   'spice',
#   'sugar',
#   'sultana'},
#  {'breast',
#   'clove',
#   'fillet',
#   'garlic',
#   'lemon',
#   'oil',
#   'olive',
#   'rosemary',
#   'stalk'},
#  {'beaten',
#   'butter',
#   'cake',
#   'caster',
#   'extract',
#   'flour',
#   'sugar',
#   'tin',
#   'vanilla'},
#  {'asda',
#   'butter',
#   'caster',
#   'flour',
#   'free-range',
#   'honey',
#   'self',
#   'sugar',
#   'walnut'},
#  {'beef',
#   'bread',
#   'cornichon',
#   'houmou',
#   'pepper',
#   'pickle',
#   'salad',
#   'slice',
#   'tomato'},
#  {'banana',
#   'butter',
#   'caster',
#   'flour',
#   'fork',
#   'free-range',
#   'plu',
#   'powder',
#   'sugar'},
#  {'asda',
#   'beaten',
#   'breast',
#   'butter',
#   'carrot',
#   'chantenay',
#   'crème',
#   'cube',
#   'fillet',
#   'flat-leaf',
#   'flour',
#   'fraîche',
#   'leek',
#   'pack',
#   'parsley',
#   'plu',
#   'stilton',
#   'stock',
#   'thyme'},
#  {'butter',
#   'caster',
#   'flour',
#   'juice',
#   'lemon',
#   'plu',
#   'rosemary',
#   'sprig',
#   'sugar',
#   'zest'},
#  {'caster',
#   'chocolate',
#   'cointreau',
#   'favourite',
#   'fruit',
#   'juice',
#   'mango',
#   'orange',
#   'passion',
#   'sugar'},
#  {'asda',
#   'brioche',
#   'butter',
#   'chive',
#   'free-range',
#   'milk',
#   'roll',
#   'salmon',
#   'serve',
#   'tomatoe'},
#  {'beaten',
#   'butter',
#   'caster',
#   'flour',
#   'pinch',
#   'royal',
#   'salt',
#   'sugar',
#   'tube',
#   'yolk'},
#  {'apricot',
#   'butter',
#   'caster',
#   'cube',
#   'flour',
#   'milk',
#   'piece',
#   'sugar',
#   'sultana',
#   'sunflower'},
#  {'butter',
#   'caster',
#   'cocoa',
#   'extract',
#   'flour',
#   'plu',
#   'powder',
#   'raspberrie',
#   'sugar',
#   'vanilla'},
#  {'beaten',
#   'butter',
#   'cube',
#   'decorate',
#   'flour',
#   'fruit',
#   'marzipan',
#   'milk',
#   'spice',
#   'sugar'},
#  {'chosen',
#   'dip',
#   'leftover',
#   'mexican',
#   'oil',
#   'onion',
#   'pepper',
#   'rice',
#   'stacker',
#   'tortilla'},
#  {'asda',
#   'bean',
#   'can',
#   'cashew',
#   'chestnut',
#   'corn',
#   'jar',
#   'noodle',
#   'nut',
#   'oak',
#   'oil',
#   'olde',
#   'onion',
#   'pack',
#   'roll',
#   'sauce',
#   'sharwood',
#   'stir-fry',
#   'water',
#   'ye'},
#  {'bacon',
#   'drizzle',
#   'leftover',
#   'mushroom',
#   'oil',
#   'pack',
#   'parmesan',
#   'rice',
#   'risotto',
#   'rocket'},
#  {'beaten',
#   'cheese',
#   'cherry',
#   'cumberland',
#   'fat',
#   'muffin',
#   'sausage',
#   'slice',
#   'special',
#   'tomatoe'},
#  {'asda',
#   'breadcrumb',
#   'butter',
#   'flour',
#   'free',
#   'pack',
#   'pork',
#   'range',
#   'sausage',
#   'special'},
#  {'brown',
#   'currant',
#   'flour',
#   'hot',
#   'marmalade',
#   'soft',
#   'spice',
#   'sugar',
#   'sultana',
#   'tea'},
#  {'asda',
#   'beaten',
#   'bread',
#   'mix',
#   'packet',
#   'pinch',
#   'powder',
#   'rock',
#   'salt',
#   'yolk'},
#  {'breast',
#   'caesar',
#   'chosen',
#   'eat',
#   'kit',
#   'pack',
#   'ready',
#   'salad',
#   'slice',
#   'taste'},
#  {'asda',
#   'ciabatta',
#   'frie',
#   'garlic',
#   'home-style',
#   'iceberg',
#   'leftover',
#   'lettuce',
#   'loaf',
#   'mayonnaise'},
#  {'butter',
#   'caster',
#   'chillie',
#   'cocoa',
#   'extract',
#   'flour',
#   'free-range',
#   'powder',
#   'sugar',
#   'vanilla'},
#  {'butter',
#   'caster',
#   'currant',
#   'flour',
#   'milk',
#   'pinch',
#   'salt',
#   'spice',
#   'sugar',
#   'sultana'},
#  {'asda',
#   'asparagu',
#   'bread',
#   'crusty',
#   'free-range',
#   'pack',
#   'parmesan',
#   'samphire',
#   'serve',
#   'special'},
#  {'bread',
#   'butter',
#   'nutmeg',
#   'oil',
#   'olive',
#   'pepper',
#   'salt',
#   'slice',
#   'sourdough',
#   'spinach'},
#  {'caramel',
#   'cream',
#   'double',
#   'extract',
#   'nielsen-massey',
#   'optional',
#   'serve',
#   'sugar',
#   'vanilla',
#   'wafer'},
#  {'caster',
#   'flour',
#   'grease',
#   'lemon',
#   'milk',
#   'oil',
#   'quarter',
#   'serve',
#   'sugar',
#   'sunflower'},
#  {'caster',
#   'cherrie',
#   'chocolate',
#   'cream',
#   'dark',
#   'double',
#   'dust',
#   'plu',
#   'stalk',
#   'sugar'},
#  {'butter',
#   'caster',
#   'flour',
#   'jam',
#   'milk',
#   'pinch',
#   'plu',
#   'raspberry',
#   'salt',
#   'sugar'},
#  {'breadcrumb',
#   'butter',
#   'lemon',
#   'milk',
#   'oil',
#   'onion',
#   'parsley',
#   'sage',
#   'sunflower',
#   'thyme'},
#  {'caster',
#   'cream',
#   'double',
#   'drop',
#   'extract',
#   'free-range',
#   'pistachio',
#   'strawberrie',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'drumstick',
#   'honey',
#   'juice',
#   'lemon',
#   'oil',
#   'pack',
#   'sauce',
#   'soy',
#   'sunflower'},
#  {'ball',
#   'butter',
#   'cream',
#   'flour',
#   'free-range',
#   'ginger',
#   'rhubarb',
#   'serve',
#   'stem',
#   'sugar'},
#  {'beaten',
#   'butter',
#   'frozen',
#   'garam',
#   'green',
#   'masala',
#   'onion',
#   'pea',
#   'pepper',
#   'tomatoe'},
#  {'baguette',
#   'bakery',
#   'butter',
#   'chive',
#   'free-range',
#   'herb',
#   'in-store',
#   'parsley',
#   'tarragon',
#   'thyme'},
#  {'apple',
#   'beaten',
#   'butcher',
#   'fat',
#   'flour',
#   'les',
#   'pastry',
#   'pork',
#   'puff',
#   'sausage'},
#  {'clove',
#   'garlic',
#   'mushroom',
#   'oil',
#   'olive',
#   'onion',
#   'orzo',
#   'pasta',
#   'skin',
#   'thigh'},
#  {'bacon',
#   'beaten',
#   'clove',
#   'cream',
#   'garlic',
#   'oil',
#   'rasher',
#   'single',
#   'spaghetti',
#   'yolk'},
#  {'butter',
#   'cadbury',
#   'caster',
#   'cocoa',
#   'creme',
#   'extract',
#   'flour',
#   'powder',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'beaten',
#   'breast',
#   'butcher',
#   'cheddar',
#   'chillie',
#   'cornflake',
#   'cube',
#   'fillet',
#   'flour',
#   'leek',
#   'mature',
#   'oil',
#   'olive',
#   'optional',
#   'pack',
#   'pea',
#   'piece',
#   'potatoe',
#   'serve',
#   'sweetcorn'},
#  {'asda',
#   'beaten',
#   'bread',
#   'coarse',
#   'day',
#   'french',
#   'grain',
#   'mayonnaise',
#   'mustard',
#   'oil',
#   'old',
#   'optional',
#   'parsley',
#   'potatoe',
#   'real',
#   'salad',
#   'serve',
#   'skin',
#   'sunflower',
#   'tomatoe',
#   'weight'},
#  {'beaten',
#   'cornflour',
#   'frozen',
#   'just-roll',
#   'pack',
#   'pastry',
#   'raspberrie',
#   'rhubarb',
#   'sheet',
#   'shortcrust',
#   'sugar'},
#  {'almond',
#   'asda',
#   'cherry',
#   'chilli',
#   'clove',
#   'coriander',
#   'curry',
#   'garlic',
#   'garnish',
#   'leftover',
#   'mild',
#   'oil',
#   'olive',
#   'onion',
#   'pea',
#   'plu',
#   'powder',
#   'quinoa',
#   'salmon',
#   'stock',
#   'sugarsnap',
#   'tomatoe'},
#  {'bacon',
#   'butter',
#   'cabbage',
#   'nutmeg',
#   'pepper',
#   'pinch',
#   'potatoe',
#   'salt',
#   'slice',
#   'streaky',
#   'yolk'},
#  {'asda',
#   'lemon',
#   'oil',
#   'olive',
#   'pepper',
#   'rub',
#   'salt',
#   'sea',
#   'special',
#   'sprig',
#   'thyme'},
#  {'cheese',
#   'fat',
#   'free-range',
#   'frozen',
#   'greek-style',
#   'milk',
#   'mint',
#   'oil',
#   'onion',
#   'pea',
#   'potatoe'},
#  {'butter',
#   'caster',
#   'chosen',
#   'easy-bake',
#   'flour',
#   'glaze',
#   'milk',
#   'plu',
#   'sachet',
#   'sugar',
#   'yeast'},
#  {'asda',
#   'bean',
#   'beaten',
#   'breadcrumb',
#   'cornflour',
#   'cranberry',
#   'crème',
#   'dill',
#   'fat',
#   'fraîche',
#   'green',
#   'hot',
#   'oil',
#   'pack',
#   'parsley',
#   'pork',
#   'potatoe',
#   'sauce',
#   'serve',
#   'spice',
#   'stock',
#   'sunflower'},
#  {'asda',
#   'casero',
#   'chilli',
#   'choi',
#   'chorizo',
#   'coriander',
#   'corn',
#   'cube',
#   'noodle',
#   'onion',
#   'pack',
#   'pak',
#   'pea',
#   'pepper',
#   'sauce',
#   'serve',
#   'snap',
#   'soy',
#   'special',
#   'stock',
#   'sugar',
#   'sweet'},
#  {'butter',
#   'caster',
#   'cream',
#   'double',
#   'flour',
#   'jam',
#   'little',
#   'plu',
#   'raspberry',
#   'strawberry',
#   'sugar'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'cube',
#   'flour',
#   'juice',
#   'lemon',
#   'plu',
#   'sugar',
#   'yolk',
#   'zest'},
#  {'asda',
#   'breast',
#   'bunch',
#   'butcher’',
#   'butter',
#   'fillet',
#   'flour',
#   'full-fat',
#   'grower’',
#   'milk',
#   'mushroom',
#   'oil',
#   'onion',
#   'parsley',
#   'pastry',
#   'pepper',
#   'plu',
#   'puff',
#   'ready',
#   'salt',
#   'wash',
#   'yolk'},
#  {'butter',
#   'cream',
#   'flour',
#   'gluten-free',
#   'ice',
#   'make',
#   'milk',
#   'non',
#   'pear',
#   'serve',
#   'water'},
#  {'arborio',
#   'butter',
#   'celery',
#   'clove',
#   'garlic',
#   'mushroom',
#   'onion',
#   'rice',
#   'stick',
#   'stock',
#   'vegetable'},
#  {'asda',
#   'caesar',
#   'cherry',
#   'crouton',
#   'lettuce',
#   'pack',
#   'parmesan',
#   'salad',
#   'serve',
#   'tomatoe',
#   'tortilla'},
#  {'banana',
#   'beaten',
#   'caster',
#   'cinnamon',
#   'flour',
#   'golden',
#   'milk',
#   'oil',
#   'powder',
#   'sugar',
#   'sunflower'},
#  {'asparagu',
#   'beaten',
#   'beetroot',
#   'garnish',
#   'mozzarella',
#   'pastry',
#   'puff',
#   'sheet',
#   'thyme',
#   'tip',
#   'torn'},
#  {'ball',
#   'butcher’',
#   'clove',
#   'cold',
#   'coriander',
#   'cornflour',
#   'fish',
#   'garlic',
#   'light',
#   'noodle',
#   'oil',
#   'oyster',
#   'pack',
#   'pepper',
#   'sauce',
#   'skin',
#   'soy',
#   'stalk',
#   'sugar',
#   'thigh',
#   'water',
#   'wonton'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'drop',
#   'essence',
#   'extract',
#   'flour',
#   'food',
#   'plu',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'caster',
#   'cornflour',
#   'flour',
#   'juice',
#   'lemon',
#   'pastry',
#   'ready-to-roll',
#   'shortcrust',
#   'sugar',
#   'zest'},
#  {'asda',
#   'caster',
#   'conserve',
#   'cream',
#   'double',
#   'drop',
#   'food',
#   'pink',
#   'strawberrie',
#   'strawberry',
#   'sugar'},
#  {'bean',
#   'brown',
#   'butter',
#   'cranberrie',
#   'extract',
#   'flour',
#   'pecan',
#   'soft',
#   'special',
#   'sugar',
#   'vanilla'},
#  {'beaten',
#   'bread',
#   'cream',
#   'double',
#   'oil',
#   'onion',
#   'pepper',
#   'salt',
#   'slice',
#   'stilton',
#   'taste'},
#  {'almond',
#   'butter',
#   'caster',
#   'flour',
#   'lemon',
#   'medium-size',
#   'plu',
#   'plum',
#   'redcurrant',
#   'sugar',
#   'zest'},
#  {'butter',
#   'caster',
#   'cube',
#   'free-range',
#   'juice',
#   'lemon',
#   'orange',
#   'plu',
#   'sugar',
#   'yolk',
#   'zest'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cherrie',
#   'cornflour',
#   'cube',
#   'farm',
#   'flour',
#   'plu',
#   'store',
#   'sugar'},
#  {'butter',
#   'caster',
#   'eat',
#   'grower’',
#   'juice',
#   'lemon',
#   'peache',
#   'plu',
#   'ready',
#   'sugar',
#   'yolk'},
#  {'beansprout',
#   'free-range',
#   'frozen',
#   'groundnut',
#   'long-grain',
#   'oil',
#   'onion',
#   'optional',
#   'pea',
#   'rice',
#   'sesame'},
#  {'blueberrie',
#   'butter',
#   'caster',
#   'flour',
#   'lemon',
#   'low-fat',
#   'milk',
#   'natural',
#   'powder',
#   'sugar',
#   'yogurt'},
#  {'asda',
#   'beaten',
#   'bread',
#   'breadcrumb',
#   'breast',
#   'butcher',
#   'cube',
#   'day',
#   'fillet',
#   'flour',
#   'frozen',
#   'grain',
#   'knorr',
#   'long',
#   'made',
#   'old',
#   'paprika',
#   'parmesan',
#   'pea',
#   'rice',
#   'stock',
#   'sweetcorn'},
#  {'bay',
#   'bone',
#   'carrot',
#   'celery',
#   'onion',
#   'peppercorn',
#   'piece',
#   'roast',
#   'sprig',
#   'stick',
#   'thyme'},
#  {'can',
#   'courgette',
#   'feta',
#   'flour',
#   'handful',
#   'matchstick',
#   'oil',
#   'olive',
#   'rocket',
#   'sweetcorn',
#   'well'},
#  {'asda',
#   'bread',
#   'breast',
#   'crisp',
#   'crème',
#   'day',
#   'fillet',
#   'fraîche',
#   'frozen',
#   'ketchup',
#   'mint',
#   'oil',
#   'old',
#   'olive',
#   'pack',
#   'pea',
#   'potato',
#   'reduced-fat',
#   'serve',
#   'sesame',
#   'sprig',
#   'tomato',
#   'wholemeal'},
#  {'beaten',
#   'breast',
#   'butcher’',
#   'choice',
#   'cornflake',
#   'cornflour',
#   'crumb',
#   'fillet',
#   'grower’',
#   'lettuce',
#   'oil',
#   'optional',
#   'pack',
#   'paprika',
#   'parsley',
#   'potatoe',
#   'sauce',
#   'serve',
#   'side',
#   'skin',
#   'sweet',
#   'torn',
#   'wedge'},
#  {'amoy',
#   'bean',
#   'breast',
#   'butter',
#   'chillie',
#   'chosen',
#   'coconut',
#   'cube',
#   'dunn',
#   'flame',
#   'frozen',
#   'green',
#   'noodle',
#   'onion',
#   'pack',
#   'peanut',
#   'river',
#   'salt',
#   'sauce',
#   'soy',
#   'stock',
#   'strip',
#   'sweetcorn'},
#  {'asda',
#   'block',
#   'butter',
#   'carrot',
#   'chilli',
#   'cider',
#   'crunchy',
#   'cucumber',
#   'dark',
#   'groundnut',
#   'honey',
#   'matchstick',
#   'noodle',
#   'oil',
#   'onion',
#   'peanut',
#   'piece',
#   'sauce',
#   'sesame',
#   'soy',
#   'sweet',
#   'turkey',
#   'vinegar'},
#  {'best',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'jam',
#   'raspberry',
#   'seedles',
#   'smooth',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'allspice',
#   'cinnamon',
#   'english',
#   'filo',
#   'flesh',
#   'ginger',
#   'happy',
#   'heather',
#   'honey',
#   'pastry',
#   'pumpkin',
#   'sheet'},
#  {'beaten',
#   'butter',
#   'cream',
#   'dill',
#   'double',
#   'flour',
#   'lemon',
#   'milk',
#   'plu',
#   'potato',
#   'salmon',
#   'sprig'},
#  {'asda',
#   'asparagu',
#   'balsamic',
#   'ciabatta',
#   'free-range',
#   'italian',
#   'oil',
#   'prosciutto',
#   'slice',
#   'special',
#   'tip',
#   'vinegar'},
#  {'bacon',
#   'butter',
#   'flour',
#   'green',
#   'mari',
#   'onion',
#   'parsley',
#   'piper',
#   'potatoe',
#   'salmon',
#   'serve',
#   'streaky'},
#  {'asda',
#   'beaten',
#   'butter',
#   'feta',
#   'filo',
#   'frozen',
#   'greek',
#   'onion',
#   'oregano',
#   'pack',
#   'pastry',
#   'spinach'},
#  {'almond',
#   'caster',
#   'chocolate',
#   'chosen',
#   'cocoa',
#   'cream',
#   'curl',
#   'dark',
#   'decorate',
#   'double',
#   'solid',
#   'sugar'},
#  {'almond',
#   'blackberrie',
#   'blueberrie',
#   'extract',
#   'flour',
#   'milk',
#   'oil',
#   'raspberrie',
#   'serve',
#   'sugar',
#   'sunflower',
#   'vanilla'},
#  {'can',
#   'giant',
#   'green',
#   'oil',
#   'onion',
#   'pepper',
#   'piece',
#   'potatoe',
#   'sunflower',
#   'sweet',
#   'sweetcorn',
#   'tomatoe'},
#  {'asda',
#   'bean',
#   'breast',
#   'chilli',
#   'clove',
#   'fillet',
#   'garlic',
#   'ginger',
#   'groundnut',
#   'lengthway',
#   'light',
#   'mangetout',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'pepper',
#   'piece',
#   'root',
#   'sauce',
#   'soy',
#   'sprout',
#   'strip',
#   'sweet'},
#  {'apricot',
#   'butter',
#   'demerara',
#   'flour',
#   'milk',
#   'nut',
#   'piece',
#   'pistachio',
#   'plu',
#   'spice',
#   'sugar',
#   'sultana'},
#  {'asda',
#   'basil',
#   'breast',
#   'button',
#   'cheddar',
#   'cheese',
#   'chosen',
#   'chunk',
#   'eat',
#   'ham',
#   'honey',
#   'lasagne',
#   'leftover',
#   'mature',
#   'mushroom',
#   'oil',
#   'olive',
#   'pack',
#   'pot',
#   'ready',
#   'roast',
#   'sauce',
#   'sheet',
#   'tomato'},
#  {'bacon',
#   'block',
#   'chosen',
#   'chutney',
#   'flour',
#   'jus-rol',
#   'milk',
#   'oil',
#   'onion',
#   'pastry',
#   'shortcrust',
#   'tomato'},
#  {'butter',
#   'caster',
#   'cream',
#   'double',
#   'flour',
#   'free-range',
#   'juice',
#   'lime',
#   'mangoe',
#   'powder',
#   'sugar',
#   'zest'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'drop',
#   'essence',
#   'flour',
#   'food',
#   'marshmallow',
#   'pink',
#   'sprinkle',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'bean',
#   'beaten',
#   'bread',
#   'breadcrumb',
#   'butter',
#   'free-range',
#   'granule',
#   'gravy',
#   'green',
#   'herb',
#   'little',
#   'made',
#   'mince',
#   'oil',
#   'pack',
#   'potato',
#   'sausage',
#   'serve',
#   'shallot',
#   'slice',
#   'smart',
#   'sunflower',
#   'turkey'},
#  {'almond',
#   'beaten',
#   'butter',
#   'cauliflower',
#   'chutney',
#   'coriander',
#   'garlic',
#   'granule',
#   'pistachio',
#   'serve',
#   'sultana',
#   'tomato'},
#  {'asda',
#   'butter',
#   'cream',
#   'cube',
#   'flour',
#   'free-range',
#   'gruyère',
#   'leek',
#   'plu',
#   'single',
#   'thyme',
#   'yolk'},
#  {'caster',
#   'flour',
#   'free-range',
#   'lemon',
#   'milk',
#   'oil',
#   'pinch',
#   'plu',
#   'salt',
#   'serve',
#   'sugar',
#   'sunflower'},
#  {'beaten',
#   'butter',
#   'fat',
#   'flour',
#   'free-range',
#   'onion',
#   'piece',
#   'plu',
#   'potato',
#   'rump',
#   'steak',
#   'swede'},
#  {'bacon',
#   'banana',
#   'beaten',
#   'bread',
#   'butter',
#   'farmhouse',
#   'maple',
#   'milk',
#   'ripe',
#   'slice',
#   'streaky',
#   'syrup'},
#  {'almond',
#   'butter',
#   'caster',
#   'cherrie',
#   'demerara',
#   'flour',
#   'free-range',
#   'nut',
#   'pine',
#   'powder',
#   'redcurrant',
#   'sugar'},
#  {'beaten',
#   'butter',
#   'cake',
#   'caster',
#   'extract',
#   'flour',
#   'room',
#   'square',
#   'sugar',
#   'temperature',
#   'tin',
#   'vanilla'},
#  {'banana',
#   'beaten',
#   'brown',
#   'butter',
#   'flour',
#   'honey',
#   'pecan',
#   'ripe',
#   'soft',
#   'spice',
#   'sugar',
#   'weight'},
#  {'asda',
#   'caster',
#   'cream',
#   'double',
#   'flour',
#   'free-range',
#   'lemon',
#   'orange',
#   'pastry',
#   'pot',
#   'shortcrust',
#   'sugar'},
#  {'avocado',
#   'caster',
#   'cherry',
#   'flour',
#   'milk',
#   'oil',
#   'powder',
#   'serve',
#   'sugar',
#   'tomatoe',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'beaten',
#   'frozen',
#   'grain',
#   'ham',
#   'long',
#   'micro',
#   'oil',
#   'onion',
#   'pea',
#   'ready',
#   'rice'},
#  {'butter',
#   'chorizo',
#   'coconut',
#   'courgette',
#   'firm',
#   'handful',
#   'little',
#   'mozzarella',
#   'oil',
#   'onion',
#   'piece',
#   'spinach'},
#  {'berrie',
#   'blueberrie',
#   'caster',
#   'cream',
#   'double',
#   'extract',
#   'pinch',
#   'raspberrie',
#   'strawberrie',
#   'sugar',
#   'tartar',
#   'vanilla'},
#  {'apricot',
#   'beaten',
#   'breadcrumb',
#   'chestnut',
#   'oil',
#   'onion',
#   'parsley',
#   'pork',
#   'sage',
#   'sausagemeat',
#   'special',
#   'sunflower'},
#  {'butter',
#   'caster',
#   'cinnamon',
#   'flour',
#   'ginger',
#   'happy',
#   'milk',
#   'nutmeg',
#   'pinch',
#   'salt',
#   'self',
#   'sugar'},
#  {'butter',
#   'caster',
#   'cinnamon',
#   'extract',
#   'flour',
#   'little',
#   'milk',
#   'plu',
#   'plum',
#   'serve',
#   'sugar',
#   'vanilla'},
#  {'can',
#   'chickpea',
#   'clove',
#   'coriander',
#   'cumin',
#   'flat-leaf',
#   'garlic',
#   'oil',
#   'olive',
#   'onion',
#   'parsley',
#   'yolk'},
#  {'asda',
#   'butter',
#   'cheese',
#   'chive',
#   'free-range',
#   'ham',
#   'leicester',
#   'milk',
#   'piece',
#   'salad',
#   'serve',
#   'sweetcorn'},
#  {'asda',
#   'breast',
#   'honey',
#   'juice',
#   'lemon',
#   'oil',
#   'olive',
#   'potatoe',
#   'skinles',
#   'sweet',
#   'thyme',
#   'zest'},
#  {'back',
#   'bacon',
#   'banana',
#   'bean',
#   'breadcrumb',
#   'breast',
#   'butter',
#   'can',
#   'cornflake',
#   'courgette',
#   'fat',
#   'fillet',
#   'frozen',
#   'just',
#   'oil',
#   'olive',
#   'onion',
#   'paprika',
#   'pepper',
#   'piece',
#   'rasher',
#   'ripe',
#   'sweetcorn',
#   'thyme'},
#  {'butter',
#   'caster',
#   'currant',
#   'flour',
#   'free-range',
#   'lemon',
#   'mini',
#   'plu',
#   'royal',
#   'sugar',
#   'yolk',
#   'zest'},
#  {'butter',
#   'caster',
#   'chunky',
#   'flour',
#   'marmalade',
#   'milk',
#   'oat',
#   'plu',
#   'porridge',
#   'powder',
#   'sugar',
#   'wholemeal'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cheese',
#   'free-range',
#   'frozen',
#   'goat',
#   'hard',
#   'onion',
#   'pea',
#   'potatoe',
#   'thyme'},
#  {'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'flour',
#   'golden',
#   'happy',
#   'milk',
#   'piece',
#   'powder',
#   'self',
#   'sugar'},
#  {'asda',
#   'butcher’',
#   'coleslaw',
#   'grower’',
#   'kit',
#   'marinade',
#   'oil',
#   'pack',
#   'piri',
#   'sauce',
#   'sweetcorn',
#   'twin'},
#  {'beaten',
#   'curd',
#   'flour',
#   'good-quality',
#   'juice',
#   'lemon',
#   'milk',
#   'plu',
#   'poppy',
#   'serve',
#   'wedge',
#   'zest'},
#  {'brown',
#   'extract',
#   'flour',
#   'light',
#   'oat',
#   'oil',
#   'porridge',
#   'raisin',
#   'soft',
#   'spread',
#   'sugar',
#   'vanilla'},
#  {'bag',
#   'beaten',
#   'butter',
#   'free-range',
#   'oil',
#   'olive',
#   'parmesan',
#   'pepper',
#   'serve',
#   'spinach',
#   'tomatoe',
#   'weight'},
#  {'asda',
#   'blueberrie',
#   'caster',
#   'drop',
#   'extract',
#   'flour',
#   'free-range',
#   'milk',
#   'oil',
#   'sugar',
#   'sunflower',
#   'vanilla'},
#  {'asda',
#   'beaten',
#   'breadcrumb',
#   'breast',
#   'bun',
#   'burger',
#   'butcher’',
#   'chosen',
#   'crisp',
#   'fillet',
#   'heinz',
#   'ketchup',
#   'oil',
#   'pack',
#   'potatoe',
#   'salad',
#   'salt',
#   'serve',
#   'sesame',
#   'sugar',
#   'sunflower',
#   'sweet',
#   'tomato',
#   'vinegar',
#   'wholemeal'},
#  {'beaten',
#   'breadcrumb',
#   'breast',
#   'brown',
#   'butcher',
#   'chip',
#   'chosen',
#   'curry',
#   'fillet',
#   'ketchup',
#   'leek',
#   'lengthway',
#   'light',
#   'long-grain',
#   'mangetout',
#   'mix',
#   'oil',
#   'olive',
#   'pack',
#   'portion',
#   'rice',
#   'sauce',
#   'shop',
#   'soy',
#   'tomato'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cumberland',
#   'flour',
#   'free-range',
#   'ju',
#   'pack',
#   'pastry',
#   'puff',
#   'roll',
#   'sausage',
#   'special'},
#  {'cheddar',
#   'chilli',
#   'free',
#   'mature',
#   'milk',
#   'oil',
#   'pepper',
#   'ricotta',
#   'spaghetti',
#   'spinach',
#   'tomatoe',
#   'tub',
#   'well'},
#  {'breast',
#   'chosen',
#   'fillet',
#   'frozen',
#   'light',
#   'mayonnaise',
#   'oil',
#   'paprika',
#   'piri',
#   'potato',
#   'salad',
#   'serve',
#   'sunflower'},
#  {'asda',
#   'carrot',
#   'granule',
#   'gravy',
#   'mince',
#   'onion',
#   'pack',
#   'parsnip',
#   'pastry',
#   'ready',
#   'roll',
#   'shortcrust',
#   'turkey'},
#  {'beetroot',
#   'crème',
#   'flour',
#   'fraîche',
#   'garnish',
#   'jus-rol',
#   'leicester',
#   'pastry',
#   'plu',
#   'reduced-fat',
#   'shortcrust',
#   'sprig',
#   'thyme'},
#  {'asda',
#   'broccoli',
#   'gravy',
#   'lemon',
#   'marbell',
#   'oil',
#   'olive',
#   'potatoe',
#   'serve',
#   'special',
#   'sprig',
#   'tenderstem',
#   'thyme'},
#  {'asda',
#   'crème',
#   'dill',
#   'flour',
#   'fraîche',
#   'free-range',
#   'milk',
#   'oil',
#   'powder',
#   'salmon',
#   'special',
#   'sprig',
#   'sunflower'},
#  {'beaten',
#   'breadcrumb',
#   'cheddar',
#   'coarse',
#   'cod',
#   'flour',
#   'frozen',
#   'oil',
#   'parsley',
#   'pea',
#   'potatoe',
#   'salad',
#   'sunflower'},
#  {'bread',
#   'butter',
#   'caster',
#   'extract',
#   'free',
#   'leftover',
#   'marmalade',
#   'milk',
#   'range',
#   'raspberrie',
#   'slice',
#   'sugar',
#   'vanilla'},
#  {'angel',
#   'butter',
#   'cake',
#   'caster',
#   'flour',
#   'food',
#   'mallow',
#   'milk',
#   'mini',
#   'powder',
#   'ready-to-roll',
#   'sugar',
#   'tub'},
#  {'asda',
#   'caster',
#   'clementine',
#   'flora',
#   'flour',
#   'juice',
#   'marmalade',
#   'orange',
#   'plu',
#   'spread',
#   'sugar',
#   'thick-cut',
#   'zest'},
#  {'blueberrie',
#   'cinnamon',
#   'extract',
#   'flour',
#   'low-fat',
#   'milk',
#   'natural',
#   'nielsen-massey',
#   'oil',
#   'plu',
#   'powder',
#   'vanilla',
#   'yogurt'},
#  {'cheese',
#   'demerara',
#   'fat',
#   'flour',
#   'gluten-free',
#   'hazelnut',
#   'les',
#   'nutella',
#   'oil',
#   'powder',
#   'soft',
#   'sugar',
#   'sunflower'},
#  {'asda',
#   'bean',
#   'butter',
#   'can',
#   'chorizo',
#   'clove',
#   'cornflour',
#   'garlic',
#   'orange',
#   'rosemary',
#   'sprig',
#   'stock',
#   'thigh'},
#  {'asda',
#   'butter',
#   'cardamom',
#   'caster',
#   'chocolate',
#   'coconut',
#   'decorate',
#   'flour',
#   'milk',
#   'mini',
#   'orange',
#   'sugar',
#   'zest'},
#  {'bacon',
#   'best',
#   'butter',
#   'edward',
#   'flour',
#   'mari',
#   'oil',
#   'piper',
#   'plu',
#   'potatoe',
#   'salad',
#   'serve',
#   'sunfower'},
#  {'asda',
#   'chilli',
#   'ketchup',
#   'kg',
#   'pack',
#   'pork',
#   'redcurrant',
#   'rib',
#   'sauce',
#   'smart',
#   'sweet',
#   'vinegar',
#   'wine'},
#  {'barley',
#   'cabbage',
#   'carrot',
#   'cube',
#   'homemade',
#   'leek',
#   'leftover',
#   'made',
#   'oil',
#   'onion',
#   'pearl',
#   'savoy',
#   'stock'},
#  {'alpen',
#   'cinnamon',
#   'favourite',
#   'flour',
#   'honey',
#   'jam',
#   'milk',
#   'mum’',
#   'plu',
#   'powder',
#   'serve',
#   'thousand',
#   'top'},
#  {'butter',
#   'caster',
#   'colour',
#   'dr',
#   'extract',
#   'flour',
#   'food',
#   'gel',
#   'oetker',
#   'royal',
#   'sugar',
#   'vanilla',
#   'whitworth'},
#  {'asparagu',
#   'beaten',
#   'bunch',
#   'butter',
#   'cheese',
#   'flour',
#   'free-range',
#   'frozen',
#   'gorgonzola',
#   'jus-rol',
#   'mascarpone',
#   'pastry',
#   'puff'},
#  {'asda',
#   'cajun',
#   'deep',
#   'fat',
#   'flour',
#   'fryer',
#   'ketchup',
#   'milk',
#   'oil',
#   'onion',
#   'serve',
#   'tomato',
#   'yolk'},
#  {'anise',
#   'butter',
#   'dill',
#   'fillet',
#   'lemon',
#   'parsley',
#   'peppercorn',
#   'salmon',
#   'sprig',
#   'star',
#   'vinegar',
#   'wine',
#   'yolk'},
#  {'asda',
#   'beaten',
#   'butter',
#   'cornflour',
#   'crème',
#   'dijon',
#   'flour',
#   'fraîche',
#   'free-range',
#   'gammon',
#   'lean',
#   'lengthway',
#   'mushroom',
#   'mustard',
#   'oil',
#   'pastry',
#   'puff',
#   'ready',
#   'reduced-fat',
#   'roll',
#   'shallot',
#   'size',
#   'stock',
#   'sunflower',
#   'thyme',
#   'turkey'},
#  {'brioche',
#   'butter',
#   'free-range',
#   'fruit',
#   'ham',
#   'hollandaise',
#   'juice',
#   'loaf',
#   'mug',
#   'sauce',
#   'serve',
#   'slice',
#   'tea'},
#  {'apricot',
#   'caster',
#   'crème',
#   'flour',
#   'fraîche',
#   'milk',
#   'oil',
#   'peache',
#   'plu',
#   'serve',
#   'sugar',
#   'sunflower',
#   'wholemeal'},
#  {'butter',
#   'caster',
#   'chosen',
#   'extract',
#   'flour',
#   'jam',
#   'milk',
#   'oil',
#   'raspberry',
#   'seedles',
#   'sugar',
#   'sunflower',
#   'vanilla'},
#  {'breast',
#   'butcher',
#   'ciabatta',
#   'fillet',
#   'green',
#   'loaf',
#   'oil',
#   'olive',
#   'onion',
#   'pesto',
#   'rocket',
#   'tomatoe',
#   'wild'},
#  {'all-butter',
#   'chunky',
#   'cranberry',
#   'dash',
#   'happy',
#   'hard',
#   'milk',
#   'pastry',
#   'pork',
#   'puff',
#   'sauce',
#   'sausage',
#   'skin'},
#  {'balsamic',
#   'chilli',
#   'dark',
#   'flake',
#   'honey',
#   'ketchup',
#   'pack',
#   'sauce',
#   'soy',
#   'sweet',
#   'tomato',
#   'vinegar',
#   'worcestershire'},
#  {'beaten',
#   'beetroot',
#   'carrot',
#   'coriander',
#   'cumin',
#   'flour',
#   'mint',
#   'oil',
#   'onion',
#   'salad',
#   'serve',
#   'vegetable',
#   'yogurt'},
#  {'asda',
#   'baker',
#   'bread',
#   'brown',
#   'butter',
#   'dollop',
#   'free-range',
#   'gold',
#   'ketchup',
#   'milk',
#   'mushroom',
#   'sauce',
#   'slice'},
#  {'caster',
#   'dust',
#   'essence',
#   'flour',
#   'greek',
#   'juice',
#   'lemon',
#   'oil',
#   'style',
#   'sugar',
#   'vanilla',
#   'yogurt',
#   'zest'},
#  {'almond',
#   'asda',
#   'bean',
#   'beaten',
#   'breadcrumb',
#   'flour',
#   'green',
#   'lemon',
#   'mustard',
#   'optional',
#   'pack',
#   'powder',
#   'zest'},
#  {'apple',
#   'bramley',
#   'caster',
#   'cream',
#   'decorate',
#   'double',
#   'juice',
#   'lemon',
#   'mint',
#   'piece',
#   'sprig',
#   'sugar',
#   'zest'},
#  {'breadcrumb',
#   'chive',
#   'courgette',
#   'cream',
#   'firm',
#   'flour',
#   'fry',
#   'litre',
#   'oil',
#   'panko',
#   'parmesan',
#   'sour',
#   'vegetable'},
#  {'blueberrie',
#   'butter',
#   'caster',
#   'custard',
#   'extract',
#   'milk',
#   'plu',
#   'pure',
#   'raspberrie',
#   'serve',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'caster',
#   'chocolate',
#   'cornflour',
#   'cream',
#   'extract',
#   'golden',
#   'halve',
#   'juice',
#   'lemon',
#   'milk',
#   'sugar',
#   'vanila',
#   'walnut'},
#  {'blackberrie',
#   'caramel',
#   'caster',
#   'cream',
#   'free-range',
#   'plu',
#   'pod',
#   'pot',
#   'single',
#   'size',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'butter',
#   'caster',
#   'cocoa',
#   'flour',
#   'milk',
#   'mini',
#   'orange',
#   'pack',
#   'plu',
#   'powder',
#   'self',
#   'sugar',
#   'zest'},
#  {'caster',
#   'chocolate',
#   'cocoa',
#   'dark',
#   'decorate',
#   'flour',
#   'juice',
#   'orange',
#   'pastry',
#   'puff',
#   'ready-made',
#   'solid',
#   'sugar'},
#  {'almond',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'dark',
#   'free-range',
#   'juice',
#   'orange',
#   'plu',
#   'solid',
#   'sugar',
#   'zest'},
#  {'arrowroot',
#   'biscuit',
#   'butter',
#   'caster',
#   'cheese',
#   'cream',
#   'digestive',
#   'essence',
#   'rhubarb',
#   'sour',
#   'sugar',
#   'vanilla',
#   'yorkshire'},
#  {'butter',
#   'cayenne',
#   'cheddar',
#   'cheese',
#   'courgette',
#   'dry',
#   'flour',
#   'free-range',
#   'mature',
#   'milk',
#   'mustard',
#   'powder',
#   'salt'},
#  {'asda',
#   'butter',
#   'caster',
#   'flour',
#   'free-range',
#   'juice',
#   'marmalade',
#   'orange',
#   'plu',
#   'powder',
#   'special',
#   'sugar',
#   'zest'},
#  {'asda',
#   'butter',
#   'caster',
#   'finelt',
#   'flour',
#   'free-range',
#   'juice',
#   'lemon',
#   'lime',
#   'milk',
#   'plu',
#   'sugar',
#   'zest'},
#  {'beaten',
#   'butter',
#   'caster',
#   'choice',
#   'flour',
#   'milk',
#   'pinch',
#   'powder',
#   'salt',
#   'self',
#   'sprinkle',
#   'strawberry',
#   'sugar'},
#  {'beaten',
#   'blackberrie',
#   'brown',
#   'butter',
#   'caster',
#   'cheese',
#   'cornflour',
#   'flour',
#   'light',
#   'milk',
#   'plu',
#   'soft',
#   'sugar'},
#  {'broken',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'dark',
#   'flour',
#   'piece',
#   'plu',
#   'powder',
#   'solid',
#   'sugar',
#   'yolk'},
#  {'caster',
#   'colour',
#   'cornflour',
#   'cream',
#   'double',
#   'green',
#   'optional',
#   'professional',
#   'strawberrie',
#   'sugar',
#   'top',
#   'vinegar',
#   'wine'},
#  {'cheddar',
#   'cheese',
#   'chive',
#   'edward',
#   'ham',
#   'mari',
#   'milk',
#   'oil',
#   'piper',
#   'potatoe',
#   'sunflower',
#   'sweetcorn',
#   'thick-cut'},
#  {'asda',
#   'beaten',
#   'breast',
#   'butcher',
#   'butter',
#   'chunk',
#   'crème',
#   'cube',
#   'eat',
#   'fillet',
#   'flour',
#   'fraîche',
#   'ham',
#   'honey',
#   'leek',
#   'lemon',
#   'pack',
#   'pastry',
#   'puff',
#   'ready',
#   'reduced-fat',
#   'roast',
#   'slice',
#   'sprig',
#   'stock',
#   'thyme',
#   'zest'},
#  {'allspice',
#   'asda',
#   'back',
#   'bacon',
#   'beaten',
#   'british',
#   'butter',
#   'fat',
#   'flour',
#   'good',
#   'hot',
#   'loin',
#   'made',
#   'onion',
#   'pack',
#   'pastry',
#   'piece',
#   'pinch',
#   'plu',
#   'pork',
#   'rasher',
#   'ready',
#   'sage',
#   'shortcrust',
#   'steak',
#   'stock',
#   'thin'},
#  {'anchovy',
#   'asda',
#   'bacon',
#   'bread',
#   'breast',
#   'ciabatta',
#   'clove',
#   'dijon',
#   'dry',
#   'fillet',
#   'garlic',
#   'head',
#   'heart',
#   'lettuce',
#   'mustard',
#   'oak',
#   'oil',
#   'olive',
#   'pack',
#   'parmesan',
#   'rasher',
#   'romaine',
#   'special',
#   'streaky',
#   'water',
#   'wine',
#   'yolk'},
#  {'asda',
#   'breast',
#   'can',
#   'coconut',
#   'coriander',
#   'corn',
#   'fillet',
#   'fish',
#   'juice',
#   'kit',
#   'lime',
#   'mangetout',
#   'milk',
#   'nam',
#   'noodle',
#   'pack',
#   'pepper',
#   'piece',
#   'pla',
#   'pouch',
#   'sauce',
#   'soy',
#   'special',
#   'stock',
#   'thai',
#   'turmeric',
#   'zest'},
#  {'asda',
#   'beansprout',
#   'beaten',
#   'brown',
#   'cayenne',
#   'chilli',
#   'coriander',
#   'dry',
#   'flake',
#   'frozen',
#   'groundnut',
#   'juice',
#   'lime',
#   'noodle',
#   'oil',
#   'onion',
#   'optional',
#   'peanut',
#   'piece',
#   'plu',
#   'quorn',
#   'roast',
#   'sauce',
#   'soy',
#   'style',
#   'sugar',
#   'zest'},
#  {'apricot',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'food',
#   'free-range',
#   'jam',
#   'milk',
#   'plu',
#   'powder',
#   'ready-to-roll',
#   'sugar',
#   'vanilla'},
#  {'butter',
#   'carrot',
#   'cream',
#   'double',
#   'juice',
#   'light',
#   'orange',
#   'pot',
#   'potato',
#   'shallot',
#   'stock',
#   'sugar',
#   'vegetable',
#   'zest'},
#  {'bacon',
#   'basil',
#   'cheese',
#   'clove',
#   'cod',
#   'cream',
#   'fillet',
#   'garlic',
#   'haddock',
#   'light',
#   'norwegian',
#   'parmesan',
#   'skin',
#   'tagliatelle'},
#  {'beaten',
#   'clove',
#   'cumin',
#   'fillet',
#   'garlic',
#   'leaf',
#   'oil',
#   'olive',
#   'pack',
#   'pastry',
#   'puff',
#   'salmon',
#   'slice',
#   'spinach'},
#  {'beaten',
#   'bunch',
#   'butter',
#   'courgette',
#   'creme',
#   'fillet',
#   'fraiche',
#   'haddock',
#   'parsley',
#   'pepper',
#   'potatoe',
#   'salmon',
#   'serve',
#   'skinles'},
#  {'bicarbonate',
#   'brown',
#   'butter',
#   'caster',
#   'cream',
#   'crunchy',
#   'ice',
#   'peanut',
#   'serve',
#   'soda',
#   'soft',
#   'strawberry',
#   'sugar',
#   'walnut'},
#  {'butter',
#   'caster',
#   'cornflour',
#   'cream',
#   'decorate',
#   'double',
#   'flour',
#   'juice',
#   'lemon',
#   'milk',
#   'plu',
#   'ramekin',
#   'sugar',
#   'zest'},
#  {'apricot',
#   'caster',
#   'chocolate',
#   'cider',
#   'cream',
#   'dark',
#   'double',
#   'drop',
#   'extract',
#   'hazelnut',
#   'ready-to-eat',
#   'sugar',
#   'vanilla',
#   'vinegar'},
#  {'asda',
#   'bean',
#   'beaten',
#   'butter',
#   'can',
#   'cheese',
#   'flageolet',
#   'flour',
#   'leek',
#   'mushroom',
#   'pastry',
#   'pot',
#   'puff',
#   'sauce'},
#  {'butter',
#   'cayenne',
#   'cheddar',
#   'flour',
#   'good',
#   'mature',
#   'mustard',
#   'parmesan',
#   'pinch',
#   'plu',
#   'poppy',
#   'powder',
#   'salt',
#   'sesame'},
#  {'beaten',
#   'breadcrumb',
#   'clove',
#   'coriander',
#   'cornflour',
#   'cube',
#   'curry',
#   'flour',
#   'garam',
#   'garlic',
#   'ketchup',
#   'masala',
#   'mild',
#   'oil',
#   'onion',
#   'optional',
#   'powder',
#   'rice',
#   'sauce',
#   'serve',
#   'soy',
#   'steak',
#   'stock',
#   'tomato',
#   'turkey',
#   'vegetable',
#   'water',
#   'wholemeal'},
#  {'almond',
#   'beaten',
#   'butter',
#   'caster',
#   'extract',
#   'free-range',
#   'juice',
#   'orange',
#   'plu',
#   'powder',
#   'semolina',
#   'sugar',
#   'vanilla',
#   'zest'},
#  {'back',
#   'bacon',
#   'beaten',
#   'breadcrumb',
#   'butter',
#   'courgette',
#   'free-range',
#   'lean',
#   'lengthway',
#   'mushroom',
#   'oil',
#   'olive',
#   'onion',
#   'parsley'},
#  {'back',
#   'bacon',
#   'bean',
#   'bread',
#   'crusty',
#   'free-range',
#   'mushroom',
#   'oil',
#   'pork',
#   'rasher',
#   'sausage',
#   'serve',
#   'sunflower',
#   'tomatoe'},
#  {'allspice',
#   'almond',
#   'cashew',
#   'caster',
#   'cayenne',
#   'chilli',
#   'cumin',
#   'macadamia',
#   'nut',
#   'pecan',
#   'powder',
#   'raw',
#   'salt',
#   'sugar'},
#  {'almond',
#   'asda',
#   'extract',
#   'honey',
#   'oil',
#   'pack',
#   'pastry',
#   'peache',
#   'ready',
#   'ricotta',
#   'shortcrust',
#   'sprig',
#   'thyme',
#   'vanilla'},
#  {'broccoli',
#   'butter',
#   'cheddar',
#   'cheese',
#   'creme',
#   'fraiche',
#   'half-fat',
#   'mature',
#   'milk',
#   'nutmeg',
#   'onion',
#   'pepper',
#   'potatoe',
#   'sweet'},
#  {'broccoli',
#   'butter',
#   'can',
#   'cheddar',
#   'fillet',
#   'floret',
#   'flour',
#   'mature',
#   'milk',
#   'oil',
#   'pack',
#   'salmon',
#   'sunflower',
#   'sweetcorn'},
#  {'asda',
#   'butter',
#   'can',
#   'chunk',
#   'coconut',
#   'flour',
#   'golden',
#   'honey',
#   'orange',
#   'pineapple',
#   'plu',
#   'powder',
#   'well',
#   'zest'},
#  {'almond',
#   'asda',
#   'caster',
#   'clementine',
#   'decorate',
#   'dr',
#   'flour',
#   'free',
#   'fruit',
#   'gluten',
#   'oetker',
#   'powder',
#   'satsuma',
#   'sugar'},
#  {'bone',
#   'bulb',
#   'butcher',
#   'flour',
#   'garlic',
#   'garnish',
#   'lamb',
#   'leg',
#   'pack',
#   'plu',
#   'rosemary',
#   'salt',
#   'serve',
#   'sprig'},
#  {'berrie',
#   'brioche',
#   'chocolate',
#   'cinnamon',
#   'extract',
#   'milk',
#   'oil',
#   'olive',
#   'optional',
#   'pinch',
#   'sauce',
#   'serve',
#   'slice',
#   'vanilla'},
#  {'almond',
#   'asda',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'free-range',
#   'juice',
#   'orange',
#   'plu',
#   'powder',
#   'special',
#   'sugar',
#   'zest'},
#  {'almond',
#   'asda',
#   'blackberrie',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'free-range',
#   'lemon',
#   'milk',
#   'special',
#   'sugar',
#   'vanilla',
#   'zest'},
#  {'asda',
#   'cake',
#   'caster',
#   'cherry',
#   'chocolate',
#   'conserve',
#   'cream',
#   'ice',
#   'madeira',
#   'scoop',
#   'slice',
#   'special',
#   'sugar',
#   'thick'},
#  {'all-butter',
#   'almond',
#   'basil',
#   'butter',
#   'caster',
#   'dust',
#   'handful',
#   'jam',
#   'pastry',
#   'peache',
#   'plu',
#   'shortcrust',
#   'strawberry',
#   'sugar'},
#  {'asda',
#   'balsamic',
#   'bite-size',
#   'breast',
#   'chillie',
#   'corn',
#   'cornflour',
#   'fillet',
#   'ginger',
#   'hot',
#   'mushroom',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'pepper',
#   'piece',
#   'root',
#   'sauce',
#   'shiitake',
#   'skinles',
#   'snap',
#   'soy',
#   'special',
#   'stock',
#   'sugar',
#   'sunflower',
#   'vinegar'},
#  {'asda',
#   'asparagu',
#   'beaten',
#   'butter',
#   'cheese',
#   'fat',
#   'frozen',
#   'full',
#   'parmesan',
#   'pastry',
#   'puff',
#   'sheet',
#   'smart',
#   'soft'},
#  {'almond',
#   'beaten',
#   'butter',
#   'caster',
#   'cinnamon',
#   'currant',
#   'glaze',
#   'nutmeg',
#   'pastry',
#   'peel',
#   'plu',
#   'puff',
#   'sprinkle',
#   'sugar'},
#  {'bag',
#   'blue',
#   'butter',
#   'cheese',
#   'cream',
#   'double',
#   'flour',
#   'free-range',
#   'leaf',
#   'milk',
#   'mushroom',
#   'nutmeg',
#   'parsley',
#   'spinach'},
#  {'almond',
#   'apricot',
#   'butter',
#   'case',
#   'caster',
#   'essence',
#   'flour',
#   'jam',
#   'pastry',
#   'pear',
#   'ripe',
#   'smooth',
#   'special',
#   'sugar'},
#  {'asda',
#   'butter',
#   'caster',
#   'extract',
#   'flour',
#   'food',
#   'free-range',
#   'milk',
#   'pearl',
#   'posh',
#   'powder',
#   'sprinkle',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'basil',
#   'bunch',
#   'clove',
#   'garlic',
#   'oil',
#   'olive',
#   'pasta',
#   'penne',
#   'special',
#   'sprig',
#   'thyme',
#   'tomatoe',
#   'tomkin'},
#  {'blue',
#   'butter',
#   'cheese',
#   'cream',
#   'flour',
#   'free-range',
#   'leek',
#   'lengthway',
#   'little',
#   'pastry',
#   'ready-made',
#   'roquefort',
#   'shortcrust',
#   'single'},
#  {'barley',
#   'breast',
#   'butter',
#   'carrot',
#   'celery',
#   'fillet',
#   'leek',
#   'oil',
#   'olive',
#   'pearl',
#   'potato',
#   'stick',
#   'stock',
#   'thyme'},
#  {'almond',
#   'caster',
#   'chocolate',
#   'chosen',
#   'cocoa',
#   'cream',
#   'dark',
#   'date',
#   'double',
#   'green',
#   'organic',
#   'raspberrie',
#   'solid',
#   'sugar'},
#  {'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'double',
#   'dr',
#   'dust',
#   'giant',
#   'oetker',
#   'plu',
#   'powder',
#   'raspberrie',
#   'star',
#   'sugar'},
#  {'bacon',
#   'butter',
#   'cinnamon',
#   'cream',
#   'maple',
#   'nutmeg',
#   'optional',
#   'panettone',
#   'plu',
#   'rasher',
#   'single',
#   'streaky',
#   'sugar',
#   'syrup'},
#  {'butter',
#   'cauliflower',
#   'cheddar',
#   'cheese',
#   'cream',
#   'dijon',
#   'double',
#   'floret',
#   'flour',
#   'mature',
#   'milk',
#   'mustard',
#   'plu',
#   'weight'},
#  {'apple',
#   'caster',
#   'cheese',
#   'cream',
#   'custard',
#   'ice',
#   'juice',
#   'pastry',
#   'puff',
#   'rhubarb',
#   'serve',
#   'soft',
#   'sugar',
#   'yolk'},
#  {'blueberrie',
#   'butter',
#   'caster',
#   'crème',
#   'flour',
#   'fraîche',
#   'milk',
#   'oil',
#   'peanut',
#   'powder',
#   'serve',
#   'smooth',
#   'strawberrie',
#   'sugar'},
#  {'asda',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'dark',
#   'milk',
#   'organic',
#   'pod',
#   'single',
#   'solid',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'beaten',
#   'breadcrumb',
#   'breast',
#   'butter',
#   'cal',
#   'drumstick',
#   'flavour',
#   'frylight',
#   'garlic',
#   'granule',
#   'herb',
#   'ketchup',
#   'mari',
#   'mustard',
#   'oil',
#   'olive',
#   'onion',
#   'paprika',
#   'piece',
#   'piper',
#   'potatoe',
#   'powder',
#   'sauce',
#   'serve',
#   'skin',
#   'spray',
#   'wedge',
#   'worcestershire'},
#  {'asda',
#   'bacon',
#   'butter',
#   'cayenne',
#   'cheddar',
#   'colman',
#   'flour',
#   'leek',
#   'mature',
#   'milk',
#   'mustard',
#   'pepper',
#   'powder',
#   'rasher'},
#  {'caster',
#   'cream',
#   'jam',
#   'milk',
#   'piece',
#   'plu',
#   'pod',
#   'raspberry',
#   'rhubarb',
#   'seedles',
#   'single',
#   'sugar',
#   'vanilla',
#   'yolk'},
#  {'asda',
#   'caster',
#   'cream',
#   'double',
#   'drop',
#   'extract',
#   'flour',
#   'free-range',
#   'nut',
#   'pistachio',
#   'powder',
#   'strawberrie',
#   'sugar',
#   'vanilla'},
#  {'asda',
#   'bacon',
#   'beef',
#   'beetroot',
#   'can',
#   'free-range',
#   'gherkin',
#   'oil',
#   'onion',
#   'parsley',
#   'potatoe',
#   'rasher',
#   'streaky',
#   'sunflower'},
#  {'breast',
#   'chunk',
#   'courgette',
#   'honey',
#   'juice',
#   'lemon',
#   'oil',
#   'onion',
#   'pepper',
#   'plu',
#   'sprig',
#   'sweetcorn',
#   'thyme',
#   'wedge'},
#  {'butter',
#   'cayenne',
#   'cheddar',
#   'cheese',
#   'dry',
#   'flour',
#   'mature',
#   'mustard',
#   'parmesan',
#   'pepper',
#   'piece',
#   'poppy',
#   'powder',
#   'sesame'},
#  {'almond',
#   'asda',
#   'beaten',
#   'bread',
#   'butter',
#   'clementine',
#   'cointreau',
#   'cream',
#   'double',
#   'dust',
#   'flour',
#   'satsuma',
#   'strong',
#   'sugar'},
#  {'breadcrumb',
#   'breast',
#   'fillet',
#   'frozen',
#   'oil',
#   'parmesan',
#   'pesto',
#   'plu',
#   'portion',
#   'potatoe',
#   'smart',
#   'sunflower',
#   'sweetcorn',
#   'wedge'},
#  {'caster',
#   'cheddar',
#   'flour',
#   'herb',
#   'mature',
#   'milk',
#   'oil',
#   'olive',
#   'oregano',
#   'piece',
#   'powder',
#   'shallot',
#   'sugar',
#   'tomatoe'},
#  {'butter',
#   'caster',
#   'chocolate',
#   'cornflour',
#   'cream',
#   'extract',
#   'flour',
#   'golden',
#   'milk',
#   'pinch',
#   'salt',
#   'sugar',
#   'syrup',
#   'vanilla'},
#  {'bay',
#   'breast',
#   'clove',
#   'fillet',
#   'garlic',
#   'honey',
#   'juice',
#   'lemon',
#   'light',
#   'oil',
#   'olive',
#   'sauce',
#   'soy',
#   'wedge'},
#  {'banana',
#   'butter',
#   'can',
#   'caramel',
#   'carnation',
#   'cream',
#   'cube',
#   'double',
#   'flour',
#   'free-range',
#   'milk',
#   'plu',
#   'sugar',
#   'yolk'},
#  {'asda',
#   'beaten',
#   'bicarbonate',
#   'butter',
#   'caster',
#   'cinnamon',
#   'flour',
#   'ginger',
#   'golden',
#   'pearl',
#   'posh',
#   'soda',
#   'sugar',
#   'syrup'},
#  {'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'dark',
#   'dash',
#   'flour',
#   'generou',
#   'handful',
#   'milk',
#   'powder',
#   'single',
#   'sugar'},
#  {'asda',
#   'beaten',
#   'breast',
#   'broccoli',
#   'chestnut',
#   'cornflour',
#   'crème',
#   'cube',
#   'fat',
#   'fillet',
#   'flour',
#   'fraîche',
#   'free',
#   'herb',
#   'leek',
#   'made',
#   'mushroom',
#   'oil',
#   'pastry',
#   'piece',
#   'potatoe',
#   'range',
#   'ready',
#   'serve',
#   'shortcrust',
#   'skin',
#   'stock',
#   'sunflower'},
#  {'asda',
#   'beaten',
#   'breadcrumb',
#   'butter',
#   'edward',
#   'free-range',
#   'mari',
#   'oil',
#   'pack',
#   'parsley',
#   'piper',
#   'potatoe',
#   'salmon',
#   'sunflower'},
#  {'asda',
#   'beaten',
#   'butter',
#   'caster',
#   'cocoa',
#   'cream',
#   'extract',
#   'flour',
#   'little',
#   'powder',
#   'punnet',
#   'raspberrie',
#   'sugar',
#   'vanilla'},
#  {'banana',
#   'blueberrie',
#   'brown',
#   'flour',
#   'light',
#   'milk',
#   'oat',
#   'oil',
#   'porridge',
#   'powder',
#   'raspberrie',
#   'ripe',
#   'soft',
#   'sugar',
#   'sunflower'},
#  {'asda',
#   'caster',
#   'chocolate',
#   'cream',
#   'dark',
#   'double',
#   'flour',
#   'ginger',
#   'milk',
#   'mini',
#   'natural',
#   'pinch',
#   'powder',
#   'special',
#   'sugar'},
#  {'asda',
#   'can',
#   'caster',
#   'fat',
#   'fruit',
#   'full',
#   'greek',
#   'juice',
#   'lemon',
#   'peache',
#   'plu',
#   'raspberrie',
#   'sugar',
#   'yogurt',
#   'yolk'},
#  {'asda',
#   'beaten',
#   'cheese',
#   'fillet',
#   'free-range',
#   'oil',
#   'olive',
#   'pack',
#   'pastry',
#   'potatoe',
#   'puff',
#   'ready',
#   'serve',
#   'steak',
#   'stilton'},
#  {'back',
#   'bacon',
#   'beaten',
#   'butter',
#   'cabbage',
#   'edward',
#   'lean',
#   'mari',
#   'oil',
#   'onion',
#   'piper',
#   'potatoe',
#   'rasher',
#   'savoy',
#   'weight'},
#  {'apple',
#   'asda',
#   'brandy',
#   'butter',
#   'caster',
#   'cocoa',
#   'extract',
#   'flour',
#   'juice',
#   'macadamia',
#   'nut',
#   'plu',
#   'prune',
#   'sugar',
#   'vanilla'},
#  {'almond',
#   'apricot',
#   'asda',
#   'butter',
#   'can',
#   'caster',
#   'drop',
#   'extract',
#   'flour',
#   'free-range',
#   'lemon',
#   'milk',
#   'special',
#   'sugar',
#   'zest'},
#  {'asda',
#   'beaten',
#   'brown',
#   'chunk',
#   'cinnamon',
#   'food',
#   'oil',
#   'pack',
#   'pastry',
#   'pumpkin',
#   'ready',
#   'roll',
#   'shortcrust',
#   'soft',
#   'sugar'},
#  {'asda',
#   'clove',
#   'coriander',
#   'fat',
#   'free',
#   'garlic',
#   'greek',
#   'handful',
#   'jar',
#   'oil',
#   'pepper',
#   'sauce',
#   'spicy',
#   'tomato',
#   'yoghurt'},
#  {'almond',
#   'biscuit',
#   'chocolate',
#   'cream',
#   'dark',
#   'double',
#   'drop',
#   'extract',
#   'raspberrie',
#   'sauce',
#   'serve',
#   'special',
#   'sugar',
#   'thin',
#   'vanilla'},
#  {'bean',
#   'cashew',
#   'chillie',
#   'choi',
#   'clove',
#   'garlic',
#   'ginger',
#   'green',
#   'oil',
#   'onion',
#   'pak',
#   'piece',
#   'sauce',
#   'soy',
#   'sunflower'},
#  {'asda',
#   'asparagu',
#   'balsamic',
#   'basil',
#   'bread',
#   'end',
#   'modena',
#   'oil',
#   'onion',
#   'optional',
#   'serve',
#   'tomatoe',
#   'vine',
#   'vinegar',
#   'woody'},
#  {'butter',
#   'caster',
#   'cold',
#   'core',
#   'cornflour',
#   'flour',
#   'free',
#   'juice',
#   'lemon',
#   'pineapple',
#   'plu',
#   'range',
#   'skin',
#   'sugar',
#   'yolk'},
#  {'asda',
#   'caster',
#   'cream',
#   'double',
#   'dust',
#   'flour',
#   'free-range',
#   'juice',
#   'lemon',
#   'pastry',
#   'ready',
#   'roll',
#   'shortcrust',
#   'sugar',
#   'zest'},
#  {'asda',
#   'butter',
#   'cayenne',
#   'cheddar',
#   'dry',
#   'flour',
#   'mature',
#   'mustard',
#   'pepper',
#   'pinch',
#   'poppy',
#   'powder',
#   'salt',
#   'stilton',
#   'walnut'},
#  {'bacon',
#   'brussel',
#   'cabbage',
#   'clove',
#   'garlic',
#   'green',
#   'oil',
#   'onion',
#   'optional',
#   'potatoe',
#   'rasher',
#   'serve',
#   'sprout',
#   'streaky',
#   'sunflower'},
#  {'allspice',
#   'almondsto',
#   'brown',
#   'butter',
#   'cinnamon',
#   'clove',
#   'cornflour',
#   'decorate',
#   'flour',
# ...
#   'bright',
#   'butcher',
#   'carrot',
#   'cheese',
#   'colour',
#   'crudite',
#   'decoration',
#   'dijon',
#   'dr',
#   'fat',
#   'food',
#   'gel',
#   'gherkin',
#   'mince',
#   'mustard',
#   'oetker',
#   'orange',
#   'pepper',
#   'rest',
#   'rocket',
#   'roll',
#   'sauce',
#   'slice',
#   'top',
#   'warburton',
#   'worcestershire'},
#  {'asda',
#   'breast',
#   'cabbage',
#   'carrot',
#   'chilli',
#   'clove',
#   'crusty',
#   'fry',
#   'garlic',
#   'ginger',
#   'growers’',
#   'kickin’',
#   'korean',
#   'lettuce',
#   'matchstick',
#   'oil',
#   'onion',
#   'pack',
#   'powder',
#   'radishe',
#   'roll',
#   'root',
#   'sauce',
#   'savoy',
#   'sesame',
#   'stir',
#   'sugar',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'bottom',
#   'breast',
#   'butcher’',
#   'celery',
#   'chunk',
#   'coarse',
#   'cornflour',
#   'crème',
#   'fat',
#   'fillet',
#   'fraiche',
#   'french',
#   'garnish',
#   'grain',
#   'leek',
#   'les',
#   'mini',
#   'mustard',
#   'oil',
#   'olive',
#   'optional',
#   'parsley',
#   'potato',
#   'serve',
#   'slice',
#   'stick',
#   'stock',
#   'sweet'},
#  {'amoy',
#   'bean',
#   'broccoli',
#   'can',
#   'chestnut',
#   'chilli',
#   'chosen',
#   'clove',
#   'floret',
#   'freshnes',
#   'frozen',
#   'garlic',
#   'ginger',
#   'green',
#   'kidney',
#   'mushroom',
#   'noodle',
#   'oil',
#   'pack',
#   'piece',
#   'plu',
#   'pumpkin',
#   'root',
#   'salt',
#   'sauce',
#   'serve',
#   'smart',
#   'soy',
#   'sunflower'},
#  {'aubergine',
#   'bay',
#   'butternut',
#   'chilli',
#   'chunk',
#   'coconut',
#   'coriander',
#   'drumstick',
#   'hot',
#   'juice',
#   'lime',
#   'mango',
#   'milk',
#   'mustard',
#   'oil',
#   'onion',
#   'optional',
#   'papaya',
#   'paste',
#   'piece',
#   'potatoe',
#   'reduced-fat',
#   'ripe',
#   'rum',
#   'squash',
#   'tamarind',
#   'thigh',
#   'turmeric',
#   'waxy'},
#  {'asda',
#   'bicarbonate',
#   'brown',
#   'butter',
#   'carrot',
#   'cheese',
#   'coconut',
#   'creamy',
#   'drop',
#   'extract',
#   'fat',
#   'flour',
#   'full',
#   'juice',
#   'lemon',
#   'light',
#   'oil',
#   'orange',
#   'pecan',
#   'soda',
#   'soft',
#   'special',
#   'spice',
#   'sugar',
#   'sultana',
#   'sunflower',
#   'vanilla',
#   'weight',
#   'zest'},
#  {'asda',
#   'banana',
#   'bar',
#   'caster',
#   'chocolate',
#   'dairy',
#   'dark',
#   'extract',
#   'flour',
#   'free',
#   'free-range',
#   'gluten',
#   'gluten-free',
#   'gum',
#   'kinnerton',
#   'luxury',
#   'make',
#   'nut',
#   'pecan',
#   'powder',
#   'ripe',
#   'spread',
#   'sugar',
#   'thi',
#   'vanilla',
#   'vitalite',
#   'weight',
#   'well',
#   'xantham'},
#  {'asda',
#   'boneles',
#   'british',
#   'butcher’',
#   'cashew',
#   'chilli',
#   'clove',
#   'coleslaw',
#   'crunchy',
#   'fillet',
#   'garlic',
#   'green',
#   'grower’',
#   'jerk',
#   'juice',
#   'kit',
#   'lime',
#   'mango',
#   'mint',
#   'nut',
#   'onion',
#   'pepper',
#   'piece',
#   'purée',
#   'rice',
#   'serve',
#   'sweet',
#   'thigh',
#   'tomato'},
#  {'asparagu',
#   'bean',
#   'british',
#   'butcher’',
#   'can',
#   'carrot',
#   'coconut',
#   'coriander',
#   'cornflour',
#   'curry',
#   'fat',
#   'kidney',
#   'milk',
#   'naan',
#   'oil',
#   'onion',
#   'pack',
#   'paste',
#   'pepper',
#   'radishe',
#   'rice',
#   'serve',
#   'spear',
#   'spinach',
#   'stock',
#   'sunflower',
#   'thigh',
#   'vegetable',
#   'water'},
#  {'balsamic',
#   'chestnut',
#   'chilli',
#   'chosen',
#   'corn',
#   'cube',
#   'ginger',
#   'hot',
#   'juice',
#   'leftover',
#   'light',
#   'lime',
#   'made',
#   'mushroom',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'plu',
#   'sauce',
#   'serve',
#   'soy',
#   'stock',
#   'turkey',
#   'udon',
#   'vegetable',
#   'vinegar',
#   'wedge',
#   'zest'},
#  {'broken',
#   'brown',
#   'butter',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'cream',
#   'dark',
#   'decorate',
#   'double',
#   'dr',
#   'drop',
#   'extract',
#   'flat-leaf',
#   'flora',
#   'flour',
#   'food',
#   'gel',
#   'light',
#   'milk',
#   'oetker',
#   'parsley',
#   'powder',
#   'soft',
#   'spread',
#   'sprig',
#   'square',
#   'sugar',
#   'tube',
#   'vanilla'},
#  {'asda',
#   'belt',
#   'biscuit',
#   'butter',
#   'caster',
#   'choco',
#   'chocolate',
#   'chosen',
#   'coconut',
#   'crunchie',
#   'drop',
#   'extract',
#   'finger',
#   'flour',
#   'food',
#   'fruittella',
#   'milk',
#   'pack',
#   'pink',
#   'plu',
#   'pot',
#   'powder',
#   'rainbow',
#   'ready',
#   'roll',
#   'rowntree’',
#   'sprinkle',
#   'sugar',
#   'tot',
#   'vanilla'},
#  {'asda',
#   'bay',
#   'bean',
#   'bread',
#   'can',
#   'cannellini',
#   'carton',
#   'chosen',
#   'clove',
#   'crusty',
#   'fat',
#   'flat',
#   'garlic',
#   'haricot',
#   'italian',
#   'leaf',
#   'mustard',
#   'oil',
#   'olive',
#   'onion',
#   'pack',
#   'parsley',
#   'passata',
#   'pork',
#   'sausage',
#   'serve',
#   'stock',
#   'vinegar',
#   'wholegrain',
#   'wine'},
#  {'bake',
#   'biscuit',
#   'blue',
#   'butter',
#   'caster',
#   'chosen',
#   'colour',
#   'create',
#   'digestive',
#   'dr',
#   'dust',
#   'extract',
#   'flour',
#   'golden',
#   'green',
#   'jam',
#   'marzipan',
#   'milk',
#   'oetkerregal-ice',
#   'pack',
#   'plu',
#   'powder',
#   'raspberry',
#   'ready',
#   'roll',
#   'sugar',
#   'tube',
#   'vanilla',
#   'water',
#   'yougreat'},
#  {'baguette',
#   'bird',
#   'carrot',
#   'caster',
#   'chilli',
#   'coriander',
#   'cucumber',
#   'day-old',
#   'eye',
#   'fish',
#   'gem',
#   'halve',
#   'juice',
#   'leftover',
#   'lettuce',
#   'lime',
#   'little',
#   'mint',
#   'oil',
#   'piece',
#   'radishe',
#   'rice',
#   'sauce',
#   'serve',
#   'shallot',
#   'sugar',
#   'sweet',
#   'torn',
#   'vinegar',
#   'wine'},
#  {'asda',
#   'avocado',
#   'bacon',
#   'bag',
#   'balsamic',
#   'bitesize',
#   'bread',
#   'breast',
#   'cherry',
#   'coarse',
#   'crusty',
#   'fillet',
#   'grain',
#   'honey',
#   'juice',
#   'leaf',
#   'lemon',
#   'mini',
#   'mustard',
#   'oil',
#   'olive',
#   'pack',
#   'piece',
#   'rasher',
#   'ripe',
#   'salad',
#   'serve',
#   'streaky',
#   'tomatoe',
#   'vinegar'},
#  {'almond',
#   'apricot',
#   'brandy',
#   'brown',
#   'butter',
#   'cherrie',
#   'cranberrie',
#   'dr',
#   'flour',
#   'glacé',
#   'jam',
#   'lemon',
#   'marzipan',
#   'natural',
#   'oetker',
#   'orange',
#   'pack',
#   'pecan',
#   'plu',
#   'raisin',
#   'ready',
#   'regal-ice',
#   'roll',
#   'rum',
#   'seedles',
#   'soft',
#   'spice',
#   'sugar',
#   'sultana',
#   'zest'},
#  {'asda',
#   'basmati',
#   'breast',
#   'butcher',
#   'chosen',
#   'clove',
#   'coriander',
#   'curry',
#   'fat',
#   'fillet',
#   'free',
#   'frozen',
#   'garlic',
#   'greek',
#   'italian',
#   'madra',
#   'natural',
#   'oil',
#   'onion',
#   'optional',
#   'pack',
#   'paste',
#   'pea',
#   'piece',
#   'rice',
#   'serve',
#   'style',
#   'tomatoe',
#   'vegetable',
#   'yogurt'},
#  {'apricot',
#   'breast',
#   'can',
#   'chosen',
#   'cucumber',
#   'del',
#   'fat',
#   'fillet',
#   'free',
#   'grain',
#   'greek',
#   'juice',
#   'korma',
#   'lemon',
#   'light',
#   'long',
#   'mayonnaise',
#   'monte',
#   'onion',
#   'pack',
#   'paste',
#   'peach',
#   'purée',
#   'rice',
#   'sharwood’',
#   'slice',
#   'smart',
#   'style',
#   'tomato',
#   'yogurt'},
#  {'biscuit',
#   'butter',
#   'caster',
#   'cheese',
#   'chocolate',
#   'chosen',
#   'cocoa',
#   'cold',
#   'cornflour',
#   'cream',
#   'creme',
#   'decorate',
#   'digestive',
#   'double',
#   'extract',
#   'fat',
#   'fraiche',
#   'juice',
#   'les',
#   'light',
#   'orange',
#   'plu',
#   'powder',
#   'soft',
#   'special',
#   'sugar',
#   'terry',
#   'valencian',
#   'water',
#   'zest'},
#  {'arborio',
#   'asda',
#   'chorizo',
#   'chosen',
#   'clove',
#   'drumstick',
#   'eat',
#   'frozen',
#   'garlic',
#   'generou',
#   'green',
#   'hot',
#   'litre',
#   'oil',
#   'olive',
#   'onion',
#   'optional',
#   'pack',
#   'paella',
#   'paprika',
#   'pea',
#   'pepper',
#   'piece',
#   'pinch',
#   'ready',
#   'rice',
#   'saffron',
#   'seafood',
#   'stock',
#   'wine'},
#  {'avocado',
#   'bean',
#   'breast',
#   'can',
#   'chilli',
#   'chunk',
#   'concentrate',
#   'coriander',
#   'fajita',
#   'frozen',
#   'gem',
#   'good',
#   'juice',
#   'lemon',
#   'lettuce',
#   'lime',
#   'little',
#   'mexican',
#   'mix',
#   'oil',
#   'olive',
#   'onion',
#   'optional',
#   'ripe',
#   'schwartz',
#   'serve',
#   'style',
#   'torn',
#   'water',
#   'wedge'},
#  {'asda',
#   'bean',
#   'broad',
#   'chorizo',
#   'clove',
#   'frozen',
#   'garlic',
#   'green',
#   'hot',
#   'litre',
#   'live',
#   'mayonnaise',
#   'mussel',
#   'oil',
#   'olive',
#   'onion',
#   'pack',
#   'paella',
#   'paprika',
#   'pinche',
#   'prawn',
#   'raw',
#   'rice',
#   'saffron',
#   'serve',
#   'spanish',
#   'special',
#   'stock',
#   'thigh',
#   'tomatoe'},
#  {'asda',
#   'breast',
#   'bunch',
#   'butcher',
#   'can',
#   'carrot-',
#   'chilli',
#   'coriander',
#   'couscou',
#   'cube',
#   'cumin',
#   'flat',
#   'kg',
#   'leaf',
#   'made',
#   'mild',
#   'mince',
#   'napolina',
#   'oil',
#   'onion',
#   'paprika',
#   'parsley',
#   'pepper',
#   'powder',
#   'sold',
#   'stock',
#   'sultana',
#   'sunflower',
#   'tomatoe',
#   'turkey'},
#  {'butter',
#   'camp',
#   'case',
#   'caster',
#   'chicory',
#   'chocolate',
#   'cocoa',
#   'coffee',
#   'colour',
#   'cupcake',
#   'dark',
#   'dr',
#   'drop',
#   'esssence',
#   'extract',
#   'flour',
#   'food',
#   'gel',
#   'green',
#   'lime',
#   'milk',
#   'oetker',
#   'paper',
#   'plu',
#   'powder',
#   'room',
#   'solid',
#   'sugar',
#   'temperature',
#   'vanilla'},
#  {'almond',
#   'apple',
#   'asda',
#   'breast',
#   'chutney',
#   'coriander',
#   'corn',
#   'crème',
#   'cube',
#   'curry',
#   'dlsigny',
#   'fillet',
#   'fraîche',
#   'french',
#   'garnish',
#   'ginger',
#   'grape',
#   'greek',
#   'made',
#   'mango',
#   'oil',
#   'plu',
#   'pot',
#   'powder',
#   'purée',
#   'special',
#   'stock',
#   'style',
#   'sunflower',
#   'tomato',
#   'yogurt'},
#  {'beaten',
#   'butter',
#   'can',
#   'cayenne',
#   'cheddar',
#   'cranberry',
#   'dijon',
#   'flour',
#   'gammon',
#   'giant',
#   'green',
#   'ham',
#   'jus-rol',
#   'mature',
#   'milk',
#   'mustard',
#   'optional',
#   'pastry',
#   'piece',
#   'pinch',
#   'plu',
#   'ready-to-roll',
#   'roast',
#   'salt',
#   'sauce',
#   'shortcrust',
#   'sprig',
#   'sugar',
#   'sweetcorn',
#   'thyme',
#   'turkey'},
#  {'asda',
#   'bag',
#   'basil',
#   'beef',
#   'butcher',
#   'chilli',
#   'chive',
#   'clove',
#   'coriander',
#   'couscou',
#   'cucumber',
#   'fat',
#   'free',
#   'garlic',
#   'giant',
#   'lean',
#   'lemon',
#   'mince',
#   'mint',
#   'natural',
#   'onion',
#   'parsley',
#   'pesto',
#   'pomegranate',
#   'quinoa',
#   'steam',
#   'tomato',
#   'tortilla',
#   'wholemeal',
#   'yoghurt',
#   'zest'},
#  {'bird',
#   'breast',
#   'bunch',
#   'caster',
#   'chilli',
#   'cinnamon',
#   'clove',
#   'coriander',
#   'eye',
#   'fat',
#   'garam',
#   'garlic',
#   'ginger',
#   'greek',
#   'green',
#   'hot',
#   'juice',
#   'lemon',
#   'lime',
#   'masala',
#   'mint',
#   'oil',
#   'pinch',
#   'powder',
#   'skin',
#   'squeeze',
#   'stalk',
#   'sugar',
#   'thumb',
#   'vegetable',
#   'yogurt'},
#  {'asda',
#   'beansprout',
#   'breast',
#   'british',
#   'carrot',
#   'chilli',
#   'coriander',
#   'cucumber',
#   'fillet',
#   'ginger',
#   'grower’',
#   'iceberg',
#   'japan',
#   'jasmine',
#   'juice',
#   'katsu',
#   'lettuce',
#   'lime',
#   'mini',
#   'oil',
#   'pack',
#   'piece',
#   'rice',
#   'sauce',
#   'simmer',
#   'spice',
#   'sweet',
#   'taste',
#   'thai',
#   'vinegar',
#   'weight'},
#  {'beaten',
#   'brandy',
#   'breadcrumb',
#   'cherry',
#   'chive',
#   'chosen',
#   'cracker',
#   'cres',
#   'flour',
#   'gem',
#   'gherkin',
#   'lemon',
#   'little',
#   'lobster',
#   'marie',
#   'paprika',
#   'parsley',
#   'portion',
#   'prawn',
#   'rose',
#   'sauce',
#   'serve',
#   'shallot',
#   'special',
#   'spicy',
#   'splash',
#   'tail',
#   'tarragon',
#   'tomatoe',
#   'vodka',
#   'wedge'},
#  {'beef',
#   'butcher',
#   'can',
#   'cheddar',
#   'cherry',
#   'chosen',
#   'cream',
#   'fajita',
#   'guacamole',
#   'iceberg',
#   'jalapeño',
#   'lettuce',
#   'lime',
#   'mature',
#   'mix',
#   'oil',
#   'onion',
#   'pack',
#   'pepper',
#   'prime',
#   'recipe',
#   'salsa',
#   'schwartz',
#   'sirloin',
#   'spicy',
#   'steak',
#   'sweetcorn',
#   'tortilla',
#   'vegetable',
#   'wedge',
#   'weight',
#   'youhot'},
#  {'asda',
#   'bean',
#   'breast',
#   'carrot',
#   'chilli',
#   'chinese',
#   'clove',
#   'coriander',
#   'duck',
#   'fillet',
#   'garlic',
#   'garnish',
#   'ginger',
#   'honey',
#   'juice',
#   'leaf',
#   'lime',
#   'mangetout',
#   'oil',
#   'optional',
#   'pea',
#   'plu',
#   'sesame',
#   'skin',
#   'snap',
#   'sprig',
#   'sprout',
#   'stock',
#   'strip',
#   'sugar',
#   'sunflower',
#   'tamarind'},
#  {'brown',
#   'butter',
#   'buttercream',
#   'cake',
#   'caster',
#   'chocolate',
#   'cocoa',
#   'colour',
#   'different',
#   'extract',
#   'flour',
#   'food',
#   'gel',
#   'gelatine',
#   'glaze',
#   'glucose',
#   'golden',
#   'good-quality',
#   'light',
#   'milk',
#   'mirror',
#   'oil',
#   'powder',
#   'self',
#   'semi',
#   'soft',
#   'star',
#   'sugar',
#   'sunflower',
#   'syrup',
#   'vanilla',
#   'yolk'},
#  {'almond',
#   'asda',
#   'bicarbonate',
#   'brown',
#   'butter',
#   'buttermilk',
#   'cherrie',
#   'cherry',
#   'chocolate',
#   'chosen',
#   'coast',
#   'cocoa',
#   'conserve',
#   'cream',
#   'dark',
#   'decorate',
#   'double',
#   'extract',
#   'flour',
#   'frozen',
#   'ivory',
#   'jar',
#   'light',
#   'morello',
#   'pack',
#   'powder',
#   'soda',
#   'soft',
#   'solid',
#   'special',
#   'sugar',
#   'vanilla'},
#  {'angel',
#   'apricot',
#   'beaten',
#   'bicarbonate',
#   'blue',
#   'brown',
#   'butter',
#   'cake',
#   'caster',
#   'cinnamon',
#   'cocoa',
#   'flour',
#   'ginger',
#   'golden',
#   'green',
#   'jam',
#   'light',
#   'mallow',
#   'milk',
#   'nutella',
#   'pack',
#   'plu',
#   'pot',
#   'powder',
#   'ready',
#   'roll',
#   'self',
#   'soda',
#   'soft',
#   'spice',
#   'sugar',
#   'syrup'},
#  {'bean',
#   'biscuit',
#   'butter',
#   'caster',
#   'chosen',
#   'coconut',
#   'cornflour',
#   'cream',
#   'decorate',
#   'digestive',
#   'extract',
#   'fat',
#   'fruit',
#   'full',
#   'italian',
#   'juice',
#   'lime',
#   'malibu',
#   'mango',
#   'mascarpone',
#   'mint',
#   'pack',
#   'pineapple',
#   'plu',
#   'pomegranate',
#   'slice',
#   'special',
#   'sugar',
#   'urban',
#   'vanilla',
#   'yolk',
#   'zest'},
#  {'asda',
#   'beansprout',
#   'blue',
#   'broccoli',
#   'brown',
#   'chilli',
#   'dragon',
#   'fish',
#   'floret',
#   'free-range',
#   'groundnut',
#   'juice',
#   'ketchup',
#   'lime',
#   'little',
#   'mushroom',
#   'noodle',
#   'oil',
#   'onion',
#   'ordinary',
#   'pack',
#   'peanut',
#   'plu',
#   'sauce',
#   'shiitake',
#   'special',
#   'sugar',
#   'sunflower',
#   'sweet',
#   'taste',
#   'thai',
#   'tomato'},
#  {'antony',
#   'asda',
#   'back',
#   'bacon',
#   'basil',
#   'beef',
#   'bread',
#   'carton',
#   'cube',
#   'free',
#   'free-range',
#   'fusilli',
#   'gluten',
#   'lean',
#   'mince',
#   'oil',
#   'olive',
#   'onion',
#   'pack',
#   'parsley',
#   'passata',
#   'pepper',
#   'roll',
#   'spaghetti',
#   'sprig',
#   'steak',
#   'stock',
#   'sugar',
#   'sweet',
#   'thompson',
#   'torn',
#   'worrall'},
#  {'asda',
#   'breast',
#   'brown',
#   'butcher’',
#   'cook',
#   'easy',
#   'fat-free',
#   'fillet',
#   'flat-leaf',
#   'gem',
#   'grain',
#   'greek-style',
#   'grower’',
#   'juice',
#   'lemon',
#   'lettuce',
#   'little',
#   'long',
#   'meli',
#   'mini',
#   'natural',
#   'oil',
#   'onion',
#   'parsley',
#   'pomegranate',
#   'quarter',
#   'rice',
#   'sauce',
#   'sesame',
#   'torn',
#   'yogurt',
#   'zest'},
#  {'asda',
#   'breast',
#   'brown',
#   'butter',
#   'can',
#   'chillie',
#   'coconut',
#   'coriander',
#   'crunchy',
#   'dark',
#   'fish',
#   'groundnut',
#   'juice',
#   'lime',
#   'milk',
#   'noodle',
#   'oil',
#   'onion',
#   'pack',
#   'peanut',
#   'piece',
#   'plu',
#   'sauce',
#   'serve',
#   'soft',
#   'soy',
#   'steak',
#   'sugar',
#   'sunflower',
#   'thai',
#   'turkey',
#   'zest'},
#  {'bean',
#   'butcher',
#   'butter',
#   'can',
#   'carrot',
#   'carton',
#   'chosen',
#   'clove',
#   'cornflour',
#   'cube',
#   'cumberland',
#   'fat',
#   'garlic',
#   'hot',
#   'lea',
#   'oil',
#   'onion',
#   'pack',
#   'paprika',
#   'perrin',
#   'pork',
#   'potatoe',
#   'sauce',
#   'sausage',
#   'sprig',
#   'stock',
#   'sugar',
#   'sunflower',
#   'thyme',
#   'tomatoe',
#   'water',
#   'worcestershire'},
#  {'amoy',
#   'asda',
#   'bite-size',
#   'breast',
#   'carrot',
#   'chilli',
#   'cider',
#   'core',
#   'cornflour',
#   'fillet',
#   'honey',
#   'juice',
#   'lengthway',
#   'mangetout',
#   'oil',
#   'onion',
#   'orange',
#   'pack',
#   'pepper',
#   'piece',
#   'pineapple',
#   'rice',
#   'salt',
#   'sauce',
#   'serve',
#   'short',
#   'skin',
#   'soy',
#   'stick',
#   'strip',
#   'sunflower',
#   'sweet',
#   'vinegar'},
#  {'asda',
#   'blue',
#   'butler’',
#   'celery',
#   'cheese',
#   'chilli',
#   'chipotle',
#   'cider',
#   'clove',
#   'cream',
#   'dijon',
#   'farmhouse',
#   'fat',
#   'flake',
#   'garlic',
#   'honey',
#   'joint',
#   'juice',
#   'ketchup',
#   'lemon',
#   'les',
#   'light',
#   'mayonnaise',
#   'mustard',
#   'optional',
#   'parsley',
#   'sauce',
#   'special',
#   'stick',
#   'tip',
#   'tomato',
#   'vinegar',
#   'worcestershire'},
#  {'asda',
#   'breadcrumb',
#   'chip',
#   'cod',
#   'crisp',
#   'crumb',
#   'crème',
#   'flora',
#   'frozen',
#   'frâiche',
#   'good',
#   'lemon',
#   'loin',
#   'mari',
#   'mild',
#   'mint',
#   'oil',
#   'olive',
#   'original',
#   'pack',
#   'paprika',
#   'pea',
#   'pinch',
#   'piper',
#   'plu',
#   'potatoe',
#   'ready',
#   'reduced-fat',
#   'serve',
#   'sesame',
#   'thick',
#   'weight',
#   'zest'},
#  ...]

# %% [markdown]
# Testing:

# %%
set(recipes_ingredients_dic['basic-royal-icing'])
# Out:
# {'egg', 'sugar'}

# %%
set(recipes_ingredients_dic['icing-recipe'])
# Out:
# {'egg', 'sugar'}

# %% [markdown]
# ### Best Rated

# %%
import numpy as np
import pandas as pd
import csv
#import graphlab as gl

# %%
def best_rated_recommender(data=users_recipes_ratings_df):
    #convert to SFrame (internal dataframe format of graphlab)
    sf = gl.SFrame(data)
    # top rated
    recipe_rating_stats = sf.groupby(key_columns='recipe',
                                    operations={'mean_rating': gl.aggregate.MEAN('rating'), 
                                                'std_rating': gl.aggregate.STD('rating')})
    return recipe_rating_stats.sort([('mean_rating', True), ('std_rating', False)])

# %% [markdown]
# ### Collaborative filtering

# %%
import numpy as np
import pandas as pd
import csv
#import graphlab as gl

# %%
def collaborative_filtering(data=users_recipes_ratings_df, user=["user_1"], K=10):
    sf = gl.SFrame(data)
    
    collaborative_filtering = gl.item_similarity_recommender.create(sf, user_id='user', item_id='recipe', target='rating',                                                similarity_type='pearson')
    pred_itemitem_pearson = collaborative_filtering.predict(sf)
    recs_itemitem_pearson = collaborative_filtering.recommend(users=user, k=K)     # top 10 collaborative filtering recomendations

    return recs_itemitem_pearson

# %% [markdown]
# ### Content-based Recommender
#
# col_recipes_ingredients.find() iterates over each recipes:[products]

# %%
for key, value in recipes_ingredients_dic.items():
    print(key, value)
# Out:
# chicken-pumpkin-curry ['ghee', 'oil', 'onion', 'pack', 'asda', 'chicken', 'thigh', 'fillet', 'skin', 'garlic', 'clove', 'ginger', 'turmeric', 'cumin', 'asda', 'garam', 'masala', 'chillie', 'can', 'coconut', 'milk', 'pumpkin', 'skin', 'fibre', 'cornflour', 'cold', 'water', 'make', 'paste', 'coriander', 'rice', 'serve']
# masterclass-pulled-ham-creamy-herb-salad ['butcher’', 'gammon', 'joint', 'cider', 'bag', 'asda', 'tender', 'leaf', 'salad', 'caper', 'frozen', 'pea', 'minute', 'radishe', 'chosen', 'gherkin', 'cider', 'vinegar', 'olive', 'oil', 'fat', 'crème', 'fraîche', 'dijon', 'mustard', 'parsley']
# banana-pecan-date-muffins ['butter', 'plu', 'light', 'soft', 'brown', 'sugar', 'ripe', 'banana', 'weight', 'egg', 'beaten', 'flour', 'salt', 'powder', 'cinnamon', 'plu', 'pecan', 'date', 'raisin-size', 'piece', 'sugar']
# easy-peasy-fish-cakes ['pack', 'smash', 'instant', 'mash', 'potato', 'can', 'asda', 'tuna', 'chunk', 'water', 'chive', 'pinch', 'cayenne', 'egg', 'beaten', 'butter', 'asda', 'cornflake', 'breadcrumb', 'filippo', 'berio', 'spray', 'oil', 'asparagu', 'serve', 'pea', 'serve', 'sweetcorn', 'serve']
# fruity-fro-yo-bombe ['banana', 'frozen', 'solid', 'can', 'ambrosia', 'light', 'devon', 'custard', 'frozen', 'hr', 'pot', 'yeo', 'valley', 'fat', 'greek', 'style', 'honey', 'asda', 'natural', 'food', 'green', 'frozen', 'raspberrie', 'chocolate', 'chip']
# salmon-fillets-with-pink-grapefruit-salsa ['pink', 'grapefruit', 'ripe', 'avocado', 'piece', 'chilli', 'onion', 'coriander', 'mild', 'olive', 'oil', 'plu', 'zest', 'lime', 'plu', 'juice', 'basmati', 'rice', 'salmon', 'fillet']
# mac-n-cheese-salad ['macaroni', 'olive', 'oil', 'asda', 'light', 'mayonnaise', 'sour', 'cream', 'chive', 'american-style', 'mustard', 'chosen', 'crispy', 'bacon', 'asda', 'cheddar', 'leicester', 'pepper', 'special', 'sweet', 'aromatico', 'tomatoe']
# ginger-cake ['butter', 'plu', 'treacle', 'plu', 'serve', 'optional', 'golden', 'syrup', 'ball', 'opie', 'stem', 'ginger', 'syrup', 'flour', 'ginger', 'spice', 'dark', 'soft', 'brown', 'sugar', 'sultana', 'optional', 'egg', 'milk', 'stem', 'ginger', 'syrup', 'jar', 'serve', 'optional']
# nadiya-hussain-berry-breakfast-muffins ['flour', 'porridge', 'oat', 'soft', 'light', 'brown', 'sugar', 'powder', 'egg', 'ripe', 'banana', 'sunflower', 'oil', 'milk', 'blueberrie', 'raspberrie']
# three-bean-salad ['olive', 'oil', 'balsamic', 'vinegar', 'dijon', 'mustard', 'oil', 'jar', 'tomatoe', 'frozen', 'broad', 'bean', 'tomatoe', 'can', 'kidney', 'bean', 'can', 'cannellini', 'bean', 'celery', 'stick', 'bunch', 'onion']
# glazed-chicken-vegetable-roast ['pack', 'asda', 'butcher', 'chicken', 'pack', 'redcurrant', 'clove', 'garlic', 'asda', 'paprika', 'wine', 'vinegar', 'worcestershire', 'sauce', 'oregano', 'olive', 'oil', 'sweet', 'potato', 'weight', 'chunk', 'pepper', 'pepper', 'onion', 'wedge', 'salad', 'serve']
# beetroot-potato-chorizo-hash ['edward', 'potatoe', 'weight', 'sweet', 'potato', 'weight', 'pack', 'asda', 'vacuum', 'beetroot', 'onion', 'wedge', 'asda', 'special', 'spanish', 'chorizo', 'casero', 'cube', 'sunflower', 'oil', 'plu', 'wholegrain', 'mustard', 'worcestershire', 'sauce', 'free-range', 'egg']
# spinach-prawn-mango-salad ['groundnut', 'oil', 'sunflower', 'oil', 'lemon', 'juice', 'light', 'soy', 'sauce', 'honey', 'root', 'ginger', 'chilli', 'optional', 'ripe', 'mangoe', 'bag', 'asda', 'spinach', 'bag', 'asda', 'wild', 'rocket', 'pack', 'asda', 'prawn']
# chocolate-bread-butter-pudding ['butter', 'leftover', 'hot', 'cros', 'bun', 'doesnt', 'matter', 'stale', 'can', 'mandarin', 'segment', 'juice', 'chocolate', 'easter', 'egg', 'full-fat', 'milk', 'caster', 'sugar', 'drop', 'vanilla', 'extract', 'egg']
# tuna-with-couscous ['couscou', 'lemon', 'olive', 'oil', 'olive', 'onion', 'tomatoe', 'parsley', 'tuna', 'steak']
# chicken-broccoli-pie ['chicken', 'breast', 'fillet', 'gammon', 'steak', 'rind', 'fat', 'chicken', 'stock', 'cube', 'sprig', 'thyme', 'pack', 'asda', 'special', 'purple', 'broccoli', 'cornflour', 'pot', 'asda', 'crème', 'fraîche', 'pack', 'filo', 'pastry', 'butter']
# pork-chops-with-mushroom-sauce ['porcini', 'mushroom', 'asda', 'pork', 'chop', 'oil', 'plu', 'sprig', 'rosemary', 'butter', 'shallot', 'chestnut', 'mushroom', 'balsamic', 'vinegar', 'crème', 'fraîche', 'coarse', 'grain', 'mustard', 'parsley', 'cabbage', 'serve']
# chicken-bean-hotpot ['rasher', 'streaky', 'bacon', 'butter', 'leek', 'lengthway', 'flour', 'hot', 'chicken', 'stock', 'flat-leaf', 'parsley', 'thyme', 'pack', 'chicken', 'boneles', 'thigh', 'fillet', 'can', 'butter', 'bean', 'potatoe', 'weight']
# baked-parma-ham-and-gorgonzola-figs ['fig', 'slice', 'special', 'parma', 'ham', 'special', 'gorgonzola', 'honey', 'virgin', 'olive', 'oil', 'balsamic', 'vinegar', 'pine', 'nut', 'basil', 'rocket', 'serve']
# fondant-fancies ['butter', 'plu', 'caster', 'sugar', 'free-range', 'egg', 'flour', 'powder', 'sugar', 'vanilla', 'extract', 'milk', 'apricot', 'jam', 'ready-to-roll', 'food']
# crepe-in-orange-liqueur ['asda', 'flour', 'free-range', 'egg', 'milk', 'butter', 'sunflower', 'oil', 'butter', 'caster', 'sugar', 'orange', 'juice', 'orange', 'zest', 'grand', 'marnier', 'cointreau', 'asda', 'almond']
# summer-fruit-pudding-with-basil ['frozen', 'summer', 'fruit', 'blackberrie', 'raspberrie', 'strawberrie', 'slice', 'bread', 'caster', 'sugar', 'bunch', 'basil', 'olive', 'oil']
# carrot-shaped-chocolate-cake ['egg', 'flora', 'light', 'spread', 'caster', 'sugar', 'flour', 'cocoa', 'powder', 'tube', 'dr', 'oetker', 'gel', 'food', 'dark', 'chocolate', 'broken', 'square', 'double', 'cream', 'butter', 'vanilla', 'extract', 'milk', 'light', 'brown', 'soft', 'sugar', 'decorate', 'chocolate', 'drop', 'decorate', 'flat-leaf', 'parsley', 'sprig']
# moules-marinieres ['pack', 'live', 'mussel', 'butter', 'shallot', 'garlic', 'clove', 'dry', 'wine', 'sprig', 'parsley', 'plu', 'sprig', 'thyme', 'bay', 'leaf', 'crusty', 'bread', 'serve']
# tomato-quiche ['ready', 'made', 'shortcrust', 'pastry', 'bunch', 'onion', 'butter', 'crème', 'fraîche', 'single', 'cream', 'free-range', 'egg', 'mature', 'cheddar', 'cheese', 'plum', 'tomatoe', 'sprig', 'thyme', 'optional']
# pea-ham-soup ['olive', 'oil', 'pack', 'asda', 'leek', 'frozen', 'pea', 'knorr', 'ham', 'cube', 'water', 'mint', 'herb', 'milk', 'frozen', 'chosen', 'mash', 'chosen', 'honey', 'roast', 'ham', 'chunk', 'bread', 'serve']
# spiced-persian-turkey ['chosen', 'korma', 'paste', 'lemon', 'juice', 'chosen', 'natural', 'yogurt', 'chosen', 'honey', 'chosen', 'mayonnaise', 'sumac', 'powder', 'baharat', 'see', 'recipe', 'coriander', 'plu', 'go', 'carrot', 'asda', 'special', 'corn', 'turkey', 'carrot', 'ribbon', 'splash', 'lemon', 'juice', 'virgin', 'olive', 'oil', 'chosen', 'almond', 'serve', 'pomegranate', 'serve', 'medjool', 'date', 'serve', 'coriander', 'serve', 'flat', 'bread', 'serve', 'peppercorn', 'cumin', 'coriander', 'clove', 'cardamom', 'allspice', 'paprika', 'cinnamon', 'nutmeg']
# chicken-and-chickpea-hotpot ['skinles', 'boneles', 'chicken', 'thigh', 'olive', 'oil', 'reduced-salt', 'chicken', 'stock', 'cube', 'water', 'carrot', 'stick', 'celery', 'herb', 'tomato', 'purée', 'redcurrant', 'can', 'chickpea', 'potatoe', 'serve']
# tunisian-style-omelette ['sweet', 'potato', 'weight', 'cube', 'smart', 'pea', 'frozen', 'sunflower', 'oil', 'onion', 'pepper', 'cumin', 'asda', 'chillie', 'can', 'chickpea', 'egg', 'beaten', 'salad', 'serve', 'bread', 'serve']
# smoky-mexican-pork-fajitas ['leftover', 'butcher', 'roast', 'bag', 'mexican', 'pork', 'loin', 'joint', 'sunflower', 'oil', 'onion', 'green', 'pepper', 'pepper', 'packet', 'fajita', 'mix', 'tortilla', 'wrap', 'cream', 'serve', 'salsa', 'serve']
# chicken-couscous-salad ['couscou', 'paprika', 'oil', 'tomatoe', 'wine', 'vinegar', 'stick', 'celery', 'asda', 'special', 'tomatoe', 'jar', 'piece', 'asda', 'special', 'pepper', 'jar', 'onion', 'pack', 'asda', 'chicken', 'breast', 'coriander']
# butternut-squash-quesadillas ['butternut', 'squash', 'cube', 'olive', 'oil', 'pack', 'chosen', 'mexican', 'style', 'corn', 'tortilla', 'mild', 'cheddar', 'can', 'napolina', 'kidney', 'bean', 'onion', 'pepper', 'coriander', 'mild', 'chilli', 'optional', 'salsa', 'serve']
# orange-carrot-soup ['butter', 'carrot', 'potato', 'shallot', 'sugar', 'light', 'vegetable', 'stock', 'chicken', 'stock', 'orange', 'zest', 'juice', 'pot', 'double', 'cream']
# greek-style-slow-roasted-leg-of-lamb ['head', 'garlic', 'butcher’', 'lamb', 'leg', 'lemon', 'juice', 'olive', 'oil', 'oregano', 'cinnamon', 'wine', 'wine', 'onion', 'segment', 'cherry', 'tomatoe', 'vine']
# rich-chocolate-ginger-cupcakes ['asda', 'special', 'dark', 'chocolate', 'milk', 'flour', 'powder', 'pinch', 'ginger', 'caster', 'sugar', 'egg', 'natural', 'ginger', 'asda', 'dark', 'chocolate', 'double', 'cream', 'asda', 'mini', 'egg']
# beef-noodle-stir-fry ['pack', 'asda', 'egg', 'noodle', 'sesame', 'oil', 'sunflower', 'oil', 'asda', 'butcher', 'rump', 'steak', 'fat', 'strip', 'leek', 'leek', 'mushroom', 'pepper', 'soy', 'sauce', 'oyster', 'sauce', 'worcester', 'sauce']
# fruity-rice-puddings ['rice', 'reduced-fat', 'coconut', 'milk', 'milk', 'coconut', 'cinnamon', 'golden', 'caster', 'sugar', 'zest', 'lemon', 'pineapple', 'mango', 'stone', 'pomegranate']
# pan-fried-pork-with-apple-wedges ['courgette', 'lengthway', 'orange', 'pepper', 'sunflower', 'oil', 'pack', 'butcher', 'pork', 'loin', 'steak', 'third', 'chicken', 'stock', 'made', 'stock', 'cube', 'herb', 'apple', 'wedge', 'reduced-fat', 'crème', 'fraîche', 'cornflour', 'cold', 'water', 'crusty', 'bread', 'serve']
# savoury-ferrero-rocher-style-nibbles-with-extra-special-crostini ['special', 'brussel', 'pâté', 'hazelnut', 'hazelnut', 'nib', 'nut', 'choice', 'asda', 'special', 'crostini', 'mini', 'paper', 'case', 'gold', 'foil', 'sheet', 'serve']
# roasted-red-peppers-with-tomatoes ['orange', 'pepper', 'onion', 'wedge', 'aubergine', 'chunk', 'olive', 'oil', 'pack', 'plum', 'tomatoe', 'balsamic', 'vinegar', 'handful', 'basil', 'lamb', 'cutlet', 'chicken', 'serve']
# steak-kidney-pudding ['olive', 'oil', 'onion', 'carrot', 'pack', 'butcher', 'beef', 'steak', 'beef', 'lamb', 'kidney', 'thyme', 'flour', 'worcestershire', 'sauce', 'ale', 'knorr', 'beef', 'stock', 'pot', 'water', 'flour', 'atora', 'original', 'beef', 'suet', 'pinch', 'mustard', 'powder']
# plum-brandy ['plum', 'sugar', 'bottle', 'brandy']
# easy-goulash ['onion', 'sunflower', 'oil', 'asda', 'casserole', 'beef', 'beef', 'stock', 'cube', 'can', 'asda', 'tomatoe', 'can', 'asda', 'tomatoe', 'chillie', 'pepper', 'herb', 'carrot', 'cornflour', 'pepper', 'green', 'pepper', 'paprika', 'tomato', 'purée', 'sour', 'cream', 'serve']
# maple-tropical-pork-skewers ['butcher', 'roast', 'bag', 'maple', 'pork', 'loin', 'joint', 'peache', 'banana', 'streaky', 'bacon', 'rasher', 'packet', 'wooden', 'skewer', 'sweet', 'chilli', 'lime', 'relish', 'serve']
# roast-chicken-with-pork-stuffing ['butter', 'shallot', 'asda', 'special', 'pork', 'leek', 'sausage', 'skin', 'pack', 'thyme', 'breadcrumb', 'parsley', 'asda', 'chicken', 'edward', 'potatoe', 'mari', 'piper', 'potatoe', 'olive', 'oil', 'asda', 'special', 'chicken', 'gravy', 'serve']
# scar-pies ['olive', 'oil', 'onion', 'pepper', 'orange', 'pepper', 'asda', 'special', 'iberico', 'chorizo', 'can', 'asda', 'tomatoe', 'garlic', 'pack', 'asda', 'ready', 'roll', 'shortcrust', 'pastry', 'flour']
# carrot-soup ['onion', 'sunflower', 'oil', 'butter', 'carrot', 'weight', 'potato', 'bay', 'leaf', 'vegetable', 'stock', 'parsley']
# leek-risotto ['vegetable', 'stock', 'cube', 'olive', 'oil', 'butter', 'leek', 'arborio', 'risotto', 'rice', 'wine', 'optional', 'thyme', 'frozen', 'pea', 'pancetta', 'parmesan']
# indian-style-lentil-soup ['onion', 'sunflower', 'oil', 'clove', 'garlic', 'piece', 'root', 'ginger', 'asda', 'korma', 'curry', 'paste', 'paprika', 'lentil', 'vegetable', 'stock', 'cube', 'carton', 'asda', 'tomatoe', 'pepper', 'tomato', 'purée', 'coriander', 'serve']
# spiced-salmon-skewers ['natural', 'yogurt', 'clove', 'garlic', 'honey', 'chilli', 'juice', 'lemon', 'vegetable', 'oil', 'mild', 'curry', 'powder', 'salmon', 'fillet', 'cube', 'coriander', 'serve']
# fish-pie-recipe ['cornflour', 'dijon', 'mustard', 'mild', 'curry', 'powder', 'milk', 'pack', 'fishmonger’', 'fish', 'pie', 'mix', 'raw', 'prawn', 'spinach', 'packet', 'instruction', 'reduced-fat', 'crème', 'fraîche', 'dill', 'sheet', 'filo', 'pastry', 'frozen', 'butter', 'sesame']
# mini-koftas ['asda', 'butcher', 'beef', 'mince', 'garlic', 'clove', 'mint', 'flat-leaf', 'parsley', 'coriander', 'cumin']
# mexican-style-tuna-melt ['jar', 'asda', 'tex', 'mex', 'hot', 'salsa', 'can', 'kidney', 'bean', 'asda', 'wrap', 'can', 'asda', 'tuna', 'brine', 'well', 'onion', 'mature', 'cheddar', 'coriander', 'olive', 'oil', 'sour', 'cream', 'serve', 'salad', 'serve']
# korean-style-pork-fillet ['butcher’', 'pork', 'fillet', 'slice', 'streaky', 'bacon', 'chosen', 'smoky', 'chilli', 'garlic', 'paste', 'salt', 'soy', 'sauce', 'rice', 'wine', 'vinegar', 'honey', 'cucumber', 'thin', 'onion', 'sesame', 'oil', 'sesame']
# rhubarb-chutney ['rhubarb', 'piece', 'orange', 'zest', 'juice', 'bramley', 'apple', 'piece', 'onion', 'wine', 'vinegar', 'sugar', 'apricot', 'piece', 'sultana', 'mustard', 'root', 'ginger', 'salt']
# sweet-sour-chicken ['amoy', 'salt', 'soy', 'sauce', 'asda', 'sweet', 'chilli', 'sauce', 'cider', 'vinegar', 'honey', 'orange', 'juice', 'cornflour', 'sunflower', 'oil', 'chicken', 'breast', 'fillet', 'bite-size', 'piece', 'carrot', 'short', 'stick', 'pepper', 'strip', 'onion', 'pack', 'mangetout', 'lengthway', 'pineapple', 'skin', 'core', 'bite-size', 'piece', 'rice', 'serve']
# spotted-dick ['flour', 'powder', 'suet', 'soft', 'brown', 'sugar', 'currant', 'lemon', 'zest', 'spice', 'milk']
# lamb-tagine ['olive', 'oil', 'pack', 'asda', 'butcher', 'lamb', 'neck', 'fillet', 'fat', 'onion', 'cinnamon', 'ginger', 'cumin', 'paprika', 'can', 'asda', 'tomatoe', 'chilli', 'pepper', 'carrot', 'honey', 'pepper', 'coriander', 'plu', 'serve', 'ready-to-eat', 'prune', 'ready-to-eat', 'apricot', 'almond', 'couscou', 'serve']
# beetroot-sweet-potato-feta-cheese-salad ['olive', 'oil', 'honey', 'sweet', 'potatoe', 'weight', 'thick', 'slice', 'onion', 'pack', 'asda', 'long', 'life', 'beetroot', 'thick', 'slice', 'walnut', 'halve', 'wine', 'vinegar', 'dijon', 'mustard', 'pack', 'rocket', 'feta', 'cheese', 'broken', 'piece']
# totally-loaded-chilli-chips ['butcher’', 'lean', 'beef', 'mince', 'onion', 'plu', 'slice', 'serve', 'can', 'asda', 'bean', 'tomato', 'sauce', 'asda', 'chilli', 'con', 'carne', 'mix', 'asda', 'steak', 'oven', 'chip', 'cream', 'tomatoe', 'asda', 'fat', 'cheddar', 'leicester', 'coriander']
# butternut-beetroot-tarts-with-creamy-camembert ['butternut', 'squash', 'olive', 'oil', 'balsamic', 'vinegar', 'flour', 'jus-rol', 'light', 'puff', 'pastry', 'sheet', 'grower', 'beetroot', 'camembert', 'egg', 'beaten', 'double', 'cream', 'thyme']
# red-lentil-vegetable-curry ['onion', 'cauliflower', 'green', 'bean', 'piece', 'ginger', 'vegetable', 'oil', 'mild', 'curry', 'powder', 'plump', 'clove', 'garlic', 'reduced-salt', 'vegetable', 'stock', 'cube', 'lentil', 'balsamic', 'vinegar', 'pinche', 'salt']
# zesty-baked-whole-salmon ['fishmonger’', 'salmon', 'head', 'fennel', 'garlic', 'clove', 'oil', 'lemon', 'lime', 'pink', 'grapefruit', 'grapefruit', 'orange', 'bay', 'sprig', 'dill', 'juice', 'lemon', 'juice', 'lime', 'oil', 'shallot', 'honey']
# coconut-ice-snowmen ['carnation', 'milk', 'sugar', 'coconut', 'decorate']
# mushroom-bacon-soup ['olive', 'oil', 'onion', 'clove', 'garlic', 'mushroom', 'vegetable', 'stock', 'made', 'vegetable', 'stock', 'cube', 'milk', 'thyme', 'plu', 'sprig', 'garnish', 'rasher', 'streaky', 'bacon', 'single', 'cream', 'chive']
# squab-pie ['cornflour', 'spice', 'soft', 'brown', 'sugar', 'lamb', 'steak', 'piece', 'onion', 'apple', 'cold', 'lamb', 'stock', 'asda', 'ready', 'roll', 'shortcrust', 'pastry', 'flour', 'free-range', 'egg', 'beaten']
# paprika-pulled-pork ['joint', 'boneles', 'pork', 'shoulder', 'sea', 'salt', 'dark', 'brown', 'sugar', 'paprika']
# pulled-pork ['pork', 'joint', 'passata', 'sweet', 'chilli', 'sauce', 'worcestershire', 'sauce', 'balsamic', 'vinegar', 'treacle', 'english', 'mustard', 'paprika', 'asda', 'garlic', 'watercres', 'serve', 'special', 'coleslaw', 'serve', 'roll', 'serve']
# smoked-salmon-terrine ['pack', 'special', 'asparagu', 'tip', 'pack', 'special', 'scottish', 'salmon', 'pack', 'special', 'golden', 'roast', 'scottish', 'salmon', 'pack', 'asda', 'prawn', 'butter', 'chosen', 'original', 'soft', 'cheese', 'dill', 'zest', 'lemon', 'plu', 'juice', 'salad', 'serve', 'dill', 'serve', 'lemon', 'wedge', 'serve']
# homemade-plum-crumble ['asda', 'hazelnut', 'plum', 'demerara', 'sugar', 'cinnamon', 'asda', 'butter', 'asda', 'flour', 'caster', 'sugar']
# house-of-horrors-cake ['flour', 'sugar', 'cocoa', 'powder', 'plu', 'decorate', 'powder', 'bicarbonate', 'soda', 'egg', 'oil', 'apple', 'juice', 'butter', 'soft', 'cheese', 'sugar', 'peanut', 'butter', 'nutella', 'butter', 'muscovado', 'sugar', 'golden', 'syrup', 'flour', 'bicarbonate', 'soda', 'ginger', 'fox’', 'glacier', 'mint', 'coco', 'pop', 'dark', 'chocolate', 'ready', 'roll', 'orange', 'food', 'dr', 'oetker', 'gel', 'food', 'colour', 'ultra', 'violet', 'golden', 'syrup', 'matchmaker', 'bag', 'malteser', 'dark', 'brown', 'sugar']
# baked-figs-with-honey ['fig', 'butter', 'plu', 'asda', 'squeezy', 'pure', 'acacia', 'honey', 'honey', 'apple', 'juice', 'sweet', 'sherry', 'pinch', 'cinnamon', 'pot', 'asda', 'fat', 'free', 'greek', 'style', 'yogurt']
# fish-pie-with-root-vegetable-topping ['carrot', 'parsnip', 'potatoe', 'butter', 'pack', 'asda', 'fish', 'pie', 'mix', 'pack', 'asda', 'boneles', 'skinles', 'river', 'cobbler', 'fillet', 'chunk', 'milk', 'onion', 'flour', 'dry', 'mustard', 'powder', 'les', 'fat', 'mature', 'cheese', 'parsley', 'pea', 'serve', 'carrot', 'serve']
# winter-chunky-vegetable-soup ['olive', 'oil', 'onion', 'celery', 'stick', 'pack', 'kale', 'spinach', 'pak', 'choi', 'garlic', 'clove', 'tomatoe', 'tomato', 'purée', 'hot', 'vegetable', 'stock', 'can', 'borlotti', 'bean', 'frozen', 'broad', 'bean', 'frozen', 'pea', 'sprig', 'thyme', 'baguette', 'parmesan']
# caesar-salad-with-ranch-dressing ['ciabatta', 'roll', 'approx', 'olive', 'oil', 'little', 'gem', 'lettuce', 'radishe', 'lemon', 'low-fat', 'greek', 'yogurt', 'wholegrain', 'mustard', 'balsamic', 'vinegar', 'pepper', 'pecorino', 'cheese', 'parmesan', 'cheese']
# hasselback-potatoes ['potatoe', 'butter', 'oil']
# fajitas ['pack', 'schwartz', 'chicken', 'fajita', 'recipe', 'mix', 'vegetable', 'oil', 'pack', 'butcher', 'prime', 'beef', 'sirloin', 'steak', 'pepper', 'pepper', 'onion', 'cream', 'pack', 'chosen', 'guacamole', 'pack', 'chosen', 'youhot', 'spicy', 'salsa', 'mature', 'cheddar', 'iceberg', 'lettuce', 'cherry', 'sweetcorn', 'can', 'weight', 'jalapeño', 'lime', 'wedge', 'chosen', 'tortilla']
# mushroom-broccoli-filo-pie ['broccoli', 'floret', 'olive', 'oil', 'plu', 'onion', 'pack', 'mushroom', 'clove', 'garlic', 'can', 'batchelor', 'low', 'fat', 'mushroom', 'soup', 'sheet', 'filo', 'pastry']
# apricot-chocolate-tart ['flour', 'plu', 'sugar', 'cocoa', 'powder', 'butter', 'apricot', 'jam', 'special', 'cocoa', 'solid', 'ivory', 'coast', 'dark', 'chocolate', 'butter', 'caster', 'sugar', 'egg', 'almond', 'apricot']
# roasted-banana-smash-toast ['banana', 'honey', 'slice', 'bread', 'light', 'mascarpone', 'pistachio']
# cucumber-prawn-gazpacho ['cucumber', 'double', 'cream', 'greek-style', 'yogurt', 'asda', 'special', 'horseradish', 'sauce', 'vegetable', 'stock', 'prawn', 'asda', 'garlic', 'coriander', 'naan', 'serve', 'pot', 'asda', 'tzatziki', 'serve']
# chicken-tzaziki-wraps ['skinles', 'chicken', 'fillet', 'lemon', 'juice', 'olive', 'oil', 'oregano', 'oregano', 'garlic', 'clove', 'pot', 'asda', 'tzatziki', 'dip', 'pack', 'asda', 'tortilla', 'wrap', 'rocket', 'watercres', 'serve']
# chocolate-popcorn-shards ['asda', 'dark', 'chocolate', 'cocoa', 'solid', 'special', 'dark', 'chocolate', 'cocoa', 'solid', 'popcorn', 'asda', 'cherry', 'berry', 'mix']
# mango-banana-trifle ['boudoir', 'finger', 'sponge', 'finger', 'rum', 'asda', 'pure', 'orange', 'mango', 'passionfruit', 'juice', 'concentrate', 'mango', 'ripe', 'banana', 'asda', 'mascarpone', 'asda', 'custard', 'double', 'cream', 'almond']
# peach-melba-semifreddo ['can', 'peache', 'fruit', 'juice', 'egg', 'yolk', 'plu', 'egg', 'caster', 'sugar', 'raspberrie', 'lemon', 'juice', 'asda', 'full', 'fat', 'greek', 'yogurt']
# rack-of-venison ['special', 'rack', 'venison', 'french', 'oil', 'dijon', 'mustard', 'pistachio', 'nut', 'special', 'beef', 'concentrate', 'special', 'redcurrant', 'sauce', 'port', 'butter', 'olive', 'oil', 'plu', 'crouton', 'slice', 'bread', 'parsley', 'vegetable', 'serve']
# shredded-brussels-sprouts-with-pancetta ['brussel', 'sprout', 'pine', 'nut', 'chosen', 'pancetta', 'sunflower', 'oil', 'butter']
# cauliflower-chickpea-curry ['cauliflower', 'floret', 'sunflower', 'oil', 'onion', 'garlic', 'clove', 'root', 'ginger', 'coriander', 'cumin', 'turmeric', 'chillie', 'garam', 'masala', 'can', 'asda', 'tomatoe', 'chilli', 'pepper', 'can', 'asda', 'chickpea', 'asda', 'naan', 'bread', 'serve']
# south-pacific-fish ['vegetable', 'oil', 'onion', 'garlic', 'clove', 'piece', 'root', 'ginger', 'coriander', 'turmeric', 'sweet', 'potatoe', 'chunk', 'can', 'coconut', 'milk', 'can', 'tomatoe', 'chilli', 'pepper', 'pepper', 'fish', 'chunky', 'piece', 'macadamia', 'nut', 'coriander', 'chilli', 'rice', 'serve']
# salmon-fishcakes ['can', 'asda', 'salmon', 'pack', 'asda', 'special', 'creamy', 'mash', 'mayonnaise', 'horseradish', 'sauce', 'flat-leaf', 'parsley', 'chive', 'lemon', 'juice', 'free-range', 'egg', 'beaten', 'asda', 'breadcrumb', 'sunflower', 'oil', 'mangetout', 'serve', 'sugar', 'snap', 'serve', 'lemon', 'wedge', 'serve']
# prawn-stir-fry ['cornflour', 'light', 'soy', 'sauce', 'sweet', 'chilli', 'sauce', 'orange', 'juice', 'asda', 'egg', 'noodle', 'asda', 'stir-fry', 'oil', 'pepper', 'pepper', 'carrot', 'stick', 'pack', 'mangetout', 'onion', 'can', 'water', 'chestnut', 'pack', 'asda', 'raw', 'tiger', 'prawn']
# salmon-pasta ['pack', 'asda', 'tagliatelle', 'pack', 'asda', 'smart', 'salmon', 'slice', 'asda', 'fat', 'crème', 'fraîche', 'dill', 'parmesan']
# the-ultimate-chocolate-brownie ['special', 'dark', 'chocolate', 'cocoa', 'solid', 'broken', 'piece', 'butter', 'egg', 'plu', 'yolk', 'golden', 'caster', 'sugar', 'flour', 'powder', 'sugar', 'dust']
# stained-glass-biscuits ['flour', 'plu', 'ginger', 'cinnamon', 'butter', 'cube', 'golden', 'syrup', 'fox', 'glacier', 'fruit']
# picnic-sausage-rolls ['pack', 'ju', 'roll', 'butter', 'puff', 'pastry', 'flour', 'pack', 'asda', 'special', 'cumberland', 'sausage', 'free-range', 'egg', 'beaten']
# cornflake-chicken-nuggets-with-spicy-potato-cubes ['potatoe', 'cube', 'olive', 'oil', 'asda', 'chillie', 'optional', 'asda', 'cornflake', 'mature', 'cheddar', 'flour', 'pack', 'asda', 'butcher', 'chicken', 'breast', 'fillet', 'piece', 'egg', 'beaten', 'leek', 'serve', 'sweetcorn', 'serve', 'pea', 'serve']
# nectarine-goats-cheese-honeyed-pecan-salad ['pecan', 'nut', 'asda', 'honey', 'salt', 'caster', 'sugar', 'plu', 'walnut', 'oil', 'wine', 'vinegar', 'dijon', 'mustard', 'salad', 'nectarine', 'piece', 'asda', 'english', 'goat’', 'cheese']
# baked-potatoes-stuffed-with-tuna-cheese ['potatoe', 'leek', 'butter', 'milk', 'can', 'asda', 'tuna', 'chunk', 'water', 'mature', 'cheddar']
# cod-haddock-tagliatelle-carbonara ['norwegian', 'cod', 'fillet', 'skin', 'norwegian', 'haddock', 'fillet', 'skin', 'tagliatelle', 'bacon', 'clove', 'garlic', 'egg', 'light', 'cream', 'parmesan', 'cheese', 'basil']
# miguel-barclays-green-shakshuka ['onion', 'handful', 'frozen', 'pea', 'handful', 'spinach', 'egg', 'feta', 'olive', 'oil']
# healthy-fish-chips ['pack', 'asda', 'frozen', 'cod', 'loin', 'fillet', 'lemon', 'zest', 'juice', 'butter', 'olive', 'oil', 'breadcrumb', 'flat-leaf', 'parsley', 'thyme', 'onion', 'asda', 'special', 'frozen', 'oven', 'chip', 'serve', 'asda', 'frozen', 'pea', 'frozen', 'mushy', 'pea', 'serve']
# james-martins-slow-cooked-lamb ['butcher', 'british', 'lamb', 'shoulder', 'fillet', 'special', 'cold', 'oil', 'onion', 'garlic', 'clove', 'chipotle', 'paste', 'harissa', 'paste', 'sprig', 'rosemary', 'bay', 'asda', 'tomato', 'purée', 'asda', 'tomato', 'ketchup', 'worcestershire', 'sauce', 'salt', 'soy', 'sauce', 'special', 'beef', 'stock', 'brioche', 'bun', 'slice', 'sourdough', 'bread', 'cabbage', 'bunch', 'coriander', 'juice', 'lime', 'virgin', 'olive', 'oil', 'crisp', 'onion']
# apple-crumble-parmesan-cake ['butter', 'plu', 'soft', 'light', 'brown', 'sugar', 'egg', 'beaten', 'almond', 'parmesan', 'flour', 'cinnamon', 'allspice', 'apple', 'chunk', 'zest', 'juice', 'lemon', 'asda', 'crumble', 'hazelnut', 'oat', 'pine', 'nut']
# pear-crumbles ['conference', 'pear', 'bottle', 'wine', 'caster', 'sugar', 'butter', 'flour', 'sugar']
# chicken-rissoles ['chicken', 'weight', 'skin', 'bread', 'day', 'old', 'egg', 'beaten', 'asda', 'real', 'mayonnaise', 'parsley', 'asda', 'coarse', 'grain', 'french', 'mustard', 'tomatoe', 'optional', 'sunflower', 'oil', 'potatoe', 'serve', 'salad', 'serve']
# pineapple-mess ['asda', 'ready', 'pineapple', 'asda', 'special', 'mini', 'meringue', 'cream', 'orange', 'liqueur', 'optional']
# poached-apricots ['sugar', 'apple', 'juice', 'juice', 'zest', 'lemon', 'peeler', 'cardamom', 'pod', 'vanilla', 'pod', 'apricot', 'firm']
# cheats-steak-ale-pie ['pack', 'asda', 'beef', 'steak', 'flour', 'onion', 'oil', 'butter', 'asda', 'special', 'whitechapel', 'porter', 'ale', 'hot', 'beef', 'stock', 'ready', 'roll', 'puff', 'pastry', 'egg', 'beaten', 'cabbage', 'serve', 'potatoe', 'serve']
# triple-berry-compote-with-porridge ['berrie', 'blueberrie', 'raspberrie', 'blackberrie', 'frozen', 'caster', 'sugar', 'cinnamon', 'stick', 'optional', 'porridge', 'serve']
# polenta-with-mushrooms-in-a-creamy-garlic-sauce ['merchant', 'gourmet', 'porcini', 'mushroom', 'pack', 'chestnut', 'mushroom', 'clove', 'garlic', 'herb', 'butter', 'brandy', 'optional', 'crème', 'fraîche', 'italfresco', 'ready', 'made', 'polenta', 'parsley', 'garnish']
# spinach-curry ['chicken', 'breast', 'piece', 'lemon', 'juice', 'sunflower', 'oil', 'onion', 'clove', 'garlic', 'piece', 'root', 'ginger', 'chilli', 'turmeric', 'coriander', 'cumin', 'asda', 'garam', 'masala', 'tomatoe', 'sweet', 'potato', 'weight', 'cube', 'can', 'chickpea', 'bag', 'asda', 'spinach', 'asda', 'chosen', 'mini', 'poppadom', 'serve', 'tomato', 'coriander', 'onion', 'side', 'salad', 'serve']
# salmon-en-croute-by-nick-nairn ['olive', 'oil', 'garlic', 'clove', 'leaf', 'spinach', 'pack', 'puff', 'pastry', 'salmon', 'fillet', 'slice', 'salmon', 'egg', 'beaten', 'cumin']
# tour-de-yorkshire-parkin-cake ['golden', 'syrup', 'butter', 'milk', 'egg', 'beaten', 'flour', 'oatmeal', 'caster', 'sugar', 'ginger', 'betty', 'crocker', 'vanilla', 'buttercream', 'style', 'rind', 'orange', 'special', 'valencian', 'orange', 'extract', 'bake', 'create', 'ready', 'roll', 'green', 'egg', 'sugar', 'plu', 'ice', 'cream', 'cone', 'mini', 'marshmallow', 'cadbury', 'chocolate', 'flake', 'asda', 'chosen', 'green', 'food', 'food', 'honey', 'oreo', 'cookie', 'cream', 'matchmaker', 'mini', 'salt', 'cake', 'board']
# beef-wellington-empanadas ['button', 'mushroom', 'onion', 'thyme', 'olive', 'oil', 'sirloin', 'steak', 'thin', 'strip', 'special', 'brussel', 'pate', 'egg', 'milk', 'turmeric', 'paprika', 'pack', 'chosen', 'ready', 'puff', 'pastry']
# roast-lamb-with-herby-stuffing ['shallot', 'sunflower', 'oil', 'plu', 'butter', 'shallot', 'shallot', 'breadcrumb', 'lemon', 'zest', 'thyme', 'parsley', 'mint', 'leg', 'lamb', 'bone', 'gravy', 'serve', 'mintto', 'serve', 'roast', 'potatoe', 'serve']
# spider-web-doughnuts ['asda', 'wholemeal', 'bread', 'flour', 'plu', 'caster', 'sugar', 'butter', 'sachet', 'asda', 'easy', 'bake', 'yeast', 'egg', 'beaten', 'milk', 'sugar', 'food', 'orange', 'food']
# irish-onion-soup-with-soda-bread-croutons ['oil', 'onion', 'clove', 'garlic', 'parsley', 'thyme', 'sugar', 'guinnes', 'vegetable', 'stock', 'cube', 'slice', 'soda', 'bread', 'les', 'fat', 'mature', 'cheese', 'sprig', 'thyme', 'garnish']
# ghost-emoji-gingerbread-biscuit-recipe ['light', 'muscovado', 'sugar', 'golden', 'syrup', 'flour', 'bicarbonate', 'soda', 'ginger', 'egg', 'yolk', 'egg', 'sugar', 'apricot', 'jam', 'ready', 'roll', 'ready', 'roll', 'royal', 'gel', 'food', 'pink', 'gel', 'food']
# chilli-prawn-skewers ['special', 'jumbo', 'prawn', 'juice', 'lime', 'onion', 'length', 'mango', 'strip', 'chilli', 'coriander', 'sweet', 'chilli', 'sauce', 'fish', 'sauce', 'special', 'oil']
# crushed-meringue-with-pears ['asda', 'meringue', 'nest', 'broken', 'piece', 'can', 'asda', 'pear', 'halve', 'syrup', 'pot', 'asda', 'greek', 'style', 'yogurt', 'drop', 'asda', 'special', 'vanilla', 'extract', 'honey', 'dark', 'chocolate']
# chicken-pie ['halve', 'chestnut', 'mushroom', 'thick-cut', 'gammon', 'steak', 'piece', 'butter', 'flour', 'chicken', 'stock', 'single', 'cream', 'chicken', 'ready-to-roll', 'puff', 'pastry', 'shortcrust', 'pastry']
# berry-pie-recipe ['butter', 'frozen', 'freshnes', 'summer', 'fruit', 'caster', 'sugar', 'vanilla', 'pod', 'cornflour', 'ready', 'shortcrust', 'pastry', 'egg', 'beaten', 'double', 'cream', 'optional', 'sugar']
# summer-fruit-trifle ['smart', 'raspberry', 'swis', 'roll', 'asda', 'strawberrie', 'asda', 'raspberrie', 'asda', 'fruit', 'forest', 'fruit', 'juice', 'asda', 'ready-made', 'custard', 'asda', 'cream', 'strawberrie', 'raspberrie', 'decorate']
# crispy-cauliflower-parmesan-snack-bites ['cauliflower', 'floret', 'sprig', 'rosemary', 'english', 'mustard', 'powder', 'clove', 'garlic', 'olive', 'oil', 'parmesan', 'mature', 'cheddar', 'vegetarian', 'version']
# duck-salad ['tamarind', 'optional', 'ginger', 'sesame', 'oil', 'garlic', 'clove', 'lime', 'juice', 'honey', 'asda', 'duck', 'breast', 'fillet', 'skin', 'sunflower', 'oil', 'carrot', 'strip', 'mangetout', 'sugar', 'snap', 'pea', 'chilli', 'chicken', 'stock', 'chinese', 'leaf', 'bean', 'sprout', 'sprig', 'coriander', 'plu', 'garnish']
# egg-biscuits ['butter', 'caster', 'sugar', 'drop', 'vanilla', 'extract', 'flour', 'cornflour', 'cocoa', 'powder', 'royal', 'sugar', 'gel', 'decorate']
# traditional-rich-fruit-cake ['asda', 'fruit', 'sultana', 'currant', 'rum', 'brandy', 'sherry', 'glacé', 'cherrie', 'flour', 'spice', 'butter', 'soft', 'brown', 'sugar', 'free-range', 'egg', 'orange', 'zest', 'lemon', 'zest', 'asda', 'almond', 'paper', 'brown', 'paper', 'deep', 'cake', 'tin', 'square', 'cake', 'tin']
# zesty-chicken-burger ['lemon', 'clove', 'garlic', 'parsley', 'butcher’', 'british', 'chicken', 'breast', 'mini', 'fillet', 'gem', 'lettuce', 'wholemeal', 'burger', 'bun', 'tomatoe', 'sweet', 'potato', 'chip', 'light', 'mayonnaise', 'serve']
# jumbo-jammie-dodger ['caster', 'sugar', 'butter', 'egg', 'yolk', 'flour', 'sugar', 'vanilla', 'extract', 'raspberry', 'jam', 'smooth', 'seedles', 'best']
# spinach-ricotta-filo-pastry-parcels ['olive', 'oil', 'onion', 'bag', 'ready', 'spinach', 'asda', 'ricotta', 'mature', 'cheddar', 'cheese', 'pack', 'jus-rol', 'filo', 'sheet']
# rhubarb-orange-trifle ['orange', 'caster', 'sugar', 'rhubarb', 'weight', 'piece', 'asda', 'trifle', 'sponge', 'asda', 'shredles', 'orange', 'marmalade', 'cointreau', 'orange', 'liqueur', 'orange', 'juice', 'pot', 'asda', 'special', 'creamy', 'custard', 'pot', 'asda', 'mascarpone', 'double', 'cream']
# buttermilk-onion-rings ['buttermilk', 'flour', 'light', 'soy', 'sauce', 'breadcrumb', 'olive', 'oil', 'pinch', 'cayenne', 'pepper', 'onion', 'thick']
# sweet-potato-chicken-curry ['onion', 'sunflower', 'oil', 'asda', 'tikka', 'curry', 'paste', 'can', 'coconut', 'milk', 'pack', 'asda', 'chicken', 'thigh', 'fillet', 'piece', 'slit', 'lentil', 'sweet', 'potato', 'bag', 'leaf', 'spinach', 'naan', 'bread', 'rice', 'serve']
# hot-sour-soup-with-carrot-noodles ['sunflower', 'oil', 'onion', 'clove', 'garlic', 'hot', 'vegetable', 'stock', 'made', 'cube', 'carrot', 'long', 'strip', 'resemble', 'noodle', 'special', 'exotic', 'mushroom', 'pack', 'cauldron', 'original', 'tofu', 'can', 'bamboo', 'shoot', 'light', 'soy', 'sauce', 'wine', 'vinegar', 'lime', 'juice', 'lime', 'zest', 'chilli', 'chive']
# healthier-macaroni-cheese-with-veg1 ['macaroni', 'chosen', 'frozen', 'freshnes', 'broccoli', 'cauliflower', 'floret', 'butter', 'flour', 'pinch', 'cayenne', 'pepper', 'pinch', 'mustard', 'powder', 'milk', 'chosen', 'les', 'fat', 'mature', 'british', 'cheese', 'parmesan', 'fine', 'breadcrumb', 'cherry', 'tomatoe']
# sausage-stuffed-onions ['onion', 'top', 'base', 'olive', 'oil', 'clove', 'garlic', 'pork', 'sausage', 'meat', 'skin', 'stalk', 'thyme', 'plu', 'sprig', 'garnish', 'zest', 'lemon', 'breadcrumb', 'flat-leaf', 'parsley', 'parmesan']
# raspberry-tiramisu ['trifle', 'sponge', 'asda', 'special', 'raspberry', 'jam', 'sweet', 'sherry', 'marsala', 'can', 'peache', 'juice', 'raspberrie', 'mascarpone', 'asda', 'special', 'creamy', 'custard', 'double', 'cream', 'dark', 'chocolate', 'decorate']
# lamb-hotpot ['lamb', 'leg', 'steak', 'sunflower', 'oil', 'onion', 'carrot', 'celery', 'stick', 'potatoe', 'bay', 'leaf', 'thyme', 'plu', 'sprig', 'chunk', 'worcestershire', 'sauce', 'hot', 'lamb', 'stock', 'butter']
# shoestring-fries-with-turmeric-mayo ['asda', 'real', 'mayonnaise', 'turmeric', 'clove', 'garlic', 'juice', 'lemon', 'grower’', 'british', 'potatoe', 'sunflower', 'oil']
# wagyu-steak-with-kimchi-pickled-vegetables ['wagyu', 'fillet', 'steak', 'mooli', 'weight', 'chinese', 'chilli', 'bean', 'paste', 'onion', 'cornish', 'sea', 'salt', 'luxury', 'pepper', 'dulse', 'flake', 'shichimi', 'togarashi', 'sesame', 'pak', 'choi', 'radishe']
# pumpkin-pies ['sheet', 'filo', 'pastry', 'pumpkin', 'flesh', 'happy', 'egg', 'happy', 'egg', 'english', 'heather', 'honey', 'allspice', 'ginger', 'cinnamon']
# witches-broomsticks ['asda', 'dark', 'chocolate', 'cocoa', 'solid', 'asda', 'milk', 'chocolate', 'asda', 'smooth', 'peanut', 'butter', 'quality', 'street', 'matchmaker', 'handle', 'mikado', 'milk', 'chocolate', 'biscuit', 'stick', 'elizabeth', 'shaw', 'dark', 'chocolate', 'cappuccino', 'flute']
# bacon-mushroom-risotto ['reduced-salt', 'chicken', 'stock', 'cube', 'olive', 'oil', 'onion', 'butcher’', 'bacon', 'medallion', 'butter', 'mushroom', 'arborio', 'risotto', 'rice', 'carnaroli', 'risotto', 'rice', 'herb', 'frozen', 'pea', 'parmesan']
# salmon-with-filo-topping ['asda', 'full', 'fat', 'soft', 'creamy', 'cheese', 'frozen', 'asda', 'north', 'atlantic', 'prawn', 'dill', 'asda', 'frozen', 'salmon', 'steak', 'sheet', 'filo', 'pastry', 'butter', 'parmesan', 'potatoe', 'serve', 'green', 'bean', 'serve']
# rosemary-drizzle-cake ['butter', 'plu', 'lemon', 'juice', 'lemon', 'caster', 'sugar', 'sprig', 'rosemary', 'rosemary', 'flour', 'flour', 'egg', 'lemon', 'zest']
# potato-blinis-smoked-salmon-sour-cream ['potato', 'double', 'cream', 'plu', 'double', 'cream', 'milk', 'flour', 'egg', 'beaten', 'lemon', 'salmon', 'sprig', 'dill', 'butter']
# veggie-lasagne ['pack', 'asda', 'leaf', 'spinach', 'olive', 'oil', 'onion', 'garlic', 'clove', 'mushroom', 'butter', 'thyme', 'litre', 'milk', 'flour', 'asda', 'coarse', 'grain', 'mustard', 'dry', 'lasagne', 'sheet', 'pre-cook', 'mature', 'cheddar', 'cheese']
# triple-melon-iced-slushie ['watermelon', 'cantaloupe', 'melon', 'honeydew', 'melon', 'pineapple', 'juice', 'lime', 'ice', 'cube', 'juice', 'lemon', 'strawberrie']
# spanish-style-tortilla-wedges ['onion', 'pepper', 'olive', 'oil', 'charlotte', 'potatoe', 'left', 'cool', 'frozen', 'pea', 'egg', 'milk', 'chosen', 'les', 'fat', 'mature', 'light', 'british', 'cheese', 'salad', 'serve']
# tuscan-white-bean-soup ['olive', 'oil', 'butter', 'onion', 'carrot', 'clove', 'garlic', 'herb', 'chicken', 'stock', 'can', 'cannellini', 'bean', 'cherry', 'tomatoe', 'leftover', 'ham', 'torn', 'piece', 'flat-leaf', 'parsley', 'optional', 'crusty', 'bread', 'serve']
# pea-soup ['butter', 'shallot', 'vegetable', 'stock', 'cube', 'potato', 'frozen', 'pea', 'sprig', 'mint', 'milk', 'pack', 'asda', 'pepper', 'sea', 'salt', 'crouton', 'serve']
# stilton-leek-and-mushroom-risotto ['litre', 'hot', 'chicken', 'stock', 'leek', 'butter', 'olive', 'oil', 'garlic', 'clove', 'mushroom', 'asda', 'arborio', 'risotto', 'rice', 'wine', 'optional', 'frozen', 'pea', 'stilton']
# squash-and-spinach-curry ['scratch', 'cook', 'butternut', 'squash', 'chunk', 'scratch', 'cook', 'onion', 'balti', 'paste', 'mango', 'chutney', 'can', 'asda', 'chickpea', 'reduced-fat', 'coconut', 'milk', 'hot', 'stock', 'made', 'veggie', 'stock', 'cube', 'pack', 'grower', 'leaf', 'spinach', 'long-grain', 'brown', 'rice', 'serve', 'poppadom', 'serve', 'optional']
# pasta-with-roasted-butternut-squash ['butternut', 'squash', 'onion', 'mushroom', 'asda', 'smart', 'herb', 'asda', 'penne', 'pasta', 'asda', 'lancashire', 'cheese', 'oil']
# stollen ['strong', 'flour', 'plu', 'sachet', 'asda', 'easy', 'bake', 'yeast', 'caster', 'sugar', 'pinch', 'spice', 'milk', 'lukewarm', 'vanilla', 'extract', 'egg', 'beaten', 'butter', 'lemon', 'sultana', 'currant', 'glacé', 'cherrie', 'peel', 'almond', 'marzipan', 'sugar', 'decorate']
# thyme-walnut-shortbread ['butter', 'still', 'firm', 'caster', 'sugar', 'flour', 'thyme', 'walnut', 'choice', 'nut']
# masterclass-focaccia ['asda', 'strong', 'bread', 'flour', 'plu', 'salt', 'sachet', 'asda', 'easy', 'bake', 'yeast', 'olive', 'oil', 'plu', 'onion', 'thyme', 'sea', 'salt']
# chocolate-truffle-fondant ['sunflower', 'spread', 'cocoa', 'powder', 'special', 'fairtrade', 'organic', 'dominican', 'republic', 'dark', 'chocolate', 'sunflower', 'spread', 'egg', 'egg', 'yolk', 'caster', 'sugar', 'flour', 'special', 'italian', 'chocolate', 'truffle']
# sausage-mummies ['asda', 'puff', 'pastry', 'flour', 'frankfurter', 'jar', 'egg', 'beaten', 'asda', 'squeezy', 'mustard']
# cheesy-sausage-salsa-rollovers ['special', 'pork', 'chilli', 'sausage', 'mission', 'deli', 'original', 'mini', 'tortilla', 'wrap', 'spinach', 'mild', 'cheddar', 'onion', 'asda', 'cool', 'tomato', 'salsa']
# salmon-and-avocado-caesar-salad ['thick', 'slice', 'bread', 'butter', 'olive', 'oil', 'heart', 'romaine', 'lettuce', 'pack', 'asda', 'special', 'salmon', 'ripe', 'avocado', 'asda', 'caesar', 'bottle', 'parmesan', 'cheese']
# halloumi-lime-kebabs ['zest', 'lime', 'lime', 'juice', 'olive', 'oil', 'coriander', 'garlic', 'clove', 'pack', 'halloumi', 'cube', 'plum', 'tomatoe', 'pepper', 'pepper', 'courgette', 'onion', 'wedge']
# farfalle-pasta-with-pea-ham-sauce ['asda', 'chosen', 'farfalle', 'pasta', 'frozen', 'pea', 'asda', 'lighter', 'soft', 'cheese', 'milk', 'parmesan', 'thick-cut', 'ham', 'piece']
# brandy-snap-rhubarb-cups ['rhubarb', 'weight', 'piece', 'caster', 'sugar', 'butter', 'plu', 'golden', 'syrup', 'flour', 'ginger', 'lemon', 'juice', 'pot', 'asda', 'mascarpone', 'ball', 'stem', 'ginger', 'syrup', 'plu', 'syrup']
# chicken-casserole ['sunflower', 'oil', 'leek', 'onion', 'pack', 'asda', 'chicken', 'thigh', 'fillet', 'skinles', 'chicken', 'stock', 'cube', 'dijon', 'mustard', 'pack', 'asda', 'chantenay', 'carrot', 'chestnut', 'mushroom', 'pack', 'asda', 'tarragon', 'cornflour', 'pot', 'fat', 'crème', 'fraîche']
# key-lime-pie-with-blueberries ['asda', 'rich', 'highland', 'shortie', 'anchor', 'butter', 'egg', 'yolk', 'asda', 'les', 'fat', 'light', 'soft', 'cheese', 'caster', 'sugar', 'lime', 'zest', 'juice', 'asda', 'double', 'cream', 'asda', 'double', 'cream', 'asda', 'blueberrie', 'lime', 'zest', 'sliver']
# warm-roasted-vegetable-chicken-pasta-salad ['aubergine', 'olive', 'oil', 'pepper', 'plum', 'tomatoe', 'asda', 'special', 'fusilli', 'giganti', 'pasta', 'balsamic', 'vinegar', 'asda', 'chosen', 'dijon', 'mustard', 'onion', 'chicken', 'skin', 'torn', 'piece', 'basil', 'leavesto', 'serve']
# mini-venison-sausage-rolls-with-cherry-conserve ['ready', 'all-butter', 'puff', 'pastry', 'special', 'venison', 'burger', 'special', 'cherry', 'conserve']
# lamb-pepper-and-red-onion-stir-fry ['olive', 'oil', 'onion', 'sweet', 'potato', 'pepper', 'pack', 'lamb', 'leg', 'steak', 'pack', 'sugar', 'snap', 'pea', 'can', 'water', 'chestnut', 'frozen', 'sweetcorn', 'pack', 'amoy', 'straight', 'wok', 'udon', 'thick', 'noodle', 'pack', 'grower’', 'sizzlin’', 'singapore', 'stir-fry', 'sauce', 'lime', 'wedge', 'peanut', 'garnish']
# spaghetti-with-smoked-salmon-peas ['asda', 'chosen', 'spaghetti', 'frozen', 'pea', 'butter', 'onion', 'asda', 'lighter', 'soft', 'cheese', 'milk', 'parmesan', 'pack', 'asda', 'smart', 'salmon', 'piece', 'parsley']
# slow-roast-beef-brisket ['sunflower', 'oil', 'asda', 'brisket', 'beef', 'onion', 'wedge', 'beef', 'stock', 'made', 'knorr', 'rich', 'beef', 'stock', 'pot', 'tomato', 'purée', 'herb', 'bay', 'gravy', 'granule', 'roast', 'potatoe', 'serve', 'asda', 'smart', 'yorkshire', 'serve', 'brocolli', 'serve', 'carrot', 'serve', 'pea', 'serve']
# steak-wellington ['fillet', 'steak', 'olive', 'oil', 'pack', 'asda', 'ready', 'puff', 'pastry', 'stilton', 'cheese', 'free-range', 'egg', 'beaten', 'potatoe', 'serve']
# best-ever-bubble-and-squeak ['weight', 'mari', 'piper', 'potatoe', 'edward', 'potatoe', 'onion', 'oil', 'savoy', 'cabbage', 'butter', 'lean', 'back', 'bacon', 'rasher', 'egg', 'beaten']
# couscous-and-halloumi-stuffed-pointed-peppers ['chosen', 'moroccan', 'style', 'giant', 'cou', 'cou', 'special', 'sweet', 'pepper', 'stick', 'celery', 'plum', 'tomatoe', 'basil', 'juice', 'zest', 'lemon', 'asda', 'les', 'fat', 'halloumi', 'pomegranate', 'lettuce', 'optional', 'coriander', 'serve']
# jerk-grilled-sea-bream ['sea', 'bream', 'fillet', 'asda', 'jerk', 'sunflower', 'oil', 'plu', 'pineapple', 'finger', 'lime', 'juice', 'honey', 'salad', 'serve', 'cherry', 'vine', 'tomatoe', 'serve']
# steak-with-peppercorn-sauce ['peppercorn', 'sunflower', 'oil', 'pack', 'butcher', 'ribeye', 'steak', 'butter', 'shallot', 'beef', 'stock', 'made', 'stock', 'cube', 'asda', 'coarse', 'grain', 'mustard', 'double', 'cream', 'salad', 'serve']
# beef-stew ['frozen', 'beef', 'pack', 'aunt', 'bessie’', 'frozen', 'casserole', 'vegetable', 'mix', 'herb', 'beef', 'stock', 'cube', 'tomato', 'purée', 'cornflour']
# beef-stroganoff ['brandy', 'optional', 'rice', 'green', 'vegetable', 'side', 'dish', 'serve', 'asda', 'british', 'beef', 'sirloin', 'steak', 'onion', 'chestnut', 'mushroom', 'butter', 'wine', 'beef', 'stock', 'sunflower', 'oil', 'paprika', 'coarse', 'grain', 'mustard', 'cream', 'parsley']
# cheats-moussaka ['potatoe', 'olive', 'oil', 'onion', 'lean', 'steak', 'mince', 'can', 'asda', 'tomatoe', 'garlic', 'tomato', 'ketchup', 'oregano', 'cinnamon', 'lamb', 'stock', 'cube', 'beef', 'stock', 'cube', 'aubergine', 'cube', 'cornflour', 'asda', 'fat', 'free', 'greek', 'style', 'yogurt', 'asda', 'greek', 'style', 'yogurt', 'egg', 'parmesan', 'salad', 'serve']
# american-cheeseburger ['butcher’', 'lean', 'beef', 'mince', 'les', 'fat', 'worcestershire', 'sauce', 'touch', 'american', 'mustard', 'plu', 'optional', 'special', 'oil', 'plu', 'onion', 'baker’', 'burger', 'bun', 'individual', 'asda', 'cheese', 'slice', 'lettuce', 'asda', 'tangy', 'burger', 'relish']
# nut-cheese-twists ['butter', 'pack', 'hovi', 'bread', 'mix', 'flour', 'asda', 'full', 'fat', 'soft', 'creamy', 'cheese', 'walnut', 'piece', 'cheddar', 'egg', 'beaten']
# trout-parcels-with-courgette-pepper ['trout', 'fillet', 'courgette', 'pepper', 'butter', 'asda', 'special', 'tomato', 'rub', 'olive', 'oil', 'potatoe', 'serve', 'lemon', 'wedge', 'serve']
# thai-fish-curry ['can', 'coconut', 'milk', 'asda', 'curry', 'paste', 'pack', 'asda', 'frozen', 'smart', 'fish', 'frozen', 'green', 'bean', 'lime', 'juice', 'thai', 'fish', 'sauce', 'brown', 'sugar', 'coriander', 'bag', 'asda', 'frozen', 'rice']
# dairy-free-poppy-seed-and-banana-pancakes ['flour', 'poppy', 'powder', 'fat', 'coconut', 'milk', 'koko', 'original', 'dairy', 'free', 'yoghurt', 'egg', 'beaten', 'oil', 'banana', 'lime', 'runny', 'honey']
# greek-salad ['special', 'sweet', 'aromatico', 'tomatoe', 'virgin', 'olive', 'oil', 'gem', 'lettuce', 'quarter', 'lemon', 'chosen', 'greek', 'feta', 'cucumber', 'chunk', 'onion', 'special', 'kalamata', 'halkidiki', 'olive', 'chilli', 'garlic', 'olive', 'pepper', 'strip', 'wine', 'vinegar', 'oregano', 'basil', 'garnish']
# courgette-feta-filo-tart ['olive', 'oil', 'courgette', 'courgette', 'pepper', 'zest', 'lemon', 'egg', 'beaten', 'mascarpone', 'dijon', 'mustard', 'feta', 'sprig', 'thyme', 'pack', 'jus-rol', 'filo', 'pastry', 'butter']
# classic-coronation-chicken ['asda', 'special', 'corn', 'chicken', 'breast', 'fillet', 'chicken', 'stock', 'made', 'stock', 'cube', 'almond', 'sunflower', 'oil', 'asda', 'curry', 'powder', 'pot', 'asda', 'special', 'french', 'crème', 'fraîche', 'dlsigny', 'pot', 'asda', 'greek', 'style', 'yogurt', 'asda', 'special', 'mango', 'apple', 'ginger', 'chutney', 'tomato', 'purée', 'grape', 'coriander', 'plu', 'garnish']
# white-chocolate-mousse ['chocolate', 'cointreau', 'orange', 'juice', 'egg', 'caster', 'sugar', 'mango', 'passion', 'fruit', 'favourite']
# beef-ale-cobbler ['casserole', 'beef', 'oil', 'onion', 'carrot', 'button', 'mushroom', 'asda', 'chosen', 'beef', 'ale', 'pour', 'sauce', 'self', 'flour', 'butter', 'milk', 'thyme', 'parsley']
# salmon-fish-rosti-recipe ['skinles', 'haddock', 'skinles', 'salmon', 'fillet', 'potatoe', 'courgette', 'egg', 'beaten', 'creme', 'fraiche', 'bunch', 'parsley', 'butter', 'pepper', 'serve']
# spaghetti-with-herby-cheese-pine-nuts ['spaghetti', 'broccoli', 'broken', 'floret', 'pine', 'nut', 'asda', 'french', 'roulé', 'cheese', 'milk', 'butter', 'asda', 'mature', 'cheddar', 'flat-leaf', 'parsley']
# garlic-and-parmesan-potato-wedges ['potatoe', 'skin', 'wedge', 'virgin', 'olive', 'oil', 'clove', 'garlic', 'parsley', 'parmesan']
# brioche-roll-with-smoked-salmon-scrambled-egg ['salmon', 'free-range', 'egg', 'milk', 'butter', 'asda', 'brioche', 'roll', 'chive', 'tomatoe', 'serve']
# peanut-butter-cookie-ice-cream-sandwiches ['crunchy', 'peanut', 'butter', 'caster', 'sugar', 'soft', 'brown', 'sugar', 'egg', 'bicarbonate', 'soda', 'walnut', 'strawberry', 'ice', 'cream', 'serve']
# pumpkin-patch-cake ['butter', 'flora', 'spread', 'caster', 'sugar', 'vanilla', 'extract', 'egg', 'flour', 'cocoa', 'powder', 'powder', 'milk', 'double', 'cream', 'chocolate', 'sugar', 'green', 'food', 'food', 'food', 'pack', 'mikado', 'milk', 'chocolate', 'biscuit', 'bake', 'create', 'ready', 'roll', 'orange', 'profiterole', 'chosen', 'great', 'bake']
# parsnip-potato-onion-hash-with-egg ['vegetable', 'oil', 'edward', 'potatoe', 'weight', 'parsnip', 'top', 'chunk', 'onion', 'wedge', 'schwartz', 'garlic', 'granule', 'cumin', 'flat-leaf', 'parsley', 'egg', 'serve']
# soft-cinnamon-pretzels ['strong', 'bread', 'flour', 'flour', 'caster', 'sugar', 'sachet', 'easy-bake', 'yeast', 'warm', 'milk', 'butter', 'bicarbonate', 'soda', 'cinnamon', 'caster', 'sugar']
# beef-fajitas-with-guacamole ['ripe', 'avocado', 'tomato', 'lime', 'pepper', 'handful', 'coriander', 'gem', 'lettuce', 'orange', 'pepper', 'pepper', 'coriander', 'cumin', 'cayenne', 'pepper', 'sunflower', 'oil', 'thin-cut', 'beef', 'steak', 'wholemeal', 'tortilla', 'wrap']
# almond-herb-crusted-salmon ['kg', 'boneles', 'salmon', 'side', 'breadcrumb', 'ciabatta', 'bread', 'day', 'old', 'almond', 'zest', 'lemon', 'plu', 'slice', 'serve', 'parsley', 'chive', 'plu', 'chive', 'serve', 'clove', 'garlic', 'olive', 'oil', 'dijon', 'mustard']
# mushroom-stroganoff ['onion', 'mushroom', 'pack', 'asda', 'stroganoff', 'sauce', 'mix', 'milk', 'smart', 'cashew', 'asda', 'long', 'grain', 'rice', 'oil']
# blueberry-cheesecake ['digestive', 'biscuit', 'butter', 'asda', 'soft', 'creamy', 'full', 'fat', 'soft', 'cheese', 'lemon', 'zest', 'lemon', 'juice', 'asda', 'vanilla', 'extract', 'caster', 'sugar', 'crème', 'fraîche', 'free-range', 'egg', 'blueberrie', 'plu', 'raspberrie', 'serve']
# masterclass-doughnuts ['butter', 'strong', 'flour', 'bread', 'plu', 'sachet', 'instant', 'yeast', 'caster', 'sugar', 'milk', 'egg', 'litre', 'sunflower', 'oil', 'good', 'pinch', 'cinnamon', 'raspberry', 'jam']
# ...
# scones ['flour', 'asda', 'special', 'butter', 'caster', 'sugar', 'milk', 'asda', 'special', 'cornish', 'cream', 'serve', 'asda', 'special', 'strawberry', 'conserve', 'strawberrie', 'serve']
# rum-punch ['sugar', 'lime', 'dark', 'rum', 'orange', 'juice', 'pineapple', 'juice', 'bol', 'grenadine', 'fruit', 'ice', 'serve']
# beef-and-horseradish-bites-recipe ['butcher', 'garlic', 'herb', 'thin', 'beef', 'sizzle', 'steak', 'take', 'fridge', 'min', 'youre', 'ready', 'cook', 'kettle', 'vegetable', 'chip', 'horseradish', 'sauce']
# bone-broth ['stick', 'celery', 'piece', 'carrot', 'onion', 'bay', 'sprig', 'thyme', 'peppercorn', 'bone', 'roast', 'chicken']
# potato-pea-spinach-curry ['onion', 'sunflower', 'oil', 'tube', 'asda', 'balti', 'curry', 'paste', 'can', 'fat', 'coconut', 'milk', 'potatoe', 'vegetable', 'stock', 'lime', 'juice', 'frozen', 'pea', 'bag', 'spinach', 'coriander', 'naan', 'bread', 'serve']
# panaforte ['pack', 'asda', 'hazelnut', 'pack', 'asda', 'almond', 'walnut', 'pistachio', 'fig', 'pack', 'asda', 'peel', 'flour', 'cocoa', 'cinnamon', 'nutmeg', 'caster', 'sugar', 'honey', 'butter', 'sugar']
# preserved-lemons ['lemon', 'coarse', 'sea', 'salt', 'bay', 'olive', 'oil']
# vivek-singhs-sticky-chicken-wings ['chicken', 'skin', 'coriander', 'peppercorn', 'clove', 'garlic', 'grain', 'mustard', 'lemon', 'juice', 'marinade', 'honey', 'cucumber', 'carrot', 'tomatoe', 'onion', 'green', 'chilli', 'coriander', 'lemon', 'juice', 'salad', 'sugar']
# pork-belly-with-rhubarb-puree ['pork', 'joint', 'approx', 'sunflower', 'oil', 'onion', 'thick', 'slice', 'ripe', 'pear', 'rhubarb', 'piece', 'orange', 'zest', 'juice', 'sugar', 'butter', 'sea', 'salt']
# crisp-topped-parsnip-and-apple-soup ['butter', 'onion', 'parsnip', 'keep', 'bramley', 'apple', 'keep', 'potato', 'celery', 'stick', 'vegetable', 'stock', 'olive', 'oil', 'les', 'fat', 'crème', 'fraîche', 'juice', 'lemon']
# gazpacho ['bread', 'tomatoe', 'cucumber', 'pepper', 'clove', 'garlic', 'virgin', 'olive', 'oil', 'wine', 'vinegar', 'caster', 'sugar', 'flat-leaf', 'parsley', 'plu', 'dry', 'sherry', 'optional', 'onion', 'serve']
# spinach-frittata ['olive', 'oil', 'bag', 'spinach', 'butter', 'pepper', 'tomatoe', 'beaten', 'free-range', 'weight', 'egg', 'parmesan', 'serve']
# vegetable-quesadillas ['leftover', 'veg', 'pot', 'asda', 'hot', 'spicy', 'salsa', 'coriander', 'asda', 'corn', 'tortilla', 'asda', 'les', 'fat', 'mature', 'british', 'cheese', 'asda', 'guacamole', 'serve']
# tropical-cheesecake ['sheet', 'leaf', 'gelatine', 'asda', 'tropical', 'granola', 'oil', 'asda', 'light', 'les', 'fat', 'original', 'soft', 'cheese', 'room', 'temperature', 'yeo', 'valley', 'greek', 'style', 'fat', 'honey', 'yogurt', 'honey', 'orange', 'zest', 'japanese', 'organic', 'matcha', 'green', 'tea', 'powder', 'optional', 'plu', 'dust']
# masterclass-tempura-prawns ['chosen', 'real', 'mayonnaise', 'yutaka', 'wasabi', 'paste', 'bag', 'special', 'frozen', 'raw', 'indonesian', 'tiger', 'prawn', 'litre', 'sunflower', 'oil', 'deep', 'flour', 'plu', 'cornflour', 'powder', 'salt', 'water', 'cold', 'chill', 'least', 'hour']
# warm-chickpea-chorizo-salad ['special', 'spanish', 'chorizo', 'casero', 'can', 'chosen', 'chickpea', 'water', 'onion', 'cherry', 'tomatoe', 'chosen', 'olive', 'onion']
# chicken-stir-fry ['pack', 'asda', 'egg', 'noodle', 'dry', 'weight', 'vegetable', 'oil', 'bag', 'grower’', 'stir-fry', 'chicken', 'sunday', 'pack', 'grower’', 'hoisin', 'stir-fry', 'sauce']
# beef-stir-fry-with-barbecue-sauce ['tomato', 'ketchup', 'balsamic', 'vinegar', 'worcestershire', 'sauce', 'french', 'mustard', 'honey', 'potatoe', 'serve', 'sunflower', 'oil', 'asda', 'butcher', 'rump', 'steak', 'bite-size', 'piece', 'carrot', 'baton', 'pack', 'asda', 'corn', 'sugar', 'snap', 'pepper', 'strip', 'onion']
# pad-thai ['asda', 'egg', 'noodle', 'groundnut', 'oil', 'plu', 'noodle', 'frozen', 'quorn', 'chicken', 'style', 'piece', 'onion', 'beansprout', 'soy', 'sauce', 'lime', 'zest', 'juice', 'cayenne', 'chilli', 'flake', 'optional', 'brown', 'sugar', 'egg', 'beaten', 'coriander', 'dry', 'roast', 'peanut']
# pepper-and-chorizo-salad ['olive', 'oil', 'asda', 'chorizo', 'sausage', 'slice', 'pepper', 'carrot', 'clove', 'garlic', 'onion', 'kale', 'can', 'green', 'lentil', 'parsley', 'wine', 'vinegar']
# hot-sour-soup ['vegetable', 'oil', 'chestnut', 'mushroom', 'chilli', 'pack', 'corn', 'hot', 'chicken', 'stock', 'made', 'stock', 'cube', 'light', 'soy', 'sauce', 'ginger', 'balsamic', 'vinegar', 'leftover', 'turkey', 'chosen', 'udon', 'noodle', 'juice', 'zest', 'lime', 'plu', 'wedge', 'serve', 'onion']
# banana-date-cake ['date', 'dark', 'rum', 'orange', 'juice', 'ripe', 'banana', 'weight', 'asda', 'butter', 'caster', 'sugar', 'orange', 'zest', 'free-range', 'egg', 'flour']
# pulled-pork-with-barbecue-sauce ['butcher', 'boneles', 'pork', 'shoulder', 'joint', 'asda', 'paprika', 'colman', 'mustard', 'powder', 'plu', 'barbecue', 'sauce', 'brown', 'sugar', 'plu', 'barbecue', 'sauce', 'sunflower', 'oil', 'apple', 'juice', 'onion', 'asda', 'tomato', 'ketchup', 'cider', 'vinegar', 'asda', 'sweet', 'chilli', 'sauce', 'worcestershire', 'sauce', 'burger', 'bun', 'serve', 'coleslaw', 'serve']
# diy-salmon-parcels ['onion', 'babycorn', 'sugarsnap', 'pea', 'courgette', 'lime', 'reduced-salt', 'soy', 'sauce', 'vegetable', 'oil', 'brown', 'sugar', 'salmon', 'fillet', 'approx']
# blueberry-batter-pudding ['sunflower', 'oil', 'flour', 'caster', 'sugar', 'free-range', 'egg', 'milk', 'drop', 'asda', 'vanilla', 'extract', 'blueberrie']
# orange-grapefruit-marmalade ['orange', 'grapefruit', 'sugar']
# stuffed-peppers ['pepper', 'colour', 'sachet', 'chosen', 'mediterranean', 'style', 'giant', 'cou', 'cou', 'vegetable', 'stock', 'made', 'stock', 'cube', 'sultana', 'tomatoe', 'pine', 'nut', 'can', 'haricot', 'bean', 'cannellini', 'bean', 'feta', 'cheese', 'salad', 'serve']
# golden-snitch-cake-pops ['butter', 'golden', 'caster', 'sugar', 'egg', 'milk', 'self', 'flour', 'vanilla', 'plu', 'asda', 'chocolate', 'ready', 'roll', 'dr', 'oetker', 'shimmer', 'spray', 'gold', 'cake', 'pop', 'stick']
# mock-jito ['sugar', 'mint', 'lime', 'lime', 'wedge', 'lemonade']
# baked-sweet-potatoes-with-chilli-feta ['sweet', 'potatoe', 'pumpkin', 'chosen', 'les', 'fat', 'light', 'soft', 'cheese', 'sunflower', 'oil', 'bunch', 'onion', 'chilli', 'feta', 'salad', 'serve']
# nectarine-cream-flan ['asda', 'ready', 'roll', 'shortcrust', 'pastry', 'flour', 'apricot', 'jam', 'nectarine', 'lemon', 'juice', 'cornflour', 'lemon', 'zest', 'crème', 'fraîche', 'free-range', 'egg', 'caster', 'sugar', 'drop', 'vanilla', 'extract', 'sugar']
# miguels-barclays-sweetcorn-and-courgette-feta-fritters ['courgette', 'matchstick', 'sweetcorn', 'can', 'well', 'egg', 'flour', 'feta', 'handful', 'rocket', 'olive', 'oil']
# tuna-sweetcorn-pizza ['pack', 'asda', 'pizza', 'mix', 'flour', 'oil', 'jar', 'asda', 'tomato', 'herb', 'pizza', 'can', 'asda', 'tuna', 'brine', 'olive', 'onion', 'can', 'sweetcorn', 'cheddar']
# miguel-barclays-mushroom-risotto ['onion', 'asda', 'risotto', 'arborio', 'rice', 'mushroom', 'handful', 'cheddar', 'olive', 'oil', 'vegetable', 'stock', 'cube']
# parsley-crumbed-chicken ['chicken', 'breast', 'fillet', 'natural', 'low-fat', 'yogurt', 'milk', 'pack', 'flat', 'leaf', 'parsley', 'clove', 'garlic', 'butter', 'breadcrumb', 'lemon', 'zest']
# black-bun ['flour', 'pinch', 'salt', 'butter', 'cube', 'lard', 'cube', 'currant', 'raisin', 'peel', 'whisky', 'almond', 'soft', 'dark', 'brown', 'sugar', 'flour', 'powder', 'cream', 'tartare', 'spice', 'milk', 'egg', 'beaten', 'glaze']
# cucur-udang-malaysian-prawn-fritters ['flour', 'flour', 'salt', 'chicken', 'stock', 'powder', 'sugar', 'turmeric', 'powder', 'pepper', 'garlic', 'chive', 'onion', 'thin', 'strip', 'raw', 'prawn', 'oil', 'asda', 'goose', 'sriracha', 'hot', 'chilli', 'sauce', 'plum', 'sauce', 'sprinkle', 'sesame']
# hedgehog-buns ['asda', 'bread', 'flour', 'plu', 'asda', 'spice', 'butter', 'cold', 'fridge', 'pack', 'asda', 'easy', 'bake', 'yeast', 'caster', 'sugar', 'free-range', 'egg', 'beaten', 'milk', 'room', 'temperature', 'currant']
# classic-ratatouille ['olive', 'oil', 'plu', 'apple', 'cider', 'vinegar', 'can', 'tomatoe', 'frozen', 'scratch', 'cook', 'garlic', 'basil', 'plu', 'garnish', 'asda', 'herbe', 'de', 'provence', 'chilli', 'powder', 'beef', 'tomatoe', 'thick', 'onion', 'thick', 'courgette', 'thick', 'aubergine', 'thick']
# steak-avocado-beetroot-salad ['asda', 'balsamic', 'condiment', 'orange', 'juice', 'lemon', 'zest', 'juice', 'shallot', 'honey', 'olive', 'oil', 'asda', 'long', 'life', 'beetroot', 'wedge', 'asda', 'special', 'fillet', 'steak', 'ripe', 'avocado', 'asda', 'leafy', 'rocket', 'salad', 'serve']
# roast-leg-of-pork-with-herb-stuffing-balls ['butcher', 'pork', 'leg', 'onion', 'wedge', 'pack', 'asda', 'sage', 'onion', 'garlic', 'mix', 'flour', 'hot', 'chicken', 'stock', 'pork', 'stock', 'asda', 'bramley', 'apple', 'sauce', 'potatoe', 'serve', 'gravy', 'serve']
# oven-cooked-new-potatoes ['potatoe', 'chicken', 'stock', 'butter']
# grilled-prawn-and-halloumi-salad ['raw', 'prawn', 'watermelon', 'triangle', 'halloumi', 'slice', 'bunch', 'basil', 'torn', 'bunch', 'mint', 'torn', 'pine', 'nut', 'olive', 'handful', 'rocket', 'drizzle', 'olive', 'oil', 'serve', 'lemon', 'wedge']
# red-velvet-pancakes ['cream', 'milk', 'egg', 'beaten', 'buttermilk', 'pure', 'vanilla', 'extract', 'self', 'flour', 'cocoa', 'powder', 'powder', 'caster', 'sugar', 'food', 'butter', 'strawberrie', 'chocolate', 'cocoa', 'powder', 'serve']
# chocolate-caramel-mousse ['can', 'carnation', 'caramel', 'asda', 'dark', 'chocolate', 'cocoa', 'solid', 'square', 'asda', 'milk', 'chocolate', 'square', 'free-range', 'egg', 'coffee', 'caster', 'sugar', 'whitworth', 'hazelnut', 'serve']
# chicken-chorizo-and-cauliflower-tray-bake ['olive', 'oil', 'chicken', 'breast', 'skin-on', 'cauliflower', 'floret', 'onion', 'wedge', 'chorizo', 'piece', 'sprig', 'thyme', 'cherry', 'tomatoe', 'vine', 'handful', 'spinach']
# gingerbread-ice-cream-sandwiches1 ['special', 'vanilla', 'extract', 'egg', 'yolk', 'caster', 'sugar', 'double', 'cream', 'golden', 'caster', 'sugar', 'golden', 'syrup', 'ginger', 'spice', 'chosen', 'milk', 'biscuit', 'sandwich']
# cherry-fool ['cherrie', 'see', 'tip', 'caster', 'sugar', 'double', 'cream', 'greek', 'yogurt', 'raspberry', 'jam', 'shortbread', 'mint', 'cherrie', 'garnish']
# vegetable-nut-loaf ['brown', 'long-grain', 'rice', 'shallot', 'carrot', 'olive', 'oil', 'butter', 'mushroom', 'marmite', 'gluten-free', 'bread', 'made', 'crumb', 'raw', 'cashew', 'nut', 'almond', 'macadamia', 'nut', 'mature', 'cheddar', 'thyme', 'plu', 'garnish', 'egg', 'brussel', 'sprout', 'serve', 'carrot', 'serve']
# beef-cheese-jalapeno-spring-rolls-with-plum-dip ['packet', 'asda', 'butcher’', 'bbq', 'beef', 'brisket', 'bourbon', 'sauce', 'sheet', 'roll', 'pastry', 'asda', 'fiery', 'cheese', 'mix', 'jalapeño', 'egg', 'beaten', 'asda', 'chipotle', 'paste', 'jar', 'special', 'plum', 'conserve', 'cider', 'vinegar', 'onion', 'radishe', 'flat-leaf', 'parsley']
# prawn-avocado-with-a-twist ['asda', 'mayonnaise', 'asda', 'special', 'tomato', 'chilli', 'chutney', 'asda', 'crème', 'fraîche', 'worcestershire', 'sauce', 'horseradish', 'tabasco', 'sauce', 'squeeze', 'lime', 'juice', 'prawn', 'ripe', 'avocado', 'cayenne', 'pepper', 'paprika']
# mixed-nut-honey-baklava ['sugar', 'lemon', 'zest', 'chosen', 'pure', 'honey', 'walnut', 'pistachio', 'butter', 'pack', 'frozen', 'jus-rol', 'filo', 'sheet']
# popcorn-turkey-bites ['chosen', 'popcorn', 'day-old', 'bread', 'paprika', 'pack', 'butcher’', 'turkey', 'breast', 'steak', 'egg', 'sweet', 'potatoe', 'herb', 'olive', 'oil', 'salad', 'serve', 'ketchup', 'serve']
# mexican-tostadas ['asda', 'mexican', 'tortilla', 'oil', 'can', 'old', 'el', 'paso', 'bean', 'onion', 'pinch', 'cumin', 'can', 'borlotti', 'bean', 'ripe', 'avocado', 'feta', 'cheese', 'little', 'gem', 'lettuce', 'chilli', 'optional', 'jar', 'asda', 'mexican', 'mild', 'salsa', 'lime', 'wedge']
# stuffed-baked-potatoes ['potatoe', 'edward', 'mari', 'piper', 'sunflower', 'oil', 'milk', 'egg', 'thick-cut', 'ham', 'chive', 'sweetcorn', 'cheddar', 'cheese']
# lancashire-hotpot ['onion', 'sunflower', 'oil', 'potatoe', 'pack', 'asda', 'smart', 'lamb', 'shoulder', 'chop', 'pack', 'asda', 'lamb', 'carrot', 'optional', 'rosemary', 'flat-leaf', 'parsley', 'bay', 'leaf', 'hot', 'lamb', 'stock', 'butter']
# slow-roasted-spiced-lamb-with-tomatoes ['leg', 'lamb', 'paprika', 'cumin', 'coriander', 'clove', 'garlic', 'tomato', 'purée', 'olive', 'oil', 'plu', 'cherry', 'tomatoe', 'vine', 'honey']
# lamb-with-balsamic-glaze ['edward', 'potatoe', 'mari', 'piper', 'potatoe', 'olive', 'oil', 'pack', 'asda', 'lamb', 'escalope', 'shallot', 'balsamic', 'vinegar', 'redcurrant', 'reduced-fat', 'crème', 'fraîche', 'coarse-grain', 'mustard', 'green']
# healthy-fish-pie ['sweet', 'potatoe', 'fish', 'frozen', 'prawn', 'milk', 'cornflour', 'milk', 'pack', 'chosen', 'les', 'fat', 'garlic', 'herb', 'light', 'soft', 'cheese', 'parmesan', 'parsley', 'nutmeg', 'frozen', 'sweetcorn', 'spinach']
# sticky-pork-ribs-with-vegetable-rice ['sunflower', 'oil', 'pack', 'butcher', 'pork', 'rib', 'amoy', 'low', 'salt', 'soy', 'sauce', 'redcurrant', 'garlic', 'clove', 'cider', 'vinegar', 'dijon', 'mustard', 'asda', 'sweet', 'chilli', 'sauce', 'honey', 'long', 'grain', 'rice', 'asda', 'frozen', 'vegetable']
# mediterranean-style-salmon-traybake ['good', 'mediterranean', 'vegetable', 'cherry', 'tomatoe', 'chosen', 'oven', 'cook', 'crispy', 'potatoe', 'pack', 'chosen', 'cook', 'frozen', 'salmon', 'fillet', 'olive', 'oil', 'lemon', 'juice', 'oregano']
# tomato-chilli-chutney ['tomatoe', 'onion', 'bramley', 'apple', 'weight', 'piece', 'root', 'ginger', 'chillie', 'remove', 'milder', 'flavour', 'garlic', 'clove', 'sultana', 'wine', 'vinegar', 'light', 'brown', 'soft', 'sugar', 'mustard', 'powder']
# jerk-sweet-potato-bean-curry ['sunflower', 'oil', 'piece', 'root', 'ginger', 'clove', 'garlic', 'pepper', 'bunch', 'onion', 'chillie', 'thyme', 'plu', 'garnish', 'lime', 'juice', 'soy', 'sauce', 'hp', 'sauce', 'spice', 'allspice', 'carton', 'chosen', 'tomatoe', 'brown', 'sugar', 'sweet', 'potato', 'weight', 'cube', 'can', 'black-eye', 'bean', 'dark', 'rum', 'optional', 'rice', 'pea', 'serve']
# bubble-squeak-cakes ['potatoe', 'leek', 'butter', 'green', 'cabbage', 'pack', 'asda', 'fat', 'pork', 'sausage', 'carton', 'asda', 'bean']
# the-ultimate-martini ['bombay', 'sapphire', 'london', 'dry', 'gin', 'dry', 'vermouth', 'green', 'olive', 'garnish']
# melon-ball-jellies ['gelatine', 'asda', 'sugar', 'strawberry', 'vanilla', 'flavour', 'water', 'watermelon', 'cantaloupe', 'melon', 'honeydew', 'melon']
# martha-collison-doughnut-recipe ['butter', 'milk', 'egg', 'strong', 'bread', 'flour', 'salt', 'fast', 'action', 'yeast', 'caster', 'sugar', 'litre', 'sunflower', 'oil', 'fondant', 'sugar', 'sugar', 'assortment', 'gel', 'food']
# spring-green-chicken-butterbean-soup ['olive', 'oil', 'butter', 'leek', 'chilli', 'chicken', 'breast', 'fillet', 'piece', 'chicken', 'stock', 'made', 'stock', 'cube', 'worcestershire', 'sauce', 'potatoe', 'green', 'stem', 'can', 'butterbean', 'parsley', 'cornflour', 'cold', 'water']
# battenberg-cake ['butter', 'plu', 'little', 'caster', 'sugar', 'plu', 'free-range', 'egg', 'flour', 'powder', 'pink', 'jar', 'no-bit', 'apricot', 'jam', 'pack', 'marzipan']
# miguel-barclays-roasted-aloo-gobi ['cauliflower', 'floret', 'potato', 'curry', 'powder', 'handful', 'frozen', 'pea', 'handful', 'spinach', 'olive', 'oil']
# steak-cous-cous-salad ['cou', 'cou', 'green', 'bean', 'pepper', 'apricot', 'almond', 'butcher', 'prime', 'beef', 'rump', 'steak', 'olive', 'oil', 'wine', 'vinegar', 'honey']
# best-baby-shower-cake ['madeira', 'cake', 'asda', 'raspberry', 'seedles', 'jam', 'quantity', 'basic', 'buttercream', 'cake', 'board', 'dr', 'oetker', 'regal', 'ice', 'ready', 'roll', 'sugar', 'dust', 'dr', 'oetker', 'gel', 'food', 'colour', 'sunshine', 'lime', 'green', 'sky', 'blue', 'bake', 'create', 'ready', 'roll', 'pink', 'silver', 'spoon', 'royal', 'sugar', 'satin', 'ribbon', 'pastel', 'colour']

# %%
recipes_ingredients_dic.items()
# Out:
# dict_items([('chicken-pumpkin-curry', ['ghee', 'oil', 'onion', 'pack', 'asda', 'chicken', 'thigh', 'fillet', 'skin', 'garlic', 'clove', 'ginger', 'turmeric', 'cumin', 'asda', 'garam', 'masala', 'chillie', 'can', 'coconut', 'milk', 'pumpkin', 'skin', 'fibre', 'cornflour', 'cold', 'water', 'make', 'paste', 'coriander', 'rice', 'serve']), ('masterclass-pulled-ham-creamy-herb-salad', ['butcher’', 'gammon', 'joint', 'cider', 'bag', 'asda', 'tender', 'leaf', 'salad', 'caper', 'frozen', 'pea', 'minute', 'radishe', 'chosen', 'gherkin', 'cider', 'vinegar', 'olive', 'oil', 'fat', 'crème', 'fraîche', 'dijon', 'mustard', 'parsley']), ('banana-pecan-date-muffins', ['butter', 'plu', 'light', 'soft', 'brown', 'sugar', 'ripe', 'banana', 'weight', 'egg', 'beaten', 'flour', 'salt', 'powder', 'cinnamon', 'plu', 'pecan', 'date', 'raisin-size', 'piece', 'sugar']), ('easy-peasy-fish-cakes', ['pack', 'smash', 'instant', 'mash', 'potato', 'can', 'asda', 'tuna', 'chunk', 'water', 'chive', 'pinch', 'cayenne', 'egg', 'beaten', 'butter', 'asda', 'cornflake', 'breadcrumb', 'filippo', 'berio', 'spray', 'oil', 'asparagu', 'serve', 'pea', 'serve', 'sweetcorn', 'serve']), ('fruity-fro-yo-bombe', ['banana', 'frozen', 'solid', 'can', 'ambrosia', 'light', 'devon', 'custard', 'frozen', 'hr', 'pot', 'yeo', 'valley', 'fat', 'greek', 'style', 'honey', 'asda', 'natural', 'food', 'green', 'frozen', 'raspberrie', 'chocolate', 'chip']), ('salmon-fillets-with-pink-grapefruit-salsa', ['pink', 'grapefruit', 'ripe', 'avocado', 'piece', 'chilli', 'onion', 'coriander', 'mild', 'olive', 'oil', 'plu', 'zest', 'lime', 'plu', 'juice', 'basmati', 'rice', 'salmon', 'fillet']), ('mac-n-cheese-salad', ['macaroni', 'olive', 'oil', 'asda', 'light', 'mayonnaise', 'sour', 'cream', 'chive', 'american-style', 'mustard', 'chosen', 'crispy', 'bacon', 'asda', 'cheddar', 'leicester', 'pepper', 'special', 'sweet', 'aromatico', 'tomatoe']), ('ginger-cake', ['butter', 'plu', 'treacle', 'plu', 'serve', 'optional', 'golden', 'syrup', 'ball', 'opie', 'stem', 'ginger', 'syrup', 'flour', 'ginger', 'spice', 'dark', 'soft', 'brown', 'sugar', 'sultana', 'optional', 'egg', 'milk', 'stem', 'ginger', 'syrup', 'jar', 'serve', 'optional']), ('nadiya-hussain-berry-breakfast-muffins', ['flour', 'porridge', 'oat', 'soft', 'light', 'brown', 'sugar', 'powder', 'egg', 'ripe', 'banana', 'sunflower', 'oil', 'milk', 'blueberrie', 'raspberrie']), ('three-bean-salad', ['olive', 'oil', 'balsamic', 'vinegar', 'dijon', 'mustard', 'oil', 'jar', 'tomatoe', 'frozen', 'broad', 'bean', 'tomatoe', 'can', 'kidney', 'bean', 'can', 'cannellini', 'bean', 'celery', 'stick', 'bunch', 'onion']), ('glazed-chicken-vegetable-roast', ['pack', 'asda', 'butcher', 'chicken', 'pack', 'redcurrant', 'clove', 'garlic', 'asda', 'paprika', 'wine', 'vinegar', 'worcestershire', 'sauce', 'oregano', 'olive', 'oil', 'sweet', 'potato', 'weight', 'chunk', 'pepper', 'pepper', 'onion', 'wedge', 'salad', 'serve']), ('beetroot-potato-chorizo-hash', ['edward', 'potatoe', 'weight', 'sweet', 'potato', 'weight', 'pack', 'asda', 'vacuum', 'beetroot', 'onion', 'wedge', 'asda', 'special', 'spanish', 'chorizo', 'casero', 'cube', 'sunflower', 'oil', 'plu', 'wholegrain', 'mustard', 'worcestershire', 'sauce', 'free-range', 'egg']), ('spinach-prawn-mango-salad', ['groundnut', 'oil', 'sunflower', 'oil', 'lemon', 'juice', 'light', 'soy', 'sauce', 'honey', 'root', 'ginger', 'chilli', 'optional', 'ripe', 'mangoe', 'bag', 'asda', 'spinach', 'bag', 'asda', 'wild', 'rocket', 'pack', 'asda', 'prawn']), ('chocolate-bread-butter-pudding', ['butter', 'leftover', 'hot', 'cros', 'bun', 'doesnt', 'matter', 'stale', 'can', 'mandarin', 'segment', 'juice', 'chocolate', 'easter', 'egg', 'full-fat', 'milk', 'caster', 'sugar', 'drop', 'vanilla', 'extract', 'egg']), ('tuna-with-couscous', ['couscou', 'lemon', 'olive', 'oil', 'olive', 'onion', 'tomatoe', 'parsley', 'tuna', 'steak']), ('chicken-broccoli-pie', ['chicken', 'breast', 'fillet', 'gammon', 'steak', 'rind', 'fat', 'chicken', 'stock', ...

# %%
def distance_recipes(recipe1,recipe2):
    rec1=set(recipes_ingredients_dic[recipe1])
    rec2=set(recipes_ingredients_dic[recipe2])
    return len(rec1.intersection(rec2))/len(rec1)

# %%
distance_recipes('fruity-fro-yo-bombe','banana-pecan-date-muffins')
# Out:
# 0.08695652173913043

# %%
def rec_user(recipe1,recipes_dict = read_collection_as_dict("recipes_ingredients")):
    
    dis = dict()
    rec1 = set(recipe1)
    
    for rec in recipes_dict.keys():
        dis[rec] = distance_recipes(recipe1,rec)

    df_return = sorted(dis.items(),key=operator.itemgetter(1),reverse=True)[0:10]
    
    return df_return
# Out:
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)

# %%
rec_user('banana-pecan-date-muffins',recipes_dict = read_collection_as_dict("recipes_ingredients"))
# Out:
# Connected successfully to agile_data_science_group_3
# MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)
# [('banana-pecan-date-muffins', 1.0),
#  ('banana-muffins', 0.6842105263157895),
#  ('pumpkin-fruit-tea-bread', 0.6842105263157895),
#  ('alice-in-wonderland-teapot-cake', 0.5789473684210527),
#  ('banana-pecan-honey-loaf', 0.5789473684210527),
#  ('gluten-free-carrot-cake', 0.5789473684210527),
#  ('apple-crumble-parmesan-cake', 0.5263157894736842),
#  ('deep-dish-apple-crumble-pie', 0.5263157894736842),
#  ('ginger-pear-upside-down-cake', 0.5263157894736842),
#  ('caramelised-pear-chocolate-upside-down-cake', 0.5263157894736842)]
