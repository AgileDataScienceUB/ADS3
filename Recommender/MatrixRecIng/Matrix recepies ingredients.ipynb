# %%
import numpy as np
import pandas as pd

# %%
ingredients = pd.read_csv('Source1Ingredients.csv')
ingredients2 = pd.read_csv('Source2Ingredients.csv')

# %%
from tqdm import tqdm
from stop_words import get_stop_words
stop_words = get_stop_words('en')


def isIngredient(word):
    if len(word) < 2:
        return False
    
    if isNumberInside(word):
        return False
    
    if isPreposition(word):
        return False
    
    if isNoisy(word):
        return False
    
    if isArticle(word):
        return False
    
    if isAction(word):
        return False

    if hasStrange(word):
        return False
    
    
    return True
    
    
def hasStrange(string):
    symbols = ['<', '/', '>', '&', ':', ';', '"']
    for s in symbols:
        if s in string:
            return True
    
    return False
def isAction(string):
    if string[-2:] == 'ed' or string[-2:] == 'ly' or string[-3:] == 'ing':
        return True
    return False
    
def isNumberInside (string):
    for caracter in string:
        if caracter.isnumeric():
            return True
    return False

def isPreposition (string):
    prepositions = ["aboard",'choose', 'almost',"about","above","across","after","against","along","amid","among","anti","around","as","at","before","behind","below","beneath","beside","besides","between","beyond","but","by","concerning","considering","despite","down","during","except","excepting","excluding","following","for","from","in","inside","into","like","minus","near","of","off","on","onto","opposite","outside","over","past","per","plus","regarding","round","save","since","than","through","to","toward","towards","under","underneath","unlike","until","up","upon","versus","via","with","within","without"]
    if string in prepositions:
        return True
    return False

def isNoisy (string):
    noisy = ['whole','baby', 'small','pound','finely','white','freshly','chopped', 'ounce', 'cup', 'ground', 'fresh', 'teaspoon', 'large', 'sliced', 'black', '<strong>for', "cup","tablespoon", "teaspoon", "tablespoon", "ml","if","tbsp","tbsb","tb","tbp","and","tsp","level","extra","cut","or","you","leave","plain","selection","medium","clear","few","price","yellow","new","half", "while", "when","very", "use", "two","three"]
    if string in noisy or string in stop_words:
        return True
    return False

def isArticle (string):
    articles = ["the","a","one","some","few"]
    if string in articles:
        return True
    return False
    
corpus = []
for ing in tqdm(ingredients['ingredient']):
    for word in ing.split():
        _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
        if _aux[-1] == 's':
            _aux = _aux[:-1]
        if isIngredient(_aux):
            corpus.append(_aux)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 22760/22760 [00:00<00:00, 27514.95it/s]

# %%
for ing in tqdm(ingredients2['ingredient']):
    try:
        for word in ing.split():
            _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
            if _aux[-1] == 's':
                _aux = _aux[:-1]
            if isIngredient(_aux):
                corpus.append(_aux)
    except:
        pass
        #print (ing)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 143165/143165 [00:05<00:00, 25500.93it/s]

# %%
print ("Total words in corpus: ", len(corpus))
# Out:
# Total words in corpus:  359826

# %%
set_corpus = set(corpus)

# %%
dict_corpus = dict.fromkeys(set_corpus, 0)
for elem in corpus:
    dict_corpus[elem] += 1

# %%
import operator
sorted_x = sorted(dict_corpus.items(), key=operator.itemgetter(1), reverse= True)

# %%
list_ingr = []
list_num = []
for ingr, num in sorted_x:
    list_ingr.append(ingr)
    list_num.append(num)

# %%
d = {'Ingredient': list_ingr, 'numTimes': list_num}
df = pd.DataFrame(data=d)
df_reduced = df[df['numTimes'] >10]

# %%
len(set_corpus)
# Out:
# 6815

# %%
recepies_dict = {}
for _id, _ing in tqdm(zip(ingredients['id'], ingredients['ingredient'])):
    if not _id in recepies_dict:
        recepies_dict[_id] = []
    for word in _ing.split():
        _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
        if _aux[-1] == 's':
            _aux = _aux[:-1]
        if _aux in set_corpus:
            recepies_dict[_id].append(_aux)
    
#recepies_dict
# Out:
# 22760it [00:00, 108089.85it/s]

# %% [raw]
# for _id, _ing in tqdm(zip(ingredients2['id'], ingredients2['ingredient'])):
#     try:
#         if not _id in recepies_dict:
#             recepies_dict[_id] = []
#         for word in _ing.split():
#             _aux = word.replace('(','').replace(')','').replace(',','').replace("'", "").replace('.', '').lower()
#             if _aux[-1] == 's':
#                 _aux = _aux[:-1]
#             if _aux in set_copus:
#                 recepies_dict[_id].append(_aux)
#     except:
#         pass

# %%
ids = list(set(ingredients['id'])) + list(set(ingredients2['id']))

# %%
matrix = pd.DataFrame(np.full((len(ids), len(set_corpus)), False, dtype=bool), index=ids, columns=set_corpus)

# %%
for key in tqdm(recepies_dict):
    for ingr in recepies_dict[key]:
        matrix[ingr][key] = True
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2467/2467 [00:18<00:00, 130.83it/s]

# %%
matrix
# Out:
#                                               kelt  crisper  tealeave  \
# hot-lemon-souffles                           False    False     False
# spanish-style-omelette                       False    False     False
# madras-egg-curry                             False    False     False
# poached-apricots                             False    False     False
# slow-cooked-duck-with-cherry-sauce           False    False     False
# mushroom-lentil-ragu-with-spaghetti          False    False     False
# turkey-mushroom-pie                          False    False     False
# summer-beef-salad-with-horseradish-dressing  False    False     False
# masterclass-hollandaise-sauce                False    False     False
# dairy-free-poppy-seed-and-banana-pancakes    False    False     False
# cherry-almond-trifle                         False    False     False
# mega-carrot-cake                             False    False     False
# sausage-meat-brioche-stuffing-muffins        False    False     False
# homemade-tomato-pasta-sauce-with-basil       False    False     False
# ham-broccoli-sweetcorn-frittata              False    False     False
# spinach-chicken-pasta                        False    False     False
# pavlova                                      False    False     False
# egg-fried-rice                               False    False     False
# baked-leek-potato-parcels                    False    False     False
# homemade-porridge                            False    False     False
# prosecco-and-cointreau-grapes                False    False     False
# moroccan-pulled-pork-with-fruity-couscous    False    False     False
# noodle-pots                                  False    False     False
# scotch-pies                                  False    False     False
# creamy-herb-mushroom-toasts                  False    False     False
# falafel-wraps-with-sweet-potato-wedges       False    False     False
# lobster-prawn-thermidor                      False    False     False
# moroccan-couscous                            False    False     False
# pea-fritters-with-poached-egg                False    False     False
# blackcurrant-pear-multi-layered-fruit-cubes  False    False     False
# ...                                            ...      ...       ...
# 98214                                        False    False     False
# 229287                                       False    False     False
# 32679                                        False    False     False
# 130985                                       False    False     False
# 196521                                       False    False     False
# 262072                                       False    False     False
# 131001                                       False    False     False
# 98237                                        False    False     False
# 196542                                       False    False     False
# 294852                                       False    False     False
# 32711                                        False    False     False
# 32717                                        False    False     False
# 32722                                        False    False     False
# 294868                                       False    False     False
# 163799                                       False    False     False
# 294871                                       False    False     False
# 294873                                       False    False     False
# 32727                                        False    False     False
# 32730                                        False    False     False
# 32733                                        False    False     False
# 229345                                       False    False     False
# 65509                                        False    False     False
# 65511                                        False    False     False
# 196585                                       False    False     False
# 262121                                       False    False     False
# 196595                                       False    False     False
# 294903                                       False    False     False
# 229369                                       False    False     False
# 294906                                       False    False     False
# 294908                                       False    False     False
#
#                                              hibiscus-lime  cilantro-arugula  \
# hot-lemon-souffles                                   False             False
# spanish-style-omelette                               False             False
# madras-egg-curry                                     False             False
# poached-apricots                                     False             False
# slow-cooked-duck-with-cherry-sauce                   False             False
# mushroom-lentil-ragu-with-spaghetti                  False             False
# turkey-mushroom-pie                                  False             False
# summer-beef-salad-with-horseradish-dressing          False             False
# masterclass-hollandaise-sauce                        False             False
# dairy-free-poppy-seed-and-banana-pancakes            False             False
# cherry-almond-trifle                                 False             False
# mega-carrot-cake                                     False             False
# sausage-meat-brioche-stuffing-muffins                False             False
# homemade-tomato-pasta-sauce-with-basil               False             False
# ham-broccoli-sweetcorn-frittata                      False             False
# spinach-chicken-pasta                                False             False
# pavlova                                              False             False
# egg-fried-rice                                       False             False
# baked-leek-potato-parcels                            False             False
# homemade-porridge                                    False             False
# prosecco-and-cointreau-grapes                        False             False
# moroccan-pulled-pork-with-fruity-couscous            False             False
# noodle-pots                                          False             False
# scotch-pies                                          False             False
# creamy-herb-mushroom-toasts                          False             False
# falafel-wraps-with-sweet-potato-wedges               False             False
# lobster-prawn-thermidor                              False             False
# moroccan-couscous                                    False             False
# pea-fritters-with-poached-egg                        False             False
# blackcurrant-pear-multi-layered-fruit-cubes          False             False
# ...                                                    ...               ...
# 98214                                                False             False
# 229287                                               False             False
# 32679                                                False             False
# 130985                                               False             False
# 196521                                               False             False
# 262072                                               False             False
# 131001                                               False             False
# 98237                                                False             False
# 196542                                               False             False
# 294852                                               False             False
# 32711                                                False             False
# 32717                                                False             False
# 32722                                                False             False
# 294868                                               False             False
# 163799                                               False             False
# 294871                                               False             False
# 294873                                               False             False
# 32727                                                False             False
# 32730                                                False             False
# 32733                                                False             False
# 229345                                               False             False
# 65509                                                False             False
# 65511                                                False             False
# 196585                                               False             False
# 262121                                               False             False
# 196595                                               False             False
# 294903                                               False             False
# 229369                                               False             False
# 294906                                               False             False
# 294908                                               False             False
#
#                                                mam  velvet  gulden  lillet  \
# hot-lemon-souffles                           False   False   False   False
# spanish-style-omelette                       False   False   False   False
# madras-egg-curry                             False   False   False   False
# poached-apricots                             False   False   False   False
# slow-cooked-duck-with-cherry-sauce           False   False   False   False
# mushroom-lentil-ragu-with-spaghetti          False   False   False   False
# turkey-mushroom-pie                          False   False   False   False
# summer-beef-salad-with-horseradish-dressing  False   False   False   False
# masterclass-hollandaise-sauce                False   False   False   False
# dairy-free-poppy-seed-and-banana-pancakes    False   False   False   False
# cherry-almond-trifle                         False   False   False   False
# mega-carrot-cake                             False   False   False   False
# sausage-meat-brioche-stuffing-muffins        False   False   False   False
# homemade-tomato-pasta-sauce-with-basil       False   False   False   False
# ham-broccoli-sweetcorn-frittata              False   False   False   False
# spinach-chicken-pasta                        False   False   False   False
# pavlova                                      False   False   False   False
# egg-fried-rice                               False   False   False   False
# baked-leek-potato-parcels                    False   False   False   False
# homemade-porridge                            False   False   False   False
# prosecco-and-cointreau-grapes                False   False   False   False
# moroccan-pulled-pork-with-fruity-couscous    False   False   False   False
# noodle-pots                                  False   False   False   False
# scotch-pies                                  False   False   False   False
# creamy-herb-mushroom-toasts                  False   False   False   False
# falafel-wraps-with-sweet-potato-wedges       False   False   False   False
# lobster-prawn-thermidor                      False   False   False   False
# moroccan-couscous                            False   False   False   False
# pea-fritters-with-poached-egg                False   False   False   False
# blackcurrant-pear-multi-layered-fruit-cubes  False   False   False   False
# ...                                            ...     ...     ...     ...
# 98214                                        False   False   False   False
# 229287                                       False   False   False   False
# 32679                                        False   False   False   False
# 130985                                       False   False   False   False
# 196521                                       False   False   False   False
# 262072                                       False   False   False   False
# 131001                                       False   False   False   False
# 98237                                        False   False   False   False
# 196542                                       False   False   False   False
# 294852                                       False   False   False   False
# 32711                                        False   False   False   False
# 32717                                        False   False   False   False
# 32722                                        False   False   False   False
# 294868                                       False   False   False   False
# 163799                                       False   False   False   False
# 294871                                       False   False   False   False
# 294873                                       False   False   False   False
# 32727                                        False   False   False   False
# 32730                                        False   False   False   False
# 32733                                        False   False   False   False
# 229345                                       False   False   False   False
# 65509                                        False   False   False   False
# 65511                                        False   False   False   False
# 196585                                       False   False   False   False
# 262121                                       False   False   False   False
# 196595                                       False   False   False   False
# 294903                                       False   False   False   False
# 229369                                       False   False   False   False
# 294906                                       False   False   False   False
# 294908                                       False   False   False   False
#
#                                              messy     ...      reese  witout  \
# hot-lemon-souffles                           False     ...      False   False
# spanish-style-omelette                       False     ...      False   False
# madras-egg-curry                             False     ...      False   False
# poached-apricots                             False     ...      False   False
# slow-cooked-duck-with-cherry-sauce           False     ...      False   False
# mushroom-lentil-ragu-with-spaghetti          False     ...      False   False
# turkey-mushroom-pie                          False     ...      False   False
# summer-beef-salad-with-horseradish-dressing  False     ...      False   False
# masterclass-hollandaise-sauce                False     ...      False   False
# dairy-free-poppy-seed-and-banana-pancakes    False     ...      False   False
# cherry-almond-trifle                         False     ...      False   False
# mega-carrot-cake                             False     ...      False   False
# sausage-meat-brioche-stuffing-muffins        False     ...      False   False
# homemade-tomato-pasta-sauce-with-basil       False     ...      False   False
# ham-broccoli-sweetcorn-frittata              False     ...      False   False
# spinach-chicken-pasta                        False     ...      False   False
# pavlova                                      False     ...      False   False
# egg-fried-rice                               False     ...      False   False
# baked-leek-potato-parcels                    False     ...      False   False
# homemade-porridge                            False     ...      False   False
# prosecco-and-cointreau-grapes                False     ...      False   False
# moroccan-pulled-pork-with-fruity-couscous    False     ...      False   False
# noodle-pots                                  False     ...      False   False
# scotch-pies                                  False     ...      False   False
# creamy-herb-mushroom-toasts                  False     ...      False   False
# falafel-wraps-with-sweet-potato-wedges       False     ...      False   False
# lobster-prawn-thermidor                      False     ...      False   False
# moroccan-couscous                            False     ...      False   False
# pea-fritters-with-poached-egg                False     ...      False   False
# blackcurrant-pear-multi-layered-fruit-cubes  False     ...      False   False
# ...                                            ...     ...        ...     ...
# 98214                                        False     ...      False   False
# 229287                                       False     ...      False   False
# 32679                                        False     ...      False   False
# 130985                                       False     ...      False   False
# 196521                                       False     ...      False   False
# 262072                                       False     ...      False   False
# 131001                                       False     ...      False   False
# 98237                                        False     ...      False   False
# 196542                                       False     ...      False   False
# 294852                                       False     ...      False   False
# 32711                                        False     ...      False   False
# 32717                                        False     ...      False   False
# 32722                                        False     ...      False   False
# 294868                                       False     ...      False   False
# 163799                                       False     ...      False   False
# 294871                                       False     ...      False   False
# 294873                                       False     ...      False   False
# 32727                                        False     ...      False   False
# 32730                                        False     ...      False   False
# 32733                                        False     ...      False   False
# 229345                                       False     ...      False   False
# 65509                                        False     ...      False   False
# 65511                                        False     ...      False   False
# 196585                                       False     ...      False   False
# 262121                                       False     ...      False   False
# 196595                                       False     ...      False   False
# 294903                                       False     ...      False   False
# 229369                                       False     ...      False   False
# 294906                                       False     ...      False   False
# 294908                                       False     ...      False   False
#
#                                              rooster   port  manila  \
# hot-lemon-souffles                             False  False   False
# spanish-style-omelette                         False  False   False
# madras-egg-curry                               False  False   False
# poached-apricots                               False  False   False
# slow-cooked-duck-with-cherry-sauce             False  False   False
# mushroom-lentil-ragu-with-spaghetti            False  False   False
# turkey-mushroom-pie                            False  False   False
# summer-beef-salad-with-horseradish-dressing    False  False   False
# masterclass-hollandaise-sauce                  False  False   False
# dairy-free-poppy-seed-and-banana-pancakes      False  False   False
# cherry-almond-trifle                           False  False   False
# mega-carrot-cake                               False  False   False
# sausage-meat-brioche-stuffing-muffins          False  False   False
# homemade-tomato-pasta-sauce-with-basil         False  False   False
# ham-broccoli-sweetcorn-frittata                False  False   False
# spinach-chicken-pasta                          False  False   False
# pavlova                                        False  False   False
# egg-fried-rice                                 False  False   False
# baked-leek-potato-parcels                      False  False   False
# homemade-porridge                              False  False   False
# prosecco-and-cointreau-grapes                  False  False   False
# moroccan-pulled-pork-with-fruity-couscous      False  False   False
# noodle-pots                                    False  False   False
# scotch-pies                                    False  False   False
# creamy-herb-mushroom-toasts                    False  False   False
# falafel-wraps-with-sweet-potato-wedges         False  False   False
# lobster-prawn-thermidor                        False  False   False
# moroccan-couscous                              False  False   False
# pea-fritters-with-poached-egg                  False  False   False
# blackcurrant-pear-multi-layered-fruit-cubes    False  False   False
# ...                                              ...    ...     ...
# 98214                                          False  False   False
# 229287                                         False  False   False
# 32679                                          False  False   False
# 130985                                         False  False   False
# 196521                                         False  False   False
# 262072                                         False  False   False
# 131001                                         False  False   False
# 98237                                          False  False   False
# 196542                                         False  False   False
# 294852                                         False  False   False
# 32711                                          False  False   False
# 32717                                          False  False   False
# 32722                                          False  False   False
# 294868                                         False  False   False
# 163799                                         False  False   False
# 294871                                         False  False   False
# 294873                                         False  False   False
# 32727                                          False  False   False
# 32730                                          False  False   False
# 32733                                          False  False   False
# 229345                                         False  False   False
# 65509                                          False  False   False
# 65511                                          False  False   False
# 196585                                         False  False   False
# 262121                                         False  False   False
# 196595                                         False  False   False
# 294903                                         False  False   False
# 229369                                         False  False   False
# 294906                                         False  False   False
# 294908                                         False  False   False
#
#                                              flanken-style  oronoco  aliseo  \
# hot-lemon-souffles                                   False    False   False
# spanish-style-omelette                               False    False   False
# madras-egg-curry                                     False    False   False
# poached-apricots                                     False    False   False
# slow-cooked-duck-with-cherry-sauce                   False    False   False
# mushroom-lentil-ragu-with-spaghetti                  False    False   False
# turkey-mushroom-pie                                  False    False   False
# summer-beef-salad-with-horseradish-dressing          False    False   False
# masterclass-hollandaise-sauce                        False    False   False
# dairy-free-poppy-seed-and-banana-pancakes            False    False   False
# cherry-almond-trifle                                 False    False   False
# mega-carrot-cake                                     False    False   False
# sausage-meat-brioche-stuffing-muffins                False    False   False
# homemade-tomato-pasta-sauce-with-basil               False    False   False
# ham-broccoli-sweetcorn-frittata                      False    False   False
# spinach-chicken-pasta                                False    False   False
# pavlova                                              False    False   False
# egg-fried-rice                                       False    False   False
# baked-leek-potato-parcels                            False    False   False
# homemade-porridge                                    False    False   False
# prosecco-and-cointreau-grapes                        False    False   False
# moroccan-pulled-pork-with-fruity-couscous            False    False   False
# noodle-pots                                          False    False   False
# scotch-pies                                          False    False   False
# creamy-herb-mushroom-toasts                          False    False   False
# falafel-wraps-with-sweet-potato-wedges               False    False   False
# lobster-prawn-thermidor                              False    False   False
# moroccan-couscous                                    False    False   False
# pea-fritters-with-poached-egg                        False    False   False
# blackcurrant-pear-multi-layered-fruit-cubes          False    False   False
# ...                                                    ...      ...     ...
# 98214                                                False    False   False
# 229287                                               False    False   False
# 32679                                                False    False   False
# 130985                                               False    False   False
# 196521                                               False    False   False
# 262072                                               False    False   False
# 131001                                               False    False   False
# 98237                                                False    False   False
# 196542                                               False    False   False
# 294852                                               False    False   False
# 32711                                                False    False   False
# 32717                                                False    False   False
# 32722                                                False    False   False
# 294868                                               False    False   False
# 163799                                               False    False   False
# 294871                                               False    False   False
# 294873                                               False    False   False
# 32727                                                False    False   False
# 32730                                                False    False   False
# 32733                                                False    False   False
# 229345                                               False    False   False
# 65509                                                False    False   False
# 65511                                                False    False   False
# 196585                                               False    False   False
# 262121                                               False    False   False
# 196595                                               False    False   False
# 294903                                               False    False   False
# 229369                                               False    False   False
# 294906                                               False    False   False
# 294908                                               False    False   False
#
#                                              scapes*  tablesopon
# hot-lemon-souffles                             False       False
# spanish-style-omelette                         False       False
# madras-egg-curry                               False       False
# poached-apricots                               False       False
# slow-cooked-duck-with-cherry-sauce             False       False
# mushroom-lentil-ragu-with-spaghetti            False       False
# turkey-mushroom-pie                            False       False
# summer-beef-salad-with-horseradish-dressing    False       False
# masterclass-hollandaise-sauce                  False       False
# dairy-free-poppy-seed-and-banana-pancakes      False       False
# cherry-almond-trifle                           False       False
# mega-carrot-cake                               False       False
# sausage-meat-brioche-stuffing-muffins          False       False
# homemade-tomato-pasta-sauce-with-basil         False       False
# ham-broccoli-sweetcorn-frittata                False       False
# spinach-chicken-pasta                          False       False
# pavlova                                        False       False
# egg-fried-rice                                 False       False
# baked-leek-potato-parcels                      False       False
# homemade-porridge                              False       False
# prosecco-and-cointreau-grapes                  False       False
# moroccan-pulled-pork-with-fruity-couscous      False       False
# noodle-pots                                    False       False
# scotch-pies                                    False       False
# creamy-herb-mushroom-toasts                    False       False
# falafel-wraps-with-sweet-potato-wedges         False       False
# lobster-prawn-thermidor                        False       False
# moroccan-couscous                              False       False
# pea-fritters-with-poached-egg                  False       False
# blackcurrant-pear-multi-layered-fruit-cubes    False       False
# ...                                              ...         ...
# 98214                                          False       False
# 229287                                         False       False
# 32679                                          False       False
# 130985                                         False       False
# 196521                                         False       False
# 262072                                         False       False
# 131001                                         False       False
# 98237                                          False       False
# 196542                                         False       False
# 294852                                         False       False
# 32711                                          False       False
# 32717                                          False       False
# 32722                                          False       False
# 294868                                         False       False
# 163799                                         False       False
# 294871                                         False       False
# 294873                                         False       False
# 32727                                          False       False
# 32730                                          False       False
# 32733                                          False       False
# 229345                                         False       False
# 65509                                          False       False
# 65511                                          False       False
# 196585                                         False       False
# 262121                                         False       False
# 196595                                         False       False
# 294903                                         False       False
# 229369                                         False       False
# 294906                                         False       False
# 294908                                         False       False
#
# [15560 rows x 6815 columns]

# %%
matrix.to_csv("RecommenderRecepieIngredient")
