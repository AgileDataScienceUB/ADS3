# %%
import pymongo

try:
    #use your database name, user and password here:
    #mongodb://<dbuser>:<dbpassword>@<mlab_url>.mlab.com:57066/<database_name>
    with open("credentials.txt", 'r', encoding='utf-8') as f:
        [name,password,url,dbname]=f.read().splitlines()
    conn=pymongo.MongoClient("mongodb://{}:{}@{}/{}".format(name,password,url,dbname))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
print("connection information",conn)
db=conn["agile_data_science_group_3"] #agile_data_science_group_3 is our database name
collection = db.resource_1 #resource_1 is one of our collection's name
collection
# Out:
# Connected successfully!!!
# connection information MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True)
# Collection(Database(MongoClient(host=['ds233895.mlab.com:33895'], document_class=dict, tz_aware=False, connect=True), 'agile_data_science_group_3'), 'resource_1')

# %%
#Given the following list of ingredient, for each ingredient we want to find all the recipes which contains that ingredient.
input_ingredients=['spaghetti','egg']

# %%
total_df=pd.DataFrame(columns=heads)
for ingredient in input_ingredients:
    regular_expression=".*"+str(ingredient)+".*"
    found_recipes=collection.find({"list_ingredients": {"$regex" : regular_expression}})
    datapoints = list(found_recipes)
    df = json_normalize(datapoints)
    total_df=pd.concat([total_df,df])

# %%
#We remove all duplicates
total_df=total_df.drop_duplicates(subset='_id')
total_df
# Out:
#                            _id  energy_KCal fat_g  \
# 0     59fb0d77eee3642f3c0683f7        431.0  16.6
# 1     59fb0d77eee3642f3c068795        514.0   5.0
# 2     59fb0d77eee3642f3c0687fe        244.0   6.7
# 3     59fb0d77eee3642f3c068829        262.0   4.1
# 4     59fb0d77eee3642f3c068896        551.0  18.4
# 5     59fb0d77eee3642f3c0688ad        367.0   9.7
# 6     59fb0d77eee3642f3c0688af        368.0    11
# 7     59fb0d77eee3642f3c0688b2        593.0  11.9
# 8     59fb0d77eee3642f3c06897f        601.0  13.2
# 9     59fb0d77eee3642f3c0689aa        474.0  13.4
# 10    59fb0d77eee3642f3c0689e3        513.0  20.7
# 11    59fb0d77eee3642f3c0689f8        488.0  16.5
# 12    59fb0d77eee3642f3c068a5b        491.0    28
# 13    59fb0d77eee3642f3c068b50        394.0    15
# 14    59fb0d77eee3642f3c068b55        651.0    29
# 15    59fb0d77eee3642f3c068b96        571.0  12.3
# 16    59fb0d77eee3642f3c068bc3        431.0   5.4
# 17    59fb0d77eee3642f3c068bc5        410.0    20
# ...
